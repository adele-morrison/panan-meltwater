# %% [markdown]
# # Creating database

# %%
import cosima_cookbook as cc

# %%
ds = '/home/272/kc5856/databases/honours_new.db'
session = cc.database.create_session(ds)

# %%
# PanAntarctic 1/10th

directory_list=['/g/data/ol01/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/', # Pan01 old control
                '/scratch/x77/jn8053/mom6/archive/panant-01-zstar-ssp126-MW-only-prsc-rest/'] #Pan01 melt

cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panant-01-zstar-ACCESSyr2
# 100%|██████████| 1000/1000 [02:40<00:00,  6.24it/s]
# 100%|██████████| 1000/1000 [02:30<00:00,  6.66it/s]
# 100%|██████████| 1000/1000 [02:31<00:00,  6.60it/s]
# 100%|██████████| 1000/1000 [02:32<00:00,  6.55it/s]
# 100%|██████████| 1000/1000 [02:30<00:00,  6.64it/s]
# 100%|██████████| 1000/1000 [02:33<00:00,  6.51it/s]
# 100%|██████████| 1000/1000 [02:46<00:00,  6.02it/s]
# 100%|██████████| 1000/1000 [02:39<00:00,  6.26it/s]
# 100%|██████████| 1000/1000 [02:44<00:00,  6.09it/s]
# 100%|██████████| 1000/1000 [02:38<00:00,  6.31it/s]
# 100%|██████████| 1000/1000 [02:47<00:00,  5.97it/s]
# 100%|██████████| 1000/1000 [02:37<00:00,  6.35it/s]
# 100%|██████████| 902/902 [02:30<00:00,  6.00it/s]
# Indexing experiment: panant-01-zstar-ssp126-MW-only-prsc-rest
# 12902

# %%
# Doing Panan005

directory_list=['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2', # Pan005 old control
                '/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/'] # Pan005 old melt

cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: panant-005-zstar-ACCESSyr2
#  69%|██████▊   | 686/1000 [08:35<03:17,  1.59it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       1 # Doing Panan005
#       3 directory_list=['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2', # Pan005 old control
#       4                 '/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/'] # Pan005 old melt
# ----> 6 cc.database.build_index(directory_list, session)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:878, in build_index(directories, session, client, prune, force, followsymlinks, nfiles)
#     867         if len(expt.ncfiles) > 0:
#     868             # Remove files that are already in the DB
#     869             files.difference_update(
#     870                 {
#     871                     f
#    (...)
#     875                 }
#     876             )
# --> 878         indexed += index_experiment(files, session, expt, nfiles)
#     880 return indexed
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:785, in index_experiment(files, session, expt, nfiles, client)
#     782 # Cap the maximum number of files to index before committing to keep memory use
#     783 # under control and make indexing less affected by errors
#     784 for fileschunk in chunks(files, nfiles):
# --> 785     results = [
#     786         index_file(f, experiment=expt, session=session) for f in tqdm(fileschunk)
#     787     ]
#     788     try:
#     789         session.add_all(results)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:786, in <listcomp>(.0)
#     782 # Cap the maximum number of files to index before committing to keep memory use
#     783 # under control and make indexing less affected by errors
#     784 for fileschunk in chunks(files, nfiles):
#     785     results = [
# --> 786         index_file(f, experiment=expt, session=session) for f in tqdm(fileschunk)
#     787     ]
#     788     try:
#     789         session.add_all(results)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:671, in index_file(ncfile_name, experiment, session)
#     669     # we'll add all attributes to the ncvar itself
#     670     for att in v.ncattrs():
# --> 671         ncvar.attrs[att] = str(v.getncattr(att))
#     673     ncfile.ncvars[v.name] = ncvar
#     675 # add file-level attributes
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/ext/associationproxy.py:1255, in _AssociationDict.__setitem__(self, key, value)
#    1253     self._set(self.col[key], key, value)
#    1254 else:
# -> 1255     self.col[key] = self._create(key, value)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/collections.py:1337, in _dict_decorators.<locals>.__setitem__.<locals>.__setitem__(self, key, value, _sa_initiator)
#    1335 if key in self:
#    1336     __del(self, self[key], _sa_initiator)
# -> 1337 value = __set(self, value, _sa_initiator)
#    1338 fn(self, key, value)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/collections.py:1134, in __set(collection, item, _sa_initiator)
#    1132     executor = collection._sa_adapter
#    1133     if executor:
# -> 1134         item = executor.fire_append_event(item, _sa_initiator)
#    1135 return item
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/collections.py:753, in CollectionAdapter.fire_append_event(self, item, initiator)
#     750     if self.empty:
#     751         self._reset_empty()
# --> 753     return self.attr.fire_append_event(
#     754         self.owner_state, self.owner_state.dict, item, initiator
#     755     )
#     756 else:
#     757     return item
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/attributes.py:1447, in CollectionAttributeImpl.fire_append_event(self, state, dict_, value, initiator)
#    1445 def fire_append_event(self, state, dict_, value, initiator):
#    1446     for fn in self.dispatch.append:
# -> 1447         value = fn(state, value, initiator or self._append_token)
#    1449     state._modified_event(dict_, self, NO_VALUE, True)
#    1451     if self.trackparent and value is not None:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/unitofwork.py:68, in track_cascade_events.<locals>.append(state, item, initiator)
#      66         if key != initiator.key:
#      67             _warn_for_cascade_backrefs(item_state, prop)
# ---> 68         sess._save_or_update_state(item_state)
#      69 return item
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/session.py:2672, in Session._save_or_update_state(self, state)
#    2670 def _save_or_update_state(self, state):
#    2671     state._orphaned_outside_of_session = False
# -> 2672     self._save_or_update_impl(state)
#    2674     mapper = _state_mapper(state)
#    2675     for o, m, st_, dct_ in mapper.cascade_iterator(
#    2676         "save-update", state, halt_on=self._contains_state
#    2677     ):
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/session.py:3287, in Session._save_or_update_impl(self, state)
#    3285 def _save_or_update_impl(self, state):
#    3286     if state.key is None:
# -> 3287         self._save_impl(state)
#    3288     else:
#    3289         self._update_impl(state)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/session.py:3245, in Session._save_impl(self, state)
#    3243     state.insert_order = len(self._new)
#    3244 if to_attach:
# -> 3245     self._after_attach(state, obj)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/session.py:3385, in Session._after_attach(self, state, obj)
#    3383     self.dispatch.detached_to_persistent(self, state)
#    3384 else:
# -> 3385     self.dispatch.transient_to_pending(self, state)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/event/attr.py:247, in _EmptyListener.__call__(self, *args, **kw)
#     244 """Execute this event."""
#     246 for fn in self.parent_listeners:
# --> 247     fn(*args, **kw)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/events.py:1429, in SessionEvents._listen.<locals>.wrap(session, state, *arg, **kw)
#    1427     runid = state.runid
#    1428 try:
# -> 1429     return fn(session, target, *arg, **kw)
#    1430 finally:
#    1431     if restore_load_context:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:258, in _validate_ncattribute(session, object_)
#     255     if old_name in session:
#     256         session.expunge(old_name)
# --> 258     object_._name = _setup_ncattribute(session, old_name)
#     260 if (
#     261     isinstance(object_, NCAttribute)
#     262     and object_._value is not None
#     263     and object_._value.id is None
#     264 ):
#     265     old_value = object_._value
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/attributes.py:465, in InstrumentedAttribute.__set__(self, instance, value)
#     464 def __set__(self, instance, value):
# --> 465     self.impl.set(
#     466         instance_state(instance), instance_dict(instance), value, None
#     467     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/attributes.py:1286, in ScalarObjectAttributeImpl.set(self, state, dict_, value, initiator, passive, check_old, pop)
#    1280     else:
#    1281         raise ValueError(
#    1282             "Object %s not associated with %s on attribute '%s'"
#    1283             % (instance_str(check_old), state_str(state), self.key)
#    1284         )
# -> 1286 value = self.fire_replace_event(state, dict_, value, old, initiator)
#    1287 dict_[self.key] = value
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/attributes.py:1312, in ScalarObjectAttributeImpl.fire_replace_event(self, state, dict_, value, previous, initiator)
#    1309         self.sethasparent(instance_state(previous), state, False)
#    1311 for fn in self.dispatch.set:
# -> 1312     value = fn(
#    1313         state, value, previous, initiator or self._replace_token
#    1314     )
#    1316 state._modified_event(dict_, self, previous)
#    1318 if self.trackparent:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/util.py:185, in _validator_events.<locals>.set_(state, value, oldvalue, initiator)
#     183 def set_(state, value, oldvalue, initiator):
#     184     if include_backrefs or not detect_is_backref(state, initiator):
# --> 185         return validator(state.obj(), key, value)
#     186     else:
#     187         return value
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:234, in NCAttribute._validate_name(self, key, value)
#     232 sess = object_session(self)
#     233 if sess is not None:
# --> 234     return _setup_ncattribute(sess, value)
#     236 return value
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/database.py:189, in _setup_ncattribute(session, attr_object)
#     183     return cache[attr_object.value]
#     185 with session.no_autoflush:
#     186     r = (
#     187         session.query(NCAttributeString)
#     188         .filter_by(value=attr_object.value)
# --> 189         .one_or_none()
#     190     )
#     191     if r is not None:
#     192         return r
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2850, in Query.one_or_none(self)
#    2826 def one_or_none(self):
#    2827     """Return at most one result or raise an exception.
#    2828
#    2829     Returns ``None`` if the query selects
#    (...)
#    2848
#    2849     """
# -> 2850     return self._iter().one_or_none()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/query.py:2916, in Query._iter(self)
#    2913 params = self._params
#    2915 statement = self._statement_20()
# -> 2916 result = self.session.execute(
#    2917     statement,
#    2918     params,
#    2919     execution_options={"_sa_orm_load_options": self.load_options},
#    2920 )
#    2922 # legacy: automatically set scalars, unique
#    2923 if result._attributes.get("is_single_entity", False):
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/orm/session.py:1717, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1715 else:
#    1716     conn = self._connection_for_bind(bind)
# -> 1717 result = conn._execute_20(statement, params or {}, execution_options)
#    1719 if compile_state_cls:
#    1720     result = compile_state_cls.orm_setup_cursor_result(
#    1721         self,
#    1722         statement,
#    (...)
#    1726         result,
#    1727     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1710, in Connection._execute_20(self, statement, parameters, execution_options)
#    1706     util.raise_(
#    1707         exc.ObjectNotExecutableError(statement), replace_context=err
#    1708     )
#    1709 else:
# -> 1710     return meth(self, args_10style, kwargs_10style, execution_options)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:334, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     330 def _execute_on_connection(
#     331     self, connection, multiparams, params, execution_options, _force=False
#     332 ):
#     333     if _force or self.supports_execution:
# --> 334         return connection._execute_clauseelement(
#     335             self, multiparams, params, execution_options
#     336         )
#     337     else:
#     338         raise exc.ObjectNotExecutableError(self)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1577, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1565 compiled_cache = execution_options.get(
#    1566     "compiled_cache", self.engine._compiled_cache
#    1567 )
#    1569 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1570     dialect=dialect,
#    1571     compiled_cache=compiled_cache,
#    (...)
#    1575     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1576 )
# -> 1577 ret = self._execute_context(
#    1578     dialect,
#    1579     dialect.execution_ctx_cls._init_compiled,
#    1580     compiled_sql,
#    1581     distilled_params,
#    1582     execution_options,
#    1583     compiled_sql,
#    1584     distilled_params,
#    1585     elem,
#    1586     extracted_params,
#    1587     cache_hit=cache_hit,
#    1588 )
#    1589 if has_events:
#    1590     self.dispatch.after_execute(
#    1591         self,
#    1592         elem,
#    (...)
#    1596         ret,
#    1597     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1953, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1950             branched.close()
#    1952 except BaseException as e:
# -> 1953     self._handle_dbapi_exception(
#    1954         e, statement, parameters, cursor, context
#    1955     )
#    1957 return result
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2138, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2134         util.raise_(
#    2135             sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2136         )
#    2137     else:
# -> 2138         util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2140 finally:
#    2141     del self._reentrant_error
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1910, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1908                 break
#    1909     if not evt_handled:
# -> 1910         self.dialect.do_execute(
#    1911             cursor, statement, parameters, context
#    1912         )
#    1914 if self._has_events or self.engine._has_events:
#    1915     self.dispatch.after_cursor_execute(
#    1916         self,
#    1917         cursor,
#    (...)
#    1921         context.executemany,
#    1922     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/sqlalchemy/engine/default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# KeyboardInterrupt:

# %%
#Now doing ACCESS

directory_list=['/scratch/x77/jn8053/access-om2/archive/01deg_jra55v13_ryf9091_21mbath_sofia_ssp126_prsc_rest/', # ACCESS melt
               '/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/'] # ACCESS control

cc.database.build_index(directory_list, session)
# Out:
# Indexing experiment: 01deg_jra55v13_ryf9091_21mbath_sofia_ssp126_prsc_rest
# Indexing experiment: 01deg_jra55v13_ryf9091_21mbath
# 100%|██████████| 1000/1000 [01:53<00:00,  8.83it/s]
# 100%|██████████| 1000/1000 [02:14<00:00,  7.42it/s]
# 100%|██████████| 543/543 [01:14<00:00,  7.27it/s]
# 2543
