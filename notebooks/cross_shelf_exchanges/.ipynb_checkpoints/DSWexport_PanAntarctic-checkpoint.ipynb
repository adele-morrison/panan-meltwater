# %% [markdown]
# # PanAntarctic comparison for  DSW export

# %%
import intake
import glob
import dask.distributed as dsk
import matplotlib.pyplot as plt
import gsw
from pathlib import Path

import cmocean as cm
import cartopy.crs as ccrs
import cartopy.feature as cft
import matplotlib.path as mpath
from IPython.display import display, Image

import netCDF4 as nc
import xarray as xr
import numpy as np
import xgcm
import calendar

from matplotlib import gridspec
from collections import OrderedDict

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
import logging
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:41075' processes=28 threads=28, memory=125.19 GiB>

# %% [markdown]
# ### Loading the data

# %% [markdown]
# #### Old method

# %%
# Importing data
pathsC = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/*/*.ocean_month_z.nc'))
pathsM = np.sort(glob.glob('/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/*/*.ocean_month_z.nc'))

# %%
# Time variant variables
def preprocess(ds):
    ds = ds[['uo','vo','agessc','so']] # Picking out variables get all grids
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
cont = cont.sel(time=slice('2001-01-01','2010-12-31'))
melt = melt.sel(time=slice('2001-01-01','2010-12-31'))

# %%
yh = grid['yh'].sel(yh=lat_slice)
yq = grid['yq'].sel(yq=lat_slice)
xh = grid['xh']
xq = grid['xq']

mask_y_transport = contour_mask['mask_y_transport'].sel(yq=lat_slice)
mask_x_transport = contour_mask['mask_x_transport'].sel(yh=lat_slice)
mask_y_transport_numbered = contour_mask['mask_y_transport_numbered'].sel(yq=lat_slice)
mask_x_transport_numbered = contour_mask['mask_x_transport_numbered'].sel(yh=lat_slice)

mask_x_transport = xr.DataArray(mask_x_transport, coords = [yh, xq[:-1]], dims=['y_ocean', 'x_ocean'])
mask_y_transport = xr.DataArray(mask_y_transport, coords = [yq[:-1], xh], dims=['y_ocean', 'x_ocean'])
mask_x_transport_numbered = xr.DataArray(mask_x_transport_numbered, coords = [yh, xq[:-1]], dims=['y_ocean', 'x_ocean'])
mask_y_transport_numbered = xr.DataArray(mask_y_transport_numbered, coords = [yq[:-1], xh], dims=['y_ocean', 'x_ocean'])

# stack contour data into 1d:
mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index = ['y_ocean', 'x_ocean'])
mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop = True)
mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index = ['y_ocean', 'x_ocean'])
mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop = True)
contour_ordering = xr.concat((mask_x_numbered_1d,mask_y_numbered_1d), dim = 'contour_index')
contour_ordering = contour_ordering.sortby(contour_ordering)
contour_index_array = np.arange(1,len(contour_ordering)+1)

# get lat and lon along contour, useful for plotting later:
lat_along_contour = contour_ordering.y_ocean
lon_along_contour = contour_ordering.x_ocean
# don't need the multi-index anymore, replace with contour count
lat_along_contour.coords['contour_index'] = contour_index_array
lon_along_contour.coords['contour_index'] = contour_index_array

# %% [markdown]
# #### New Method

# %%
# Contour mask
contour_mask_1 = xr.open_dataset('/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc')#['contour_masked_above']
contour_mask_2 = xr.open_dataset('/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc')#['contour_masked_above']

# %%
lat_slice = slice(-79,-59)
grid_01 = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/output050/20050501.ocean_static.nc')#.sel(yq=lat_slice,yh=lat_slice)
grid_005 = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output030/19930701.ocean_static.nc')#.sel(yq=lat_slice,yh=lat_slice)

# %%
# Grids and masks
grids = {'01deg': grid_01, '005deg': grid_005}
masks = {'01deg': contour_mask_1, '005deg': contour_mask_2}

# Dictionary to store results
contour_data = {}

for res in ['01deg', '005deg']:
    grid = grids[res]
    contour_mask = masks[res]

    # Select grid coordinates
    yh = grid['yh'].sel(yh=lat_slice)
    yq = grid['yq'].sel(yq=lat_slice)
    xh = grid['xh']
    xq = grid['xq']

    # Select masks for this lat slice
    mask_y_transport = contour_mask['mask_y_transport'].sel(yq=lat_slice)
    mask_x_transport = contour_mask['mask_x_transport'].sel(yh=lat_slice)
    mask_y_transport_numbered = contour_mask['mask_y_transport_numbered'].sel(yq=lat_slice)
    mask_x_transport_numbered = contour_mask['mask_x_transport_numbered'].sel(yh=lat_slice)

    mask_x_transport = xr.DataArray(
        mask_x_transport,
        coords=[yh[:mask_x_transport.shape[0]], xq[:mask_x_transport.shape[1]]],
        dims=['y_ocean', 'x_ocean']
    )
    mask_y_transport = xr.DataArray(
        mask_y_transport,
        coords=[yq[:mask_y_transport.shape[0]], xh[:mask_y_transport.shape[1]]],
        dims=['y_ocean', 'x_ocean']
    )
    mask_x_transport_numbered = xr.DataArray(
        mask_x_transport_numbered,
        coords=[yh[:mask_x_transport_numbered.shape[0]], xq[:mask_x_transport_numbered.shape[1]]],
        dims=['y_ocean', 'x_ocean']
    )
    mask_y_transport_numbered = xr.DataArray(
        mask_y_transport_numbered,
        coords=[yq[:mask_y_transport_numbered.shape[0]], xh[:mask_y_transport_numbered.shape[1]]],
        dims=['y_ocean', 'x_ocean']
    )

    # Stack contour data into 1D
    mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index=['y_ocean', 'x_ocean'])
    mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop=True)
    mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index=['y_ocean', 'x_ocean'])
    mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop=True)

    # Combine and sort contour
    contour_ordering = xr.concat((mask_x_numbered_1d, mask_y_numbered_1d), dim='contour_index')
    contour_ordering = contour_ordering.sortby(contour_ordering)
    contour_index_array = np.arange(1, len(contour_ordering) + 1)

    # Get lat/lon along contour
    lat_along_contour = contour_ordering.y_ocean
    lon_along_contour = contour_ordering.x_ocean
    lat_along_contour.coords['contour_index'] = contour_index_array
    lon_along_contour.coords['contour_index'] = contour_index_array

    # Save results
    contour_data[res] = {
        'lat': lat_along_contour,
        'lon': lon_along_contour,
        'contour_index': contour_index_array
    }

# %%
# Dictionary to store tickmark indices for both resolutions
distance_indices_all = {}

for res in ['01deg', '005deg']:
    lon_along_contour = contour_data[res]['lon']

    distance_indices = np.zeros(8, dtype=int)
    for i in np.arange(100, len(lon_along_contour.values)):
        if distance_indices[1] == 0 and lon_along_contour.values[i] > -240:
            distance_indices[1] = lon_along_contour.contour_index.values[i]
        if distance_indices[2] == 0 and lon_along_contour.values[i] > -180:
            distance_indices[2] = lon_along_contour.contour_index.values[i]
        if distance_indices[3] == 0 and lon_along_contour.values[i] > -120:
            distance_indices[3] = lon_along_contour.contour_index.values[i]
        if distance_indices[4] == 0 and lon_along_contour.values[i] > -60:
            distance_indices[4] = lon_along_contour.contour_index.values[i]
        if distance_indices[5] == 0 and lon_along_contour.values[i] > 0:
            distance_indices[5] = lon_along_contour.contour_index.values[i]
        if distance_indices[6] == 0 and lon_along_contour.values[i] > 60:
            distance_indices[6] = lon_along_contour.contour_index.values[i]

    distance_indices[7] = len(lon_along_contour.contour_index.values) - 1

    # Save for this resolution
    distance_indices_all[res] = distance_indices

# %%
# Define in longitude space what the cut-off values for regions should be.
AdelieW = -280
AdelieE = -200
RossW = -200
RossE = -150
# WAW = -150
# WAE = -65
AmW = -150
AmE = -100
BeW = -100
BeE = -65

WeddellW = -65
WeddellE = 0
PrydzW = 0
PrydzE = 80

# %%
# Dictionary to store basin indices for both resolutions
basin_indices_all = {}

# Define basin longitude thresholds (already defined in your script)
# AdelieE, RossE, AmE, BeE, WeddellE, PrydzE

for res in ['01deg', '005deg']:
    lon_along_contour = contour_data[res]['lon']

    basin_indices = np.zeros(7, dtype=int)
    for i in np.arange(100, len(lon_along_contour.values)):
        if basin_indices[1] == 0 and lon_along_contour.values[i] > AdelieE:
            basin_indices[1] = lon_along_contour.contour_index.values[i]
        if basin_indices[2] == 0 and lon_along_contour.values[i] > RossE:
            basin_indices[2] = lon_along_contour.contour_index.values[i]
        if basin_indices[3] == 0 and lon_along_contour.values[i] > AmE:
            basin_indices[3] = lon_along_contour.contour_index.values[i]
        if basin_indices[4] == 0 and lon_along_contour.values[i] > BeE:
            basin_indices[4] = lon_along_contour.contour_index.values[i]
        if basin_indices[5] == 0 and lon_along_contour.values[i] > WeddellE:
            basin_indices[5] = lon_along_contour.contour_index.values[i]
        if basin_indices[6] == 0 and lon_along_contour.values[i] > PrydzE:
            basin_indices[6] = lon_along_contour.contour_index.values[i]

    # Save for this resolution
    basin_indices_all[res] = basin_indices

# %%
# If already loaded, just use:
distance_along_contour_01 = xr.open_dataset('/g/data/x77/kc5856/Post_Process/panan-01/1000m_isobath_contour_distance.nc').distance_along_contour
distance_along_contour_005 = xr.open_dataset('/g/data/x77/kc5856/Post_Process/panan-005/1000m_isobath_contour_distance.nc').distance_along_contour

# %%
Adelie = slice(basin_indices[0],basin_indices[1])
Ross = slice(basin_indices[1],basin_indices[2])
Am = slice(basin_indices[2],basin_indices[3])
Be = slice(basin_indices[3],basin_indices[4])
Weddell = slice(basin_indices[4], basin_indices[5])
Prydz = slice(basin_indices[5],12004)

# %% [markdown]
# ## File Loading

# %%
land_mask = np.squeeze(grid_005['deptho'].values)*0
land_mask[np.isnan(land_mask)] = 1
land_mask = np.where(land_mask==1,land_mask,np.nan)
land_mask_masked = np.ma.masked_where((land_mask==0),land_mask)

# make land go all the way to -90S:
land_mask_lat = grid_005['deptho'].yh.values
land_mask_lat[0] = -90

# %%
# Define paths
grid_path = '/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output030/19930701.ocean_static.nc'
save_dir = '/g/data/x77/kc5856/sofia-cross_slope_transport/cross_slope_binned/'

# Load grid
grid = xr.open_dataset(grid_path)
deptho = grid['deptho'].sel(yh=lat_slice)
yh = grid['yh'].sel(yh=lat_slice)
xh = grid['xh']

# %%
file_dir = '/g/data/x77/kc5856/sofia-cross_slope_transport/plots/'

# %%
pan01_cont_circ = xr.open_dataset(file_dir+'Circumpolar_Control_pan01_transport_profile.nc').to_array().squeeze()
pan01_cont_Ade = xr.open_dataset(file_dir+'Adelie_Control_pan01_transport_profile.nc').to_array().squeeze()
pan01_cont_Ros = xr.open_dataset(file_dir+'Ross_Control_pan01_transport_profile.nc').to_array().squeeze()
pan01_cont_Am = xr.open_dataset(file_dir+'Amundsen_Control_pan01_transport_profile.nc').to_array().squeeze()
pan01_cont_Be = xr.open_dataset(file_dir+'Bellingshausen_Control_pan01_transport_profile.nc').to_array().squeeze()
pan01_cont_We = xr.open_dataset(file_dir+'Weddell_Control_pan01_transport_profile.nc').to_array().squeeze()
pan01_cont_Pr = xr.open_dataset(file_dir+'Prydz_Control_pan01_transport_profile.nc').to_array().squeeze()

pan01_melt_circ = xr.open_dataset(file_dir+'Circumpolar_Melt_pan01_transport_profile.nc').to_array().squeeze()
pan01_melt_Ade = xr.open_dataset(file_dir+'Adelie_Melt_pan01_transport_profile.nc').to_array().squeeze()
pan01_melt_Ros = xr.open_dataset(file_dir+'Ross_Melt_pan01_transport_profile.nc').to_array().squeeze()
pan01_melt_Am = xr.open_dataset(file_dir+'Amundsen_Melt_pan01_transport_profile.nc').to_array().squeeze()
pan01_melt_Be = xr.open_dataset(file_dir+'Bellingshausen_Melt_pan01_transport_profile.nc').to_array().squeeze()
pan01_melt_We = xr.open_dataset(file_dir+'Weddell_Melt_pan01_transport_profile.nc').to_array().squeeze()
pan01_melt_Pr = xr.open_dataset(file_dir+'Prydz_Melt_pan01_transport_profile.nc').to_array().squeeze()

# %%
pan005_cont_circ = xr.open_dataset(file_dir+'Circumpolar_Control_pan005_transport_profile.nc').to_array().squeeze()
pan005_cont_Ade = xr.open_dataset(file_dir+'Adelie_Control_pan005_transport_profile.nc').to_array().squeeze()
pan005_cont_Ros = xr.open_dataset(file_dir+'Ross_Control_pan005_transport_profile.nc').to_array().squeeze()
pan005_cont_Am = xr.open_dataset(file_dir+'Amundsen_Control_pan005_transport_profile.nc').to_array().squeeze()
pan005_cont_Be = xr.open_dataset(file_dir+'Bellingshausen_Control_pan005_transport_profile.nc').to_array().squeeze()
pan005_cont_We = xr.open_dataset(file_dir+'Weddell_Control_pan005_transport_profile.nc').to_array().squeeze()
pan005_cont_Pr = xr.open_dataset(file_dir+'Prydz_Control_pan005_transport_profile.nc').to_array().squeeze()

pan005_melt_circ = xr.open_dataset(file_dir+'Circumpolar_Melt_pan005_transport_profile.nc').to_array().squeeze()
pan005_melt_Ade = xr.open_dataset(file_dir+'Adelie_Melt_pan005_transport_profile.nc').to_array().squeeze()
pan005_melt_Ros = xr.open_dataset(file_dir+'Ross_Melt_pan005_transport_profile.nc').to_array().squeeze()
pan005_melt_Am = xr.open_dataset(file_dir+'Amundsen_Melt_pan005_transport_profile.nc').to_array().squeeze()
pan005_melt_Be = xr.open_dataset(file_dir+'Bellingshausen_Melt_pan005_transport_profile.nc').to_array().squeeze()
pan005_melt_We = xr.open_dataset(file_dir+'Weddell_Melt_pan005_transport_profile.nc').to_array().squeeze()
pan005_melt_Pr = xr.open_dataset(file_dir+'Prydz_Melt_pan005_transport_profile.nc').to_array().squeeze()

# %%
pan01_anom_circ = pan01_melt_circ - pan01_cont_circ
pan01_anom_Ade = pan01_melt_Ade - pan01_cont_Ade
pan01_anom_Ros = pan01_melt_Ros - pan01_cont_Ros
pan01_anom_Am = pan01_melt_Am - pan01_cont_Am
pan01_anom_Be = pan01_melt_Be - pan01_cont_Be
pan01_anom_We = pan01_melt_We - pan01_cont_We
pan01_anom_Pr = pan01_melt_Pr - pan01_cont_Pr

# %%
pan005_anom_circ = pan005_melt_circ - pan005_cont_circ
pan005_anom_Ade = pan005_melt_Ade - pan005_cont_Ade
pan005_anom_Ros = pan005_melt_Ros - pan005_cont_Ros
pan005_anom_Am = pan005_melt_Am - pan005_cont_Am
pan005_anom_Be = pan005_melt_Be - pan005_cont_Be
pan005_anom_We = pan005_melt_We - pan005_cont_We
pan005_anom_Pr = pan005_melt_Pr - pan005_cont_Pr

# %%
# Cumulative sums
pan01_cont_cumsum = xr.open_dataset(file_dir+'Control_pan01_cumulative_transport.nc')['Control_cumulative_transport']
pan01_melt_cumsum = xr.open_dataset(file_dir+'Melt_pan01_cumulative_transport.nc')['Melt_cumulative_transport']
pan01_anom_cumsum = pan01_melt_cumsum - pan01_cont_cumsum

pan005_cont_cumsum = xr.open_dataset(file_dir+'Control_pan005_cumulative_transport.nc')['Control_cumulative_transport']
pan005_melt_cumsum = xr.open_dataset(file_dir+'Melt_pan005_cumulative_transport.nc')['Melt_cumulative_transport']
pan005_anom_cumsum = pan005_melt_cumsum - pan005_cont_cumsum

# %%
# --- Colors and line styles ---
colors = {
    'control': 'k', 
    'melt': '#BB5566',
    'anom_01': '#0072B2', 
    'anom_005': '#D55E00',
    'pan01': '#0072B2',
    'pan005': '#D55E00'
}

linestyles = {
    'control': '--', 
    'melt': '-', 
    'anom_01': '-', 
    'anom_005': '-',
    'pan01': '-',
    'pan005':'-'
}
linewidths = {k: 2 for k in colors.keys()}
labels = {
    'control': 'Control', 
    'melt': 'Melt', 
    'anom_01': '0.1°', 
    'anom_005': '0.05°',
    'pan01':'0.1°',
    'pan005':'0.05°'
}


# --- Sector names and letters (removed Amundsen + Bellingshausen) ---
sector_names = ['Circumpolar', 'Adélie', 'Ross', 'Weddell', 'Prydz']
letter_labels = ['a)', 'b)', 'c)', 'd)', 'e)']

# --- Data arrays (removed Am + Be entries) ---
sector_pan01_control = [pan01_cont_circ, pan01_cont_Ade, pan01_cont_Ros, pan01_cont_We, pan01_cont_Pr]
sector_pan01_melt    = [pan01_melt_circ, pan01_melt_Ade, pan01_melt_Ros, pan01_melt_We, pan01_melt_Pr]

sector_pan005_control = [pan005_cont_circ, pan005_cont_Ade, pan005_cont_Ros, pan005_cont_We, pan005_cont_Pr]
sector_pan005_melt    = [pan005_melt_circ, pan005_melt_Ade, pan005_melt_Ros, pan005_melt_We, pan005_melt_Pr]

sector_anoms_01 = [pan01_anom_circ, pan01_anom_Ade, pan01_anom_Ros, pan01_anom_We, pan01_anom_Pr]
sector_anoms_005 = [pan005_anom_circ, pan005_anom_Ade, pan005_anom_Ros, pan005_anom_We, pan005_anom_Pr]

# %% [markdown]
# ### Tests

# %%
print(distance_along_contour_01[1279].item(),
      distance_along_contour_01[2177].item(),
      distance_along_contour_01[3381].item(),
      distance_along_contour_01[4831].item(),
     )
# Out:
# 4.867607778039024 7.618652000280812 11.540634377472639 16.706596499033996

# %%
print(distance_along_contour_005[2522].item(),
      distance_along_contour_005[4352].item(),
      distance_along_contour_005[6522].item(),
      distance_along_contour_005[9627].item(),
     )
# Out:
# 4.867222260225902 7.6187790871825865 11.220472448229376 16.806816603224323

# %%
# --- Plot config ---
colors = {'Control_pan01': '#000000', 'Melt_pan01': '#BB5566',
          'Control_pan005': '#5555FF', 'Melt_pan005': '#FFAA00'}
linestyles = {'Control_pan01': '-', 'Melt_pan01': '--',
              'Control_pan005': '-', 'Melt_pan005': '--'}
labels = {'Control_pan01': 'Control 0.1°', 'Melt_pan01': 'Melt 0.1°',
          'Control_pan005': 'Control 0.05°', 'Melt_pan005': 'Melt 0.05°'}

# --- Define figure ---
fig, ax = plt.subplots(figsize=(10, 4))

# --- Plot each cumulative transport ---
for key, array, res in zip(
    ['Control_pan01', 'Melt_pan01', 'Control_pan005', 'Melt_pan005'],
    [pan01_cont_cumsum, pan01_melt_cumsum, pan005_cont_cumsum, pan005_melt_cumsum],
    ['01deg', '01deg', '005deg', '005deg']
):
    # Select longitude array for this resolution
    lon_vals = contour_data[res]['lon']

    # Optional offset for label placement
    offset = 0 if 'pan01' in key else -0.4

    # Plot line
    ax.plot(lon_vals, array, label=labels[key],
            color=colors[key], linestyle=linestyles[key], linewidth=2)

    # Add text at the end of the line
    ax.text(lon_vals[-1] + 5, offset + array[-1],
            f"{array[-1].values:.2f} Sv", color=colors[key], fontsize=10)

# --- Customize axes ---
ax.set_ylabel('Cumulative transport (Sv)', fontsize=12)
ax.set_ylim(-2, 12)
ax.grid(axis='y')

# ✅ Use pan01 ticks/labels as reference
res_ref = '01deg'
indices = distance_indices_all[res_ref]
x_ticks = contour_data[res_ref]['lon'].values[indices]
ax.set_xticks(x_ticks)
ax.set_xticklabels([f"{lon:.0f}°" for lon in x_ticks])

ax.set_xlabel('Longitude along contour', fontsize=12)
ax.legend(loc='upper left', bbox_to_anchor=(0, 0), fontsize=10)

# --- Add labels/title ---
ax.text(0.01, 1.04, 'h)', fontsize=13, fontweight='bold', transform=ax.transAxes)
ax.text(0.07, 1.04, 'Dense Shelf Water export over 1000m isobath',
        fontsize=13, transform=ax.transAxes)

plt.tight_layout()
plt.show()

# %%
# --- Plot config for anomalies ---
colors = {'pan01': '#0072B2', 'pan005': '#D55E00'}
linestyles = {'pan01': '-', 'pan005': '-'}
labels = {'pan01': '0.1° Anomaly', 'pan005': '0.05° Anomaly'}

# --- Define figure ---
fig, ax = plt.subplots(figsize=(10, 4))

# --- Plot each anomaly ---
for key, array, res in zip(
    ['pan01', 'pan005'],
    [pan01_anom_cumsum, pan005_anom_cumsum],
    ['01deg', '005deg']
):
    lon_vals = contour_data[res]['lon']

    # Optional offset for label placement
    offset = 0 if key == 'pan01' else -0.4

    # Plot line
    ax.plot(lon_vals, array, label=labels[key],
            color=colors[key], linestyle=linestyles[key], linewidth=2)

    # Add text at the end of the line
    ax.text(lon_vals[-1] + 5, offset + array[-1],
            f"{array[-1].values:.2f} Sv", color=colors[key], fontsize=10)

# --- Customize axes ---
ax.set_ylabel('Cumulative transport anomaly (Sv)', fontsize=12)
ax.set_ylim(-2, 2)  # adjust for anomaly scale
ax.grid(axis='y')

# ✅ Use pan01 ticks/labels as reference
res_ref = '01deg'
indices = distance_indices_all[res_ref]
x_ticks = contour_data[res_ref]['lon'].values[indices]
ax.set_xticks(x_ticks)
ax.set_xticklabels([f"{lon:.0f}°" for lon in x_ticks])

ax.set_xlabel('Longitude along contour', fontsize=12)
ax.legend(loc='lower left', bbox_to_anchor=(0, 0), fontsize=10)

ax.set_xlim(-280,80)

# --- Add labels/title ---
ax.text(0.01, 1.04, 'h)', fontsize=13, fontweight='bold', transform=ax.transAxes)
ax.text(0.07, 1.04, 'Dense Shelf Water transport anomalies over 1000m isobath',
        fontsize=13, transform=ax.transAxes)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plots

# %%
# X-limits for control vs melt (rows 1 + 2)
xlims_ctrlmelt = {
    'Circumpolar': (-0.1, 8.6),
    'Adélie': (-2, 2),
    'Ross': (-0.1, 4.1),
    'Amundsen': (-0.4, 0.2),
    'Bellingshausen': (-0.3, 0.3),
    'Weddell': (-0.5, 3),
    'Prydz': (-0.1, 2.2)
}

# X-limits for anomalies (row 3)
xlims_anom = {
    'Circumpolar': (-1.6, 0.6),
    'Adélie': (-0.8, 0.2),
    'Ross': (-0.6, 0.2),
    'Amundsen': (-0.02, 0.1),
    'Bellingshausen': (-0.05, 0.4),
    'Weddell': (-1.1, 1),
    'Prydz': (-1, 0.5)
}

# %%
# --- Sector names and letters ---
sector_names = ['Circumpolar', 'Adélie', 'Ross', 'Amundsen', 'Bellingshausen', 'Weddell', 'Prydz']
letter_labels = ['a)', 'b)', 'c)', 'd)', 'e)', 'f)', 'g)']


# --- Data arrays (removed Am + Be entries) ---
sector_pan01_control = [pan01_cont_circ, pan01_cont_Ade, pan01_cont_Ros, pan01_cont_Am,
                        pan01_cont_Be, pan01_cont_We, pan01_cont_Pr]
sector_pan01_melt    = [pan01_melt_circ, pan01_melt_Ade, pan01_melt_Ros, pan01_melt_Am,
                        pan01_melt_Be, pan01_melt_We, pan01_melt_Pr]

sector_pan005_control = [pan005_cont_circ, pan005_cont_Ade, pan005_cont_Ros, pan005_cont_Am,
                         pan005_cont_Be, pan005_cont_We, pan005_cont_Pr]
sector_pan005_melt    = [pan005_melt_circ, pan005_melt_Ade, pan005_melt_Ros, pan005_melt_Am,
                         pan005_melt_Be, pan005_melt_We, pan005_melt_Pr]

sector_anoms_01 = [pan01_anom_circ, pan01_anom_Ade, pan01_anom_Ros, pan01_anom_Am,
                   pan01_anom_Be, pan01_anom_We, pan01_anom_Pr]
sector_anoms_005 = [pan005_anom_circ, pan005_anom_Ade, pan005_anom_Ros, pan005_anom_Am,
                    pan005_anom_Be, pan005_anom_We, pan005_anom_Pr]

colors = {'pan01': '#0000a2',
          'pan005': '#E84141',}

# %%
plt.rcParams['font.size'] = 12

# --- Select only desired sectors ---
exclude = ["Amundsen", "Bellingshausen"]
keep_indices = [i for i, name in enumerate(sector_names) if name not in exclude]
kept_sector_names = [sector_names[i] for i in keep_indices]
kept_letter_labels = [letter_labels[i] for i in keep_indices]

# --- Define figure with only first two rows and remaining columns ---
fig, axes = plt.subplots(nrows=3, ncols=len(kept_sector_names), 
                         figsize=(15, 10.5), sharey=False,
                        gridspec_kw={'hspace': 0.2, 'height_ratios': [1, 1, 1]})

for new_col, (i, (name, letter)) in enumerate(zip(keep_indices, zip(kept_sector_names, kept_letter_labels))):
    # Row 1: PanAnt (control vs melt)
    ax = axes[0, new_col]
    sector_pan01_control[i].plot(ax=ax, y='rho2_l', color=colors['pan01'],
                                  linestyle='--', linewidth=linewidths['pan01'], label='Control')
    sector_pan01_melt[i].plot(ax=ax, y='rho2_l', color=colors['pan01'],
                               linestyle='-', linewidth=linewidths['pan01'], label='Meltwater')
    
    ax.set_xlim(xlims_ctrlmelt[name])
    plt.setp(ax.get_xticklabels(), visible=False)
    ax.grid()
    ax.set_ylim(1037.3, 1036.7)
    ax.set_title("")
    ax.text(0.01, 1.03, f'{letter} {name}', transform=ax.transAxes, fontsize=14, fontweight='bold')

    # Row 2: ACCESS (control vs melt)
    ax = axes[1, new_col]
    sector_pan005_control[i].plot(ax=ax, y='rho2_l', color=colors['pan005'],
                                  linestyle='--', linewidth=linewidths['pan005'], label='Control')
    sector_pan005_melt[i].plot(ax=ax, y='rho2_l', color=colors['pan005'],
                               linestyle='-', linewidth=linewidths['pan005'], label='Meltwater')
    ax.set_xlim(xlims_ctrlmelt[name])
    ax.set_title("")
    ax.set_ylim(1037.3, 1036.7)
    plt.setp(ax.get_xticklabels(), visible=True)
    ax.grid()

    # Row 3: Anomalies
    ax = axes[2, new_col]
    sector_anoms_01[i].plot(ax=ax, y='rho2_l', color=colors['pan01'],
                                  linestyle='-', linewidth=linewidths['pan01'], label='0.1°')
    sector_anoms_005[i].plot(ax=ax, y='rho2_l', color=colors['pan005'],
                               linestyle='-', linewidth=linewidths['pan005'], label='0.05°')
    ax.set_xlim(xlims_anom[name])
    ax.set_title("")
    ax.set_ylim(1037.3, 1036.7)
    plt.setp(ax.get_xticklabels(), visible=True)
    ax.grid()

plt.subplots_adjust(hspace=0.4)   # default for all
# then manually shift row 3 down using its position
for ax in axes[2, :]:
    pos = ax.get_position()
    ax.set_position([pos.x0, pos.y0 - 0.05, pos.width, pos.height])  # move row 3 down slightly

# --- Axis labels and shared y-axis cleanup ---
for row, axrow in enumerate(axes):
    for col, ax in enumerate(axrow):
        if col == 0:
            ax.set_ylabel(r'$\sigma_2$ (kg/m$^3$)', fontsize=14)
        else:
            ax.set_ylabel('')
            ax.tick_params(labelleft=False)   # hide y-tick labels

# --- Legends ---
axes[0, 0].legend(loc='upper right', fontsize=12)#, title="0.1°")
axes[1, 0].legend(loc='upper right', fontsize=12)#, title="0.05°")
axes[2, 0].legend(loc='upper left', fontsize=12)#, title="0.05°")

# Get all axes in row 2
row2_axes = axes[1, :]

# Find the midpoint between the leftmost and rightmost axes
left = row2_axes[0].get_position().x0
right = row2_axes[-1].get_position().x1
bottom = np.mean([ax.get_position().y0 for ax in row2_axes])

fig.text((left + right) / 2, bottom - 0.05,  # adjust vertical offset
         "Cumulatively integrated 5-year transport (Sv)",
         ha='center', va='center', fontsize=14)

# --- Add vertical row labels on the left ---
fig.text(0.03, 0.77, '0.1°', va='center', ha='center', rotation='vertical',
         fontsize=16, fontweight='bold')
fig.text(0.03, 0.50, '0.05°', va='center', ha='center', rotation='vertical',
         fontsize=16, fontweight='bold')
fig.text(0.03, 0.18, 'Anomalies', va='center', ha='center', rotation='vertical',
         fontsize=16, fontweight='bold')

# --- Common x-label and save ---
fig.supxlabel("Cumulatively integrated 5-year transport anomaly (Sv)", fontsize=14)
fig.tight_layout(rect=[0.03, 0, 1, 1]) 
fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_profiles_top2rows_anom.png", dpi=300)
plt.close(fig)
display(Image(filename="/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_profiles_top2rows_anom.png", width=1200))

# %%
plt.rcParams['font.size'] = 12

# --- Plot config ---
colors = {'Control_pan01': '#0000a2',
          'Control_pan005': '#E84141',}
linestyles = {'Control_pan01': '-', 
              'Control_pan005': '-'}
labels = {'Control_pan01': '0.1° PanAnt.',
          'Control_pan005': '0.05° PanAnt'}
line_offsets = {'Control_pan01': -1, 'Control_pan005': 1}

# --- Define figure ---
fig, ax = plt.subplots(figsize=(10, 4))

# --- Plot each cumulative transport ---
for key, array, res in zip(
    ['Control_pan01', 'Control_pan005'],
    [pan01_cont_cumsum, pan005_cont_cumsum],
    ['01deg', '005deg']
):
    # Select longitude array for this resolution
    lon_vals = contour_data[res]['lon']

    # Optional offset for label placement
    offset = 0 if 'pan01' in key else -0.4

    # Plot line
    ax.plot(lon_vals, array, label=labels[key],
            color=colors[key], linestyle=linestyles[key], linewidth=2)

    # Add text at the end of the line
    ax.text(lon_vals[-1] + 5, offset + array[-1] + 0.3 * line_offsets[key],
            f"{array[-1].values:.2f} Sv", color=colors[key], fontsize=12)


# --- Customize axes ---
ax.set_ylabel('Cumulative DSW transport (Sv)', fontsize=12)
ax.set_ylim(-2, 12)
ax.set_xlim(-280, 80)
ax.grid(axis='y')

# Use pan01 ticks/labels as reference
res_ref = '01deg'
indices = distance_indices_all[res_ref]
x_ticks = contour_data[res_ref]['lon'].values[indices]
ax.set_xticks(x_ticks)
ax.set_xticklabels([f"{lon:.0f}°" for lon in x_ticks])

ax.set_xlabel('Longitude along contour', fontsize=12)
ax.legend(loc='upper left')

plt.tight_layout()

fig.savefig("/g/data/g40/kc5856/thesis_figures/validation_DSWexport_missingACCESS.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
# --- Sector names and letters ---
sector_names = ['Circumpolar', 'Adélie', 'Ross', 'Amundsen', 'Bellingshausen', 'Weddell', 'Prydz']
letter_labels = ['a)', 'b)', 'c)', 'd)', 'e)', 'f)', 'g)']

# --- Data arrays ---
sector_pan01_control = [pan01_cont_circ, pan01_cont_Ade, pan01_cont_Ros, pan01_cont_Am,
                        pan01_cont_Be, pan01_cont_We, pan01_cont_Pr]
sector_pan01_melt    = [pan01_melt_circ, pan01_melt_Ade, pan01_melt_Ros, pan01_melt_Am,
                        pan01_melt_Be, pan01_melt_We, pan01_melt_Pr]

sector_pan005_control = [pan005_cont_circ, pan005_cont_Ade, pan005_cont_Ros, pan005_cont_Am,
                         pan005_cont_Be, pan005_cont_We, pan005_cont_Pr]
sector_pan005_melt    = [pan005_melt_circ, pan005_melt_Ade, pan005_melt_Ros, pan005_melt_Am,
                         pan005_melt_Be, pan005_melt_We, pan005_melt_Pr]

sector_anoms_01 = [pan01_anom_circ, pan01_anom_Ade, pan01_anom_Ros, pan01_anom_Am,
                   pan01_anom_Be, pan01_anom_We, pan01_anom_Pr]
sector_anoms_005 = [pan005_anom_circ, pan005_anom_Ade, pan005_anom_Ros, pan005_anom_Am,
                    pan005_anom_Be, pan005_anom_We, pan005_anom_Pr]

# --- Define figure ---
fig, axes = plt.subplots(nrows=3, ncols=7, figsize=(15, 10), sharey=True)

# --- Loop rows/cols ---
for col, (name, letter) in enumerate(zip(sector_names, letter_labels)):

    # Row 1: pan01 (control vs melt)
    ax = axes[0, col]
    sector_pan01_control[col].plot(ax=ax, y='rho2_l', color='black',
                                   linestyle='--', linewidth=linewidths['control'],
                                   label='Control')
    sector_pan01_melt[col].plot(ax=ax, y='rho2_l', color='black',
                                linestyle='-', linewidth=linewidths['melt'],
                                label='Melt')
    ax.set_ylim(1037.4, 1036.4)
    ax.set_xlim(xlims_ctrlmelt[name])   # same for row 1 + 2
    plt.setp(ax.get_xticklabels(), visible=False)
    ax.grid()
    ax.set_title('')   # remove auto-title
    ax.text(0.01, 1.03, f'{letter} {name}', transform=ax.transAxes, fontsize=8, fontweight='bold')

    # Row 2: pan005 (control vs melt)
    ax = axes[1, col]
    sector_pan005_control[col].plot(ax=ax, y='rho2_l', color='black',
                                    linestyle='--', linewidth=linewidths['control'])
    sector_pan005_melt[col].plot(ax=ax, y='rho2_l', color='black',
                                 linestyle='-', linewidth=linewidths['melt'])
    ax.set_ylim(1037.4, 1036.4)
    ax.set_xlim(xlims_ctrlmelt[name])   # same for row 1 + 2
    plt.setp(ax.get_xticklabels(), visible=True)
    ax.grid()
    ax.set_title('')   # remove auto-title

    # Row 3: anomalies (pan01 vs pan005)
    ax = axes[2, col]
    sector_anoms_01[col].plot(ax=ax, y='rho2_l', color=colors['anom_01'],
                              linestyle='-', linewidth=linewidths['anom_01'])
    sector_anoms_005[col].plot(ax=ax, y='rho2_l', color=colors['anom_005'],
                               linestyle='-', linewidth=linewidths['anom_005'])
    ax.set_ylim(1037.4, 1036.4)
    ax.set_xlim(xlims_anom[name])   # same for row 1 + 2
    plt.setp(ax.get_xticklabels(), visible=True)
    ax.grid()
    ax.set_title('')   # remove auto-title

# --- Axis labels ---
for row, axrow in enumerate(axes):
    for col, ax in enumerate(axrow):
        if col == 0:
            ax.set_ylabel(r'$\sigma_2$ (kg/m$^3$)', fontsize=11)
        else:
            ax.set_ylabel('')

# --- Legends ---
axes[0, 0].legend(loc='lower right', fontsize=8, title="Pan01")
axes[1, 0].legend(loc='lower right', fontsize=8, title="Pan005")
axes[2, 0].legend(loc='lower right', fontsize=8, title="Anomalies")

fig.supxlabel("Transport (Sv)", fontsize=12)
fig.tight_layout()
fig.savefig("control_melt_anomaly_comparison.png", dpi=300)
plt.close(fig)
display(Image(filename="control_melt_anomaly_comparison.png", width=1200))

# %%
sector_pan01_control[0].sel(rho2_l='1037.1',method='nearest')
#7.1624234 is max
# Out:
# <xarray.DataArray ()> Size: 8B
# array(7.1624234)
# Coordinates:
#     rho2_l    float64 8B 1.037e+03
#     variable  <U25 100B 'Control_transport_profile'

# %%
sector_pan005_control[0].sel(rho2_l='1037.1',method='nearest')
# 8.30502047 is max
# Out:
# <xarray.DataArray ()> Size: 8B
# array(8.30502047)
# Coordinates:
#     rho2_l    float64 8B 1.037e+03
#     variable  <U25 100B 'Control_transport_profile'

# %%
colors = {'pan01_res': '#0000a2',
          'pan005_res': '#E84141',
          'pan01': '#0000a2',
          'pan005': '#E84141',
          'pan01_pre' : '#18669C',
          'access_pre': 'tab:orange'}

# %%
# --- Define figure (now 5 columns instead of 7) ---
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(12, 10), sharey=True)

# --- Loop rows/cols ---
for col, (name, letter) in enumerate(zip(sector_names, letter_labels)):

    # Row 1: pan01 (control vs melt)
    ax = axes[0, col]
    sector_pan01_control[col].plot(ax=ax, y='rho2_l', color=colors['pan01_res'],
                                   linestyle=linestyles['control'], linewidth=linewidths['control'],
                                   label=labels['control'])
    sector_pan01_melt[col].plot(ax=ax, y='rho2_l', color=colors['pan01_res'],
                                linestyle=linestyles['melt'], linewidth=linewidths['melt'],
                                label=labels['melt'])
    ax.set_ylim(1037.4, 1036.4)
    ax.set_xlim(xlims_ctrlmelt[name])   # same for row 1 + 2
    plt.setp(ax.get_xticklabels(), visible=False)
    ax.grid()
    ax.set_title('')   # remove auto-title
    ax.text(0.01, 1.03, f'{letter} {name}', transform=ax.transAxes, fontsize=14, fontweight='bold')

    # Row 2: pan005 (control vs melt)
    ax = axes[1, col]
    sector_pan005_control[col].plot(ax=ax, y='rho2_l', color=colors['pan005_res'],
                                    linestyle=linestyles['control'], linewidth=linewidths['control'],label=labels['control'])
    sector_pan005_melt[col].plot(ax=ax, y='rho2_l', color=colors['pan005_res'],
                                 linestyle=linestyles['melt'], linewidth=linewidths['melt'],label=labels['melt'])
    ax.set_ylim(1037.4, 1036.4)
    ax.set_xlim(xlims_ctrlmelt[name])   # same for row 1 + 2
    plt.setp(ax.get_xticklabels(), visible=True)
    ax.grid()
    ax.set_title('')   # remove auto-title

    # Row 3: anomalies (pan01 vs pan005)
    ax = axes[2, col]
    sector_anoms_01[col].plot(ax=ax, y='rho2_l', color=colors['pan01_res'],
                              linestyle=linestyles['anom_01'], linewidth=linewidths['anom_01'],label=labels['anom_01'])
    sector_anoms_005[col].plot(ax=ax, y='rho2_l', color=colors['pan005_res'],
                               linestyle=linestyles['anom_005'], linewidth=linewidths['anom_005'],label=labels['anom_005'])
    ax.set_ylim(1037.4, 1036.4)
    ax.set_xlim(xlims_anom[name])   # same for row 1 + 2
    plt.setp(ax.get_xticklabels(), visible=True)
    ax.grid()
    ax.set_title('')   # remove auto-title

# --- Axis labels ---
for row, axrow in enumerate(axes):
    for col, ax in enumerate(axrow):
        if col == 0:
            ax.set_ylabel(r'$\sigma_2$ (kg/m$^3$)', fontsize=11)
        else:
            ax.set_ylabel('')

# --- Legends ---
axes[0, 0].legend(loc='lower right', fontsize=12)#, title="Pan01")
axes[1, 0].legend(loc='lower right', fontsize=12)#, title="Pan005")
axes[2, 0].legend(loc='upper left', fontsize=12)#, title="Anomalies")

fig.supxlabel("Transport (Sv)", fontsize=12)

# --- After plotting but before saving ---
row_labels = ['0.1°', '0.05°', 'Anomalies']

# y positions for each row (in figure coordinates)
row_positions = [0.83, 0.52, 0.20]  # tweak if spacing looks off

for label, ypos in zip(row_labels, row_positions):
    fig.text(
        0.00, ypos, label,
        va='center', ha='center',
        rotation='vertical',
        fontsize=16, fontweight='bold'
    )

fig.tight_layout()

fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_regional.png", dpi=300, bbox_inches='tight')
plt.show()
#display(Image(filename="control_melt_anomaly_comparison_no_AmBe.png", width=1200))

# %% [markdown]
# # Net transport

# %%
# Cumulative transport in ax7
slices_01 = {
    'Ade': slice(1037.08,1037.4),
    'Ros': slice(1037.11,1037.4),
    'AmBe': slice(1037,1037.4),
    'We': slice(1037.15,1037.4),
    'Pr': slice(1036.99,1037.4),
}

slices_005 = {
    'Ade': slice(1037.08,1037.4),
    'Ros': slice(1037.11,1037.4),
    'AmBe': slice(1037,1037.4),
    'We': slice(1037.15,1037.4),
    'Pr': slice(1036.99,1037.4),
}

# %%
region_labels = ["Adélie", "Ross",
           "Amundsen-\nBellingshausen", 
           "Weddell", "Prydz"]

# %%
region_indices_01 = {
    'Ade': slice(0, 1279),
    'Ros': slice(1279, 2177),
    'AmBe': slice(2177, 3381),
    'We': slice(3381, 4831),
    'Pr': slice(4831, None)
}

region_indices_005 = {
    'Ade': slice(0, 2522),        # 0 → 2542
    'Ros': slice(2522, 4352),   # 2542 → 4300
    
    'AmBe': slice(4352, 6522),  # 4300 → 6678
    'We': slice(6522, 9627),    # 6678 → 9598
    'Pr': slice(9627, None)       # 9600 → end
}

# %%
net_pan01 = {}
net_pan005 = {}

# Use 01 indices for pan01
for region, idx in region_indices_01.items():
    start_01 = idx.start
    stop_01 = idx.stop if idx.stop is not None else len(pan01_anom_cumsum)
    net_pan01[region] = (
        pan01_anom_cumsum.isel(contour_index=stop_01-1) -
        pan01_anom_cumsum.isel(contour_index=start_01)
    ).item()

# Use 005 indices for pan005
for region, idx in region_indices_005.items():
    start_005 = idx.start
    stop_005 = idx.stop if idx.stop is not None else len(pan005_anom_cumsum)
    net_pan005[region] = (
        pan005_anom_cumsum.isel(contour_index=stop_005-1) -
        pan005_anom_cumsum.isel(contour_index=start_005)
    ).item()

print(net_pan01)
print(net_pan005)
# Out:
# {'Ade': -0.18341886046873107, 'Ros': -0.378067328814232, 'AmBe': 0.21936810279223717, 'We': -0.23547013076614132, 'Pr': 0.024077229627819996}
# {'Ade': -0.1735735182336905, 'Ros': -0.4125971232238066, 'AmBe': 0.21605022676570673, 'We': -0.41853197634162687, 'Pr': -0.06531066994817802}

# %%
# doing it for melt and cont 

# Define data groups
datasets = {
    "pan01_cont": (pan01_cont_cumsum, region_indices_01),
    "pan01_melt": (pan01_melt_cumsum, region_indices_01),
    "pan005_cont": (pan005_cont_cumsum, region_indices_005),
    "pan005_melt": (pan005_melt_cumsum, region_indices_005),
}

# Store results
net_results = {}

# Loop through each dataset and compute net transport
for name, (data, region_indices) in datasets.items():
    net_results[name] = {}
    for region, idx in region_indices.items():
        start = idx.start
        stop = idx.stop if idx.stop is not None else len(data)
        net_results[name][region] = (
            data.isel(contour_index=stop - 1) - data.isel(contour_index=start)
        ).item()

# Print all results
for name, result in net_results.items():
    print(f"\n{name}:")
    print(result)
# Out:
# pan01_cont:
# {'Ade': 1.5683674816375082, 'Ros': 3.403464760792495, 'AmBe': 0.0007024025730659744, 'We': 2.5825610763054723, 'Pr': 2.2567077598467717}
#
# pan01_melt:
# {'Ade': 1.3849486211687771, 'Ros': 3.025397431978263, 'AmBe': 0.22007050536530315, 'We': 2.347090945539331, 'Pr': 2.2807849894745917}
#
# pan005_cont:
# {'Ade': 1.5853739307116423, 'Ros': 3.927924332195363, 'AmBe': 0.09300755895637458, 'We': 2.669393501690399, 'Pr': 2.304361986859382}
#
# pan005_melt:
# {'Ade': 1.411800412477952, 'Ros': 3.5153272089715566, 'AmBe': 0.3090577857220813, 'We': 2.250861525348772, 'Pr': 2.239051316911204}

# %%
# --- Colors and line styles ---

colors = {'pan01': '#0000a2',
          'pan005': '#E84141',
          'pan01_pre' : '#18669C',
          'access_pre': 'tab:orange',
          'pan01_cont': '#7C8CFF',   # light blue
          'pan005_cont': '#F59C9C',  # light red
         }

linewidths = {k: 2 for k in colors.keys()}

# %%
linestyles = {
    'control': '--', 
    'melt': '-', 
    'anom_01': '-', 
    'anom_005': '-',
    'pan01': '-',
    'pan005':'-'
}

labels = {
    'control': 'Control', 
    'melt': 'Melt', 
    'anom_01': '0.1°', 
    'anom_005': '0.05°',
    'pan01':'0.1°',
    'pan005':'0.05°'
}


# --- Sector names and letters (removed Amundsen + Bellingshausen) ---
sector_names = ['Circumpolar', 'Adélie', 'Ross', 'Weddell', 'Prydz']
letter_labels = ['a)', 'b)', 'c)', 'd)', 'e)']

# --- Data arrays (removed Am + Be entries) ---
sector_pan01_control = [pan01_cont_circ, pan01_cont_Ade, pan01_cont_Ros, pan01_cont_We, pan01_cont_Pr]
sector_pan01_melt    = [pan01_melt_circ, pan01_melt_Ade, pan01_melt_Ros, pan01_melt_We, pan01_melt_Pr]

sector_pan005_control = [pan005_cont_circ, pan005_cont_Ade, pan005_cont_Ros, pan005_cont_We, pan005_cont_Pr]
sector_pan005_melt    = [pan005_melt_circ, pan005_melt_Ade, pan005_melt_Ros, pan005_melt_We, pan005_melt_Pr]

sector_anoms_01 = [pan01_anom_circ, pan01_anom_Ade, pan01_anom_Ros, pan01_anom_We, pan01_anom_Pr]
sector_anoms_005 = [pan005_anom_circ, pan005_anom_Ade, pan005_anom_Ros, pan005_anom_We, pan005_anom_Pr]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.size'] = 14

# --- Define bar setup ---
bar_width = 0.2
offset = bar_width * 1.5  # horizontal spacing between grouped bars

# --- Define region labels (with Circumpolar first) ---
region_labels = ["Circumpolar", "Adélie", "Ross",
                 "Amundsen-\nBellingshausen",
                 "Weddell", "Prydz"]

# --- Compute circumpolar totals (sum of all regional values) ---
circ_totals = {}
for name in net_results.keys():
    circ_totals[name] = sum(net_results[name].values())

# --- Combine data arrays in region order ---
region_order = list(net_results['pan01_cont'].keys())  # assumed to match region_labels[1:]
vals = {}
for name in net_results.keys():
    vals[name] = [circ_totals[name]] + [net_results[name][r] for r in region_order]

# --- Define which regions to plot (exclude Amundsen–Bellingshausen visually) ---
regions_to_plot = ["Circumpolar", "Adélie", "Ross", "Weddell", "Prydz"]

# Find indices of these regions in region_labels
plot_indices = [region_labels.index(r) for r in regions_to_plot]

# Filter the plotted data
for name in vals.keys():
    vals[name] = [vals[name][i] for i in plot_indices]

# Update x positions and tick labels for plotting only
x = np.arange(len(regions_to_plot))
region_labels_plot = regions_to_plot


# --- Create figure and plot ---
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars: 4 per region (control left, melt right for each resolution)
bars01_cont = ax.bar(x - offset, vals['pan01_cont'], width=bar_width,
                     label='0.1° Control', color=colors['pan01_cont'])
bars01_melt = ax.bar(x - bar_width/2, vals['pan01_melt'], width=bar_width,
                     label='0.1° Meltwater', color=colors['pan01'])
bars005_cont = ax.bar(x + bar_width/2, vals['pan005_cont'], width=bar_width,
                      label='0.05° Control', color=colors['pan005_cont'])
bars005_melt = ax.bar(x + offset, vals['pan005_melt'], width=bar_width,
                      label='0.05° Meltwater', color=colors['pan005'])

# --- Add value labels above/below bars ---
for bars in [bars01_cont, bars01_melt, bars005_cont, bars005_melt]:
    for bar in bars:
        height = bar.get_height()
        va = 'bottom' if height >= 0 else 'top'
        y = height + 0.02 if height >= 0 else height - 0.02
        ax.text(bar.get_x() + bar.get_width()/2, y, f'{height:.2f}',
                ha='center', va=va, fontsize=10)

# --- Add percentage change labels above pairs ---
for i in range(len(x)):
    # 0.1° pair
    cont_01 = vals['pan01_cont'][i]
    melt_01 = vals['pan01_melt'][i]
    if cont_01 != 0:
        perc01 = 100 * (melt_01 - cont_01) / abs(cont_01)
        xpos01 = x[i] - (offset + bar_width/2) / 2
        ypos01 = max(cont_01, melt_01) + 0.5
        ax.text(xpos01, ypos01, f'{perc01:.1f}%', color='#0000a2',
                ha='center', va='bottom', fontsize=11, fontweight='bold')

    # 0.05° pair
    cont_005 = vals['pan005_cont'][i]
    melt_005 = vals['pan005_melt'][i]
    if cont_005 != 0:
        perc005 = 100 * (melt_005 - cont_005) / abs(cont_005)
        xpos005 = x[i] + (offset + bar_width/2) / 2
        ypos005 = max(cont_005, melt_005) + 0.5
        ax.text(xpos005, ypos005, f'{perc005:.1f}%', color='#E84141',
                ha='center', va='bottom', fontsize=11, fontweight='bold')

# --- Style ---
ax.axhline(0, color='k', linewidth=1)
ax.set_xticks(x)
ax.set_xticklabels(region_labels_plot)
ax.set_ylabel('Net DSW export anomaly (Sv)')
ax.set_ylim(0, 12)
ax.legend(loc='best', ncol=2)
plt.tight_layout()
plt.title('test with new lims')

# --- Save and show ---
#fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_regional_cont_vs_melt.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams['font.size'] = 14

region_labels = ["Adélie", "Ross",
           "Amundsen-\nBellingshausen", 
           "Weddell", "Prydz"]

# --- Include circumpolar as first entry ---
regions = ['Circumpolar'] + list(net_pan01.keys())
x = np.arange(len(regions))
bar_width = 0.35

# --- Add circumpolar cumulative transport ---
# Sum all regional net transports to get circumpolar total
circ_pan01 = sum(net_pan01.values())
circ_pan005 = sum(net_pan005.values())

# Combine into arrays for plotting
pan01_vals = [circ_pan01] + [net_pan01[r] for r in net_pan01]
pan005_vals = [circ_pan005] + [net_pan005[r] for r in net_pan005]

# --- Plot ---
fig, ax = plt.subplots(figsize=(12,6))
bars1 = ax.bar(x - bar_width/2, pan01_vals, width=bar_width,
               label='0.1°', color=colors['pan01'])
bars2 = ax.bar(x + bar_width/2, pan005_vals, width=bar_width,
               label='0.05°', color=colors['pan005'])

# Add value labels above/below bars
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        va = 'bottom' if height >=0 else 'top'
        y = height + 0.02 if height >= 0 else height - 0.02
        ax.text(bar.get_x() + bar.get_width()/2, y, f'{height:.2f} Sv', 
                ha='center', va=va, fontsize=10)

ax.axhline(0, color='k', linewidth=1)
ax.set_xticks(x)
ax.set_xticklabels(['Circumpolar'] + region_labels)
ax.set_ylim(-1.7, 0.3)
ax.set_ylabel('Net DSW transport anomaly (Sv)')
ax.legend(loc='best')
plt.tight_layout()
plt.show()

# --- Save figure ---
fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_regional_summed_with_circumpolar.png", 
            dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.size'] = 14

# --- Define bar setup ---
bar_width = 0.2
offset = bar_width * 1.5  # horizontal spacing between grouped bars

# --- Define region labels (with Circumpolar first) ---
region_labels = ["Circumpolar", "Adélie", "Ross",
                 "Amundsen-\nBellingshausen",
                 "Weddell", "Prydz"]

# --- Compute circumpolar totals (sum of all regional values) ---
circ_totals = {}
for name in net_results.keys():
    circ_totals[name] = sum(net_results[name].values())

# --- Combine data arrays in region order ---
region_order = list(net_results['pan01_cont'].keys())  # assumed to match region_labels[1:]
vals = {}
for name in net_results.keys():
    vals[name] = [circ_totals[name]] + [net_results[name][r] for r in region_order]

# --- Define which regions to plot (exclude Amundsen–Bellingshausen visually) ---
regions_to_plot = ["Circumpolar", "Adélie", "Ross", "Weddell", "Prydz"]

# Find indices of these regions in region_labels
plot_indices = [region_labels.index(r) for r in regions_to_plot]

# Filter the plotted data
for name in vals.keys():
    vals[name] = [vals[name][i] for i in plot_indices]

# Update x positions and tick labels for plotting only
x = np.arange(len(regions_to_plot))
region_labels_plot = regions_to_plot


# --- Create figure and plot ---
fig, ax = plt.subplots(figsize=(12, 6))

# Plot bars: 4 per region (control left, melt right for each resolution)
bars01_cont = ax.bar(x - offset, vals['pan01_cont'], width=bar_width,
                     label='0.1° Control', color=colors['pan01_cont'])
bars01_melt = ax.bar(x - bar_width/2, vals['pan01_melt'], width=bar_width,
                     label='0.1° Meltwater', color=colors['pan01'])
bars005_cont = ax.bar(x + bar_width/2, vals['pan005_cont'], width=bar_width,
                      label='0.05° Control', color=colors['pan005_cont'])
bars005_melt = ax.bar(x + offset, vals['pan005_melt'], width=bar_width,
                      label='0.05° Meltwater', color=colors['pan005'])

# --- Add value labels above/below bars ---
for bars in [bars01_cont, bars01_melt, bars005_cont, bars005_melt]:
    for bar in bars:
        height = bar.get_height()
        va = 'bottom' if height >= 0 else 'top'
        y = height + 0.02 if height >= 0 else height - 0.02
        ax.text(bar.get_x() + bar.get_width()/2, y, f'{height:.2f}',
                ha='center', va=va, fontsize=10)

# --- Add percentage change labels above pairs ---
for i in range(len(x)):
    # 0.1° pair
    cont_01 = vals['pan01_cont'][i]
    melt_01 = vals['pan01_melt'][i]
    if cont_01 != 0:
        perc01 = 100 * (melt_01 - cont_01) / abs(cont_01)
        xpos01 = x[i] - (offset + bar_width/2) / 2
        ypos01 = max(cont_01, melt_01) + 0.5
        ax.text(xpos01, ypos01, f'{perc01:.1f}%', color='#0000a2',
                ha='center', va='bottom', fontsize=11, fontweight='bold')

    # 0.05° pair
    cont_005 = vals['pan005_cont'][i]
    melt_005 = vals['pan005_melt'][i]
    if cont_005 != 0:
        perc005 = 100 * (melt_005 - cont_005) / abs(cont_005)
        xpos005 = x[i] + (offset + bar_width/2) / 2
        ypos005 = max(cont_005, melt_005) + 0.5
        ax.text(xpos005, ypos005, f'{perc005:.1f}%', color='#E84141',
                ha='center', va='bottom', fontsize=11, fontweight='bold')

# --- Style ---
ax.axhline(0, color='k', linewidth=1)
ax.set_xticks(x)
ax.set_xticklabels(region_labels_plot)
ax.set_ylabel('Net DSW export anomaly (Sv)')
ax.set_ylim(0, 12)
ax.legend(loc='best', ncol=2)
plt.tight_layout()

# --- Save and show ---
#fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_regional_cont_vs_melt.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams['font.size'] = 12

# --- Define combined figure layout: 2 rows (top: 3 cols, bottom: 1 col full width) ---
fig = plt.figure(figsize=(14, 10))
gs = gridspec.GridSpec(2, 3, height_ratios=[1, 1], hspace=0.3)

region_labels = ["Circumpolar", "Adélie", "Ross",
                 "Amundsen-\nBellingshausen",
                 "Weddell", "Prydz"]
regions_to_plot = ["Circumpolar", "Adélie", "Ross", "Weddell", "Prydz"]

# =====================
# Top row: 3 panels
# =====================
# Panel 1: pan01 (control vs melt)
ax1 = fig.add_subplot(gs[0, 0])
sector_pan01_control[0].plot(ax=ax1, y='rho2_l',
                             color=colors['pan01'], linestyle=linestyles['control'],
                             linewidth=linewidths['pan01'], label=labels['control'])
sector_pan01_melt[0].plot(ax=ax1, y='rho2_l',
                          color=colors['pan01'], linestyle=linestyles['melt'],
                          linewidth=linewidths['pan01'], label=labels['melt'])
ax1.set_ylim(1037.4, 1036.4)
ax1.set_xlim(xlims_ctrlmelt['Circumpolar'])
ax1.grid()
ax1.set_ylabel(r'$\sigma_2$ (kg/m$^3$)', fontsize=11)
ax1.legend(loc='upper right', fontsize=11, title="0.1° PanAntarctic")
ax1.set_xlabel("")
ax1.set_title("")

# Panel 2: pan005 (control vs melt)
ax2 = fig.add_subplot(gs[0, 1])
sector_pan005_control[0].plot(ax=ax2, y='rho2_l',
                              color=colors['pan005'], linestyle=linestyles['control'],
                              linewidth=linewidths['pan005'], label=labels['control'])
sector_pan005_melt[0].plot(ax=ax2, y='rho2_l',
                           color=colors['pan005'], linestyle=linestyles['melt'],
                           linewidth=linewidths['pan005'], label=labels['melt'])
ax2.set_ylim(1037.4, 1036.4)
ax2.set_xlim(xlims_ctrlmelt['Circumpolar'])
ax2.grid()
ax2.set_ylabel('')
ax2.tick_params(labelleft=False)
ax2.legend(loc='upper right', fontsize=11, title="0.05° PanAntarctic")
ax2.set_xlabel("")
ax2.set_title("")

# Panel 3: anomalies
ax3 = fig.add_subplot(gs[0, 2])
sector_anoms_01[0].plot(ax=ax3, y='rho2_l',
                        color=colors['pan01'], linestyle=linestyles['anom_01'],
                        linewidth=linewidths['pan01'], label=labels['anom_01'])
sector_anoms_005[0].plot(ax=ax3, y='rho2_l',
                         color=colors['pan005'], linestyle=linestyles['anom_005'],
                         linewidth=linewidths['pan005'], label=labels['anom_005'])
ax3.set_ylim(1037.6, 1036.4)
ax3.set_xlim(xlims_anom['Circumpolar'])
ax3.grid()
ax3.set_ylabel('')
ax3.tick_params(labelleft=False)
ax3.legend(loc='upper left', fontsize=11, title="Anomalies")
ax3.set_xlabel("Transport anomaly (Sv)", fontsize=12)

# Shared xlabel for left & middle panels
fig.text(0.35, 0.5, "Cumulatively integrated cross-1000m isobath transport (Sv)",
         ha="center", fontsize=12)

# =====================
# Bottom row: 1 wide bar chart with circumpolar
# =====================
ax4 = fig.add_subplot(gs[1, :])  # span all 3 columns

# Compute circumpolar net transport (sum of all regions)
circ_pan01 = sum(net_pan01.values())
circ_pan005 = sum(net_pan005.values())

# Include circumpolar as first "region"
regions_with_circ = ['Circumpolar'] + list(net_pan01.keys())
pan01_vals = [circ_pan01] + [net_pan01[r] for r in net_pan01]
pan005_vals = [circ_pan005] + [net_pan005[r] for r in net_pan005]

x = np.arange(len(regions_with_circ))
bar_width = 0.35

bars1 = ax4.bar(x - bar_width/2, pan01_vals, width=bar_width,
                label='0.1°', color=colors['pan01'])
bars2 = ax4.bar(x + bar_width/2, pan005_vals, width=bar_width,
                label='0.05°', color=colors['pan005'])

# Add labels above/below depending on sign
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        if height >= 0:
            va, y = 'bottom', height + 0.02
        else:
            va, y = 'top', height - 0.02
        ax4.text(bar.get_x() + bar.get_width()/2., y,
                 f'{height:.2f} Sv', ha='center', va=va, fontsize=10)

ax4.axhline(0, color='k', linewidth=1)
ax4.set_ylim(-0.8, 0.4)
ax4.set_xticks(x)
ax4.set_xticklabels(region_labels)
ax4.set_ylabel('Net DSW transport anomaly (Sv)')
ax4.legend(loc='lower right')

# === Panel labels ===
fig.text(0.02, 0.95, "a)", fontsize=16, fontweight='bold', va="top", ha="left")
fig.text(0.02, 0.46, "b)", fontsize=16, fontweight='bold', va="top", ha="left")

# =====================
# Final layout
# =====================
plt.tight_layout()
fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_combined_with_circumpolar.png",
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams['font.size'] = 12

# --- Define combined figure layout: 2 rows (top: 3 cols, bottom: 1 col full width) ---
fig = plt.figure(figsize=(14, 10))
gs = gridspec.GridSpec(2, 3, height_ratios=[1, 1], hspace=0.3)

# =====================
# Top row: 3 panels
# =====================
# Panel 1: pan01 (control vs melt)
ax1 = fig.add_subplot(gs[0, 0])
sector_pan01_control[0].plot(ax=ax1, y='rho2_l',
                             color=colors['pan01'], linestyle=linestyles['control'],
                             linewidth=linewidths['pan01'], label=labels['control'])
sector_pan01_melt[0].plot(ax=ax1, y='rho2_l',
                          color=colors['pan01'], linestyle=linestyles['melt'],
                          linewidth=linewidths['pan01'], label=labels['melt'])
ax1.set_ylim(1037.4, 1036.4)
ax1.set_xlim(xlims_ctrlmelt['Circumpolar'])
ax1.grid()
ax1.set_ylabel(r'$\sigma_2$ (kg/m$^3$)', fontsize=11)
ax1.legend(loc='upper right', fontsize=11, title="0.1° PanAntarctic")
ax1.set_xlabel("")
ax1.set_title("")

# Panel 2: pan005 (control vs melt)
ax2 = fig.add_subplot(gs[0, 1])
sector_pan005_control[0].plot(ax=ax2, y='rho2_l',
                              color=colors['pan005'], linestyle=linestyles['control'],
                              linewidth=linewidths['pan005'], label=labels['control'])
sector_pan005_melt[0].plot(ax=ax2, y='rho2_l',
                           color=colors['pan005'], linestyle=linestyles['melt'],
                           linewidth=linewidths['pan005'], label=labels['melt'])
ax2.set_ylim(1037.4, 1036.4)
ax2.set_xlim(xlims_ctrlmelt['Circumpolar'])
ax2.grid()
ax2.set_ylabel('')
ax2.tick_params(labelleft=False)
ax2.legend(loc='upper right', fontsize=11, title="0.05° PanAntarctic")
ax2.set_xlabel("")
ax2.set_title("")

# Panel 3: anomalies
ax3 = fig.add_subplot(gs[0, 2])
sector_anoms_01[0].plot(ax=ax3, y='rho2_l',
                        color=colors['pan01'], linestyle=linestyles['anom_01'],
                        linewidth=linewidths['pan01'], label=labels['anom_01'])
sector_anoms_005[0].plot(ax=ax3, y='rho2_l',
                         color=colors['pan005'], linestyle=linestyles['anom_005'],
                         linewidth=linewidths['pan005'], label=labels['anom_005'])
ax3.set_ylim(1037.6, 1036.4)
ax3.set_xlim(xlims_anom['Circumpolar'])
ax3.grid()
ax3.set_ylabel('')
ax3.tick_params(labelleft=False)
ax3.legend(loc='upper left', fontsize=11, title="Anomalies")
ax3.set_xlabel("Transport anomaly (Sv)", fontsize=12)

# Shared xlabel for left & middle panels
fig.text(0.35, 0.5, "Cumulatively integrated cross-1000m isobath transport (Sv)",
         ha="center", fontsize=12)

# =====================
# Bottom row: 1 wide bar chart with circumpolar
# =====================
ax4 = fig.add_subplot(gs[1, :])  # span all 3 columns

# Compute circumpolar net transport (sum of all regions)
circ_pan01 = sum(net_pan01.values())
circ_pan005 = sum(net_pan005.values())

# Include circumpolar as first "region"
regions_with_circ = ['Circumpolar'] + list(net_pan01.keys())
pan01_vals = [circ_pan01] + [net_pan01[r] for r in net_pan01]
pan005_vals = [circ_pan005] + [net_pan005[r] for r in net_pan005]

x = np.arange(len(regions_with_circ))
bar_width = 0.35

bars1 = ax4.bar(x - bar_width/2, pan01_vals, width=bar_width,
                label='0.1°', color=colors['pan01'])
bars2 = ax4.bar(x + bar_width/2, pan005_vals, width=bar_width,
                label='0.05°', color=colors['pan005'])

# Add labels above/below depending on sign
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        if height >= 0:
            va, y = 'bottom', height + 0.02
        else:
            va, y = 'top', height - 0.02
        ax4.text(bar.get_x() + bar.get_width()/2., y,
                 f'{height:.2f} Sv', ha='center', va=va, fontsize=10)

ax4.axhline(0, color='k', linewidth=1)
ax4.set_ylim(-0.8, 0.4)
ax4.set_xticks(x)
ax4.set_xticklabels(region_labels)
ax4.set_ylabel('Net DSW transport anomaly (Sv)')
ax4.legend(loc='lower right')

# === Panel labels ===
fig.text(0.02, 0.95, "a)", fontsize=16, fontweight='bold', va="top", ha="left")
fig.text(0.02, 0.46, "b)", fontsize=16, fontweight='bold', va="top", ha="left")

# =====================
# Final layout
# =====================
plt.tight_layout()
fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_combined_with_circumpolar.png",
            dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.rcParams['font.size'] = 12

# --- Define combined figure layout: 2 rows (top: 3 cols, bottom: 1 col full width) ---
fig = plt.figure(figsize=(14, 10))
gs = gridspec.GridSpec(2, 3, height_ratios=[1, 1], hspace=0.3)

# =====================
# Top row: 3 panels
# =====================
# Panel 1: pan01 (control vs melt)
ax1 = fig.add_subplot(gs[0, 0])
sector_pan01_control[0].plot(ax=ax1, y='rho2_l',
                             color=colors['pan01'], linestyle=linestyles['control'],
                             linewidth=linewidths['pan01'], label=labels['control'])
sector_pan01_melt[0].plot(ax=ax1, y='rho2_l',
                          color=colors['pan01'], linestyle=linestyles['melt'],
                          linewidth=linewidths['pan01'], label=labels['melt'])
ax1.set_ylim(1037.4, 1036.4)
ax1.set_xlim(xlims_ctrlmelt['Circumpolar'])
ax1.grid()
ax1.set_ylabel(r'$\sigma_2$ (kg/m$^3$)', fontsize=11)
ax1.legend(loc='upper right', fontsize=11, title="0.1° PanAntarctic")
ax1.set_xlabel("")
ax1.set_title("")

# Panel 2: pan005 (control vs melt)
ax2 = fig.add_subplot(gs[0, 1])
sector_pan005_control[0].plot(ax=ax2, y='rho2_l',
                              color=colors['pan005'], linestyle=linestyles['control'],
                              linewidth=linewidths['pan005'], label=labels['control'])
sector_pan005_melt[0].plot(ax=ax2, y='rho2_l',
                           color=colors['pan005'], linestyle=linestyles['melt'],
                           linewidth=linewidths['pan005'], label=labels['melt'])
ax2.set_ylim(1037.4, 1036.4)
ax2.set_xlim(xlims_ctrlmelt['Circumpolar'])
ax2.grid()
ax2.set_ylabel('')
ax2.tick_params(labelleft=False)
ax2.legend(loc='upper right', fontsize=11, title="0.05° PanAntarctic")
ax2.set_xlabel("")
ax2.set_title("")

# Panel 3: anomalies
ax3 = fig.add_subplot(gs[0, 2])
sector_anoms_01[0].plot(ax=ax3, y='rho2_l',
                        color=colors['pan01'], linestyle=linestyles['anom_01'],
                        linewidth=linewidths['pan01'], label=labels['anom_01'])
sector_anoms_005[0].plot(ax=ax3, y='rho2_l',
                         color=colors['pan005'], linestyle=linestyles['anom_005'],
                         linewidth=linewidths['pan005'], label=labels['anom_005'])
ax3.set_ylim(1037.6, 1036.4)
ax3.set_xlim(xlims_anom['Circumpolar'])
ax3.grid()
ax3.set_ylabel('')
ax3.tick_params(labelleft=False)
ax3.legend(loc='upper left', fontsize=11, title="Anomalies")
ax3.set_xlabel("Transport anomaly (Sv)", fontsize=12)

# Shared xlabel for left & middle panels
fig.text(0.35, 0.5, "Cumulatively integrated cross-1000m isobath transport (Sv)",
         ha="center", fontsize=12)

# =====================
# Bottom row: 1 wide bar chart with new grouped bars
# =====================

ax4 = fig.add_subplot(gs[1, :])  # span all 3 columns

bar_width = 0.2
offset = bar_width * 1.5  # horizontal spacing between grouped bars

# Compute circumpolar totals (sum of all regional values)
circ_totals = {}
for name in net_results.keys():
    circ_totals[name] = sum(net_results[name].values())

# Combine data arrays in region order
region_order = list(net_results['pan01_cont'].keys())  # assumed to match region_labels[1:]
vals = {}
for name in net_results.keys():
    vals[name] = [circ_totals[name]] + [net_results[name][r] for r in region_order]

# Exclude Amundsen–Bellingshausen visually
regions_to_plot = ["Circumpolar", "Adélie", "Ross", "Weddell", "Prydz"]
plot_indices = [region_labels.index(r) for r in regions_to_plot]
for name in vals.keys():
    vals[name] = [vals[name][i] for i in plot_indices]

# Update x positions and tick labels for plotting only
x = np.arange(len(regions_to_plot))
region_labels_plot = regions_to_plot

# Plot bars
bars01_cont = ax4.bar(x - offset, vals['pan01_cont'], width=bar_width,
                      label='0.1° Control', color=colors['pan01_cont'])
bars01_melt = ax4.bar(x - bar_width/2, vals['pan01_melt'], width=bar_width,
                      label='0.1° Meltwater', color=colors['pan01'])
bars005_cont = ax4.bar(x + bar_width/2, vals['pan005_cont'], width=bar_width,
                       label='0.05° Control', color=colors['pan005_cont'])
bars005_melt = ax4.bar(x + offset, vals['pan005_melt'], width=bar_width,
                       label='0.05° Meltwater', color=colors['pan005'])

# Add value labels above/below bars
for bars in [bars01_cont, bars01_melt, bars005_cont, bars005_melt]:
    for bar in bars:
        height = bar.get_height()
        va = 'bottom' if height >= 0 else 'top'
        y = height + 0.02 if height >= 0 else height - 0.02
        ax4.text(bar.get_x() + bar.get_width()/2, y, f'{height:.2f}',
                 ha='center', va=va, fontsize=10)

# Add percentage change labels above pairs
for i in range(len(x)):
    # 0.1° pair
    cont_01 = vals['pan01_cont'][i]
    melt_01 = vals['pan01_melt'][i]
    if cont_01 != 0:
        perc01 = 100 * (melt_01 - cont_01) / abs(cont_01)
        xpos01 = x[i] - (offset + bar_width/2) / 2
        ypos01 = max(cont_01, melt_01) + 0.5
        ax4.text(xpos01, ypos01, f'{perc01:.1f}%', color='#0000a2',
                 ha='center', va='bottom', fontsize=11, fontweight='bold')

    # 0.05° pair
    cont_005 = vals['pan005_cont'][i]
    melt_005 = vals['pan005_melt'][i]
    if cont_005 != 0:
        perc005 = 100 * (melt_005 - cont_005) / abs(cont_005)
        xpos005 = x[i] + (offset + bar_width/2) / 2
        ypos005 = max(cont_005, melt_005) + 0.5
        ax4.text(xpos005, ypos005, f'{perc005:.1f}%', color='#E84141',
                 ha='center', va='bottom', fontsize=11, fontweight='bold')

ax4.axhline(0, color='k', linewidth=1)
ax4.set_xticks(x)
ax4.set_xticklabels(region_labels_plot)
ax4.set_ylabel('Net DSW export (Sv)')
ax4.set_ylim(0, 12)
ax4.legend(loc='best', ncol=2)

# === Panel labels ===
fig.text(0.02, 0.95, "a)", fontsize=16, fontweight='bold', va="top", ha="left")
fig.text(0.02, 0.46, "b)", fontsize=16, fontweight='bold', va="top", ha="left")

# =====================
# Final layout
# =====================
plt.tight_layout()
fig.savefig("/g/data/g40/kc5856/thesis_figures/resolution_DSWexport_combined_allexperiments.png",
            dpi=300, bbox_inches='tight')
plt.show()
