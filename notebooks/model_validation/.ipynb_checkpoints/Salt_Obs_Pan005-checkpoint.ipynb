# %% [markdown]
# # Temp_Obs_Pan05

# %%
import intake
import glob
import dask.distributed as dsk
import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np
import xesmf as xe
import gsw

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:37241' processes=28 threads=28, memory=125.19 GiB>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-475060' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/distributed/client.py:2377> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/distributed/client.py", line 2386, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2025-09-25 23:25:29,917 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 221, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,919 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 208, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,921 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 209, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,922 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 225, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,924 - distributed.scheduler - WARNING - Attempting to reschedule task ('rechunk-split-rechunk-merge-5208b806eb32722897369035ce827b2f', 2, 0), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,926 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 210, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,929 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 222, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,930 - distributed.scheduler - WARNING - Attempting to reschedule task ('rechunk-split-rechunk-merge-8276c2ed8ced79d6a6177c57eea47a1f', 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,932 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 212, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,935 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 223, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,936 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 203, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,938 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 200, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,939 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 220, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,941 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 211, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,946 - distributed.scheduler - WARNING - Attempting to reschedule task ('rechunk-split-rechunk-merge-635e3a8f0526e380b84b976a516cde52', 0, 2, 0), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,947 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 217, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,948 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 214, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,949 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 202, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,950 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 215, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,952 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 219, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,953 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 218, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,955 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 216, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,957 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 213, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,958 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 224, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,961 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 201, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.
# 2025-09-25 23:25:29,963 - distributed.scheduler - WARNING - Attempting to reschedule task ('getitem-open_dataset-so-concatenate-d015c65bf9aa8f700d75cdabd8ae46a0', 227, 0, 2, 9), which was not found on the scheduler. Aborting reschedule.

# %% [markdown]
# ### Importing the data

# %%
# Model data
lat_slice = slice(None,-39)
paths_model = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/outpu*/*.ocean_month_z.nc'))

# %%
# Importing obs
shelf = xr.open_dataset('/g/data/g40/akm157/data/schmidtko/AASW_Temp_Salt.nc', chunks='auto')['AS'].sel(lat=lat_slice)
deep =  xr.open_dataset('/g/data/ik11/observations/woa23/woa23_decav_s00_04.nc', decode_times=False)['s_an'].sel(lat=lat_slice)

# %%
# Loading model data
def preprocess_model(ds):
    ds = ds[['so']].sel(yh=slice(None,-39))
    return ds
    
model = xr.open_mfdataset(paths_model, preprocess = preprocess_model, chunks = 'auto')

# %% [markdown]
# ## Converting all into AS

# %%
# Converting model to AS
# Calculating pressure
p_model = gsw.p_from_z(-model['z_l'], model['yh'])

# Calculating absolute salinity
SA_model = gsw.SA_from_SP(model['so'], p_model, model['xh'], model['yh'])

# %%
# Taking the average of the ten years after spin up
salt_model_ave = SA_model.sel(time=slice('2006-01-01','2010-12-31')).mean(dim='time')

# %%
salt_model_ave
# Out:
# <xarray.DataArray 'so' (z_l: 75, yh: 1641, xh: 7200)> Size: 7GB
# dask.array<mean_agg-aggregate, shape=(75, 1641, 7200), dtype=float64, chunksize=(75, 564, 600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 13kB -81.1 -81.08 -81.06 ... -39.09 -39.05 -39.01
#   * z_l      (z_l) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03

# %%
# Converting WOA to SA
# Calculating pressure
p_deep = gsw.p_from_z(-deep['depth'], deep['lat'])

# Calculating absolute salinity
SA_deep = gsw.SA_from_SP(deep, p_deep, deep['lon'], deep['lat'])

# %% [markdown]
# ## Getting bottom masks

# %%
# Extracting temperature at bottom
bottom_mask_model = salt_model_ave.where(~np.isfinite(salt_model_ave.shift({'z_l': -1})))
bottom_mask_model = ~np.isnan(bottom_mask_model)

botsalt_model_map = salt_model_ave.where(bottom_mask_model).sum(dim='z_l')

# %%
# Extracting temperature at bottom for WOA
bottom_mask_deep = SA_deep.where(~np.isfinite(SA_deep.shift({'depth': -1})))
bottom_mask_deep = ~np.isnan(bottom_mask_deep)

botsalt_deep_map = SA_deep.where(bottom_mask_deep).sum(dim='depth')

# %%
botsalt_shelf = shelf

# %%
botsalt_deep_map.plot()

# %%
botsalt_shelf
# Out:
# <xarray.DataArray 'AS' (lat: 160, lon: 1440)> Size: 2MB
# dask.array<open_dataset-AS, shape=(160, 1440), dtype=float64, chunksize=(160, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 1kB -79.88 -79.75 -79.62 ... -60.25 -60.12 -60.0
#   * lon      (lon) float64 12kB 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8

# %%
botsalt_shelf.plot()

# %%
def shift_lon_minus280_80(lon):
    """
    Shift longitudes to -280 -> 80 range.
    Works whether input is 0-360 or -180-180.
    """
    lon = lon % 360  # ensure 0-360
    lon_new = lon.copy()
    lon_new[lon > 80] -= 360  # shift values > 80 into negative range
    return lon_new

# Shelf
lon_shelf_new = shift_lon_minus280_80(botsalt_shelf.lon)
botsalt_shelf_map = botsalt_shelf.assign_coords(lon=lon_shelf_new).sortby("lon")

# Deep
lon_deep_new = shift_lon_minus280_80(botsalt_deep_map.lon)
botsalt_deep_map = botsalt_deep_map.assign_coords(lon=lon_deep_new).sortby("lon")

# %%
botsalt_shelf_map.plot(vmin=33,vmax=35,cmap=cm.cm.thermal)

# %%
botsalt_deep_map.plot(vmin=33,vmax=35,cmap=cm.cm.thermal)

# %%
botsalt_model_map = botsalt_model_map.astype('float32')
botsalt_model_map
# Out:
# <xarray.DataArray 'so' (yh: 1641, xh: 7200)> Size: 47MB
# dask.array<astype, shape=(1641, 7200), dtype=float32, chunksize=(564, 600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 13kB -81.1 -81.08 -81.06 ... -39.09 -39.05 -39.01

# %%
botsalt_model_map = botsalt_model_map.load()

# %%
botsalt_model_map.plot(vmin=33,vmax=35,cmap=cm.cm.thermal)

# %% [markdown]
# ### Fix up the land masks

# %%
botsalt_deep_map_new = botsalt_deep_map.where(botsalt_deep_map != 0, np.nan)
botsalt_deep_map_new

# %%
botsalt_deep_map_new.plot(vmin=33,vmax=35,cmap=cm.cm.thermal)

# %%
botsalt_model_map_new = botsalt_model_map.where(botsalt_model_map != 0, np.nan)
botsalt_model_map_new

# %%
botsalt_model_map_new.plot(vmin=33,vmax=35,cmap=cm.cm.thermal)

# %%
botsalt_model_map_new.to_netcdf('/g/data/x77/kc5856/thesis_model_validation/pan005_control_sob_last10yrave.nc')
botsalt_deep_map_new.to_netcdf('/g/data/x77/kc5856/thesis_model_validation/deep_WOA23_sob_last10yrave.nc')
botsalt_shelf_map.to_netcdf('/g/data/x77/kc5856/thesis_model_validation/shelf_schmidtko_sob_last10yrave.nc')

# %% [markdown]
# ### Taking the anomalies

# %% [markdown]
# Shelf obs and model are both on 1/10th degree grids. (but not identical).
# WOA is on 1/4 degree.
# So we need to do some regridding.

# %%
import xesmf as xe

# %%
botsalt_model_map_new = botsalt_model_map_new.rename({'xh': 'lon', 'yh': 'lat'}) # comment out if already done this session

# %%
# Build regridder from model grid -> obs grid
# xESMF expects coords named 'lon' and 'lat' (or specify lon/lat dims explicitly).
regridder = xe.Regridder(botsalt_model_map_new, botsalt_deep_map_new, method='conservative')  # or 'bilinear'

# Regrid the high-res model onto the obs grid
model_on_obs = regridder(botsalt_model_map_new)

# %%
# compute anomaly
anomaly_deep = model_on_obs - botsalt_deep_map_new   # model minus obs (change sign if you prefer obs-model)

# %%
anomaly_deep.plot(vmin=-.1,vmax=.1,cmap=cm.cm.delta) # checking -1 to 1 range against Schmidt et al, 2025.

# %% [markdown]
# Doing the shelf anomaly:

# %%
# Check if grids are the same
print(botsalt_model_map_new.lon.equals(botsalt_shelf_map.lon))
print(botsalt_model_map_new.lat.equals(botsalt_shelf_map.lat))
# Out:
# False
# False

# %%
## Model and shelf obs regridding
# Create regridder: model -> obs
regridder_shelf = xe.Regridder(botsalt_model_map_new, botsalt_shelf_map, method='conservative', periodic=True, reuse_weights=False)

# Regrid model onto obs grid
model_on_obs_shelf = regridder_shelf(botsalt_model_map_new)

# %%
shelf_mask = ~np.isnan(botsalt_shelf_map)  # True where obs exist (shelf)
anomaly_shelf = model_on_obs_shelf - botsalt_shelf_map   # model minus obs
anomaly_shelf = anomaly_shelf.where(shelf_mask)   # mask outside shelf

# %%
anomaly_shelf.plot(vmin=-.1,vmax=.1,cmap=cm.cm.delta)

# %%
# Save anomalies
anomaly_deep.to_netcdf('/g/data/x77/kc5856/thesis_model_validation/pan005_control_obs_sob_deep_anomaly.nc')
anomaly_shelf.to_netcdf('/g/data/x77/kc5856/thesis_model_validation/pan005_control_obs_sob_shelf_anomaly.nc')

# %% [markdown]
# ## Plotting

# %%
anomaly_deep = xr.open_dataset('/g/data/x77/kc5856/thesis_model_validation/pan005_control_obs_sob_deep_anomaly.nc',decode_times=False).to_array()
anomaly_shelf = xr.open_dataset('/g/data/x77/kc5856/thesis_model_validation/pan005_control_obs_sob_shelf_anomaly.nc',decode_times=False).to_array()

# %%
# Shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
# Shelf contour
depth = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['deptho']
land_mask = (0 * depth).fillna(1)
land = xr.where(np.isnan(depth.rename('land')), 1, np.nan)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_005')

# %%
import matplotlib.patches as mpatches

# %%
# With conservative temperature

projection = ccrs.SouthPolarStereo()
    
plt.figure(figsize=(7, 8))
ax = plt.axes(projection=projection)
ax.set_extent([-280, 80, -80, -59], crs=ccrs.PlateCarree())
    
# Circular boundary
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5,0.495], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# Filled land 
land.plot.contourf(ax=ax, colors='lightgrey',
                   zorder=3,
                   transform=ccrs.PlateCarree(),
                   add_colorbar=False)

# Add a light grey circle patch to get last bit of land
circle_patch = mpatches.Circle(
    (0, 0),  # center at South Pole in projection coordinates
    radius=1000000,  # adjust radius until circle ends around -80° latitude
    facecolor='lightgrey',
    edgecolor=None,
    zorder=2,
    transform=ccrs.SouthPolarStereo()
)
ax.add_patch(circle_patch)

#Plotting
anomaly_deep.plot(
    x="lon",
    y="lat",
    transform=ccrs.PlateCarree(),
    vmin=-.1,
    vmax=.1,
    extend="both",
    cmap=cm.cm.delta, #cm ocean colour maps for more options, matplotlib has more also.
    add_colorbar=False,
    zorder= 1
)

# White shelf mask in between
shelf_mask.where(shelf_mask == 1).plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    add_colorbar=False,
    cmap="gray",  # black=0, white=1
    vmin=0, vmax=1,
)


anomaly_shelf.plot(
    x="lon",
    y="lat",
    transform=ccrs.PlateCarree(),
    vmin=-.1,
    vmax=.1,
    extend="both",
    cmap=cm.cm.delta, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Bottom abs. salinity anomaly (g/kg)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
    zorder= 4
)

# Longitudes
for lon in range(-180, 181, 60):
    ax.plot([lon, lon], [-90, -59],
            transform=ccrs.PlateCarree(),
            color="gray", linestyle="--", linewidth=0.5, zorder=20)

# Latitudes
for lat in (-80, -70, -55):
    lons = np.linspace(-280, 80, 400)
    ax.plot(lons, [lat]*len(lons),
            transform=ccrs.PlateCarree(),
            color="gray", linestyle="--", linewidth=0.5, zorder=20)


# Coast line
ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=1, transform = ccrs.PlateCarree(), zorder=15)
# Shelf contour
ax.contour(shelf_mask['xh'], shelf_mask['yh'], shelf_mask,
           levels = [0, 1], colors = 'k', linewidths=0.5,transform = ccrs.PlateCarree(), zorder=15)


plt.title("0.05° PanAntarctic - Obs, bottom salinity");
