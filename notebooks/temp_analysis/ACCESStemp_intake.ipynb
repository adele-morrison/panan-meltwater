# %% [markdown]
# # ACCESS temp intake

# %%
import intake

import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

# %%
#Importing data
control = intake.open_esm_datastore('/home/272/kc5856/access_control_new.json', columns_with_iterables=['variable'])
melt = intake.open_esm_datastore('/home/272/kc5856/access_meltwater_ssp126.json', columns_with_iterables=['variable'])

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46073 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:43423' processes=28 threads=28, memory=126.00 GiB>

# %%
#Time variant variables #Can this be condensed?
control_temp = control.search(file_id='ocean',variable="temp", frequency="1 mon")#.to_dask() is creating errors
melt_temp = melt.search(file_id='ocean',variable="temp", frequency="1 mon")

# %%
#Time invariant variables
data_fixed = control.search(variable=["area_t","ht"],path=".*output000.*").to_dask()
dzt_C = control.search(variable=["dzt"],path=".*output000.*",file_id=["ocean"]).to_dask()
dzt_M = melt.search(variable=["dzt"],path=".*output000.*",file_id=["ocean"]).to_dask()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 data_fixed = control.search(variable=["area_t","ht"],path=".*output000.*").to_dask()
#       3 dzt_C = control.search(variable=["dzt"],path=".*output000.*",file_id=["ocean"]).to_dask()
# ----> 4 dzt_M = melt.search(variable=["dzt"],path=".*output000.*",file_id=["ocean"]).to_dask()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/intake_esm/core.py:814, in esm_datastore.to_dask(self, **kwargs)
#     799 """
#     800 Convert result to an xarray dataset.
#     801
#    (...)
#     811 :py:class:`~xarray.Dataset`
#     812 """
#     813 if len(self) != 1:  # quick check to fail more quickly if there are many results
# --> 814     raise ValueError(
# ...
