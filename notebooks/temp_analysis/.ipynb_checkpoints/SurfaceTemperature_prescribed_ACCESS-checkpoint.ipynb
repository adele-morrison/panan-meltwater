# %% [markdown]
# # ACCESS Surface temp

# %%
import intake
import glob
import dask.distributed as dsk
import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np
import xesmf as xe

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
import logging
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:33861' processes=28 threads=28, memory=126.00 GiB>
# 2025-10-30 16:58:22,331 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('getitem-f883fdba9930ebfddccc9a97042eef11', 2, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: <Task ('getitem-f883fdba9930ebfddccc9a97042eef11', 2, 9) getitem(...)>
# new run_spec: Alias(('getitem-f883fdba9930ebfddccc9a97042eef11', 2, 9)->('concatenate-rechunk-merge-rechunk-split-getitem-f883fdba9930ebfddccc9a97042eef11', 2, 9))
# old dependencies: {('getitem-811fde7c52b567fb9e0d2b747c928187', 0, 2, 9)}
# new dependencies: {('concatenate-rechunk-merge-rechunk-split-getitem-f883fdba9930ebfddccc9a97042eef11', 2, 9)}

# %%
#Importing data

pathsC = np.sort(glob.glob('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/outpu*/ocean/ocean.nc'))
pathsM = np.sort(glob.glob('/scratch/x77/jn8053/access-om2/archive/01deg_jra55v13_ryf9091_21mbath_sofia_ssp126_prsc_rest/*/ocean/ocean.nc'))

# %%
## Creating shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['ht']
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom5')

# %%
#Time variant variables
def preprocess(ds):
    ds = ds['temp'].sel(yt_ocean=shelf_mask['yt_ocean']).isel(st_ocean=0)
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
#Time slicing
cont = cont.sel(time=slice('1910-01-01','1919-12-31'))
melt = melt.sel(time=slice('1910-01-01','1919-12-31'))

# %%
#Time invariant variables
area = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['area_t']

# %%
## Selecting temperature
# This is already in conservative temperature so don't need to convert

tempC = cont['temp']
tempM = melt['temp']

# %%
# Correcting area
area_corr = area*(tempC.isel(time=0)*0 +1)

# %%
area_corr.plot()

# %%
tempC
# Out:
# <xarray.DataArray 'temp' (time: 120, yt_ocean: 510, xt_ocean: 3600)> Size: 881MB
# dask.array<getitem, shape=(120, 510, 3600), dtype=float32, chunksize=(2, 270, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     st_ocean  float64 8B 0.5413
#   * time      (time) object 960B 1910-01-16 12:00:00 ... 1919-12-16 12:00:00
# Attributes:
#     long_name:      Conservative temperature
#     units:          K
#     valid_range:    [-10. 500.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_conservative_temperature

# %% [markdown]
# ## Mapping

# %%
tempC_map = tempC.sel(time=slice('1915-01-01','1919-12-31')).mean(dim='time')
tempM_map = tempM.sel(time=slice('1915-01-01','1919-12-31')).mean(dim='time')
surface_temp_anom_ave = tempM_map - tempC_map

# %%
# Checking size
surface_temp_anom_ave
# Out:
# <xarray.DataArray 'temp' (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
# dask.array<sub, shape=(510, 3600), dtype=float32, chunksize=(270, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     st_ocean  float64 8B 0.5413

# %%
surface_temp_anom_ave = surface_temp_anom_ave.load()

# %%
surface_temp_anom_ave.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/surface_temp_map_prescribed_ACCESS.nc')

# %%
land = xr.where(np.isnan(depth.rename('land')), 1, np.nan)
projection = ccrs.SouthPolarStereo()

# %%
plt.figure(figsize=(7, 8))
ax = plt.axes(projection=projection)
ax.set_extent([-280, 80, -80, -59], crs=ccrs.PlateCarree())

# Circular boundary
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5,0.495], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# Filled land 
land.plot.contourf(ax=ax, colors='white',
                   zorder=2,
                   transform=ccrs.PlateCarree(),
                   add_colorbar=False)

# Coast line
ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
# Shelf contour
ax.contour(shelf_mask.cf['X'], shelf_mask.cf['Y'], shelf_mask,
           levels = [0, 1], colors = 'k', linewidths=0.5,transform = ccrs.PlateCarree())

# Adding polar axes
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, 
                    xlocs=range(-180,171,60), ylocs=[], 
                    color='darkgray', alpha=0.5, linestyle='--', zorder=10)
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=False, linewidth=1, 
                    xlocs=[], ylocs=(-80,-70,-55), 
                    color='darkgray', alpha=0.5, linestyle='--', zorder=10)

# Plotting
surface_temp_anom_ave.plot(
    x="xt_ocean",
    y="yt_ocean",
    transform=ccrs.PlateCarree(),
    vmin=-0.5,
    vmax=0.5,
    extend="both",
    cmap=cm.cm.balance, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Surface temperature anomaly ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("ACCESS-OM2-01",fontsize = 18);

# %% [markdown]
# ### Time series

# %%
# Spatial average
sfctemp_cont_time = (area_corr * tempC.where(shelf_mask == 1)).sum(['xt_ocean', 'yt_ocean']) / area_corr.where(shelf_mask == 1).sum(['xt_ocean', 'yt_ocean'])
sfctemp_pert_time = (area_corr * tempM.where(shelf_mask == 1)).sum(['xt_ocean', 'yt_ocean']) / area_corr.where(shelf_mask == 1).sum(['xt_ocean', 'yt_ocean'])

# %%
# Check shape
sfctemp_cont_time
# Out:
# <xarray.DataArray (time: 120)> Size: 480B
# dask.array<truediv, shape=(120,), dtype=float32, chunksize=(2,), chunktype=numpy.ndarray>
# Coordinates:
#     st_ocean  float64 8B 0.5413
#   * time      (time) object 960B 1910-01-16 12:00:00 ... 1919-12-16 12:00:00

# %%
sfctemp_cont_time = sfctemp_cont_time.load()
sfctemp_pert_time = sfctemp_pert_time.load()

# %%
sfctemp_cont_time.plot(label="Control")
sfctemp_pert_time.plot(label="Perturbation")
plt.ylabel("Surface temperature ($^\circ$C)")
plt.legend(loc="lower left")
plt.title("ACCESS Time Series of Surface Temperature on Shelf")
# Out:
# Text(0.5, 1.0, 'ACCESS Time Series of Surface Temperature on Shelf')

# %%
sfctemp_anom_time = sfctemp_pert_time - sfctemp_cont_time
sfctemp_anom_time = sfctemp_anom_time.load()

# %%
sfctemp_anom_time.plot()

# %%
sfctemp_anom_time.groupby('time.month').mean('time').plot()

# %%
sfctemp_anom_time.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/surface_temp_anom_prescribed_access.nc')
