# %% [markdown]
# # Pan005 Bottom Temperature for formation regions

# %%
import gsw
import glob
import dask.distributed as dsk
import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np
import xesmf as xe

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
import logging
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:36221' processes=28 threads=28, memory=125.19 GiB>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152033' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152049' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152041' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152035' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152050' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152043' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152034' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152051' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152042' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152036' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152053' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152044' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152038' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152052' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152045' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152037' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152054' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152047' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152039' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152055' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152046' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152040' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152032' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-152048' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161037' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161052' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161044' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161036' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161029' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161046' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161038' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161031' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161045' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161039' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161030' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161047' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161041' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161032' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161049' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161040' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161033' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161048' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161042' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161035' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161050' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161043' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161034' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-161051' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
pathsC = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/outpu*/*.ocean_month_z.nc'))[120:]
pathsM = np.sort(glob.glob('/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/outpu*/*.ocean_month_z.nc'))[:60]

# %%
## Shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['deptho']
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_005')

# %%
# Time variant variables
def preprocess(ds):
    ds = ds[['thetao','so']].where(shelf_mask == 1)
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
#Time slicing
cont = cont.sel(time=slice('2001-01-01','2010-12-31'))
melt = melt.sel(time=slice('2001-01-01','2010-12-31'))

# %%
#Time invariant variables
areaC = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['areacello'].sel(xh=shelf_mask['xh'])
areaM = xr.open_dataset('/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/output120/20010101.ocean_static.nc')['areacello'].sel(xh=shelf_mask['xh'])

# %% [markdown]
# ### Corrected area

# %%
# Variable for landmask
saltC = cont['so']
saltM = melt['so']

# %%
# Correcting area
areaC_corr = areaC*(saltC.isel(time=0,z_l=0)*0 +1)
areaM_corr = areaM*(saltM.isel(time=0,z_l=0)*0 +1)

# %%
areaC_corr
# Out:
# <xarray.DataArray (yh: 1066, xh: 7200)> Size: 31MB
# dask.array<multiply, shape=(1066, 7200), dtype=float32, chunksize=(563, 600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 9kB -78.99 -78.96 -78.94 ... -55.08 -55.05 -55.02
#     z_l      float64 8B 0.5413
#     time     object 8B 2001-01-16 12:00:00

# %%
## Weddell Sea
# Saved as _W
lat_slice_W = slice(-78,-71)
lon_slice_W = slice(-64.95,-44.95)

## Ross Sea
# Saved as _R
lat_slice_R = slice(-78,-71.5)
lon_slice_R = slice(-200,-175)

## Adelie Coast
# Saved as _A
lat_slice_A = slice(-69,-64.5)
lon_slice_A = slice(45,79)

## Prydz Bay
# Saved as _P
lat_slice_P = slice(-69,-65)
lon_slice_P = slice(-235,-205)

# %% [markdown]
# #### Getting data from full bottom temp files

# %% [markdown]
# Bottom temperature files were generated in `BottomTemperature_Pan005.ipynb`.

# %%
# Opening files
bottemp_cont = np.sort(glob.glob('/g/data/g40/kc5856/temperature_ssp126/pan005_cont_bottom_temp_*'))
bottemp_melt = np.sort(glob.glob('/g/data/g40/kc5856/temperature_ssp126/pan005_melt_bottom_temp_*'))

# %%
bottemp_cont = xr.open_mfdataset(bottemp_cont, concat_dim='time', combine='nested')
bottemp_melt = xr.open_mfdataset(bottemp_melt, concat_dim='time', combine='nested')

# %%
bottemp_cont
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:  (time: 120, yh: 1066, xh: 7200)
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 9kB -78.99 -78.96 -78.94 ... -55.08 -55.05 -55.02
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2009-04-16 00:00:00
# Data variables:
#     so       (time, yh, xh) float64 7GB dask.array<chunksize=(1, 1066, 7200), meta=np.ndarray>

# %%
bottemp_cont = bottemp_cont.to_array().squeeze()
bottemp_melt = bottemp_melt.to_array().squeeze()

# %%
bottemp_cont
# Out:
# <xarray.DataArray (time: 120, yh: 1066, xh: 7200)> Size: 7GB
# dask.array<getitem, shape=(120, 1066, 7200), dtype=float64, chunksize=(1, 1066, 7200), chunktype=numpy.ndarray>
# Coordinates:
#   * xh        (xh) float64 58kB -280.0 -279.9 -279.9 ... 79.87 79.92 79.97
#   * yh        (yh) float64 9kB -78.99 -78.96 -78.94 ... -55.08 -55.05 -55.02
#   * time      (time) object 960B 2001-01-16 12:00:00 ... 2009-04-16 00:00:00
#     variable  <U2 8B 'so'

# %%
# To fix the label issues
#bottemp_cont = xr.DataArray(bottemp_cont, dims=cont['thetao'].dims, coords=cont['thetao'].coords)
bottemp_cont.attrs['units'] = '°C'
bottemp_cont.name = 'CT'

#bottemp_melt = xr.DataArray(bottemp_melt, dims=melt['thetao'].dims, coords=melt['thetao'].coords)
bottemp_melt.attrs['units'] = '°C'
bottemp_melt.name = 'CT'

# %%
bottemp_cont = bottemp_cont.sortby('time')
bottemp_melt = bottemp_melt.sortby('time')

# %%
bottemp_cont
# Out:
# <xarray.DataArray 'CT' (time: 120, yh: 1066, xh: 7200)> Size: 7GB
# dask.array<getitem, shape=(120, 1066, 7200), dtype=float64, chunksize=(1, 1066, 7200), chunktype=numpy.ndarray>
# Coordinates:
#   * xh        (xh) float64 58kB -280.0 -279.9 -279.9 ... 79.87 79.92 79.97
#   * yh        (yh) float64 9kB -78.99 -78.96 -78.94 ... -55.08 -55.05 -55.02
#   * time      (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
#     variable  <U2 8B 'so'
# Attributes:
#     units:    °C

# %% [markdown]
# ## Time Series

# %%
bottemp_cont_shelf = bottemp_cont.where(shelf_mask == 1)
bottemp_pert_shelf = bottemp_melt.where(shelf_mask == 1)

# %%
# Restricting to regions
bottemp_cont_W = bottemp_cont_shelf.sel(yh=lat_slice_W,xh=lon_slice_W)
bottemp_pert_W = bottemp_pert_shelf.sel(yh=lat_slice_W,xh=lon_slice_W)

bottemp_cont_R = bottemp_cont_shelf.sel(yh=lat_slice_R,xh=lon_slice_R)
bottemp_pert_R = bottemp_pert_shelf.sel(yh=lat_slice_R,xh=lon_slice_R)

bottemp_cont_A = bottemp_cont_shelf.sel(yh=lat_slice_A,xh=lon_slice_A)
bottemp_pert_A = bottemp_pert_shelf.sel(yh=lat_slice_A,xh=lon_slice_A)

bottemp_cont_P = bottemp_cont_shelf.sel(yh=lat_slice_P,xh=lon_slice_P)
bottemp_pert_P = bottemp_pert_shelf.sel(yh=lat_slice_P,xh=lon_slice_P)

# %%
# Spatial averages
bottemp_cont_W_time = (areaC_corr * bottemp_cont_W).sum(['xh', 'yh']) / areaC_corr.sum(['xh', 'yh'])
bottemp_pert_W_time = (areaM_corr * bottemp_pert_W).sum(['xh', 'yh']) / areaM_corr.sum(['xh', 'yh'])

bottemp_cont_R_time = (areaC_corr * bottemp_cont_R).sum(['xh', 'yh']) / areaC_corr.sum(['xh', 'yh'])
bottemp_pert_R_time = (areaM_corr * bottemp_pert_R).sum(['xh', 'yh']) / areaM_corr.sum(['xh', 'yh'])

bottemp_cont_A_time = (areaC_corr * bottemp_cont_A).sum(['xh', 'yh']) / areaC_corr.sum(['xh', 'yh'])
bottemp_pert_A_time = (areaM_corr * bottemp_pert_A).sum(['xh', 'yh']) / areaM_corr.sum(['xh', 'yh'])

bottemp_cont_P_time = (areaC_corr * bottemp_cont_P).sum(['xh', 'yh']) / areaC_corr.sum(['xh', 'yh'])
bottemp_pert_P_time = (areaM_corr * bottemp_pert_P).sum(['xh', 'yh']) / areaM_corr.sum(['xh', 'yh'])

# %%
# Check shape
bottemp_cont_W_time
# Out:
# <xarray.DataArray (time: 120)> Size: 960B
# dask.array<truediv, shape=(120,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     z_l       float64 8B 0.5413
#   * time      (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
#     variable  <U2 8B 'so'

# %%
bottemp_cont_W_time = bottemp_cont_W_time.load()
bottemp_pert_W_time = bottemp_pert_W_time.load()

# %%
bottemp_cont_R_time = bottemp_cont_R_time.load()
bottemp_pert_R_time = bottemp_pert_R_time.load()

# %%
bottemp_cont_A_time = bottemp_cont_A_time.load()
bottemp_pert_A_time = bottemp_pert_A_time.load()

# %%
bottemp_cont_P_time = bottemp_cont_P_time.load()
bottemp_pert_P_time = bottemp_pert_P_time.load()

# %% [markdown]
# ## Between model comparison

# %%
pan005_bottemp_anom = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_CT_pan005.nc', chunks = 'auto')
pan01_bottemp_anom = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_CT_pan01.nc', chunks = 'auto')
acc_bottemp_anom = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_access.nc', chunks = 'auto')

# %%
pan01_bottemp_anom_new = pan01_bottemp_anom.to_series()

# %%
acc_bottemp_anom_new = acc_bottemp_anom.to_series()

# %%
pan005_bottemp_anom_new = pan005_bottemp_anom.to_series()

# %%
import pandas as pd

# %%
# Slice 1910–1919 and 2001–2010
pan005_bottemp_anom_new = pan005_bottemp_anom_new['2001-01-01':'2010-10-16']
pan01_bottemp_anom_new = pan01_bottemp_anom_new['2001-01-01':'2010-10-16']
acc_bottemp_anom_new = acc_bottemp_anom_new['1910-01-16':'1919-12-16']

# Reset index to normalized months
pan005_bottemp_anom_new.index = range(1, len(pan005_bottemp_anom_new)+1)
pan01_bottemp_anom_new.index = range(1, len(pan01_bottemp_anom_new)+1)
acc_bottemp_anom_new.index = range(1, len(acc_bottemp_anom_new)+1)

# %%
# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(pan005_bottemp_anom_new.index, pan005_bottemp_anom_new.values, label='PanAntarctic 1/20th')
plt.plot(pan01_bottemp_anom_new.index, pan01_bottemp_anom_new.values, label='PanAntarctic 1/10th')
plt.plot(acc_bottemp_anom_new.index, acc_bottemp_anom_new.values, label='ACCESS-OM2-01')

# Set x-axis ticks to represent years 1 through 10
plt.xticks(ticks=range(1, 121, 12), labels=[str(i) for i in range(1, 11)])

# Labeling and formatting
plt.xlabel('Time (years)')
plt.ylabel("Bottom temperature anomaly ($^\circ$C)")
plt.title('Bottom temperature anomaly, shelf only')
plt.legend()
plt.grid(True, color='lightgrey')
plt.tight_layout()
plt.show()
