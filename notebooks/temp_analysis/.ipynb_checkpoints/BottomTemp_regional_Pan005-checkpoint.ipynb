# %% [markdown]
# # Pan005 Bottom Temperature for formation regions

# %%
import gsw
import glob
import dask.distributed as dsk
import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np
import xesmf as xe

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
import logging
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:43177' processes=28 threads=28, memory=125.19 GiB>
# ...

# %%
pathsC = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/outpu*/*.ocean_month_z.nc'))[120:]
pathsM = np.sort(glob.glob('/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/outpu*/*.ocean_month_z.nc'))[:60]

# %%
## Shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['deptho']
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_005')

# %%
# Time variant variables
def preprocess(ds):
    ds = ds[['thetao','so']].where(shelf_mask == 1)
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
#Time slicing
cont = cont.sel(time=slice('2001-01-01','2010-12-31'))
melt = melt.sel(time=slice('2001-01-01','2010-12-31'))

# %%
#Time invariant variables
areaC = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['areacello'].sel(xh=shelf_mask['xh'])
areaM = xr.open_dataset('/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/output120/20010101.ocean_static.nc')['areacello'].sel(xh=shelf_mask['xh'])

# %% [markdown]
# ### Corrected area

# %%
# Variable for landmask
saltC = cont['so']
saltM = melt['so']

# %%
# Correcting area
areaC_corr = areaC*(saltC.isel(time=0,z_l=0)*0 +1)
areaM_corr = areaM*(saltM.isel(time=0,z_l=0)*0 +1)

# %%
areaC_corr.plot()

# %%
## Weddell Sea
# Saved as _W
lat_slice_W = slice(-78,-71)
lon_slice_W = slice(-64.95,-44.95)

## Ross Sea
# Saved as _R
lat_slice_R = slice(-78,-71.5)
lon_slice_R = slice(-200,-175)

## Adelie Coast
# Saved as _A
lat_slice_A = slice(-69,-64.5)
lon_slice_A = slice(45,79)

## Prydz Bay
# Saved as _P
lat_slice_P = slice(-69,-65)
lon_slice_P = slice(-235,-205)

# %% [markdown]
# #### Getting data from full bottom temp files

# %% [markdown]
# Bottom temperature files were generated in `BottomTemperature_Pan005.ipynb`.

# %%
# Opening files
bottemp_cont = np.sort(glob.glob('/g/data/g40/kc5856/temperature_ssp126/pan005_cont_bottom_temp_*'))
bottemp_melt = np.sort(glob.glob('/g/data/g40/kc5856/temperature_ssp126/pan005_melt_bottom_temp_*'))

# %%
bottemp_cont = xr.open_mfdataset(bottemp_cont, concat_dim='time', combine='nested')
bottemp_melt = xr.open_mfdataset(bottemp_melt, concat_dim='time', combine='nested')

# %%
bottemp_cont
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:  (time: 120, yh: 1066, xh: 7200)
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 9kB -78.99 -78.96 -78.94 ... -55.08 -55.05 -55.02
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2009-04-16 00:00:00
# Data variables:
#     so       (time, yh, xh) float64 7GB dask.array<chunksize=(1, 1066, 7200), meta=np.ndarray>

# %%
bottemp_cont = bottemp_cont.to_array().squeeze()
bottemp_melt = bottemp_melt.to_array().squeeze()

# %%
# To fix the label issues
#bottemp_cont = xr.DataArray(bottemp_cont, dims=cont['thetao'].dims, coords=cont['thetao'].coords)
bottemp_cont.attrs['units'] = '°C'
bottemp_cont.name = 'CT'

#bottemp_melt = xr.DataArray(bottemp_melt, dims=melt['thetao'].dims, coords=melt['thetao'].coords)
bottemp_melt.attrs['units'] = '°C'
bottemp_melt.name = 'CT'

# %%
bottemp_cont = bottemp_cont.sortby('time')
bottemp_melt = bottemp_melt.sortby('time')

# %%
bottemp_cont
# Out:
# <xarray.DataArray 'CT' (time: 120, yh: 1066, xh: 7200)> Size: 7GB
# dask.array<getitem, shape=(120, 1066, 7200), dtype=float64, chunksize=(1, 1066, 7200), chunktype=numpy.ndarray>
# Coordinates:
#   * xh        (xh) float64 58kB -280.0 -279.9 -279.9 ... 79.87 79.92 79.97
#   * yh        (yh) float64 9kB -78.99 -78.96 -78.94 ... -55.08 -55.05 -55.02
#   * time      (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
#     variable  <U2 8B 'so'
# Attributes:
#     units:    °C

# %% [markdown]
# ## Time Series

# %%
bottemp_cont = bottemp_cont.astype(float)
bottemp_melt = bottemp_melt.astype(float)

# %%
bottemp_cont_shelf = bottemp_cont.where(shelf_mask == 1)
bottemp_pert_shelf = bottemp_melt.where(shelf_mask == 1)

# %%
bottemp_cont_shelf.isel(time=0).plot()

# %%
# Restricting to regions
bottemp_cont_W = bottemp_cont_shelf.sel(yh=lat_slice_W,xh=lon_slice_W)
bottemp_pert_W = bottemp_pert_shelf.sel(yh=lat_slice_W,xh=lon_slice_W)

bottemp_cont_R = bottemp_cont_shelf.sel(yh=lat_slice_R,xh=lon_slice_R)
bottemp_pert_R = bottemp_pert_shelf.sel(yh=lat_slice_R,xh=lon_slice_R)

bottemp_cont_A = bottemp_cont_shelf.sel(yh=lat_slice_A,xh=lon_slice_A)
bottemp_pert_A = bottemp_pert_shelf.sel(yh=lat_slice_A,xh=lon_slice_A)

bottemp_cont_P = bottemp_cont_shelf.sel(yh=lat_slice_P,xh=lon_slice_P)
bottemp_pert_P = bottemp_pert_shelf.sel(yh=lat_slice_P,xh=lon_slice_P)

# %%
# Spatial averages
bottemp_cont_W_time = (areaC_corr * bottemp_cont_W).sum(['xh', 'yh']) / areaC_corr.sel(yh=lat_slice_W,xh=lon_slice_W).sum(['xh', 'yh'])
bottemp_pert_W_time = (areaM_corr * bottemp_pert_W).sum(['xh', 'yh']) / areaM_corr.sel(yh=lat_slice_W,xh=lon_slice_W).sum(['xh', 'yh'])

bottemp_cont_R_time = (areaC_corr * bottemp_cont_R).sum(['xh', 'yh']) / areaC_corr.sel(yh=lat_slice_R,xh=lon_slice_R).sum(['xh', 'yh'])
bottemp_pert_R_time = (areaM_corr * bottemp_pert_R).sum(['xh', 'yh']) / areaM_corr.sel(yh=lat_slice_R,xh=lon_slice_R).sum(['xh', 'yh'])

bottemp_cont_A_time = (areaC_corr * bottemp_cont_A).sum(['xh', 'yh']) / areaC_corr.sel(yh=lat_slice_A,xh=lon_slice_A).sum(['xh', 'yh'])
bottemp_pert_A_time = (areaM_corr * bottemp_pert_A).sum(['xh', 'yh']) / areaM_corr.sel(yh=lat_slice_A,xh=lon_slice_A).sum(['xh', 'yh'])

bottemp_cont_P_time = (areaC_corr * bottemp_cont_P).sum(['xh', 'yh']) / areaC_corr.sel(yh=lat_slice_P,xh=lon_slice_P).sum(['xh', 'yh'])
bottemp_pert_P_time = (areaM_corr * bottemp_pert_P).sum(['xh', 'yh']) / areaM_corr.sel(yh=lat_slice_P,xh=lon_slice_P).sum(['xh', 'yh'])

# %%
# Check shape
bottemp_cont_W_time
# Out:
# <xarray.DataArray (time: 120)> Size: 960B
# dask.array<truediv, shape=(120,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     z_l       float64 8B 0.5413
#   * time      (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
#     variable  <U2 8B 'so'

# %%
bottemp_cont_W_time = bottemp_cont_W_time.load()
bottemp_pert_W_time = bottemp_pert_W_time.load()

# %%
bottemp_cont_R_time = bottemp_cont_R_time.load()
bottemp_pert_R_time = bottemp_pert_R_time.load()

# %%
bottemp_cont_A_time = bottemp_cont_A_time.load()

# %%
bottemp_pert_A_time = bottemp_pert_A_time.load()

# %%
bottemp_cont_P_time = bottemp_cont_P_time.load()
bottemp_pert_P_time = bottemp_pert_P_time.load()

# %%
fig, axes = plt.subplots(
    nrows=4, ncols=1,
    sharex=True, figsize=(10, 12)
)

# First subplot: W_time
bottemp_cont_W_time.plot(ax=axes[0], label="Control")
bottemp_pert_W_time.plot(ax=axes[0], label="Perturbation")
axes[0].set_ylabel("Bottom temp anomaly (°C)")
axes[0].legend(loc="lower left")
axes[0].set_title("Bottom Temperature Anomaly on Shelf, Weddell Sea")

# Second subplot: R_time
bottemp_cont_R_time.plot(ax=axes[1], label="Control")
bottemp_pert_R_time.plot(ax=axes[1], label="Perturbation")
axes[1].set_ylabel("Bottom temp anomaly (°C)")
axes[1].legend(loc="lower left")
axes[1].set_title("Bottom Temperature Anomaly on Shelf, Ross Sea")

# Third subplot: A_time
bottemp_cont_A_time.plot(ax=axes[2], label="Control")
bottemp_pert_A_time.plot(ax=axes[2], label="Perturbation")
axes[2].set_ylabel("Bottom temp anomaly (°C)")
axes[2].legend(loc="lower left")
axes[2].set_title("Bottom Temperature Anomaly on Shelf, Adélie Coast")

# Fourth subplot: P_time
bottemp_cont_P_time.plot(ax=axes[3], label="Control")
bottemp_pert_P_time.plot(ax=axes[3], label="Perturbation")
axes[3].set_ylabel("Bottom temp anomaly (°C)")
axes[3].legend(loc="lower left")
axes[3].set_title("Bottom Temperature Anomaly on Shelf, Prydz Bay")

# Common X‑axis label
axes[-1].set_xlabel("Time")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
bottemp_anom_W_time = bottemp_pert_W_time - bottemp_cont_W_time
bottemp_anom_W_time = bottemp_anom_W_time.load()

# %%
bottemp_anom_R_time = bottemp_pert_R_time - bottemp_cont_R_time
bottemp_anom_R_time = bottemp_anom_R_time.load()

# %%
bottemp_anom_A_time = bottemp_pert_A_time - bottemp_cont_A_time
bottemp_anom_A_time = bottemp_anom_A_time.load()

# %%
bottemp_anom_P_time = bottemp_pert_P_time - bottemp_cont_P_time
bottemp_anom_P_time = bottemp_anom_P_time.load()

# %%
bottemp_anom_W_time.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_W_pan005.nc')
bottemp_anom_R_time.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_R_pan005.nc')
bottemp_anom_A_time.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_A_pan005.nc')
bottemp_anom_P_time.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_P_pan005.nc')

# %% [markdown]
# ### All regions in one plot

# %%
bottemp_anom_W_time.plot(label="Weddell Sea")
bottemp_anom_R_time.plot(label="Ross Sea")
bottemp_anom_A_time.plot(label="Adélie Coast")
bottemp_anom_P_time.plot(label="Prydz Bay")
plt.ylabel("Bottom temperature anomaly ($^\circ$C)")
plt.legend(loc="lower left")
plt.title("Pan005 Time Series of Bottom Temperature on Shelf, AABW formation regions")
# Out:
# Text(0.5, 1.0, 'Pan005 Time Series of Bottom Temperature on Shelf, AABW formation regions')

# %% [markdown]
# ## Between model comparison

# %%
# Importing data
pan01_bottemp_W = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_W_pan01.nc', chunks = 'auto') 
pan005_bottemp_W = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_W_pan005.nc', chunks = 'auto')
acc_bottemp_W = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_W_access.nc', chunks = 'auto')

pan01_bottemp_R = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_R_pan01.nc', chunks = 'auto') 
pan005_bottemp_R = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_R_pan005.nc', chunks = 'auto')
acc_bottemp_R = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_R_access.nc', chunks = 'auto')

pan01_bottemp_A = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_A_pan01.nc', chunks = 'auto') 
pan005_bottemp_A = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_A_pan005.nc', chunks = 'auto')
acc_bottemp_A = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_A_access.nc', chunks = 'auto')

pan01_bottemp_P = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_P_pan01.nc', chunks = 'auto') 
pan005_bottemp_P = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_P_pan005.nc', chunks = 'auto')
acc_bottemp_P = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/bottemp_anom_P_access.nc', chunks = 'auto')

# %%
pan01_bottemp_W_new = pan01_bottemp_W.to_series()
pan005_bottemp_W_new = pan005_bottemp_W.to_series()
acc_bottemp_W_new = acc_bottemp_W.to_series()

pan01_bottemp_R_new = pan01_bottemp_R.to_series()
pan005_bottemp_R_new = pan005_bottemp_R.to_series()
acc_bottemp_R_new = acc_bottemp_R.to_series()

pan01_bottemp_A_new = pan01_bottemp_A.to_series()
pan005_bottemp_A_new = pan005_bottemp_A.to_series()
acc_bottemp_A_new = acc_bottemp_A.to_series()

pan01_bottemp_P_new = pan01_bottemp_P.to_series()
pan005_bottemp_P_new = pan005_bottemp_P.to_series()
acc_bottemp_P_new = acc_bottemp_P.to_series()

# %%
import pandas as pd

# %%
# Slice 1910–1919 and 2001–2010
pan01_bottemp_W_new = pan01_bottemp_W_new['2001-01-01':'2010-10-16']
pan005_bottemp_W_new = pan005_bottemp_W_new['2001-01-01':'2010-10-16']
acc_bottemp_W_new = acc_bottemp_W_new['1910-01-01':'1919-10-16']

pan01_bottemp_R_new = pan01_bottemp_R_new['2001-01-01':'2010-10-16']
pan005_bottemp_R_new = pan005_bottemp_R_new['2001-01-01':'2010-10-16']
acc_bottemp_R_new = acc_bottemp_R_new['1910-01-01':'1919-10-16']

pan01_bottemp_A_new = pan01_bottemp_A_new['2001-01-01':'2010-10-16']
pan005_bottemp_A_new = pan005_bottemp_A_new['2001-01-01':'2010-10-16']
acc_bottemp_A_new = acc_bottemp_A_new['1910-01-01':'1919-10-16']

pan01_bottemp_P_new = pan01_bottemp_P_new['2001-01-01':'2010-10-16']
pan005_bottemp_P_new = pan005_bottemp_P_new['2001-01-01':'2010-10-16']
acc_bottemp_P_new = acc_bottemp_P_new['1910-01-01':'1919-10-16']

# %%
# Reset index to normalized months
pan01_bottemp_W_new.index = range(1, len(pan01_bottemp_W_new)+1)
pan005_bottemp_W_new.index = range(1, len(pan005_bottemp_W_new)+1)
acc_bottemp_W_new.index = range(1, len(acc_bottemp_W_new)+1)

pan01_bottemp_R_new.index = range(1, len(pan01_bottemp_R_new)+1)
pan005_bottemp_R_new.index = range(1, len(pan005_bottemp_R_new)+1)
acc_bottemp_R_new.index = range(1, len(acc_bottemp_R_new)+1)

pan01_bottemp_A_new.index = range(1, len(pan01_bottemp_A_new)+1)
pan005_bottemp_A_new.index = range(1, len(pan005_bottemp_A_new)+1)
acc_bottemp_A_new.index = range(1, len(acc_bottemp_A_new)+1)

pan01_bottemp_P_new.index = range(1, len(pan01_bottemp_P_new)+1)
pan005_bottemp_P_new.index = range(1, len(pan005_bottemp_P_new)+1)
acc_bottemp_P_new.index = range(1, len(acc_bottemp_P_new)+1)

# %%
fig, axes = plt.subplots(
    nrows=4, ncols=1,
    sharex=True, figsize=(10, 12)
)

# First subplot: Weddell
pan01_bottemp_W_new.plot(ax=axes[0], label="PanAn 1/10th")
pan005_bottemp_W_new.plot(ax=axes[0], label="PanAn 1/20th")
acc_bottemp_W_new.plot(ax=axes[0], label="ACCESS-OM2")
axes[0].set_ylabel("Bottom temp anomaly (°C)")
axes[0].legend(loc="lower left")
axes[0].set_title("Bottom Temperature Anomaly on Shelf, Weddell Sea")

# Second subplot: Ross
pan01_bottemp_R_new.plot(ax=axes[1], label="PanAn 1/10th")
pan005_bottemp_R_new.plot(ax=axes[1], label="PanAn 1/20th")
acc_bottemp_R_new.plot(ax=axes[1], label="ACCESS-OM2")
axes[1].set_ylabel("Bottom temp anomaly (°C)")
axes[1].legend(loc="lower left")
axes[1].set_title("Bottom Temperature Anomaly on Shelf, Ross Sea")

# Third subplot: Adélie
pan01_bottemp_A_new.plot(ax=axes[2], label="PanAn 1/10th")
pan005_bottemp_A_new.plot(ax=axes[2], label="PanAn 1/20th")
acc_bottemp_A_new.plot(ax=axes[2], label="ACCESS-OM2")
axes[2].set_ylabel("Bottom temp anomaly (°C)")
axes[2].legend(loc="lower left")
axes[2].set_title("Bottom Temperature Anomaly on Shelf, Adélie Coast")

# Fourth subplot: Prydz
pan01_bottemp_P_new.plot(ax=axes[3], label="PanAn 1/10th")
pan005_bottemp_P_new.plot(ax=axes[3], label="PanAn 1/20th")
acc_bottemp_P_new.plot(ax=axes[3], label="ACCESS-OM2")
axes[3].set_ylabel("Bottom temp anomaly (°C)")
axes[3].legend(loc="lower left")
axes[3].set_title("Bottom Temperature Anomaly on Shelf, Prydz Bay")

# Common X‑axis label
axes[-1].set_xlabel("Time")

# Adjust layout
plt.tight_layout()
plt.show()
