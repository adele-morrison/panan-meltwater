# %% [markdown]
# # Pan01 temp transects

# %%
import dask.distributed as dsk
import glob
import intake
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import xesmf as xe

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
import logging
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:40175' processes=28 threads=28, memory=125.19 GiB>

# %%
pathsC = np.sort(glob.glob('/g/data/ik11/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/*/*.ocean_month_z.nc'))[-66:]
pathsM = np.sort(glob.glob('/g/data/g40/akm157/model_output/mom6-panan/panant-01-zstar-ssp126-MW-only/*/*.ocean_month_z.nc'))

# %%
shelf_mask = shelf_mask = xr.open_dataset('/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc')['contour_masked_above']

# %%
areaC = xr.open_dataset('/g/data/ik11/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/output050/20050501.ocean_static.nc')['areacello'].sel(xh=shelf_mask['xh'])
areaM = xr.open_dataset('/g/data/g40/akm157/model_output/mom6-panan/panant-01-zstar-ssp126-MW-only/output020/20010101.ocean_static.nc')['areacello'].sel(xh=shelf_mask['xh'])

# %%
def preprocess(ds):
    ds = ds[['thetao', 'volcello']].sel(yh=slice(-70,-59))
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
tempC = cont['thetao']
volcC = cont['volcello']
thikC = cont['volcello']/areaC

# %%
tempM = melt['thetao']
volcM = melt['volcello']
thikM = melt['volcello']/areaM

# %%
temp_135lon_C = tempC.sel(xh='45',method='nearest').mean('time')
temp_135lon_M = tempM.sel(xh='45',method='nearest').mean('time')

# %%
temp_135_anom = temp_135lon_M - temp_135lon_C

# %%
temp_135_anom.load()
# Out:
# <xarray.DataArray 'thetao' (z_l: 75, yh: 247)> Size: 74kB
# array([[       nan,        nan,        nan, ..., 0.02497   , 0.01431739,
#         0.00111914],
#        [       nan,        nan,        nan, ..., 0.02488559, 0.01418179,
#         0.00096989],
#        [       nan,        nan,        nan, ..., 0.02476341, 0.01397234,
#         0.00075424],
#        ...,
#        [       nan,        nan,        nan, ..., 0.00031781, 0.00034755,
#         0.00049525],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]], dtype=float32)
# Coordinates:
#     xh       float64 8B 45.05
#   * yh       (yh) float64 2kB -70.0 -69.96 -69.92 ... -59.14 -59.08 -59.03
#   * z_l      (z_l) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03

# %%
temp_135_anom_new = temp_135_anom.sel(z_l=slice(0,500))
temp_135_anom_new = temp_135_anom_new.load()

# %%
#Old
temp_135_anom_new.plot(cbar_kwargs={"label": "Temperature ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7})
plt.gca().invert_yaxis()
plt.title("Pan01 temperature for top 500m at 45° longitude")
# Out:
# Text(0.5, 1.0, 'Pan01 temperature for top 500m at 45° longitude')

# %%
temp_135_anom.plot(cbar_kwargs={"label": "Temperature ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7})
plt.gca().invert_yaxis()
plt.title("Pan01 temperature for top 500m at 45° longitude")
# Out:
# Text(0.5, 1.0, 'Pan01 temperature for top 500m at 45° longitude')
