# %% [markdown]
# # ACCESS Sea Ice Thickness

# %%
import glob
import dask.distributed as dsk
import xesmf as xe
from pathlib import Path
import numpy as np
import xarray as xr

import xgcm
import cf_xarray

# For plotting
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import cmocean as cm
import pyproj
import cartopy.feature as cft
import glob

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:37911' processes=28 threads=28, memory=125.19 GiB>

# %%
#Importing data

pathsC = np.sort(glob.glob('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/outpu*/ice/OUTPUT/iceh*.nc'))
pathsM = np.sort(glob.glob('/scratch/x77/jn8053/access-om2/archive/01deg_jra55v13_ryf9091_21mbath_sofia_ssp126_prsc_rest/outpu*/ice/OUTPUT/iceh*.nc'))

# %%
VARS = ['hi_m']
time_slice = slice('1910-01-01','1919-12-31')

# %%
# Time variant variables
def preprocess(ds):
    ds = ds[['hi_m']]
    
    return ds

# %%
cont = xr.open_mfdataset(
        pathsC,
        preprocess = preprocess,
        combine="by_coords",
        chunks={"time": 1},
        decode_coords=False,
        compat="override",
        data_vars="minimal",
        coords="minimal",
    )

# %%
melt = xr.open_mfdataset(
        pathsM,
        preprocess = preprocess,
        combine="by_coords",
        chunks={"time": 1},
        decode_coords=False,
        compat="override",
        data_vars="minimal",
        coords="minimal",
    )

# %%
cont = cont.sel(time=slice('1910-01-01','1919-12-31'))
melt = melt.sel(time=slice('1910-01-01','1919-12-31'))

# %%
cont
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:  (time: 120, nj: 2700, ni: 3600)
# Coordinates:
#   * time     (time) object 960B 1910-01-01 00:00:00 ... 1919-12-01 00:00:00
# Dimensions without coordinates: nj, ni
# Data variables:
#     hi_m     (time, nj, ni) float32 5GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
# Attributes:
#     title:        sea ice model output for CICE
#     contents:     Diagnostic and Prognostic Variables
#     source:       Los Alamos Sea Ice Model (CICE) Version 5
#     comment:      This Year Has 365 days
#     comment2:     File written on model date 19000201
#     comment3:     seconds elapsed into model date:      0
#     conventions:  CF-1.0
#     history:      This dataset was created on 2023-04-17 at 23:18:20.3
#     io_flavor:    io_netcdf

# %%
# data in coordinates (TLON TLAT time)
cont = cont.rename({'ni': 'xt_ocean', 'nj': 'yt_ocean'})
melt = melt.rename({'ni': 'xt_ocean', 'nj': 'yt_ocean'})

# %%
grid = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')

# %%
# Assuming 'grid' has geolon and geolat with matching dimensions to data_2
cont = cont.assign_coords(
    xt_ocean=("xt_ocean", grid.xt_ocean.values),  # along x dimension
    yt_ocean=("yt_ocean", grid.yt_ocean.values)   # along y dimension
)

melt = melt.assign_coords(
    xt_ocean=("xt_ocean", grid.xt_ocean.values),  # along x dimension
    yt_ocean=("yt_ocean", grid.yt_ocean.values)   # along y dimension
)

# %%
cont
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:   (time: 120, yt_ocean: 2700, xt_ocean: 3600)
# Coordinates:
#   * time      (time) object 960B 1910-01-01 00:00:00 ... 1919-12-01 00:00:00
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98
# Data variables:
#     hi_m      (time, yt_ocean, xt_ocean) float32 5GB dask.array<chunksize=(1, 675, 900), meta=np.ndarray>
# Attributes:
#     title:        sea ice model output for CICE
#     contents:     Diagnostic and Prognostic Variables
#     source:       Los Alamos Sea Ice Model (CICE) Version 5
#     comment:      This Year Has 365 days
#     comment2:     File written on model date 19000201
#     comment3:     seconds elapsed into model date:      0
#     conventions:  CF-1.0
#     history:      This dataset was created on 2023-04-17 at 23:18:20.3
#     io_flavor:    io_netcdf

# %% [markdown]
# # Map

# %%
sit_map_C = cont['hi_m'].sel(time=slice('1915-01-01','1919-12-31')).mean(dim='time')
sit_map_M = melt['hi_m'].sel(time=slice('1915-01-01','1919-12-31')).mean(dim='time')

# %%
sit_map_anom = sit_map_M - sit_map_C
sit_map_anom
# Out:
# <xarray.DataArray 'hi_m' (yt_ocean: 2700, xt_ocean: 3600)> Size: 39MB
# dask.array<sub, shape=(2700, 3600), dtype=float32, chunksize=(675, 900), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98

# %%
sit_map_anom = sit_map_anom.load()

# %%
sit_map_anom
# Out:
# <xarray.DataArray 'hi_m' (yt_ocean: 2700, xt_ocean: 3600)> Size: 39MB
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 22kB -81.11 -81.07 -81.02 ... 89.89 89.94 89.98

# %%
sit_map_anom.plot()

# %%
## Creating shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['ht']
land_mask = (0 * depth).fillna(1)
land = xr.where(np.isnan(depth.rename('land')), 1, np.nan)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom5')

# %% [markdown]
# # Time series

# %%
area_old = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['area_t']
var = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean.nc')['salt']
area_corr = area_old*(var.isel(time=0,st_ocean=0)*0 +1)

# %%
area_corr.plot()

# %%
cont_shelf = cont['hi_m'].where(shelf_mask == 1)
melt_shelf = melt['hi_m'].where(shelf_mask == 1)

# %%
cont_shelf = cont_shelf.drop_vars(['geolon_t','geolat_t'])
melt_shelf = melt_shelf.drop_vars(['geolon_t','geolat_t'])

# %%
cont_shelf
# Out:
# <xarray.DataArray 'hi_m' (time: 120, yt_ocean: 510, xt_ocean: 3600)> Size: 881MB
# dask.array<where, shape=(120, 510, 3600), dtype=float32, chunksize=(1, 510, 900), chunktype=numpy.ndarray>
# Coordinates:
#   * time      (time) object 960B 1910-01-01 00:00:00 ... 1919-12-01 00:00:00
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
# Attributes:
#     units:          m
#     long_name:      grid cell mean ice thickness
#     coordinates:    TLON TLAT time
#     cell_measures:  area: tarea
#     cell_methods:   time: mean
#     time_rep:       averaged

# %%
cont_shelf.isel(time=0).plot()

# %%
# Spatial average
sit_time_C = (area_corr * cont_shelf).sum(['xt_ocean', 'yt_ocean']) / area_corr.where(shelf_mask == 1).sum(['xt_ocean', 'yt_ocean'])
sit_time_M = (area_corr * melt_shelf).sum(['xt_ocean', 'yt_ocean']) / area_corr.where(shelf_mask == 1).sum(['xt_ocean', 'yt_ocean'])

# %%
sit_time_C
# Out:
# <xarray.DataArray (time: 120)> Size: 480B
# dask.array<truediv, shape=(120,), dtype=float32, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     st_ocean  float64 8B 0.5413
#   * time      (time) object 960B 1910-01-01 00:00:00 ... 1919-12-01 00:00:00

# %%
sit_time_C.plot(label = 'Control')
sit_time_M.plot(label = 'Perturbation')

plt.legend(loc='lower right')
plt.ylabel('Sea Ice Thickness (m)');
plt.title('Sea Ice Thickness Pan01 prescribed')
# Out:
# Text(0.5, 1.0, 'Sea Ice Thickness Pan01 prescribed')

# %%
sit_time_C.groupby('time.month').mean('time').plot(label='Control')
sit_time_M.groupby('time.month').mean('time').plot(label='Perturbation')

plt.legend()
plt.ylabel('Sea Ice Thickness (m)')
# Out:
# Text(0, 0.5, 'Sea Ice Thickness (m)')

# %%
seasonal_anom = (sit_time_M.groupby('time.month').mean('time') - sit_time_C.groupby('time.month').mean('time'))
seasonal_anom.plot()

plt.ylabel('Sea Ice Thickness Anomaly (m)')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
# Save data
sit_map_C.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_map_cont_prescribed_ACCESS.nc')
sit_map_M.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_map_melt_prescribed_ACCESS.nc')
sit_map_anom.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_map_anom_prescribed_ACCESS.nc')

seasonal_anom.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_seasonal_time_anom_prescribed_ACCESS.nc')
