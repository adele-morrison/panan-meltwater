# %% [markdown]
# # Pan005 Sea Ice Thickness

# %%
import glob
import dask.distributed as dsk
import xesmf as xe
from pathlib import Path
import numpy as np
import xarray as xr

import xgcm
import cf_xarray

# For plotting
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import cmocean as cm
import pyproj
import cartopy.feature as cft
import glob

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:45025' processes=28 threads=28, memory=125.19 GiB>

# %%
# Importing data
pathsC = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/outpu*/*.ice_month.nc'))[120:]
pathsM = np.sort(glob.glob('/g/data/g40/akm157/model_output/mom6-panan/panant-005-zstar-ssp126-MW-only/outpu*/*.ice_month.nc'))[:60]

# %%
# Time variant variables
def preprocess(ds):
    ds = ds['sithick']
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
cont = cont.sel(time=slice('2001-01-01','2010-12-31'))
melt = melt.sel(time=slice('2001-01-01','2010-12-31'))

# %%
cont = cont.rename({'xT': 'xh', 'yT': 'yh'})
melt = melt.rename({'xT': 'xh', 'yT': 'yh'})

# %%
cont
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:  (time: 120, yh: 1690, xh: 7200)
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 14kB -81.1 -81.08 -81.06 ... -37.16 -37.12 -37.08
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
# Data variables:
#     sithick  (time, yh, xh) float32 6GB dask.array<chunksize=(1, 1690, 7200), meta=np.ndarray>

# %% [markdown]
# # Map

# %%
sit_map_C = cont['sithick'].sel(time=slice('2006-01-01','2010-12-31')).mean(dim='time')
sit_map_M = melt['sithick'].sel(time=slice('2006-01-01','2010-12-31')).mean(dim='time')

# %%
sit_map_anom = sit_map_M - sit_map_C
sit_map_anom
# Out:
# <xarray.DataArray 'sithick' (yh: 1690, xh: 7200)> Size: 49MB
# dask.array<sub, shape=(1690, 7200), dtype=float32, chunksize=(1690, 7200), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 14kB -81.1 -81.08 -81.06 ... -37.16 -37.12 -37.08

# %%
sit_map_anom = sit_map_anom.load()

# %%
## Creating shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output030/19930701.ocean_static.nc')['deptho']
land_mask = (0 * depth).fillna(1)
land = xr.where(np.isnan(depth.rename('land')), 1, np.nan)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_005')

# %%
projection = ccrs.SouthPolarStereo()
    
plt.figure(figsize=(7, 8))
ax = plt.axes(projection=projection)
ax.set_extent([-280, 80, -80, -50], crs=ccrs.PlateCarree())
    
# Circular boundary
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5,0.495], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# Filled land 
land.plot.contourf(ax=ax, colors='white',
                   zorder=2,
                   transform=ccrs.PlateCarree(),
                   add_colorbar=False)

# Coast line
ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
# Shelf contour
ax.contour(shelf_mask.cf['X'], shelf_mask.cf['Y'], shelf_mask,
           levels = [0, 1], colors = 'k', linewidths=0.5,transform = ccrs.PlateCarree())

# Adding polar axes
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, 
                    xlocs=range(-180,171,60), ylocs=[], 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=False, linewidth=1, 
                    xlocs=[], ylocs=(-80,-70,-55), 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)

sit_map_anom.plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    vmin=-0.06,
    vmax=0.06,
    extend="both",
    cmap=cm.cm.balance, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Sea Ice Thickness Anomaly (m)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("PanAntarctic 1/20th Sea Ice Thickness anomaly");

# %% [markdown]
# # Time series

# %%
area_old = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output030/19930701.ocean_static.nc')['areacello']
var = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output030/19930701.ocean_month_z.nc')['so']
area_corr = area_old*(var.isel(time=0,z_l=0)*0 +1)

# %%
cont_shelf = cont['sithick'].where(shelf_mask == 1)
melt_shelf = melt['sithick'].where(shelf_mask == 1)

# %%
cont_shelf.isel(time=0).plot()

# %%
# Spatial average
sit_time_C = (area_corr * cont_shelf).sum(['xh', 'yh']) / area_corr.where(shelf_mask == 1).sum(['xh', 'yh'])
sit_time_M = (area_corr * melt_shelf).sum(['xh', 'yh']) / area_corr.where(shelf_mask == 1).sum(['xh', 'yh'])

# %%
sit_time_C
# Out:
# <xarray.DataArray (time: 120)> Size: 480B
# dask.array<truediv, shape=(120,), dtype=float32, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     z_l      float64 8B 0.5413
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00

# %%
sit_time_C
# Out:
# <xarray.DataArray (time: 120)> Size: 480B
# dask.array<truediv, shape=(120,), dtype=float32, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#     z_l      float64 8B 0.5413
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00

# %%
sit_time_C.plot(label = 'Control')
sit_time_M.plot(label = 'Perturbation')

plt.legend(loc='lower right')
plt.ylabel('Sea Ice Thickness (UNITS?)');
plt.title('Sea Ice Thickness 0.05')
# Out:
# Text(0.5, 1.0, 'Sea Ice Thickness 0.05')

# %%
sit_time_C.groupby('time.month').mean('time').plot(label='Control')
sit_time_M.groupby('time.month').mean('time').plot(label='Perturbation')

plt.legend()
plt.ylabel('Sea Ice Thickness (m)')
# Out:
# Text(0, 0.5, 'Sea Ice Thickness (m)')

# %%
seasonal_anom = (sit_time_M.groupby('time.month').mean('time') - sit_time_C.groupby('time.month').mean('time'))
seasonal_anom.plot()

plt.ylabel('Sea Ice Thickness Anomaly (m)')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
# Save data
sit_map_C.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_map_cont_Pan005.nc')
sit_map_M.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_map_melt_Pan005.nc')
sit_map_anom.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_map_anom_Pan005.nc')

# %%
seasonal_anom.to_netcdf('/g/data/g40/kc5856/thesis_figures/data_files/ice_thickness_seasonal_time_anom_Pan005.nc')
