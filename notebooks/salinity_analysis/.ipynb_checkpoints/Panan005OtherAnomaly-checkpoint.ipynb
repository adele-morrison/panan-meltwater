# %%
import intake

import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

# %%
pancontrol005 = intake.open_esm_datastore('/home/272/kc5856/catalog_dir/panant_005_zstar_access_yr2.json', columns_with_iterables=['variable'])
pantrial005 = intake.open_esm_datastore('/home/272/kc5856/panantrial/panant_005_zstar_MWonly.json', columns_with_iterables=['variable'])

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:39319' processes=28 threads=28, memory=125.19 GiB>

# %%
#Time variant variables #ASK HOW TO CONDENSE
control_WFO = pancontrol005.search(variable="wfo", frequency="1mon").to_dask()
trial_WFO = pantrial005.search(variable="wfo", frequency="1mon").to_dask()
control_TOB = pancontrol005.search(variable="tob", frequency="1mon").to_dask()
trial_TOB = pantrial005.search(variable="tob", frequency="1mon").to_dask()
control_temp = pancontrol005.search(variable=["thetao"],frequency="1mon",file_id=["XXXXXXXX_ocean_month_z"]).to_dask()
trial_temp = pantrial005.search(variable="thetao", frequency="1mon").to_dask()

# %%
#Area weighting
data_fixed = pancontrol005.search(variable=["areacello","deptho"],path=".*output021.*").to_dask()

# %%
areacello = data_fixed.areacello
control_TOB = control_TOB.assign_coords({"areacello": areacello})
trial_TOB = trial_TOB.assign_coords({"areacello": areacello})
control_temp = control_temp.assign_coords({"areacello": areacello})
trial_temp = trial_temp.assign_coords({"areacello": areacello})
control_WFO = control_WFO.assign_coords({"areacello": areacello})
trial_WFO = trial_WFO.assign_coords({"areacello": areacello})

# %%
TOBpert = trial_TOB.tob.sel(time=slice('2001-01','2010-01')).mean(dim='time')
TOBcont = control_TOB.tob.sel(time=slice('2001-01','2010-01')).mean(dim='time')
TOBanom = TOBpert - TOBcont

# %%
#Last years 
TOBpert_end = trial_TOB.tob.sel(time=slice('2007-01','2010-01')).mean(dim='time')
TOBcont_end = control_TOB.tob.sel(time=slice('2007-01','2010-01')).mean(dim='time')
TOBanom_end = TOBpert_end - TOBcont_end

# %%
#Last years 
temppert_end = trial_temp.thetao.sel(time=slice('2007-01','2010-01')).mean(dim='time')
tempcont_end = control_temp.thetao.sel(time=slice('2007-01','2010-01')).mean(dim='time')
tempanom_end = temppert_end - tempcont_end

# %%
land_50m = cft.NaturalEarthFeature("physical", "land", "50m", edgecolor="black", facecolor="papayawhip", linewidth=0.5)
projection = ccrs.SouthPolarStereo()

# %%
def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = data_fixed.deptho
land_mask = (depth*0).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_005')

# %%
TOBanom_end = TOBanom_end.load()

# %%
tempanom_end = tempanom_end.load()

# %%
plt.figure(figsize=(16, 14))
ax = plt.axes(projection=projection)

ax.set_extent([-280, 80, -80, -35], crs=ccrs.PlateCarree())

# Compute a circle in axes coordinates, which we can use as a boundary for the map. 
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5, 0.5], 0.30
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
ax.contour(shelf_mask.cf['X'], shelf_mask.cf['Y'], shelf_mask,
           levels = [0, 1], colors = 'black', linewidths=0.5,transform = ccrs.PlateCarree())

tempanom_end.plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    vmin=-0.4,
    vmax=0.4,
    extend="both",
    cmap=cm.cm.balance, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Temperature ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("Panan005 Depth-Averaged Temperature 2007-2010");

# %%
plt.figure(figsize=(16, 14))
ax = plt.axes(projection=projection)

ax.set_extent([-280, 80, -80, -35], crs=ccrs.PlateCarree())

# Compute a circle in axes coordinates, which we can use as a boundary for the map. 
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5, 0.5], 0.30
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
ax.contour(shelf_mask.cf['X'], shelf_mask.cf['Y'], shelf_mask,
           levels = [0, 1], colors = 'black', linewidths=0.5,transform = ccrs.PlateCarree())

TOBanom_end.plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    vmin=-0.4,
    vmax=0.4,
    extend="both",
    cmap=cm.cm.balance, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Temperature ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("Panan005 Temperature at Ocean Bottom 2007-2010");

# %%
plt.figure(figsize=(8, 7))
ax = plt.axes(projection=projection)

ax.set_extent([-280, 80, -80, -35], crs=ccrs.PlateCarree())

# Compute a circle in axes coordinates, which we can use as a boundary for the map. 
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5, 0.5], 0.35
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
ax.contour(shelf_mask.cf['X'], shelf_mask.cf['Y'], shelf_mask,
           levels = [0, 1], colors = 'black', linewidths=0.5,transform = ccrs.PlateCarree())

TOBanom.plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    vmin=-0.4,
    vmax=0.4,
    extend="both",
    cmap=cm.cm.balance, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Temperature ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("Panan005 Temperature at Ocean Bottom");
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 15.19 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %% [markdown]
# ### Time series plots

# %%
tempcont_top_time = control_temp.thetao.isel(z_l=0).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
tempcont_mid_time = control_temp.thetao.sel(z_l='500', method='nearest').sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
tempcont_bot_time = control_TOB.tob.sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))

temppert_top_time = trial_temp.thetao.isel(z_l=0).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
temppert_mid_time = trial_temp.thetao.sel(z_l='500', method='nearest').sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
temppert_bot_time = trial_TOB.tob.sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))

# %%
tempanom_top_time = temppert_top_time - tempcont_top_time
tempanom_mid_time = temppert_mid_time - tempcont_mid_time
tempanom_bot_time = temppert_bot_time - tempcont_bot_time

# %%
tempcont_top_time.plot(label="Control")
temppert_top_time.plot(label="Perturbation")
plt.legend(loc="lower left")
plt.title("Time Series of Temperature at Ocean Surface")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 50.59 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 50.54 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Text(0.5, 1.0, 'Time Series of Temperature at Ocean Surface')

# %%
tempcont_mid_time.plot(label="Control")
temppert_mid_time.plot(label="Perturbation")
plt.legend(loc="lower left")
plt.title("Time Series of Temperature at 500 m Depth")
# Out:
# Text(0.5, 1.0, 'Time Series of Temperature at 500 m Depth')

# %%
tempcont_bot_time.plot(label="Control")
temppert_bot_time.plot(label="Perturbation")
plt.legend(loc="lower left")
plt.title("Time Series of Temperature at Ocean Floor")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 12.66 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 12.60 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Text(0.5, 1.0, 'Time Series of Temperature at Ocean Floor')

# %%
tempcont_top_shelf = control_temp.thetao.isel(z_l=0).where(shelf_mask == 1).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
tempcont_mid_shelf = control_temp.thetao.sel(z_l='500', method='nearest').where(shelf_mask == 1).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
tempcont_bot_shelf = control_TOB.tob.where(shelf_mask == 1).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))

temppert_top_shelf = trial_temp.thetao.isel(z_l=0).where(shelf_mask == 1).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
temppert_mid_shelf = trial_temp.thetao.sel(z_l='500', method='nearest').where(shelf_mask == 1).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))
temppert_bot_shelf = trial_TOB.tob.where(shelf_mask == 1).sel(time=slice('2001-01','2010-01')).weighted(areacello.fillna(0)).mean(dim=('xh','yh'))

tempanom_top_shelf = temppert_top_shelf - tempcont_top_shelf
tempanom_mid_shelf = temppert_mid_shelf - tempcont_mid_shelf
tempanom_bot_shelf = temppert_bot_shelf - tempcont_bot_shelf

# %%
tempcont_top_shelf.plot(label="Control")
temppert_top_shelf.plot(label="Perturbation")
plt.legend(loc="lower left")
plt.title("Time Series of Shelf Temperature at Ocean Surface")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 57.18 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 57.12 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Text(0.5, 1.0, 'Time Series of Shelf Temperature at Ocean Surface')

# %%
tempcont_mid_shelf.plot(label="Control")
temppert_mid_shelf.plot(label="Perturbation")
plt.legend(loc="lower left")
plt.title("Time Series of Shelf Temperature at 500 m Depth")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 57.18 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 57.12 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Text(0.5, 1.0, 'Time Series of Shelf Temperature at 500 m Depth')

# %%
tempcont_bot_shelf.plot(label="Control")
temppert_bot_shelf.plot(label="Perturbation")
plt.legend(loc="upper left")
plt.title("Time Series of Shelf Temperature at Ocean Floor")
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 20.89 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2025-02-25 20:21:00,136 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.11 GiB -- Worker memory limit: 4.47 GiB
# 2025-02-25 20:21:10,209 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# ...

# %%
WFOpert = trial_WFO.wfo.sel(time=slice('2001-01','2010-01')).mean(dim='time')
WFOcont = control_WFO.wfo.sel(time=slice('2001-01','2010-01')).mean(dim='time')
WFOanom = WFOpert - WFOcont

# %%
plt.figure(figsize=(18, 5))
WFOanom.plot()
plt.ylim(-80,-65)
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/distributed/client.py:3357: UserWarning: Sending large graph of size 14.38 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# (-80.0, -65.0)

# %%
WFOanom = WFOanom.compute()

# %%
plt.figure(figsize=(7, 8))
WFOanom.plot()
plt.ylim(-70,-69)
plt.xlim(-73,-71)
# Out:
# (-73.0, -71.0)

# %%
plt.figure(figsize=(7, 8))
WFOanom.plot()
plt.ylim(-76,-72)
plt.xlim(-130,-120)
# Out:
# (-130.0, -120.0)
