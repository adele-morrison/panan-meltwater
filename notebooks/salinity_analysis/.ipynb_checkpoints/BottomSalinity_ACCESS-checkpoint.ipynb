# %% [markdown]
# # ACCESS salinity

# %%
import intake
import glob
import dask.distributed as dsk
import matplotlib.pyplot as plt
import xarray as xr
import cf_xarray as cfxr
import numpy as np
import xesmf as xe

import cmocean as cm
import cartopy.crs as ccrs

import cartopy.feature as cft
import matplotlib.path as mpath

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
import logging
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
from dask.distributed import Client
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:46259' processes=28 threads=28, memory=125.19 GiB>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846431' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847683' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848136' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845461' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847613' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845500' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846293' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845950' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846401' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847196' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847652' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848451' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845430' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848559' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845881' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848036' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845812' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845470' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846261' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846714' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847512' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847166' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848419' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845851' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847096' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847551' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846576' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846231' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846684' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848283' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847936' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845263' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848389' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845713' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845370' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846960' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846614' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847066' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847868' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847520' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848320' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845645' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845301' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846096' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846998' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847800' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847452' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848254' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847907' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845233' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846029' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845683' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846134' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846931' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846584' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845166' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848292' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845616' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846067' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846517' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847316' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845098' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848224' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845548' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846450' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847355' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848156' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846381' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846832' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847286' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848086' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847741' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848539' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845969' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846870' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848470' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845107' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845900' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847146' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847256' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845380' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848508' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845831' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845489' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846733' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847531' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847185' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847987' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847641' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848439' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-848094' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845418' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-845870' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846663' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-846321' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-847115' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# ...
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981788' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981775' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981802' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981790' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981777' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981804' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981789' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981778' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981803' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981791' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981780' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981805' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981793' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981779' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981806' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981792' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981781' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981808' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981794' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981783' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981807' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981795' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981782' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981809' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981797' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981784' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981810' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981796' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981785' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981812' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981798' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-981787' coro=<Client._gather.<locals>.wait() done, defined at /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py:2394> exception=AllExit()>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/distributed/client.py", line 2403, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
#Importing data

pathsC = np.sort(glob.glob('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/outpu*/ocean/ocean.nc'))
pathsM = np.sort(glob.glob('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath_sofia_ssp126/*/ocean/ocean.nc'))

# %%
## Creating shelf mask another way

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['ht']
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom5')

# %%
#Time variant variables
def preprocess(ds):
    ds = ds[['salt', 'st_ocean','dzt']].sel(yt_ocean=shelf_mask['yt_ocean'])
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
#Time slicing
cont = cont.sel(time=slice('1910-01-01','1919-12-31'))
melt = melt.sel(time=slice('1910-01-01','1919-12-31'))

# %%
#Time invariant variables
areaC = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')['area_t'].sel(xt_ocean=shelf_mask['xt_ocean'])
areaM = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath_sofia_ssp126/output040/ocean/ocean_grid.nc')['area_t'].sel(xt_ocean=shelf_mask['xt_ocean'])

# %%
# Salinity variable
saltC = cont['salt']
saltM = melt['salt']

# %%
# Correcting area
areaC_corr = areaC*saltC.isel(time=0,st_ocean=0)*0 +1
areaM_corr = areaM*saltM.isel(time=0,st_ocean=0)*0 +1

# %%
areaC_corr
# Out:
# <xarray.DataArray (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
# dask.array<add, shape=(510, 3600), dtype=float32, chunksize=(270, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     geolon_t  (yt_ocean, xt_ocean) float32 7MB ...
#     geolat_t  (yt_ocean, xt_ocean) float32 7MB ...
#     st_ocean  float64 8B 0.5413
#     time      object 8B 1910-01-16 12:00:00

# %% [markdown]
# ## Bottom salinity

# %%
bottom_mask_saltC = saltC.where(~np.isfinite(saltC.shift({'st_ocean': -1})))
bottom_mask_saltC = ~np.isnan(bottom_mask_saltC)

# %%
bottom_mask_saltM = saltM.where(~np.isfinite(saltM.shift({'st_ocean': -1})))
bottom_mask_saltM = ~np.isnan(bottom_mask_saltM)

# %%
botsalt_cont = saltC.where(bottom_mask_saltC).sum(dim='st_ocean')
botsalt_pert = saltM.where(bottom_mask_saltM).sum(dim='st_ocean')

# %% [markdown]
# ### Time series

# %%
# Restrict to shelf
botsalt_cont_shelf = botsalt_cont.where(shelf_mask == 0)
botsalt_pert_shelf = botsalt_pert.where(shelf_mask == 0)

# %%
# Spatial average
botsalt_cont_time = (areaC_corr * botsalt_cont_shelf).sum(['xt_ocean', 'yt_ocean']) / areaC_corr.sum(['xt_ocean', 'yt_ocean'])
botsalt_pert_time = (areaM_corr * botsalt_pert_shelf).sum(['xt_ocean', 'yt_ocean']) / areaM_corr.sum(['xt_ocean', 'yt_ocean'])

# %%
botsalt_cont_time
# Out:
# <xarray.DataArray (time: 120)> Size: 480B
# dask.array<truediv, shape=(120,), dtype=float32, chunksize=(2,), chunktype=numpy.ndarray>
# Coordinates:
#     st_ocean  float64 8B 0.5413
#   * time      (time) object 960B 1910-01-16 12:00:00 ... 1919-12-16 12:00:00

# %%
botsalt_cont_time = botsalt_cont_time.load()
botsalt_pert_time = botsalt_pert_time.load()

# %%
botsalt_cont_time.plot(label="Control")
botsalt_pert_time.plot(label="Perturbation")
#plt.xlim(380,4000)
#plt.ylim(-1.30,-0.70)
plt.ylabel("Practical Salinity (psu)")
plt.legend(loc="lower left")
plt.title("ACCESS Time Series of Bottom Salinity on Shelf")
# Out:
# Text(0.5, 1.0, 'ACCESS Time Series of Bottom Salinity on Shelf')

# %%
botsalt_anom = botsalt_pert_time - botsalt_cont_time
botsalt_anom = botsalt_anom.load()

# %%
botsalt_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/botsalt_anom_access.nc')

# %% [markdown]
# #### Mapping bottom salinity

# %%
saltC_map = saltC.sel(time=slice('1915-01-01','1919-12-31'))
saltM_map = saltM.sel(time=slice('1915-01-01','1919-12-31'))

# %%
botsalt_cont_map = saltC_map.where(bottom_mask_saltC).sum(dim='st_ocean').mean(dim='time')
botsalt_pert_map = saltM_map.where(bottom_mask_saltM).sum(dim='st_ocean').mean(dim='time')
botsalt_anom_map = botsalt_pert_map - botsalt_cont_map

# %%
botsalt_anom_map = botsalt_anom_map.load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 botsalt_anom_map = botsalt_anom_map.load()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/xarray/core/dataarray.py:1183, in DataArray.load(self, **kwargs)
#    1163 def load(self, **kwargs) -> Self:
#    1164     """Manually trigger loading of this array's data from disk or a
#    1165     remote source into memory and return this array.
#    1166
#    (...)
#    1181     dask.compute
#    1182     """
# -> 1183     ds = self._to_temp_dataset().load(**kwargs)
#    1184     new = self._from_temp_dataset(ds)
#    1185     self._variable = new._variable
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/xarray/core/dataset.py:541, in Dataset.load(self, **kwargs)
#     538 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     540 # evaluate all the chunked arrays simultaneously
# --> 541 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     542     *lazy_data.values(), **kwargs
#     543 )
#     545 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     546     self.variables[k].data = data
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/site-packages/dask/base.py:656, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     653     postcomputes.append(x.__dask_postcompute__())
#     655 with shorten_traceback():
# --> 656     results = schedule(dsk, keys, **kwargs)
#     658 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.04/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
land_mask = (0 * depth).fillna(1)
land = xr.where(np.isnan(depth.rename('land')), 1, np.nan)
projection = ccrs.SouthPolarStereo()

# %%
projection = ccrs.SouthPolarStereo()
    
plt.figure(figsize=(7, 8))
ax = plt.axes(projection=projection)
ax.set_extent([-280, 80, -80, -59], crs=ccrs.PlateCarree())
    
# Circular boundary
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5,0.495], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# Filled land 
land.plot.contourf(ax=ax, colors='white',
                   zorder=2,
                   transform=ccrs.PlateCarree(),
                   add_colorbar=False)

# Coast line
ax.contour(land_mask.cf['X'], land_mask.cf['Y'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
# Shelf contour
ax.contour(shelf_mask.cf['X'], shelf_mask.cf['Y'], shelf_mask,
           levels = [0, 1], colors = 'k', linewidths=0.5,transform = ccrs.PlateCarree())

# Adding polar axes
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, 
                    xlocs=range(-180,171,60), ylocs=[], 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=False, linewidth=1, 
                    xlocs=[], ylocs=(-80,-70,-55), 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)

botsalt_anom_map.plot(
    x="xt_ocean",
    y="yt_ocean",
    transform=ccrs.PlateCarree(),
    vmin=-0.06,
    vmax=0.06,
    extend="both",
    cmap=cm.cm.balance, #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Bottom salinity anomaly (psu)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("ACCESS-OM2 bottom salinity anomaly");
