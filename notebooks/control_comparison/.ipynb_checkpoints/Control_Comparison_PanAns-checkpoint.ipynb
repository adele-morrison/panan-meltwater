# %% [markdown]
# # Comparing PanAntarctic controls

# %%
import intake
from pathlib import Path
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import xarray as xr
import glob

xr.set_options(keep_attrs=True)

import cf_xarray as cfxr
from dask.distributed import Client
import xesmf

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:45421' processes=28 threads=28, memory=125.19 GiB>
# 2025-08-15 11:31:40,361 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34979' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-tob-original-concatenate-90f5e8b596485a8127a313a6de0e176d', 76, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 99, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221500.3470564')
# 2025-08-15 11:31:40,821 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:43,084 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:53,903 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43363' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 75, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 79, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221513.903674')
# 2025-08-15 11:31:54,067 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44167' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 111, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 89, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.0668921')
# 2025-08-15 11:31:54,069 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43349' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 82, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 114, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 83, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 104, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 115, 0, 0), ('concatenate-7957ced775047d669dd375624bf01fff', 36, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 106, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 116, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.0690858')
# 2025-08-15 11:31:54,071 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38945' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 94, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 117, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 95, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 116, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 106, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 107, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.0709827')
# 2025-08-15 11:31:54,073 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35161' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 74, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 71, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.0729506')
# 2025-08-15 11:31:54,074 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37883' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 60, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 69, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 100, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 101, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 98, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 82, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 74, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 83, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 61, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 99, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 80, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 81, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 85, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 84, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 75, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.0744517')
# 2025-08-15 11:31:54,097 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,124 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45655' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 73, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 90, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 118, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 119, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.1241152')
# 2025-08-15 11:31:54,186 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,220 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,245 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,272 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,420 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,516 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:54,585 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36689' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 84, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 100, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221514.5852866')
# 2025-08-15 11:31:55,015 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39715' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 105, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 119, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221515.014993')
# 2025-08-15 11:31:56,372 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33843' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 77, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 76, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 62, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.3724217')
# 2025-08-15 11:31:56,374 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45485' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 114, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 72, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 64, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 115, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.3745708')
# 2025-08-15 11:31:56,378 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45683' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 78, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 113, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.3786545')
# 2025-08-15 11:31:56,422 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42175' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 103, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 87, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.4227674')
# 2025-08-15 11:31:56,441 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42471' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 95, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 108, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 96, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 90, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 80, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 97, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 94, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 91, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.44128')
# 2025-08-15 11:31:56,442 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35373' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 63, 0, 0), ('concatenate-7957ced775047d669dd375624bf01fff', 32, 0, 0), ('concatenate-7957ced775047d669dd375624bf01fff', 35, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.4424932')
# 2025-08-15 11:31:56,443 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38947' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 86, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 107, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.4434595')
# 2025-08-15 11:31:56,444 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38267' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 109, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 91, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221516.4443388')
# 2025-08-15 11:31:57,598 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:57,660 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33629' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 109, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 108, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 60, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 97, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221517.660155')
# 2025-08-15 11:31:57,746 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38743' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 87, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 86, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 66, 0, 0), ('concatenate-7957ced775047d669dd375624bf01fff', 34, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221517.7461133')
# 2025-08-15 11:31:57,748 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41947' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 78, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 113, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 98, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 96, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 102, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 112, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 79, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 103, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221517.7479804')
# 2025-08-15 11:31:57,749 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39251' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 88, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 110, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221517.7495127')
# 2025-08-15 11:31:57,750 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44675' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 118, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 117, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 112, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 81, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 102, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 85, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221517.7505326')
# 2025-08-15 11:31:57,751 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42315' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 77, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 101, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221517.751664')
# 2025-08-15 11:31:58,658 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44955' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-7957ced775047d669dd375624bf01fff', 31, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 68, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221518.6579497')
# 2025-08-15 11:31:58,659 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34943' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 67, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 93, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221518.6591587')
# 2025-08-15 11:31:58,660 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38357' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 110, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 111, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 92, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 89, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 105, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 104, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 61, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 93, 0, 0), ('concatenate-90f5e8b596485a8127a313a6de0e176d', 65, 0, 0), ('rechunk-merge-1ac8d4c4008fc9e23c29267739b66a75', 88, 0, 0)} (stimulus_id='handle-worker-cleanup-1755221518.6600566')
# 2025-08-15 11:31:58,873 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:31:58,939 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45641' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-90f5e8b596485a8127a313a6de0e176d', 92, 0, 0), 'original-array-ca996c624b1d56367569e9a5546acfc2', ('concatenate-7957ced775047d669dd375624bf01fff', 33, 0, 0), 'shuffle-taker-bcf4821910da95cec51538ad60ebbcab'} (stimulus_id='handle-worker-cleanup-1755221518.9395058')
# 2025-08-15 11:31:59,745 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:01,638 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:01,768 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:01,820 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:01,885 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:01,957 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:02,087 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:02,160 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:02,264 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:03,072 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:04,232 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:04,328 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:04,400 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:04,497 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:04,615 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:05,833 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:05,974 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:06,087 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:07,676 - distributed.nanny - WARNING - Restarting worker
# 2025-08-15 11:32:23,991 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:32,537 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,547 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,690 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,691 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,692 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,693 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,813 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,900 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:33,901 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:34,205 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:35,208 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:35,208 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:35,209 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:35,210 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:35,211 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-15 11:32:36,971 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing

# %% [markdown]
# ## Importing the data

# %%
paths01 = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/*/*.ocean_month.nc'))[24:]
paths005 = np.sort(glob.glob('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/outpu*/*.ocean_month.nc'))[120:]

# %%
path_to_ocean_static_01 = Path('/g/data/ol01/outputs/mom6-panan/panant-01-zstar-ACCESSyr2/output021/20000701.ocean_static.nc')
path_to_ocean_static_005 = Path('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output030/19930701.ocean_static.nc')

# %%
grid010 = xr.open_dataset(path_to_ocean_static_01)
grid005 = xr.open_dataset(path_to_ocean_static_005)

# %%
xh_005 = grid005.xh.values
xh_01  = grid010.xh.values
yh_005 = grid005.yh.values
yh_01  = grid010.yh.values

# Take every 2nd point from 0.05° grid
xh_005_sub = xh_005[::2]
yh_005_sub = yh_005[::2]

# Compare — allow for small floating point differences
xh_match = np.allclose(xh_01, xh_005_sub, atol=1e-10)
yh_match = np.allclose(yh_01, yh_005_sub, atol=1e-10)

print("Longitudes match:", xh_match)
print("Latitudes match:", yh_match)
# Out:
# Longitudes match: False
# Latitudes match: False

# %%
print("Δlat 0.05° grid:", np.diff(xh_005).mean())
print("Δlat 0.1° grid:", np.diff(xh_01).mean())
print("Δlon 0.05° grid:", np.diff(yh_005).mean())
print("Δlon 0.1° grid:", np.diff(yh_01).mean())
# Out:
# Δlat 0.05° grid: 0.04999999999999982
# Δlat 0.1° grid: 0.09999999999999858
# Δlon 0.05° grid: 0.026062747978938372
# Δlon 0.1° grid: 0.05209801050148874

# %% [markdown]
# This means that the 1/10th isn't just every second grid point on the 1/20th.

# %% [markdown]
# ## Load some raw data

# %%
# Time variant variables
def preprocess(ds):
    ds = ds[['sob','tob']]
    return ds

deg010 = xr.open_mfdataset(paths01, preprocess = preprocess, chunks = 'auto')
deg005 = xr.open_mfdataset(paths005, preprocess = preprocess, chunks = 'auto')

# %%
salt_01 = deg010['sob']
salt_005 = deg005['sob']

# %%
temp_01 = deg010['tob']
temp_005 = deg005['tob']

# %% [markdown]
# ## Regridding

# %%
# Working copy of the variables I am using
var_005_clean = salt_005
grid010_clean = grid010

# %%
# %%time

# If lon/lat don't exist yet, build them from xh, yh
if "xh" in var_005_clean.coords and "yh" in var_005_clean.coords:
    lon2d, lat2d = np.meshgrid(var_005_clean["xh"].values,
                                var_005_clean["yh"].values)
    var_005_clean = var_005_clean.assign_coords(
        lon=(["yh", "xh"], lon2d),
        lat=(["yh", "xh"], lat2d)
    )

if "xh" in grid010_clean.coords and "yh" in grid010_clean.coords:
    lon2d, lat2d = np.meshgrid(grid010_clean["xh"].values,
                                grid010_clean["yh"].values)
    grid010_clean = grid010_clean.assign_coords(
        lon=(["yh", "xh"], lon2d),
        lat=(["yh", "xh"], lat2d)
    )

# Create regridder
regridder_005_to_01deg = xesmf.Regridder(
    var_005_clean,
    grid010_clean,
    method="bilinear",
    periodic=True,
    filename="bilinear_weights_005_to_01deg.nc",
    reuse_weights=True #true bc its already run
)
# Out:
# CPU times: user 2.5 s, sys: 2.09 s, total: 4.58 s
# Wall time: 7.43 s

# %%
salt_005_regridded = regridder_005_to_01deg(salt_005).drop_vars(["lon", "lat"])
temp_005_regridded = regridder_005_to_01deg(temp_005).drop_vars(["lon", "lat"])
temp_005_regridded
# Out:
# <xarray.DataArray (time: 120, yh: 845, xh: 3600)> Size: 1GB
# dask.array<astype, shape=(120, 845, 3600), dtype=float32, chunksize=(1, 845, 3600), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
#   * xh       (xh) float64 29kB -279.9 -279.8 -279.7 -279.6 ... 79.75 79.85 79.95
#   * yh       (yh) float64 7kB -81.11 -81.07 -81.02 ... -37.3 -37.22 -37.14
# Attributes:
#     regrid_method:  bilinear

# %%
coords_match = (
    np.allclose(salt_005_regridded.xh, salt_01.xh) and
    np.allclose(salt_005_regridded.yh, salt_01.yh)
)
print("Coordinates match:", coords_match)
# Out:
# Coordinates match: True

# %%
coords_match = (
    np.allclose(temp_005_regridded.xh, temp_01.xh) and
    np.allclose(temp_005_regridded.yh, temp_01.yh)
)
print("Coordinates match:", coords_match)
# Out:
# Coordinates match: True

# %% [markdown]
# yay they match now!

# %% [markdown]
# ### For plotting

# %%
# Shelf mask

def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = grid010['deptho']
land_mask = (0 * depth).fillna(1)
land = xr.where(np.isnan(depth.rename('land')), 1, np.nan)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_01')

# %%
import matplotlib.path as mpath
import cmocean as cm

# %% [markdown]
# ### Between control anomaly of bottom salinity

# %%
sob_anom = salt_01 - salt_005_regridded
sob_anom
# Out:
# <xarray.DataArray (time: 120, yh: 845, xh: 3600)> Size: 1GB
# dask.array<sub, shape=(120, 845, 3600), dtype=float32, chunksize=(1, 845, 3600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 29kB -279.9 -279.8 -279.7 -279.6 ... 79.75 79.85 79.95
#   * yh       (yh) float64 7kB -81.11 -81.07 -81.02 ... -37.3 -37.22 -37.14
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
# Attributes:
#     units:          psu
#     long_name:      Sea Water Salinity at Sea Floor
#     cell_methods:   area:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_salinity_at_sea_floor

# %%
sob_anom_map = sob_anom.sel(time=slice('2006-01-01','2010-12-31')).mean(dim='time')

# %%
sob_anom_map
# Out:
# <xarray.DataArray (yh: 845, xh: 3600)> Size: 12MB
# dask.array<mean_agg-aggregate, shape=(845, 3600), dtype=float32, chunksize=(845, 3600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 29kB -279.9 -279.8 -279.7 -279.6 ... 79.75 79.85 79.95
#   * yh       (yh) float64 7kB -81.11 -81.07 -81.02 ... -37.3 -37.22 -37.14
# Attributes:
#     units:          psu
#     long_name:      Sea Water Salinity at Sea Floor
#     cell_methods:   area:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_salinity_at_sea_floor

# %%
# %%time

sob_anom_map = sob_anom_map.load()
# Out:
# 2025-08-15 11:56:08,087 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:56:35,718 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.11 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 12:00:40,750 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.95 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 12:01:04,630 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 12:01:05,082 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.97 GiB -- Worker memory limit: 4.47 GiB
# CPU times: user 35.4 s, sys: 27.5 s, total: 1min 2s
# Wall time: 10min 10s

# %%
projection = ccrs.SouthPolarStereo()
    
plt.figure(figsize=(7, 8))
ax = plt.axes(projection=projection)
ax.set_extent([-280, 80, -80, -59], crs=ccrs.PlateCarree())
    
# Circular boundary
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5,0.495], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# Filled land 
land.plot.contourf(ax=ax, colors='white',
                   zorder=2,
                   transform=ccrs.PlateCarree(),
                   add_colorbar=False)

# Coast line
ax.contour(land_mask.cf['xh'], land_mask.cf['yh'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
# Shelf contour
ax.contour(shelf_mask.cf['xh'], shelf_mask.cf['yh'], shelf_mask,
           levels = [0, 1], colors = 'k', linewidths=0.5,transform = ccrs.PlateCarree())

# Adding polar axes
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, 
                    xlocs=range(-180,171,60), ylocs=[], 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=False, linewidth=1, 
                    xlocs=[], ylocs=(-80,-70,-55), 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)

# Plotting
sob_anom_map.plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    vmin=-0.06,
    vmax=0.06,
    extend="both",
    cmap= plt.get_cmap('RdBu').reversed(), 
    cbar_kwargs={"label": "Bottom salinity anomaly (yr)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("PanAn 1/10th - PanAn 1/20th, bottom salinity");

# %% [markdown]
# ### Between controls of bottom temperature

# %%
tob_anom = temp_01 - temp_005_regridded
tob_anom
# Out:
# <xarray.DataArray (time: 120, yh: 845, xh: 3600)> Size: 1GB
# dask.array<sub, shape=(120, 845, 3600), dtype=float32, chunksize=(1, 845, 3600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 29kB -279.9 -279.8 -279.7 -279.6 ... 79.75 79.85 79.95
#   * yh       (yh) float64 7kB -81.11 -81.07 -81.02 ... -37.3 -37.22 -37.14
#   * time     (time) object 960B 2001-01-16 12:00:00 ... 2010-12-16 12:00:00
# Attributes:
#     units:          degC
#     long_name:      Sea Water Potential Temperature at Sea Floor
#     cell_methods:   area:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_potential_temperature_at_sea_floor

# %%
tob_anom_map = tob_anom.sel(time=slice('2006-01-01','2010-12-31')).mean(dim='time')
tob_anom_map
# Out:
# <xarray.DataArray (yh: 845, xh: 3600)> Size: 12MB
# dask.array<mean_agg-aggregate, shape=(845, 3600), dtype=float32, chunksize=(845, 3600), chunktype=numpy.ndarray>
# Coordinates:
#   * xh       (xh) float64 29kB -279.9 -279.8 -279.7 -279.6 ... 79.75 79.85 79.95
#   * yh       (yh) float64 7kB -81.11 -81.07 -81.02 ... -37.3 -37.22 -37.14
# Attributes:
#     units:          degC
#     long_name:      Sea Water Potential Temperature at Sea Floor
#     cell_methods:   area:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_potential_temperature_at_sea_floor

# %%
# %%time
tob_anom_map = tob_anom_map.load()
# Out:
# [gadi-cpu-bdw-0025:1821985:0:1822517] Caught signal 7 (Bus error: nonexistent physical address)
# [gadi-cpu-bdw-0025:1822053:0:1822491] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# ==== backtrace (tid:1822491) ====
#  0 0x0000000000012990 __funlockfile()  :0
#  1 0x00000000000afff5 __memcmp_avx2_movbe_rtm()  :0
#  2 0x0000000002ed42f2 llvm::LLLexer::LexIdentifier()  LLLexer.cpp:0
#  3 0x0000000002f1ea7a llvm::LLParser::Run()  :0
#  4 0x0000000002ecf195 parseAssemblyInto()  Parser.cpp:0
#  5 0x0000000002ecf46b llvm::parseAssemblyString()  :0
#  6 0x0000000000778750 LLVMPY_ParseAssembly()  ???:0
#  7 0x0000000000006d8a ffi_call_unix64()  :0
#  8 0x00000000000061cd ffi_call_int()  ffi64.c:0
#  9 0x000000000000691d ffi_call()  ???:0
# 10 0x00000000000092c9 _ctypes_callproc.cold()  :0
# 11 0x00000000000087ee PyCFuncPtr_call.cold()  :0
# 12 0x00000000002128ee PyObject_Call()  ???:0
# 13 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 14 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 15 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 16 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 17 0x00000000002df799 slot_tp_call()  :0
# 18 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 19 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 20 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 21 0x000000000020fe99 slot_tp_init()  :0
# 22 0x00000000001d6961 type_call()  :0
# 23 0x00000000002128ee PyObject_Call()  ???:0
# 24 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 25 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 26 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 27 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 28 0x000000000020fe99 slot_tp_init()  :0
# 29 0x00000000001d66db _PyObject_MakeTpCall.localalias()  :0
# 30 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 31 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 32 0x000000000020fe99 slot_tp_init()  :0
# 33 0x00000000001d66db _PyObject_MakeTpCall.localalias()  :0
# 34 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 35 0x0000000000227218 method_vectorcall()  :0
# 36 0x0000000000004942 compile_and_invoke()  _dispatcher.cpp:0
# 37 0x00000000000053bf Dispatcher_call()  _dispatcher.cpp:0
# 38 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 39 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 40 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 41 0x0000000000212964 PyObject_Call()  ???:0
# 42 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 43 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 44 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 45 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 46 0x00000000002df799 slot_tp_call()  :0
# 47 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 48 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 49 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 50 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 51 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 52 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 53 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 54 0x00000000002df799 slot_tp_call()  :0
# 55 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 56 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 57 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# =================================
# [gadi-cpu-bdw-0025:1822027:0:1822513] Caught signal 7 (Bus error: nonexistent physical address)
# [gadi-cpu-bdw-0025:1822051:0:1822504] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# [gadi-cpu-bdw-0025:1822039:0:1822495] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_rangesDwarf Error: Can't find  section. section..debug_ranges
#  section.
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_rangesDwarf Error: Can't find .debug_ranges section..debug_ranges section.
#  section.
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_rangesDwarf Error: Can't find  section. section..debug_ranges
#
#  section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_rangesDwarf Error: Can't find .debug_ranges section. section.
#
# [gadi-cpu-bdw-0025:1822076:0:1822498] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# [gadi-cpu-bdw-0025:1821995:0:1822511] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.BFD:
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# [gadi-cpu-bdw-0025:1822031:0:1822492] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_rangesDwarf Error: Can't find  section..debug_ranges
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.BFD:
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_rangesDwarf Error: Can't find  section..debug_ranges
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.Dwarf Error: Can't find
#
# .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# [gadi-cpu-bdw-0025:1821980:0:1822490] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find BFD: .debug_ranges section.Dwarf Error: Can't find
# .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# [gadi-cpu-bdw-0025:1821975:0:1822500] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.Dwarf Error: Can't find
# .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_rangesDwarf Error: Can't find  section..debug_ranges
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges section..debug_ranges
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.BFD:
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.Dwarf Error: Can't find
# BFD: .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.Dwarf Error: Can't find
# .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_rangesBFD:  section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find BFD: .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.BFD:
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.BFD:
# BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_rangesDwarf Error: Can't find .debug_ranges section..debug_ranges section.
#  section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_rangesDwarf Error: Can't find  section. section..debug_ranges
#
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_rangesBFD:  section.Dwarf Error: Can't find
# .debug_rangesDwarf Error: Can't find  section.
# .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# ==== backtrace (tid:1822504) ====
#  0 0x0000000000012990 __funlockfile()  :0
#  1 0x00000000000afff5 __memcmp_avx2_movbe_rtm()  :0
#  2 0x0000000002ed42f2 llvm::LLLexer::LexIdentifier()  LLLexer.cpp:0
#  3 0x0000000002f1ea7a llvm::LLParser::Run()  :0
#  4 0x0000000002ecf195 parseAssemblyInto()  Parser.cpp:0
#  5 0x0000000002ecf46b llvm::parseAssemblyString()  :0
#  6 0x0000000000778750 LLVMPY_ParseAssembly()  ???:0
#  7 0x0000000000006d8a ffi_call_unix64()  :0
#  8 0x00000000000061cd ffi_call_int()  ffi64.c:0
#  9 0x000000000000691d ffi_call()  ???:0
# 10 0x00000000000092c9 _ctypes_callproc.cold()  :0
# 11 0x00000000000087ee PyCFuncPtr_call.cold()  :0
# 12 0x00000000002128ee PyObject_Call()  ???:0
# 13 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 14 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 15 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 16 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 17 0x00000000002df799 slot_tp_call()  :0
# 18 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 19 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 20 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 21 0x000000000020fe99 slot_tp_init()  :0
# 22 0x00000000001d6961 type_call()  :0
# 23 0x00000000002128ee PyObject_Call()  ???:0
# 24 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 25 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 26 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 27 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 28 0x000000000020fe99 slot_tp_init()  :0
# 29 0x00000000001d66db _PyObject_MakeTpCall.localalias()  :0
# 30 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 31 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 32 0x000000000020fe99 slot_tp_init()  :0
# 33 0x00000000001d66db _PyObject_MakeTpCall.localalias()  :0
# 34 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 35 0x0000000000227218 method_vectorcall()  :0
# 36 0x0000000000004942 compile_and_invoke()  _dispatcher.cpp:0
# 37 0x00000000000053bf Dispatcher_call()  _dispatcher.cpp:0
# 38 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 39 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 40 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 41 0x0000000000212964 PyObject_Call()  ???:0
# 42 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 43 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 44 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 45 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 46 0x00000000002df799 slot_tp_call()  :0
# 47 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 48 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 49 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 50 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 51 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 52 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 53 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 54 0x00000000002df799 slot_tp_call()  :0
# 55 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 56 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 57 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# =================================
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# ==== backtrace (tid:1822513) ====
#  0 0x0000000000012990 __funlockfile()  :0
#  1 0x00000000000b0037 __memcmp_avx2_movbe_rtm()  :0
#  2 0x0000000002ed42f2 llvm::LLLexer::LexIdentifier()  LLLexer.cpp:0
#  3 0x0000000002f1ea7a llvm::LLParser::Run()  :0
#  4 0x0000000002ecf195 parseAssemblyInto()  Parser.cpp:0
#  5 0x0000000002ecf46b llvm::parseAssemblyString()  :0
#  6 0x0000000000778750 LLVMPY_ParseAssembly()  ???:0
#  7 0x0000000000006d8a ffi_call_unix64()  :0
#  8 0x00000000000061cd ffi_call_int()  ffi64.c:0
#  9 0x000000000000691d ffi_call()  ???:0
# 10 0x00000000000092c9 _ctypes_callproc.cold()  :0
# 11 0x00000000000087ee PyCFuncPtr_call.cold()  :0
# 12 0x00000000002128ee PyObject_Call()  ???:0
# 13 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 14 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 15 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 16 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 17 0x00000000002df799 slot_tp_call()  :0
# 18 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 19 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 20 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 21 0x000000000020fe99 slot_tp_init()  :0
# 22 0x00000000001d6961 type_call()  :0
# 23 0x00000000002128ee PyObject_Call()  ???:0
# 24 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 25 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 26 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 27 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 28 0x000000000020fe99 slot_tp_init()  :0
# 29 0x00000000001d66db _PyObject_MakeTpCall.localalias()  :0
# 30 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 31 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 32 0x000000000020fe99 slot_tp_init()  :0
# 33 0x00000000001d66db _PyObject_MakeTpCall.localalias()  :0
# 34 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 35 0x0000000000227218 method_vectorcall()  :0
# 36 0x0000000000004942 compile_and_invoke()  _dispatcher.cpp:0
# 37 0x00000000000053bf Dispatcher_call()  _dispatcher.cpp:0
# 38 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 39 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 40 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 41 0x0000000000212964 PyObject_Call()  ???:0
# 42 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 43 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 44 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 45 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 46 0x00000000002df799 slot_tp_call()  :0
# 47 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 48 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 49 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 50 0x00000000001e8049 _PyEval_EvalFrameDefault()  ???:0
# 51 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# 52 0x00000000001db2a3 _PyObject_FastCallDictTstate.localalias()  :0
# 53 0x00000000002104c9 _PyObject_Call_Prepend()  ???:0
# 54 0x00000000002df799 slot_tp_call()  :0
# 55 0x00000000001d66ab _PyObject_MakeTpCall.localalias()  :0
# 56 0x00000000001e3d2a _PyEval_EvalFrameDefault()  ???:0
# 57 0x0000000000208a4f _PyFunction_Vectorcall()  ???:0
# =================================
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_rangesBFD:  section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.Dwarf Error: Can't find
# .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges section..debug_ranges
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_rangesBFD:  section.
# Dwarf Error: Can't find .debug_ranges section.
# ...
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: ConnectionPool closing.
# 2025-08-15 11:32:23,974 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 1267, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: ConnectionPool closing.
# 2025-08-15 11:32:23,973 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 1267, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: ConnectionPool closing.
# 2025-08-15 11:32:23,976 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 1267, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: ConnectionPool closing.
# 2025-08-15 11:32:23,971 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/asyncio/timeouts.py", line 115, in __aexit__
#     raise TimeoutError from exc_val
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/worker.py", line 1267, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: ConnectionPool closing.
# 2025-08-15 11:34:01,896 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.94 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:34:52,926 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:34:53,094 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:35:50,985 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.09 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:36:02,244 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.95 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:38:25,481 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 2.94 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:39:42,341 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:40:51,075 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:41:10,028 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.13 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:41:26,516 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.13 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:42:43,316 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.59 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:42:46,016 - distributed.worker.memory - WARNING - Worker is at 66% memory usage. Resuming worker. Process memory: 2.98 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:42:47,816 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.59 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:42:49,217 - distributed.worker.memory - WARNING - Worker is at 75% memory usage. Resuming worker. Process memory: 3.39 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:42:49,516 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.63 GiB -- Worker memory limit: 4.47 GiB
# 2025-08-15 11:42:51,016 - distributed.worker.memory - WARNING - Worker is at 60% memory usage. Resuming worker. Process memory: 2.70 GiB -- Worker memory limit: 4.47 GiB
# CPU times: user 1min 2s, sys: 35.4 s, total: 1min 38s
# Wall time: 12min 32s

# %%
projection = ccrs.SouthPolarStereo()
    
plt.figure(figsize=(7, 8))
ax = plt.axes(projection=projection)
ax.set_extent([-280, 80, -80, -59], crs=ccrs.PlateCarree())
    
# Circular boundary
theta = np.linspace(0, 2 * np.pi, 100)
center, radius = [0.5,0.495], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

# Filled land 
land.plot.contourf(ax=ax, colors='white',
                   zorder=2,
                   transform=ccrs.PlateCarree(),
                   add_colorbar=False)

# Coast line
ax.contour(land_mask.cf['xh'], land_mask.cf['yh'], land_mask,
           levels = [0, 1], colors = 'dimgrey',linewidths=0.5, transform = ccrs.PlateCarree())
# Shelf contour
ax.contour(shelf_mask.cf['xh'], shelf_mask.cf['yh'], shelf_mask,
           levels = [0, 1], colors = 'k', linewidths=0.5,transform = ccrs.PlateCarree())

# Adding polar axes
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, 
                    xlocs=range(-180,171,60), ylocs=[], 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)
ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=False, linewidth=1, 
                    xlocs=[], ylocs=(-80,-70,-55), 
                    color='gray', alpha=0.5, linestyle='--', zorder=10)

# Plotting
tob_anom_map.plot(
    x="xh",
    y="yh",
    transform=ccrs.PlateCarree(),
    vmin=-0.3,
    vmax=0.3,
    extend="both",
    cmap= plt.get_cmap('RdBu').reversed(), #cm ocean colour maps for more options, matplotlib has more also.
    cbar_kwargs={"label": "Bottom temperature anomaly ($^\circ$C)", "fraction": 0.03, "aspect": 15, "shrink": 0.7},
);

plt.title("PanAn 1/10th - PanAn 1/20th, bottom temperature");
