# %% [markdown]
# # Pan01 Across Isobath Transport

# %%
import pandas as pd
import intake
import cosima_cookbook as cc
import dask
import matplotlib.pyplot as plt
import netCDF4 as nc
import xarray as xr
import numpy as np
import cmocean

from dask.distributed import Client

# %%
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:45883' processes=28 threads=28, memory=251.19 GiB>

# %%
expt_con = 'panant-01-zstar-ACCESSyr2'
expt_melt = 'panant-01-zstar-ssp126-MW-only'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)
freq = '1 monthly'

start_time = '2001-01-01'
end_time = '2010-12-31'
time_slice = slice(start_time, end_time)

# %%
lat_range = slice(-90, -59)

# %%
darray = cc.querying.getvar(expt=expt_con, variable='deptho', session=session)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 darray = cc.querying.getvar(expt=expt_con, variable='deptho', session=session)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/cosima_cookbook/querying.py:368, in getvar(expt, variable, session, ncfile, start_time, end_time, n, frequency, attrs, attrs_unique, return_dataset, **kwargs)
#     364     return d[variables]
#     366 ncfiles = list(str(f.NCFile.ncfile_path) for f in ncfiles)
# --> 368 ds = xr.open_mfdataset(
#     369     ncfiles,
#     370     parallel=True,
#     371     combine="by_coords",
#     372     preprocess=_preprocess,
#     373     **xr_kwargs,
#     374 )
#     376 if return_dataset:
#     377     da = ds
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/backends/api.py:1606, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1593     combined = _nested_combine(
#    1594         datasets,
#    1595         concat_dims=concat_dim,
#    (...)
#    1601         combine_attrs=combine_attrs,
#    1602     )
#    1603 elif combine == "by_coords":
#    1604     # Redo ordering from coordinates, ignoring how they were ordered
#    1605     # previously
# -> 1606     combined = combine_by_coords(
#    1607         datasets,
#    1608         compat=compat,
#    1609         data_vars=data_vars,
#    1610         coords=coords,
#    1611         join=join,
#    1612         combine_attrs=combine_attrs,
#    1613     )
#    1614 else:
#    1615     raise ValueError(
#    1616         f"{combine} is an invalid option for the keyword argument"
#    1617         " ``combine``"
#    1618     )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/combine.py:961, in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs)
#     957     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     959     # Perform the multidimensional combine on each group of data variables
#     960     # before merging back together
# --> 961     concatenated_grouped_by_data_vars = tuple(
#     962         _combine_single_variable_hypercube(
#     963             tuple(datasets_with_same_vars),
#     964             fill_value=fill_value,
#     965             data_vars=data_vars,
#     966             coords=coords,
#     967             compat=compat,
#     968             join=join,
#     969             combine_attrs=combine_attrs,
#     970         )
#     971         for vars, datasets_with_same_vars in grouped_by_vars
#     972     )
#     974 return merge(
#     975     concatenated_grouped_by_data_vars,
#     976     compat=compat,
#    (...)
#     979     combine_attrs=combine_attrs,
#     980 )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/combine.py:962, in <genexpr>(.0)
#     957     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     959     # Perform the multidimensional combine on each group of data variables
#     960     # before merging back together
#     961     concatenated_grouped_by_data_vars = tuple(
# --> 962         _combine_single_variable_hypercube(
#     963             tuple(datasets_with_same_vars),
#     964             fill_value=fill_value,
#     965             data_vars=data_vars,
#     966             coords=coords,
#     967             compat=compat,
#     968             join=join,
#     969             combine_attrs=combine_attrs,
#     970         )
#     971         for vars, datasets_with_same_vars in grouped_by_vars
#     972     )
#     974 return merge(
#     975     concatenated_grouped_by_data_vars,
#     976     compat=compat,
#    (...)
#     979     combine_attrs=combine_attrs,
#     980 )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/combine.py:622, in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     616 if len(datasets) == 0:
#     617     raise ValueError(
#     618         "At least one Dataset is required to resolve variable names "
#     619         "for combined hypercube."
#     620     )
# --> 622 combined_ids, concat_dims = _infer_concat_order_from_coords(list(datasets))
#     624 if fill_value is None:
#     625     # check that datasets form complete hypercube
#     626     _check_shape_tile_ids(combined_ids)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/combine.py:147, in _infer_concat_order_from_coords(datasets)
#     141             tile_ids = [
#     142                 tile_id + (position,)
#     143                 for tile_id, position in zip(tile_ids, order, strict=True)
#     144             ]
#     146 if len(datasets) > 1 and not concat_dims:
# --> 147     raise ValueError(
#     148         "Could not find any dimension coordinates to use to "
#     149         "order the datasets for concatenation"
#     150     )
#     152 combined_ids = dict(zip(tile_ids, datasets, strict=True))
#     154 return combined_ids, concat_dims
#
# ValueError: Could not find any dimension coordinates to use to order the datasets for concatenation
