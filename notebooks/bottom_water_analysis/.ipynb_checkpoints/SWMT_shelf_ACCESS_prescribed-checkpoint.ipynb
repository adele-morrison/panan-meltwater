# %% [markdown]
# # SWMT on shelf for ACCESS-OM2-01

# %%
import intake
import cosima_cookbook as cc
import glob

import cartopy.crs as ccrs
import cf_xarray as cfxr
import cmocean as cm
import dask.distributed
import gsw
import matplotlib.pyplot as plt
from matplotlib import gridspec 
import matplotlib.colors as mcolors
import matplotlib.path as mpath
import numpy as np
import xarray as xr
import pdb
import os
import pathlib
import shutil

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker = 1)

# %% [markdown]
# ### Defining the functions

# %%
def get_variables(expt, freq, start_time, end_time, lon_slice, lat_slice, model):

    # The models require different diagnostics to calculate the heat and salt fluxes.
    # mom6 outputs a net flux, whilst with mom5 we need to work with the separate components.
    model_vars = {
                    "mom5": {
                        "temperature":           ["temp"],
                        "salinity":              ["salt"],
                        "water_flux_into_ocean": ["pme_river"],
                        "salt_flux":             ["sfc_salt_flux_ice", "sfc_salt_flux_restore"],
                        "heat_flux":             ["sfc_hflux_coupler", "sfc_hflux_from_runoff",
                                                  "frazil_3d_int_z", "sfc_hflux_pme"],
                        "area":                  ["area_t"],
                        "maximum_depth":         ["ht"],
                    },
                    "mom6": {
                        "temperature":           ["thetao"],
                        "salinity":              ["so"],
                        "water_flux_into_ocean": ["wfo"],
                        "salt_flux":             ["salt_flux"],
                        "heat_flux":             ["hfds"],
                        "area":                  ["areacello"],
                        "maximum_depth":         ["deptho"],
                    }
                }
    # Load variables in a dictionary
    ds = {}
    keys = list(model_vars[model].keys())
    for k in keys:
        ds[k] = {}
        for var in model_vars[model][k]:
            if k in ["area", "maximum_depth"]:
                ds[k][var] = cc.querying.getvar(expt, var, session, n = 1) 
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice)
            else:
                try:
                    ds[k][var] = cc.querying.getvar(expt, var, session,
                                                frequency = freq,
                                                start_time = start_time,
                                                end_time = end_time,
                                                chunks = {'time': 1})
                    ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice, time = slice(start_time, end_time))
                
                    # Correct temperatures (if in K convert to C)
                    if k == 'temperature' and np.max(ds[k][var]) > 100:
                        ds[k][var] = ds[k][var] - 273.15
    
                    # If 3D field, grab the surface
                    if ds[k][var].cf.axes.get('Z'):
                        surface_z = ds[k][var].cf['Z'][0].values
                        ds[k][var] = ds[k][var].cf.sel(Z = 0, method = 'nearest')
                except Exception as e:
                    raise Exception(f"Data loading error: var={var}, freq={freq}, start_time={start_time}, end_time={end_time}, expt={expt}: {str(e)}")

    # Get temperature and salinity to calculate few other things we'll need later on
    SP = ds['salinity'][model_vars[model]['salinity'][0]]
    CT = ds['temperature'][model_vars[model]['temperature'][0]]

    # Calculate pressure
    pressure = gsw.p_from_z(-surface_z, SP.cf['Y']).rename('pressure')

    # Calculate absolute salinity
    SA = gsw.SA_from_SP(SP, pressure, SP.cf['X'], SP.cf['Y']).rename('SA')

    # Ensure we have conservative temperature; Convert MOM6's potential temperature to conservative
    if model == 'mom6':
        CT = gsw.CT_from_pt(SA, CT)
        ds['temperature'][model_vars[model]['temperature'][0]].data = CT.values

    # Calculate potential density
    pot_rho_0 = gsw.sigma0(SA, CT)#.rename('pot_rho_11')

    # Save everything to our dictionary
    ds['pressure'] = pressure
    ds['SA'] = SA
    ds['pot_rho_0'] = pot_rho_0
    
    # Calculate days per month accounting for leap years
    months_standard_noleap = np.array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    months_standard_leap = np.array([31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    if 'ryf' or 'panan' in expt:
        nyears = len(np.unique(CT['time.year']))
        days_per_month = np.tile(months_standard_noleap, nyears)
    elif 'iaf' in expt:
        nyears = len(np.unique(CT['time.year']))
        if CT['time.year'][0] % 4 == 0:
            days_per_month = months_standard_leap
        else: 
            days_per_month = months_standard_noleap
        for yr in CT['time.year'][::12][1:]:
            if yr % 4 == 0:
                days_per_month = np.concatenate([days_per_month, months_standard_leap])
            else:
                days_per_month = np.concatenate([days_per_month, months_standard_noleap])
    days_per_month = xr.DataArray(days_per_month, dims = ['time'], coords = {'time': CT['time']}, name = 'days_per_month')
    ds['days_per_month'] = days_per_month

    return ds

# %%
def compute_salt_transformation(ds):
    
    # First retrieve temperature and water_flux as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Multiply the water flux by absolute salinity to get it in the correct units
    water_flux_into_ocean = xr.Dataset(ds['water_flux_into_ocean']).to_array().squeeze().drop_vars('variable')
    water_flux_into_ocean = ds['SA'] * water_flux_into_ocean

    # Caculate the haline contraction coefficient
    haline_contraction = gsw.beta(ds['SA'], CT, ds['pressure']).rename('beta')

    # Calculate the net salt flux and multiply by 1000 to convert units
    net_salt_flux = xr.Dataset(ds['salt_flux']).to_array().sum(dim = 'variable') * 1000

    # Note that we also multiply pme_river by absolute salinity to have the correct units
    salt_transformation = haline_contraction * (water_flux_into_ocean - net_salt_flux) * ds['days_per_month']
    salt_transformation = salt_transformation.load()

    return salt_transformation

def compute_heat_transformation(ds):

    # First retrieve temperature as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Calculate the thermal expansion coefficient 
    thermal_expansion = gsw.alpha(ds['SA'], CT, ds['pressure']).rename('alpha')
    
    # Calculate the net surface heating
    net_surface_heating = xr.Dataset(ds['heat_flux']).to_array().sum(dim = 'variable')
    
    # Calculate the heat transformation
    heat_transformation = thermal_expansion * net_surface_heating * ds['days_per_month']
    heat_transformation = heat_transformation.load()

    return heat_transformation

# %%
def isopycnal_bins(ds, salt_transformation, heat_transformation):

    # Next section does a few things. It cycles through isopycnal bins, determines which cells are 
    # within the given bin for each month, finds the transformation values for those cells for each month, 
    # and sums these through time. You are left with an array of shape (isopyncal bins * lats * lons) 
    # where the array associated with a given isopycnal bin is NaN everywhere except where pot_rho_0
    # was within the bin, there it has a time summed transformation value.
    
    # Choose appropriate bin range
    # isopycnal_bins = np.arange(31, 33.5, 0.02)  # 125 bins - 31, 33.5, 0.02 (sigma1)
    isopycnal_bins = np.concatenate([np.arange(25.0, 26.5, 0.05), np.arange(26.5, 28.5, 0.02)])  # 130 bins (sigma0)
    bin_bottoms = isopycnal_bins[:-1]
    isopycnal_bin_mid = (isopycnal_bins[1:] + bin_bottoms) / 2
    isopycnal_bin_diff = np.diff(isopycnal_bins)

    pot_rho_0 = ds['pot_rho_0']

    results_salt = []
    results_heat = []

    for i in range(len(bin_bottoms)):
        # Create binary mask for each bin
        bin_mask = xr.where((pot_rho_0 > bin_bottoms[i]) & (pot_rho_0 <= isopycnal_bins[i + 1]), 1, np.nan)

        # Multiply and sum over time
        salt_sum = (salt_transformation * bin_mask).sum(dim='time')
        heat_sum = (heat_transformation * bin_mask).sum(dim='time')

        results_salt.append(salt_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))
        results_heat.append(heat_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))

    # Concatenate results along isopycnal dimension
    salt_transformation = xr.concat(results_salt, dim='isopycnal_bins')
    heat_transformation = xr.concat(results_heat, dim='isopycnal_bins')

    # Normalise by number of days and bin thickness
    ndays = ds['days_per_month'].sum()
    c_p = 3992.1 # J kg-1 degC-1

    salt_transformation /= ndays
    heat_transformation /= (c_p * ndays)

    salt_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]
    heat_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]

    # Overwrite zeros with NANs 
    # (Note: the code within the for-loop should provide nans but lazy computing with dask can sometimes give unpredictable results)
    salt_transformation = salt_transformation.where(salt_transformation != 0)
    heat_transformation = heat_transformation.where(heat_transformation != 0)

    # Change the sign so that positive means conversion into denser water masses
    salt_transformation *= -1
    heat_transformation *= -1

    # Renaming
    salt_transformation.name = "salt_transformation"
    heat_transformation.name = "heat_transformation"

    return salt_transformation.load(), heat_transformation.load()

# %% [markdown]
# ## Opening the saved data
#
# For saving method, scroll to section below.

# %%
# Importing the saved files
salt_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_*'))
heat_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_*'))

salt_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_*'))
heat_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_*'))

# %%
salt_tr_C = xr.open_mfdataset(salt_files_C, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_tr_C = xr.open_mfdataset(heat_files_C, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_tr_C = salt_tr_C.to_array().squeeze()
heat_tr_C = heat_tr_C.to_array().squeeze()

# %%
net_tr_C = salt_tr_C + heat_tr_C

# %%
salt_tr_M = xr.open_mfdataset(salt_files_M, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_tr_M = xr.open_mfdataset(heat_files_M, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_tr_M = salt_tr_M.to_array().squeeze()
heat_tr_M = heat_tr_M.to_array().squeeze()

# %%
net_tr_M = salt_tr_M + heat_tr_M

# %% [markdown]
# #### Antarctic shelf dense water formation

# %%
def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
lat_slice = slice(None, -59)
depth = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output040/ocean/ocean_grid.nc')['ht'].sel(yt_ocean=lat_slice)
area = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output040/ocean/ocean_grid.nc')['area_t'].sel(yt_ocean=lat_slice)
varr = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output040/ocean/ocean.nc')['salt'].sel(yt_ocean=lat_slice).isel(st_ocean=0,time=0)
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom5')

# %%
# Creating corrected area
area_corr = (area*(varr*0+1))#.drop_vars('variable')
area_corr = area_corr.drop_vars(['time','st_ocean'])
area_corr
# Out:
# <xarray.DataArray (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
# array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        ...,
#        [32539520., 32539520., 32539520., ..., 32539520., 32539520.,
#         32539520.],
#        [32637138., 32637138., 32637138., ..., 32637138., 32637138.,
#         32637138.],
#        [32734998., 32734998., 32734998., ..., 32734998., 32734998.,
#         32734998.]], dtype=float32)
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     geolon_t  (yt_ocean, xt_ocean) float32 7MB ...
#     geolat_t  (yt_ocean, xt_ocean) float32 7MB ...

# %%
# Check mask
area_corr.plot()

# %%
swmt_shelf_C = (net_tr_C * area_corr / 1e6).where(shelf_mask == 1)
heat_shelf_C = (heat_tr_C * area_corr / 1e6).where(shelf_mask == 1)
salt_shelf_C = (salt_tr_C * area_corr / 1e6).where(shelf_mask == 1)

swmt_shelf_C = swmt_shelf_C.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_shelf_C = heat_shelf_C.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_shelf_C = salt_shelf_C.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})

# %%
swmt_shelf_sum_C = swmt_shelf_C.cf.sum(['xt_ocean', 'yt_ocean']).compute()

# %%
heat_shelf_sum_C = heat_shelf_C.cf.sum(['xt_ocean', 'yt_ocean']).compute()
# Out:
# 2025-10-02 15:25:45,178 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45341
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:54220 remote=tcp://127.0.0.1:45341>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:25:48,328 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39837
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:40646 remote=tcp://127.0.0.1:39837>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:25:48,688 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40787 -> tcp://127.0.0.1:35625
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40787 remote=tcp://127.0.0.1:41894>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:25:45,488 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:39837 -> tcp://127.0.0.1:35625
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:39837 remote=tcp://127.0.0.1:40646>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:01,215 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35013
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:33472 remote=tcp://127.0.0.1:35013>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:03,806 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:45341 -> tcp://127.0.0.1:36665
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:45341 remote=tcp://127.0.0.1:54220>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:04,426 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35013 -> tcp://127.0.0.1:36057
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35013 remote=tcp://127.0.0.1:33472>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:05,444 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46417
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:49276 remote=tcp://127.0.0.1:46417>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:07,221 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40787
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:41894 remote=tcp://127.0.0.1:40787>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:07,417 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35893 -> tcp://127.0.0.1:36057
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35893 remote=tcp://127.0.0.1:33958>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:09,233 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35893
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:33958 remote=tcp://127.0.0.1:35893>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:39,299 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:37025 -> tcp://127.0.0.1:42695
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:37025 remote=tcp://127.0.0.1:55768>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:40,961 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35849 -> tcp://127.0.0.1:42695
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35849 remote=tcp://127.0.0.1:59384>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:41,747 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37025
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55768 remote=tcp://127.0.0.1:37025>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:45,685 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:45341 -> tcp://127.0.0.1:46417
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:45341 remote=tcp://127.0.0.1:44388>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:47,611 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41791
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 1910, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 546, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 1909, in wait_for
#     async with asyncio.timeout(timeout):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/timeouts.py", line 98, in __aexit__
#     raise TimeoutError
# TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 368, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:41791 after 30 s
# 2025-10-02 15:26:47,796 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35849
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:59384 remote=tcp://127.0.0.1:35849>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:48,296 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:34053 -> tcp://127.0.0.1:46417
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:34053 remote=tcp://127.0.0.1:57646>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:48,793 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:33915 -> tcp://127.0.0.1:46417
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:33915 remote=tcp://127.0.0.1:48050>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:48,828 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35013 -> tcp://127.0.0.1:46417
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35013 remote=tcp://127.0.0.1:60082>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:26:53,803 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33915
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48050 remote=tcp://127.0.0.1:33915>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:26:55,709 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35013
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:60082 remote=tcp://127.0.0.1:35013>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:27:07,595 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34053
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:57646 remote=tcp://127.0.0.1:34053>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:27:07,600 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:46417 -> tcp://127.0.0.1:36665
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:46417 remote=tcp://127.0.0.1:49276>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:27:07,637 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35849 -> tcp://127.0.0.1:36665
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35849 remote=tcp://127.0.0.1:59346>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:27:07,639 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37025
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
# ...
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:51316 remote=tcp://127.0.0.1:35013>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:39:24,073 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42695 -> tcp://127.0.0.1:45815
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42695 remote=tcp://127.0.0.1:36906>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:39:25,584 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39841
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:53260 remote=tcp://127.0.0.1:39841>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:39:27,592 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:39263 -> tcp://127.0.0.1:45815
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:39263 remote=tcp://127.0.0.1:33916>: TimeoutError: [Errno 110] Connection timed out
# 2025-10-02 15:39:27,897 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42695
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:36906 remote=tcp://127.0.0.1:42695>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:39:27,941 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35013
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:46564 remote=tcp://127.0.0.1:35013>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:39:28,080 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39263
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:33916 remote=tcp://127.0.0.1:39263>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-10-02 15:39:28,587 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:45341
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 1910, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 546, in connect
#     stream = await self.client.connect(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/tcpclient.py", line 279, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 342, in connect
#     comm = await wait_for(
#            ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 1909, in wait_for
#     async with asyncio.timeout(timeout):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/timeouts.py", line 98, in __aexit__
#     raise TimeoutError
# TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 368, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:45341 after 30 s

# %%
salt_shelf_sum_C = salt_shelf_C.cf.sum(['xt_ocean', 'yt_ocean']).compute()

# %%
# Time mean
heat_shelf_sum_ave_C = heat_shelf_sum_C.mean(dim='time')
salt_shelf_sum_ave_C = salt_shelf_sum_C.mean(dim='time')

for da in [heat_shelf_sum_ave_C, salt_shelf_sum_ave_C]:
    da.attrs["units"] = "Sv"

# %%
heat_shelf_sum_ave_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf_rho0/plots/heat_shelf_sum_ave_rho0_C_prescribed_access.nc')
salt_shelf_sum_ave_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf_rho0/plots/salt_shelf_sum_ave_rho0_C_prescribed_access.nc')

# %%
# Time mean
swmt_shelf_sum_ave_C = swmt_shelf_sum_C.mean(dim='time')

for da in [swmt_shelf_sum_ave_C]:#, heat_shelf_sum_ave_C, salt_shelf_sum_ave_C]:
    da.attrs["units"] = "Sv"

# %%
swmt_shelf_M = (net_tr_M * area_corr / 1e6).where(shelf_mask == 1)
heat_shelf_M = (heat_tr_M * area_corr / 1e6).where(shelf_mask == 1)
salt_shelf_M = (salt_tr_M * area_corr / 1e6).where(shelf_mask == 1)

swmt_shelf_M = swmt_shelf_M.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_shelf_M = heat_shelf_M.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_shelf_M = salt_shelf_M.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})

# %%
swmt_shelf_sum_M = swmt_shelf_M.cf.sum(['xt_ocean', 'yt_ocean']).compute()
#swmt_shelf_sum_M = heat_shelf_M.cf.sum(['xt_ocean', 'yt_ocean']).compute()
#salt_shelf_sum_M = salt_shelf_M.cf.sum(['xt_ocean', 'yt_ocean']).compute()

# %%
swmt_shelf_sum_ave_M = swmt_shelf_sum_M.mean(dim='time')
#heat_shelf_sum_ave_M = swmt_shelf_sum_M.mean(dim='time')
#salt_shelf_sum_ave_M = salt_shelf_sum_M.mean(dim='time')

for da in [swmt_shelf_sum_ave_M]: #, heat_shelf_sum_ave_M, salt_shelf_sum_ave_M]:
    da.attrs["units"] = "Sv"

# %%
swmt_shelf_sum_ave_C
# Out:
# <xarray.DataArray (isopycnal_bins: 129)> Size: 1kB
# array([-0.36447419, -0.34376907, -0.36019709, -0.36088566, -0.40468862,
#        -0.38230814, -0.39809706, -0.3673443 , -0.35111656, -0.38938923,
#        -0.38031374, -0.42343686, -0.40938837, -0.44480059, -0.4631102 ,
#        -0.50073179, -0.52528508, -0.51393738, -0.53838657, -0.59116977,
#        -0.62669178, -0.64562147, -0.54629645, -0.47209689, -0.5028898 ,
#        -0.53843796, -0.5505661 , -0.55237253, -0.52406213, -0.46686848,
#        -0.44752385, -0.44412987, -0.48922609, -0.50285784, -0.48331816,
#        -0.42137768, -0.42593174, -0.4739366 , -0.4585883 , -0.46076768,
#        -0.52819596, -0.50994984, -0.45389988, -0.48659768, -0.47696755,
#        -0.53503215, -0.55516542, -0.52589278, -0.48110304, -0.45563342,
#        -0.39908309, -0.26922128, -0.10574736,  0.09055779,  0.19393175,
#         0.25390528,  0.2701044 ,  0.24432733,  0.29205511,  0.41933853,
#         0.46768007,  0.57952988,  0.96792071,  1.268919  ,  1.27087083,
#         1.51553529,  1.7177654 ,  1.77735165,  1.82107293,  1.91129373,
#         2.01207024,  2.3638763 ,  2.89693774,  3.26315184,  3.3917654 ,
#         3.58547684,  3.82333555,  4.20647858,  4.57999869,  5.18424534,
#         5.49642244,  5.70416058,  6.23888438,  6.93031844,  7.40078559,
#         7.74174286,  7.94075767,  8.53283517,  8.97311414,  8.96955955,
#         8.74871986,  8.49055176,  7.71056318,  7.24598033,  6.26775034,
#         4.99906779,  4.16330826,  3.62287159,  3.27109784,  2.84664549,
#         2.53022338,  2.24599343,  1.99261963,  1.63946996,  1.32960163,
#         1.15441742,  0.92583116,  0.62515596,  0.25154438,  0.18125983,
#         0.14392117,  0.13207861,  0.10472739,  0.09399827,  0.07822283,
#         0.05976163,  0.05232276,  0.05672199,  0.05357704,  0.04991851,
#         0.05909686,  0.0463923 ,  0.04001317,  0.04223393,  0.03363843,
#         0.03067749,  0.0218766 ,  0.01766028,  0.02015922])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#     st_ocean        float64 8B 0.5413
# Attributes:
#     units:    Sv

# %%
swmt_shelf_sum_ave_C.compute()
# Out:
# <xarray.DataArray (isopycnal_bins: 129)> Size: 1kB
# array([-0.36447419, -0.34376907, -0.36019709, -0.36088566, -0.40468862,
#        -0.38230814, -0.39809706, -0.3673443 , -0.35111656, -0.38938923,
#        -0.38031374, -0.42343686, -0.40938837, -0.44480059, -0.4631102 ,
#        -0.50073179, -0.52528508, -0.51393738, -0.53838657, -0.59116977,
#        -0.62669178, -0.64562147, -0.54629645, -0.47209689, -0.5028898 ,
#        -0.53843796, -0.5505661 , -0.55237253, -0.52406213, -0.46686848,
#        -0.44752385, -0.44412987, -0.48922609, -0.50285784, -0.48331816,
#        -0.42137768, -0.42593174, -0.4739366 , -0.4585883 , -0.46076768,
#        -0.52819596, -0.50994984, -0.45389988, -0.48659768, -0.47696755,
#        -0.53503215, -0.55516542, -0.52589278, -0.48110304, -0.45563342,
#        -0.39908309, -0.26922128, -0.10574736,  0.09055779,  0.19393175,
#         0.25390528,  0.2701044 ,  0.24432733,  0.29205511,  0.41933853,
#         0.46768007,  0.57952988,  0.96792071,  1.268919  ,  1.27087083,
#         1.51553529,  1.7177654 ,  1.77735165,  1.82107293,  1.91129373,
#         2.01207024,  2.3638763 ,  2.89693774,  3.26315184,  3.3917654 ,
#         3.58547684,  3.82333555,  4.20647858,  4.57999869,  5.18424534,
#         5.49642244,  5.70416058,  6.23888438,  6.93031844,  7.40078559,
#         7.74174286,  7.94075767,  8.53283517,  8.97311414,  8.96955955,
#         8.74871986,  8.49055176,  7.71056318,  7.24598033,  6.26775034,
#         4.99906779,  4.16330826,  3.62287159,  3.27109784,  2.84664549,
#         2.53022338,  2.24599343,  1.99261963,  1.63946996,  1.32960163,
#         1.15441742,  0.92583116,  0.62515596,  0.25154438,  0.18125983,
#         0.14392117,  0.13207861,  0.10472739,  0.09399827,  0.07822283,
#         0.05976163,  0.05232276,  0.05672199,  0.05357704,  0.04991851,
#         0.05909686,  0.0463923 ,  0.04001317,  0.04223393,  0.03363843,
#         0.03067749,  0.0218766 ,  0.01766028,  0.02015922])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#     st_ocean        float64 8B 0.5413
# Attributes:
#     units:    Sv

# %%
swmt_shelf_sum_ave_M.compute()
# Out:
# <xarray.DataArray (isopycnal_bins: 129)> Size: 1kB
# array([-0.44123732, -0.43595126, -0.43664666, -0.45208898, -0.4608731 ,
#        -0.47194993, -0.45411321, -0.46676024, -0.50146118, -0.55065379,
#        -0.51760796, -0.52418914, -0.56526577, -0.61835355, -0.63998429,
#        -0.62146285, -0.63902399, -0.66794957, -0.71080247, -0.75611631,
#        -0.78938872, -0.79255371, -0.76071409, -0.74440364, -0.76772478,
#        -0.82961454, -0.76710746, -0.69832968, -0.64713381, -0.62008538,
#        -0.56689074, -0.62834889, -0.61776758, -0.66495279, -0.64377472,
#        -0.69649805, -0.70547371, -0.73973966, -0.71810108, -0.77137501,
#        -0.78517282, -0.75389714, -0.75126392, -0.67921132, -0.59227677,
#        -0.52496772, -0.48763445, -0.51596543, -0.52473542, -0.40269115,
#        -0.29444912, -0.18738994, -0.05925471,  0.11660256,  0.16735331,
#         0.17627884,  0.24452184,  0.32081392,  0.48436465,  0.57671794,
#         0.84816543,  1.0014404 ,  1.2335423 ,  1.33536635,  1.43247286,
#         1.49377738,  1.63793532,  1.90203858,  2.00150342,  2.1963673 ,
#         2.42998958,  2.72768752,  3.1405886 ,  3.56262007,  3.69774113,
#         4.0279076 ,  4.37196649,  4.65863186,  5.14565441,  5.61031826,
#         5.9647521 ,  6.58931139,  6.99157847,  7.48810935,  8.03153541,
#         8.34331157,  8.44553469,  8.7679794 ,  9.41696723,  9.37430119,
#         8.85015107,  8.00668549,  7.34624048,  6.24915269,  4.94820631,
#         4.12044948,  3.50930104,  3.13096849,  2.67881856,  2.37612064,
#         2.24258227,  1.9667253 ,  1.6350662 ,  1.20744397,  0.9096125 ,
#         0.58731291,  0.29478851,  0.18621768,  0.13700702,  0.10171223,
#         0.08817952,  0.08539281,  0.06642196,  0.0538668 ,  0.05583896,
#         0.05526947,  0.04766265,  0.04275829,  0.04439211,  0.0397638 ,
#         0.04307628,  0.03258969,  0.03012369,  0.01955401,  0.01715271,
#         0.01262654,  0.01273263,  0.01272978,  0.01191651])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#     st_ocean        float64 8B 0.5413
# Attributes:
#     units:    Sv

# %%
swmt_shelf_sum_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_C_access_rho0.nc')
swmt_shelf_sum_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_M_access_rho0.nc')

swmt_shelf_sum_ave_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_C_access_rho0.nc')
swmt_shelf_sum_ave_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_M_access_rho0.nc')

# %%
#Cell defining 25% and 75% markers.
cont_d25 = 27.93
cont_d75 = 27.79

# %%
fig, ax1 = plt.subplots(figsize=(4.5, 5.33))

ax1.plot(swmt_shelf_sum_ave_C, swmt_shelf_sum_ave_C['isopycnal_bins'], color = 'k', label='Control: 3.38 Sv')
ax1.plot(swmt_shelf_sum_ave_M, swmt_shelf_sum_ave_M['isopycnal_bins'], color = 'r', label='Meltwater: 2.86 Sv')
ax1.plot([0, 0], [26.5,28.49], 'k', linewidth=0.5)
ax1.plot([-5, 15], [cont_d25, cont_d25], 'k--', linewidth=1)
ax1.plot([-5, 15], [cont_d75, cont_d75], 'k--', linewidth=1)
ax1.set_ylim((28.45, 26.5))
ax1.set_xlim((-1.5, 10))
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()
ax1.set_ylabel('Density $\sigma_0$ (kg m$^{-3}$)')
ax1.set_xlabel('Surface water-mass transformation (Sv)')
ax1.legend();

# %%
swmt_shelf_sum_ave_C = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_C_access_rho0.nc')

# %%
figure = plt.figure(figsize = (7, 7))

plt.plot(swmt_shelf_sum_ave_C, swmt_shelf_sum_ave_C['isopycnal_bins'], color = 'k', label='net')
plt.plot(heat_shelf_sum_ave_C, heat_shelf_sum_ave_C['isopycnal_bins'], color = 'r', label='heat')
plt.plot(salt_shelf_sum_ave_C, salt_shelf_sum_ave_C['isopycnal_bins'], color = 'b', label='salt')
plt.plot([0, 0], [28.45, 26.5], 'k', linewidth = 0.5)

plt.ylim((28.45, 26.5))
plt.xlim((-1.5, 10))
plt.ylabel(r'$\sigma_1$ (kg m$^{-3}$)', fontsize = 14)
plt.xlabel('Surface water-mass transformation (Sv)', fontsize = 14)
plt.legend(loc = 1, fontsize = 14);

# %% [markdown]
# ### SWMT map:

# %%
transformation_density = 27.79
shelf_subduction_plot_C = net_tr_C.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_C = depth.cf['X']
swmt_yt_C = depth.cf['Y']

# %%
shelf_subduction_plot_M = net_tr_M.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_M = depth_M.cf['X']
swmt_yt_M = depth_M.cf['Y']

# %%
shelf_subduction_plot_C_map = shelf_subduction_plot_C.mean(dim='time')

# %%
shelf_subduction_plot_C.astype('float32').compute()

# %%
shelf_subduction_plot_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_map_rho0_C_prescribed_access.nc')
shelf_subduction_plot_C_map.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_map_ave_rho0_C_prescribed_access.nc')

# %%
shelf_subduction_plot_M.astype('float32').compute()
# Out:
# <xarray.DataArray (time: 10, yt_ocean: 510, xt_ocean: 3600)> Size: 73MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
# Dimensions without coordinates: time

# %%
anom_xt = swmt_xt_M.fillna(0) - swmt_xt_C.fillna(0)
anom_yt = swmt_yt_M.fillna(0) - swmt_yt_C.fillna(0)
shelf_subduction_plot_anom = shelf_subduction_plot_M.fillna(0) - shelf_subduction_plot_C.fillna(0)

# %%
# Taking time means
shelf_subduction_plot_ave_anom = shelf_subduction_plot_anom.mean(dim='time')
shelf_subduction_plot_ave_anom
# Out:
# <xarray.DataArray (yt_ocean: 510, xt_ocean: 3600)> Size: 15MB
# dask.array<mean_agg-aggregate, shape=(510, 3600), dtype=float64, chunksize=(100, 100), chunktype=numpy.ndarray>
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413

# %%
shelf_subduction_plot_ave_anom = shelf_subduction_plot_ave_anom.load()

# %%
# Check before saving
shelf_subduction_plot_ave_anom.plot(vmin=-2,vmax=2, cmap=cm.cm.balance)

# %%
shelf_subduction_plot_ave_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_plot_anom_access.nc')

# %% [markdown]
# ### Finding the 25% and 75%
#
# Control max = 8.97311414 Sv (at density 27.67).
# - 25% of max (2.243278535 Sv) = 27.93 Sv
# - 75% of max (6.729835605 Sv) = 27.79 Sv
#
# - Control mean transport in this slice = BLANK Sv
# - Melt mean transport in this slice = BLANK Sv.
#
# We just use the control lines as our formation region.

# %%
# Finding maximum
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(27.70,27.9)).plot() # Pick slice based on plot, test for max value

# %%
# Finding maximum
swmt_shelf_sum_ave_C.sel(isopycnal_bins=27.95,method='nearest').compute() # Pick slice based on plot, test for max value
# Out:
# <xarray.DataArray ()> Size: 8B
# array(1.99261963)
# Coordinates:
#     isopycnal_bins  float64 8B 27.95
#     st_ocean        float64 8B 0.5413
# Attributes:
#     units:    Sv

# %% [markdown]
# Finding the sums: (change density values below to match 25 and 75 thresholds)

# %%
val_25 = 27.93
val_75 = 27.79

# %%
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(val_75,val_25)).compute().mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(3.38274397)
# Coordinates:
#     st_ocean  float64 8B 0.5413

# %%
swmt_shelf_sum_ave_M.sel(isopycnal_bins=slice(val_75,val_25)).compute().mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(2.8607094)
# Coordinates:
#     st_ocean  float64 8B 0.5413

# %% [markdown]
# ### Time series plot

# %%
swmt_shelf_time_C = swmt_shelf_sum_C.sel(isopycnal_bins=slice(val_75,val_25)).mean('isopycnal_bins').compute()

# %%
swmt_shelf_time_M = swmt_shelf_sum_M.sel(isopycnal_bins=slice(val_75,val_25)).mean('isopycnal_bins').compute()

# %%
swmt_shelf_time_C.plot(label="Control")
swmt_shelf_time_M.plot(label="Meltwater")
plt.ylabel("Surface water mass transformation (Sv)")
plt.xlabel("Year")
plt.legend(loc="lower left")
plt.title("ACCESS Surface Water Mass Transformation over 25-75% range")
# Out:
# Text(0.5, 1.0, 'ACCESS Surface Water Mass Transformation over 25-75% range')

# %%
# Saving
swmt_shelf_time_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_rho0_C.nc')
swmt_shelf_time_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_rho0_M.nc')

# %%
swmt_shelf_time_anom = swmt_shelf_time_M - swmt_shelf_time_C

# %%
swmt_shelf_time_anom.plot()

# %%
swmt_shelf_time_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_rho0_anom.nc')

# %% [markdown]
# ## Saving per year via manual method

# %%
# Change to your experiment of interest
expt_con = '01deg_jra55v13_ryf9091_21mbath'
expt_melt = '01deg_jra55v13_ryf9091_21mbath_sofia_ssp126_prsc_rest'
db = '/home/272/kc5856/databases/honours_prescribed.db'
session = cc.database.create_session(db)
freq = '1 monthly'

# Select time period and region
lon_slice = slice(None, None)
lat_slice = slice(None, -59)

# %% [markdown]
# #### First doing the control

# %%
# Check time slice
start_time = '1910-01-01'
end_time = '1910-12-31'
ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')

# %%
# Painfully manual don't mind this

start_time = '1910-01-01'
end_time = '1910-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_01.nc')

# %%
# Painfully manual don't mind this 2

start_time = '1911-01-01'
end_time = '1911-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_02.nc')

# %%
# Painfully manual don't mind this 3

start_time = '1912-01-01'
end_time = '1912-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_03.nc')

# %%
# Painfully manual don't mind this 4

start_time = '1913-01-01'
end_time = '1913-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_04.nc')

# %%
# Painfully manual don't mind this 5

start_time = '1914-01-01'
end_time = '1914-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_05.nc')

# %%
# Painfully manual don't mind this 6
start_time = '1915-01-01'
end_time = '1915-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_06.nc')

# %%
# Painfully manual don't mind this 7
start_time = '1916-01-01'
end_time = '1916-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_07.nc')

# %%
# Painfully manual don't mind this 8
start_time = '1917-01-01'
end_time = '1917-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_08.nc')

# %%
# Painfully manual don't mind this 9
start_time = '1918-01-01'
end_time = '1918-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_09.nc')

# %%
# Painfully manual don't mind this 10
start_time = '1919-01-01'
end_time = '1919-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_C_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_C_10.nc')

# %% [markdown]
# #### Second doing the perturbation

# %%
# Painfully manual don't mind this

start_time = '1910-01-01'
end_time = '1910-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_01.nc')

# %%
# Painfully manual don't mind this 2

start_time = '1911-01-01'
end_time = '1911-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_02.nc')

# %%
# Painfully manual don't mind this 3

start_time = '1912-01-01'
end_time = '1912-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_03.nc')

# %%
# Painfully manual don't mind this 4

start_time = '1913-01-01'
end_time = '1913-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_04.nc')

# %%
# Painfully manual don't mind this 5

start_time = '1914-01-01'
end_time = '1914-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_05.nc')

# %%
# Painfully manual don't mind this 6
start_time = '1915-01-01'
end_time = '1915-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_06.nc')

# %%
# Painfully manual don't mind this 7
start_time = '1916-01-01'
end_time = '1916-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_07.nc')

# %%
# Painfully manual don't mind this 8
start_time = '1917-01-01'
end_time = '1917-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_08.nc')

# %%
# Painfully manual don't mind this 9
start_time = '1918-01-01'
end_time = '1918-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_09.nc')

# %%
# Painfully manual don't mind this 10
start_time = '1919-01-01'
end_time = '1919-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_salt_trans_access_M_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/binned_heat_trans_access_M_10.nc')
