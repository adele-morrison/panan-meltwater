# %% [markdown]
# # SWMT on shelf for PanAntarctic 1/20th

# %%
import intake
import cosima_cookbook as cc
import glob

import cartopy.crs as ccrs
import cf_xarray as cfxr
import cmocean as cm
import dask.distributed
import gsw
import matplotlib.pyplot as plt
from matplotlib import gridspec 
import matplotlib.colors as mcolors
import matplotlib.path as mpath
import numpy as np
import xarray as xr
import pdb
import os
import pathlib
import shutil

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker = 1)
# Out:
# 2025-08-06 14:07:30,873 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38207' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-42b3e37c59845173dab802449d07afe2', 0, 0, 8, 61), ('getitem-721af230ef2105173f7e71935e147929', 4, 0, 9, 63), ('getitem-42b3e37c59845173dab802449d07afe2', 0, 0, 9, 63), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 6, 60), ('getitem-42b3e37c59845173dab802449d07afe2', 0, 0, 7, 60), ('getitem-42b3e37c59845173dab802449d07afe2', 4, 0, 9, 63), ('getitem-721af230ef2105173f7e71935e147929', 3, 0, 9, 63), ('getitem-721af230ef2105173f7e71935e147929', 0, 0, 9, 63), ('getitem-42b3e37c59845173dab802449d07afe2', 3, 0, 9, 63), ('getitem-42b3e37c59845173dab802449d07afe2', 0, 0, 8, 62), ('open_dataset-heat_transformation-07a3ad502e84d2b4190b537bcc2db7bb', 0, 5, 61)} (stimulus_id='handle-worker-cleanup-1754453250.8719811')
# 2025-08-06 14:07:30,909 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39319' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-f92decb6daa5ffeba05cc82b47079d9c', 0, 8, 63), ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 2, 63), 'shuffle-taker-e52311e75edf83048f1bd647db6df2ee', ('open_dataset-salt_transformation-f92decb6daa5ffeba05cc82b47079d9c', 0, 9, 63)} (stimulus_id='handle-worker-cleanup-1754453250.907687')
# 2025-08-06 14:07:30,935 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39403' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-721af230ef2105173f7e71935e147929', 0, 0, 8, 63), ('getitem-721af230ef2105173f7e71935e147929', 0, 0, 7, 63), ('broadcast_to-concatenate-stack-getitem-721af230ef2105173f7e71935e147929', 0, 0, 8, 62), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 3, 63)} (stimulus_id='handle-worker-cleanup-1754453250.9343007')
# 2025-08-06 14:07:30,955 - distributed.scheduler - WARNING - Received heartbeat from unregistered worker 'tcp://127.0.0.1:39403'.
# 2025-08-06 14:07:30,966 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40229' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 9, 63), ('open_dataset-salt_transformation-7953af303e4f8c927ca13d4f98c2bd71', 0, 1, 20), 'shuffle-taker-267c6502bd4b57af3c61d80f5259e115', ('open_dataset-salt_transformation-fd6d660cb0db559597ac177d567a5a09', 0, 8, 63)} (stimulus_id='handle-worker-cleanup-1754453250.9650233')
# 2025-08-06 14:07:30,981 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42163' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 7, 62), 'shuffle-taker-d128364a008a9f36d18ae42db4dc67e6', ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 5, 63)} (stimulus_id='handle-worker-cleanup-1754453250.9811137')
# 2025-08-06 14:07:30,998 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36815' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 2, 62), 'shuffle-taker-815b677fedec52d9d1225c747c96e7d9', ('getitem-721af230ef2105173f7e71935e147929', 4, 0, 6, 63), ('getitem-721af230ef2105173f7e71935e147929', 4, 0, 8, 63), ('broadcast_to-concatenate-stack-getitem-721af230ef2105173f7e71935e147929', 4, 0, 8, 62)} (stimulus_id='handle-worker-cleanup-1754453250.9971275')
# 2025-08-06 14:07:31,021 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37531' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('broadcast_to-concatenate-stack-getitem-721af230ef2105173f7e71935e147929', 3, 0, 8, 63), 'shuffle-sorter-9876c0d6182978ddcbcf8ce72ce562bb', ('open_dataset-salt_transformation-8ec8f7254fcbbe42160a8f5e08d0e577', 0, 7, 63)} (stimulus_id='handle-worker-cleanup-1754453251.020156')
# 2025-08-06 14:07:31,044 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33201' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-49b9dae4ffc4f300327997c614ea22d2', ('open_dataset-salt_transformation-98b33cc58045578c95d955e001713665', 0, 9, 63), ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 7, 61)} (stimulus_id='handle-worker-cleanup-1754453251.04379')
# 2025-08-06 14:07:31,059 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39911' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-702128e1ebfdef2aa25ad01670130605'} (stimulus_id='handle-worker-cleanup-1754453251.0584521')
# 2025-08-06 14:07:31,074 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45927' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-7f791fa9eb1e48b2c4ccb425746d267a', ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 5, 60), ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 9, 62)} (stimulus_id='handle-worker-cleanup-1754453251.074192')
# 2025-08-06 14:07:31,089 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37079' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 2, 60), ('broadcast_to-concatenate-stack-getitem-42b3e37c59845173dab802449d07afe2', 4, 0, 7, 63), ('getitem-42b3e37c59845173dab802449d07afe2', 4, 0, 8, 63), 'shuffle-taker-7868d4ea4485cabf5263b1c2fd6b5949'} (stimulus_id='handle-worker-cleanup-1754453251.0883904')
# 2025-08-06 14:07:31,109 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33877' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 4, 61), ('broadcast_to-concatenate-stack-getitem-42b3e37c59845173dab802449d07afe2', 6, 0, 9, 63), ('open_dataset-heat_transformation-5f47915890c2fe429adc504f03c9ea5a', 0, 8, 63)} (stimulus_id='handle-worker-cleanup-1754453251.108687')
# 2025-08-06 14:07:31,130 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37655' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-sorter-7c22aa8be3a8a24e29157209bb2ef591', ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 2, 61), ('broadcast_to-concatenate-stack-getitem-42b3e37c59845173dab802449d07afe2', 3, 0, 7, 63), ('getitem-42b3e37c59845173dab802449d07afe2', 3, 0, 8, 63)} (stimulus_id='handle-worker-cleanup-1754453251.1303203')
# 2025-08-06 14:07:31,160 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45099' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-7953af303e4f8c927ca13d4f98c2bd71', 0, 1, 29), ('open_dataset-heat_transformation-07a3ad502e84d2b4190b537bcc2db7bb', 0, 7, 63), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 8, 60), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 7, 63), 'shuffle-taker-e21dd025bffe30c5178314c392d65798'} (stimulus_id='handle-worker-cleanup-1754453251.1595752')
# 2025-08-06 14:07:31,172 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40337' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-9eeffc23cf74f937c5f4fb4add8f46d2'} (stimulus_id='handle-worker-cleanup-1754453251.1719918')
# 2025-08-06 14:07:31,184 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44173' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 6, 63), 'shuffle-taker-57e10119419f0567ac2235a38d2a1c22', ('open_dataset-salt_transformation-7953af303e4f8c927ca13d4f98c2bd71', 0, 9, 33)} (stimulus_id='handle-worker-cleanup-1754453251.1840668')
# 2025-08-06 14:07:31,197 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46583' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-721af230ef2105173f7e71935e147929', 8, 0, 7, 62), ('broadcast_to-concatenate-stack-getitem-721af230ef2105173f7e71935e147929', 8, 0, 6, 61), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 9, 63), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 8, 60), ('broadcast_to-concatenate-stack-getitem-721af230ef2105173f7e71935e147929', 8, 0, 6, 60), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 9, 60), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 7, 63), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 9, 62), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 4, 62), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 8, 61), ('getitem-721af230ef2105173f7e71935e147929', 8, 0, 9, 61)} (stimulus_id='handle-worker-cleanup-1754453251.196544')
# 2025-08-06 14:07:31,211 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40721' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-7953af303e4f8c927ca13d4f98c2bd71', 0, 9, 24), ('open_dataset-salt_transformation-acf8a183aa9a6ebc21dad55b234693e8', 0, 9, 63), ('open_dataset-salt_transformation-fd6d660cb0db559597ac177d567a5a09', 0, 8, 62), ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 5, 62), 'shuffle-taker-5d6506564252b7e150c7ce8bb7becf79'} (stimulus_id='handle-worker-cleanup-1754453251.2103984')
# 2025-08-06 14:07:31,241 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38621' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-921e6ddf308cc0a789f95c1cb0543bf9', 8, 63), ('open_dataset-heat_transformation-48e08173150b077e53628de3c438e58c', 0, 7, 63), ('open_dataset-heat_transformation-48e08173150b077e53628de3c438e58c', 0, 9, 63), ('array-ec70c28e04b2d44999b83c4086586d70', 0, 0)} (stimulus_id='handle-worker-cleanup-1754453251.2407868')
# 2025-08-06 14:07:31,283 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33437' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-8d9ce21546b553c3b8875fb71c3bf22c', 0, 8, 63), ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 3, 60), 'shuffle-taker-13a3f028f0c79ee9705c405c808bbc8b', ('open_dataset-salt_transformation-8d9ce21546b553c3b8875fb71c3bf22c', 0, 9, 63)} (stimulus_id='handle-worker-cleanup-1754453251.28257')
# 2025-08-06 14:07:31,302 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36033' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-42b3e37c59845173dab802449d07afe2', 5, 0, 9, 63), ('open_dataset-heat_transformation-7e9029a611fba13bdcf17f26c83c1588', 0, 7, 63), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 3, 61), ('getitem-42b3e37c59845173dab802449d07afe2', 5, 0, 8, 63), 'shuffle-taker-bf127c6931ff913a37fee12569a5a5f5'} (stimulus_id='handle-worker-cleanup-1754453251.3022697')
# 2025-08-06 14:07:31,323 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43299' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-e5766cb3e289c401284ae2e75a5f232f', 'original-open_dataset-heat_transformation-07a3ad502e84d2b4190b537bcc2db7bb'} (stimulus_id='handle-worker-cleanup-1754453251.3234415')
# 2025-08-06 14:07:31,343 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35985' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-2c029a08104446647d5a580a05d4dc94', 0, 7, 63), 'shuffle-taker-8173997349a5e33887f8f6a4fefce8c6', ('open_dataset-salt_transformation-2c029a08104446647d5a580a05d4dc94', 0, 9, 63)} (stimulus_id='handle-worker-cleanup-1754453251.3424232')
# 2025-08-06 14:07:31,363 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33335' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-42b3e37c59845173dab802449d07afe2', 9, 0, 7, 62), ('broadcast_to-concatenate-stack-getitem-42b3e37c59845173dab802449d07afe2', 9, 0, 4, 61), 'original-open_dataset-heat_transformation-c2b29eaf77f87832ab89d8855e655523', ('getitem-42b3e37c59845173dab802449d07afe2', 9, 0, 8, 63), ('getitem-42b3e37c59845173dab802449d07afe2', 9, 0, 7, 61), ('getitem-42b3e37c59845173dab802449d07afe2', 9, 0, 9, 63), ('rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 4, 63)} (stimulus_id='handle-worker-cleanup-1754453251.362846')
# 2025-08-06 14:07:31,382 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45427' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-371033f59bbd1115e5f335051df3041d', ('rechunk-split-rechunk-merge-0e97527d16c4dfe3c885aebcb7b7fcef', 0, 0, 3, 62), ('open_dataset-heat_transformation-fb765a640b56afb57eeaab9cd77d8323', 0, 9, 63)} (stimulus_id='handle-worker-cleanup-1754453251.3823774')
# 2025-08-06 14:07:31,408 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40503' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-salt_transformation-7953af303e4f8c927ca13d4f98c2bd71', 'original-open_dataset-salt_transformation-5a199d92307ab7a8409fcbc176676dc6', 'original-open_dataset-heat_transformation-5f47915890c2fe429adc504f03c9ea5a', 'original-open_dataset-heat_transformation-fb765a640b56afb57eeaab9cd77d8323', 'shuffle-taker-772b5cb3201196b4e58a286aa78cb822'} (stimulus_id='handle-worker-cleanup-1754453251.4074662')
# 2025-08-06 14:07:31,456 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33057' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-heat_transformation-48e08173150b077e53628de3c438e58c', 'original-open_dataset-salt_transformation-f0875e8692621676ef2c8aed39c124b5', 'original-open_dataset-heat_transformation-3cdc0aa5caaf1449672b72e28b9f2a0b', 'original-open_dataset-salt_transformation-98b33cc58045578c95d955e001713665', 'original-open_dataset-salt_transformation-8ec8f7254fcbbe42160a8f5e08d0e577', 'original-open_dataset-salt_transformation-f92decb6daa5ffeba05cc82b47079d9c', ('open_dataset-salt_transformation-fd6d660cb0db559597ac177d567a5a09', 0, 6, 63), 'original-open_dataset-heat_transformation-7ec7114cb372bc084205801813e83a56', 'original-open_dataset-salt_transformation-acf8a183aa9a6ebc21dad55b234693e8', 'original-open_dataset-salt_transformation-8d9ce21546b553c3b8875fb71c3bf22c', 'original-open_dataset-salt_transformation-2c029a08104446647d5a580a05d4dc94', ('broadcast_to-concatenate-stack-getitem-721af230ef2105173f7e71935e147929', 9, 0, 9, 63), 'original-open_dataset-salt_transformation-fd6d660cb0db559597ac177d567a5a09', 'original-open_dataset-heat_transformation-725ab24cf74e9b047fb24d2df7486ad3', 'original-open_dataset-heat_transformation-7e9029a611fba13bdcf17f26c83c1588'} (stimulus_id='handle-worker-cleanup-1754453251.456431')
# 2025-08-06 14:08:02,176 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,178 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,179 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,181 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,183 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,185 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,186 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-08-06 14:08:02,188 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing

# %%
def get_variables(expt, freq, start_time, end_time, lon_slice, lat_slice, model):

    # The models require different diagnostics to calculate the heat and salt fluxes.
    # mom6 outputs a net flux, whilst with mom5 we need to work with the separate components.
    model_vars = {
                    "mom5": {
                        "temperature":           ["temp"],
                        "salinity":              ["salt"],
                        "water_flux_into_ocean": ["pme_river"],
                        "salt_flux":             ["sfc_salt_flux_ice", "sfc_salt_flux_restore"],
                        "heat_flux":             ["sfc_hflux_coupler", "sfc_hflux_from_runoff",
                                                  "frazil_3d_int_z", "sfc_hflux_pme"],
                        "area":                  ["area_t"],
                        "maximum_depth":         ["ht"],
                    },
                    "mom6": {
                        "temperature":           ["thetao"],
                        "salinity":              ["so"],
                        "water_flux_into_ocean": ["wfo"],
                        "salt_flux":             ["salt_flux"],
                        "heat_flux":             ["hfds"],
                        "area":                  ["areacello"],
                        "maximum_depth":         ["deptho"],
                    }
                }
    # Load variables in a dictionary
    ds = {}
    keys = list(model_vars[model].keys())
    for k in keys:
        ds[k] = {}
        for var in model_vars[model][k]:
            if k in ["area", "maximum_depth"]:
                ds[k][var] = cc.querying.getvar(expt, var, session, ncfile = 'ocean_static.nc', n = 1) 
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice)
                
            if k in ["water_flux_into_ocean","salt_flux","heat_flux"]:
                ds[k][var] = cc.querying.getvar(expt, var, session,
                                                    ncfile = 'ocean_month.nc',
                                                    frequency = freq,
                                                    start_time = start_time,
                                                    end_time = end_time,
                                                    chunks = {'time': 1})
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice, time = slice(start_time, end_time))
                
            # If neither of the above ifs were True, then do the else block
            if k not in ["area", "maximum_depth", "water_flux_into_ocean","salt_flux","heat_flux"]:
                try:
                    ds[k][var] = cc.querying.getvar(expt, var, session,
                                                    ncfile='ocean_month_z.nc',
                                                    frequency=freq,
                                                    start_time=start_time,
                                                    end_time=end_time,
                                                    chunks={'time': 1})
                    ds[k][var] = ds[k][var].cf.sel(X=lon_slice, Y=lat_slice, time=slice(start_time, end_time))
                    
                    # Correct temperatures (if in K convert to C)
                    if k == 'temperature' and np.max(ds[k][var]) > 100:
                        ds[k][var] = ds[k][var] - 273.15
    
                    # If 3D field, grab the surface
                    if ds[k][var].cf.axes.get('Z'):
                        surface_z = ds[k][var].cf['Z'][0].values
                        ds[k][var] = ds[k][var].cf.sel(Z=0, method='nearest')
                except Exception as e:
                    raise Exception(f"Data loading error: var={var}, freq={freq}, start_time={start_time}, end_time={end_time}, expt={expt}: {str(e)}")

    # Get temperature and salinity to calculate few other things we'll need later on
    SP = ds['salinity'][model_vars[model]['salinity'][0]]
    CT = ds['temperature'][model_vars[model]['temperature'][0]]

    # Calculate pressure
    pressure = gsw.p_from_z(-surface_z, SP.cf['Y']).rename('pressure')

    # Calculate absolute salinity
    SA = gsw.SA_from_SP(SP, pressure, SP.cf['X'], SP.cf['Y']).rename('SA')

    # Ensure we have conservative temperature; Convert MOM6's potential temperature to conservative
    if model == 'mom6':
        CT = gsw.CT_from_pt(SA, CT)
        ds['temperature'][model_vars[model]['temperature'][0]].data = CT.values

    # Calculate potential density
    pot_rho_0 = gsw.sigma0(SA, CT)#.rename('pot_rho_11')

    # Save everything to our dictionary
    ds['pressure'] = pressure
    ds['SA'] = SA
    ds['pot_rho_0'] = pot_rho_0
    
    # Calculate days per month accounting for leap years
    months_standard_noleap = np.array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    months_standard_leap = np.array([31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    if 'ryf' or 'panan' in expt:
        nyears = len(np.unique(CT['time.year']))
        days_per_month = np.tile(months_standard_noleap, nyears)
    elif 'iaf' in expt:
        nyears = len(np.unique(CT['time.year']))
        if CT['time.year'][0] % 4 == 0:
            days_per_month = months_standard_leap
        else: 
            days_per_month = months_standard_noleap
        for yr in CT['time.year'][::12][1:]:
            if yr % 4 == 0:
                days_per_month = np.concatenate([days_per_month, months_standard_leap])
            else:
                days_per_month = np.concatenate([days_per_month, months_standard_noleap])
    days_per_month = xr.DataArray(days_per_month, dims = ['time'], coords = {'time': CT['time']}, name = 'days_per_month')
    ds['days_per_month'] = days_per_month

    return ds

# %%
def compute_salt_transformation(ds):
    
    # First retrieve temperature and water_flux as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Multiply the water flux by absolute salinity to get it in the correct units
    water_flux_into_ocean = xr.Dataset(ds['water_flux_into_ocean']).to_array().squeeze().drop_vars('variable')
    water_flux_into_ocean = ds['SA'] * water_flux_into_ocean

    # Caculate the haline contraction coefficient
    haline_contraction = gsw.beta(ds['SA'], CT, ds['pressure']).rename('beta')

    # Calculate the net salt flux and multiply by 1000 to convert units
    net_salt_flux = xr.Dataset(ds['salt_flux']).to_array().sum(dim = 'variable') * 1000

    # Note that we also multiply pme_river by absolute salinity to have the correct units
    salt_transformation = haline_contraction * (water_flux_into_ocean - net_salt_flux) * ds['days_per_month']
    salt_transformation = salt_transformation.load()

    return salt_transformation

def compute_heat_transformation(ds):

    # First retrieve temperature as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Calculate the thermal expansion coefficient 
    thermal_expansion = gsw.alpha(ds['SA'], CT, ds['pressure']).rename('alpha')
    
    # Calculate the net surface heating
    net_surface_heating = xr.Dataset(ds['heat_flux']).to_array().sum(dim = 'variable')
    
    # Calculate the heat transformation
    heat_transformation = thermal_expansion * net_surface_heating * ds['days_per_month']
    heat_transformation = heat_transformation.load()

    return heat_transformation

# %%
def isopycnal_bins(ds, salt_transformation, heat_transformation):

    # Next section does a few things. It cycles through isopycnal bins, determines which cells are 
    # within the given bin for each month, finds the transformation values for those cells for each month, 
    # and sums these through time. You are left with an array of shape (isopyncal bins * lats * lons) 
    # where the array associated with a given isopycnal bin is NaN everywhere except where pot_rho_0
    # was within the bin, there it has a time summed transformation value.
    
    # Choose appropriate bin range
    #isopycnal_bins = np.arange(31, 33.5, 0.02)  # 125 bins - 31, 33.5, 0.02 (sigma1)
    isopycnal_bins = np.concatenate([np.arange(25.0, 26.5, 0.05), np.arange(26.5, 28.5, 0.02)])  # 130 bins (sigma0)
    bin_bottoms = isopycnal_bins[:-1]
    isopycnal_bin_mid = (isopycnal_bins[1:] + bin_bottoms) / 2
    isopycnal_bin_diff = np.diff(isopycnal_bins)

    pot_rho_0 = ds['pot_rho_0']

    results_salt = []
    results_heat = []

    for i in range(len(bin_bottoms)):
        # Create binary mask for each bin
        bin_mask = xr.where((pot_rho_0 > bin_bottoms[i]) & (pot_rho_0 <= isopycnal_bins[i + 1]), 1, np.nan)

        # Multiply and sum over time
        salt_sum = (salt_transformation * bin_mask).sum(dim='time')
        heat_sum = (heat_transformation * bin_mask).sum(dim='time')

        results_salt.append(salt_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))
        results_heat.append(heat_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))

    # Concatenate results along isopycnal dimension
    salt_transformation = xr.concat(results_salt, dim='isopycnal_bins')
    heat_transformation = xr.concat(results_heat, dim='isopycnal_bins')

    # Normalise by number of days and bin thickness
    ndays = ds['days_per_month'].sum()
    c_p = 3992.1 # J kg-1 degC-1

    salt_transformation /= ndays
    heat_transformation /= (c_p * ndays)

    salt_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]
    heat_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]

    # Overwrite zeros with NANs 
    # (Note: the code within the for-loop should provide nans but lazy computing with dask can sometimes give unpredictable results)
    salt_transformation = salt_transformation.where(salt_transformation != 0)
    heat_transformation = heat_transformation.where(heat_transformation != 0)

    # Change the sign so that positive means conversion into denser water masses
    salt_transformation *= -1
    heat_transformation *= -1

    # Renaming
    salt_transformation.name = "salt_transformation"
    heat_transformation.name = "heat_transformation"

    return salt_transformation.load(), heat_transformation.load()

# %% [markdown]
# ## Test saved data

# %%
test_dir = '/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/binned_salt_trans_pan005_C_2001.nc'

# %%
try:
    test = xr.open_dataset(test_dir)
    print(test)

    # Check if the Dataset is empty (no variables other than coords)
    if len(test.data_vars) == 0:
        print("Dataset has no data variables.")
    else:
        print("Dataset contains data variables:", list(test.data_vars))

except Exception as e:
    print("Failed to open file:", e)
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:              (isopycnal_bins: 129, xh: 7200, yh: 1019)
# Coordinates:
#   * isopycnal_bins       (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.47
#   * xh                   (xh) float64 58kB -280.0 -279.9 -279.9 ... 79.92 79.97
#   * yh                   (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.05 -59.02
#     z_l                  float64 8B ...
# Data variables:
#     salt_transformation  (isopycnal_bins, yh, xh) float64 8GB ...
# Dataset contains data variables: ['salt_transformation']

# %%
test_var = test['salt_transformation']
print(test_var.isel(isopycnal_bins=40, yh=0, xh=0).values)  # Single value
# Out:
# nan

# %%
if not test['salt_transformation'].isnull().any().compute().item():
    print("All NaNs")
else:
    print("Has at least one non-NaN")
# Out:
# Has at least one non-NaN

# %% [markdown]
# ## Opening the saved data

# %%
# Importing the saved files
salt_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/binned_salt_trans_pan005_C_*.nc'))
heat_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/binned_heat_trans_pan005_C_*.nc'))

salt_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/binned_salt_trans_pan005_M_*.nc'))
heat_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/binned_heat_trans_pan005_M_*.nc'))

# %%
salt_tr_C = xr.open_mfdataset(salt_files_C, concat_dim='time', combine='nested', chunks={'time': 1, 'yh': 100, 'xh': 100})
heat_tr_C = xr.open_mfdataset(heat_files_C, concat_dim='time', combine='nested', chunks={'time': 1, 'yh': 100, 'xh': 100})
salt_tr_C = salt_tr_C.to_array().squeeze()
heat_tr_C = heat_tr_C.to_array().squeeze()

# %%
salt_tr_C
# Out:
# <xarray.DataArray (time: 10, isopycnal_bins: 129, yh: 1019, xh: 7200)> Size: 76GB
# dask.array<getitem, shape=(10, 129, 1019, 7200), dtype=float64, chunksize=(1, 129, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#   * xh              (xh) float64 58kB -280.0 -279.9 -279.9 ... 79.87 79.92 79.97
#   * yh              (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.05 -59.02
#     z_l             float64 8B 0.5413
#     variable        <U19 76B 'salt_transformation'
# Dimensions without coordinates: time

# %%
salt_tr_M = xr.open_mfdataset(salt_files_M, concat_dim='time', combine='nested', chunks={'time': 1, 'yh': 100, 'xh': 100})
heat_tr_M = xr.open_mfdataset(heat_files_M, concat_dim='time', combine='nested', chunks={'time': 1, 'yh': 100, 'xh': 100})
salt_tr_M = salt_tr_M.to_array().squeeze()
heat_tr_M = heat_tr_M.to_array().squeeze()

# %%
net_tr_C = salt_tr_C + heat_tr_C
net_tr_M = salt_tr_M + heat_tr_M

# %% [markdown]
# #### Antarctic shelf dense water formation

# %%
def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
lat_slice = slice(None, -59)
depth = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['deptho'].sel(yh=lat_slice)
area = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_static.nc')['areacello'].sel(yh=lat_slice)
varr = xr.open_dataset('/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESSyr2/output239/20101201.ocean_month_z.nc')['so'].sel(yh=lat_slice).isel(z_l=0)
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom6_005')

# %%
varr
# Out:
# <xarray.DataArray 'so' (time: 1, yh: 1019, xh: 7200)> Size: 29MB
# [7336800 values with dtype=float32]
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#     z_l      float64 8B 0.5413
#   * time     (time) object 8B 2010-12-16 12:00:00
# Attributes:
#     units:          psu
#     long_name:      Sea Water Salinity
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  volume: volcello area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_salinity

# %%
area_corr = (area*(varr*0+1))
area_corr = area_corr.drop_vars(['time','z_l']).squeeze()
area_corr
# Out:
# <xarray.DataArray (yh: 1019, xh: 7200)> Size: 29MB
# array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        ...,
#        [8168440.5, 8168440.5, 8168440.5, ..., 8168440.5, 8168440.5,
#         8168440.5],
#        [8174556.5, 8174556.5, 8174556.5, ..., 8174556.5, 8174556.5,
#         8174556.5],
#        [8192951. , 8192951. , 8192951. , ..., 8192951. , 8192951. ,
#         8192951. ]], dtype=float32)
# Coordinates:
#   * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#   * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02

# %%
# Check mask
area_corr.plot()

# %% [markdown]
# Corrected area not needed because it is already being multiplied with a variable with the correct mask below?

# %%
swmt_shelf_C = (net_tr_C * area_corr / 1e6).where(shelf_mask == 1)
heat_shelf_C = (heat_tr_C * area_corr / 1e6).where(shelf_mask == 1)
salt_shelf_C = (salt_tr_C * area_corr / 1e6).where(shelf_mask == 1)

swmt_shelf_C = swmt_shelf_C.chunk({'time': 1, 'yh': 100, 'xh': 100})
heat_shelf_C = heat_shelf_C.chunk({'time': 1, 'yh': 100, 'xh': 100})
salt_shelf_C = salt_shelf_C.chunk({'time': 1, 'yh': 100, 'xh': 100})

# %%
swmt_shelf_sum_C = swmt_shelf_C.cf.sum(['xh', 'yh'])
swmt_shelf_sum_C
# Out:
# <xarray.DataArray (time: 10, isopycnal_bins: 129)> Size: 10kB
# dask.array<sum-aggregate, shape=(10, 129), dtype=float64, chunksize=(1, 129), chunktype=numpy.ndarray>
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#     z_l             float64 8B 0.5413
# Dimensions without coordinates: time

# %%
swmt_shelf_sum_C = swmt_shelf_sum_C.compute()

# %%
# Time mean
swmt_shelf_sum_ave_C = swmt_shelf_sum_C.mean(dim='time')

for da in [swmt_shelf_sum_ave_C]:#, heat_shelf_sum_ave_C, salt_shelf_sum_ave_C]:
    da.attrs["units"] = "Sv"

# %%
swmt_shelf_sum_ave_C # check

# %%
swmt_shelf_sum_ave_C.compute()

# %%
swmt_shelf_sum_ave_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_C_pan005.nc')

# %%
swmt_shelf_M = (net_tr_M * area_corr / 1e6).where(shelf_mask == 1)
heat_shelf_M = (heat_tr_M * area_corr / 1e6).where(shelf_mask == 1)
salt_shelf_M = (salt_tr_M * area_corr / 1e6).where(shelf_mask == 1)

swmt_shelf_M = swmt_shelf_M.chunk({'time': 1, 'yh': 100, 'xh': 100})
heat_shelf_M = heat_shelf_M.chunk({'time': 1, 'yh': 100, 'xh': 100})
salt_shelf_M = salt_shelf_M.chunk({'time': 1, 'yh': 100, 'xh': 100})

# %%
swmt_shelf_sum_M = swmt_shelf_M.cf.sum(['xh', 'yh'])
swmt_shelf_sum_M
# Out:
# <xarray.DataArray (time: 10, isopycnal_bins: 129)> Size: 10kB
# dask.array<sum-aggregate, shape=(10, 129), dtype=float64, chunksize=(1, 129), chunktype=numpy.ndarray>
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#     z_l             float64 8B 0.5413
# Dimensions without coordinates: time

# %%
swmt_shelf_sum_M = swmt_shelf_sum_M.compute()
# Out:
# 2025-08-06 11:13:02,887 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:36671 -> tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36671 remote=tcp://127.0.0.1:38072>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:04,283 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36671
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38072 remote=tcp://127.0.0.1:36671>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:08,956 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:32943 -> tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:32943 remote=tcp://127.0.0.1:43862>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:08,956 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:39521 -> tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:39521 remote=tcp://127.0.0.1:58160>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:11,245 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:33777 -> tcp://127.0.0.1:43937
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:33777 remote=tcp://127.0.0.1:42760>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:13,351 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41805
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42954 remote=tcp://127.0.0.1:41805>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:13,452 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33777
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42760 remote=tcp://127.0.0.1:33777>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:22,320 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41805 -> tcp://127.0.0.1:43937
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41805 remote=tcp://127.0.0.1:42954>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:23,332 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:32943
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:43862 remote=tcp://127.0.0.1:32943>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:31,783 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:35765 -> tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:35765 remote=tcp://127.0.0.1:52426>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:34,301 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34123
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42728 remote=tcp://127.0.0.1:34123>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:34,705 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:44147 -> tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:44147 remote=tcp://127.0.0.1:57568>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:40,454 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33493
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:34772 remote=tcp://127.0.0.1:33493>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:40,524 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:44147
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:57568 remote=tcp://127.0.0.1:44147>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:40,556 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41189
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:47666 remote=tcp://127.0.0.1:41189>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:40,593 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39521
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:58160 remote=tcp://127.0.0.1:39521>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:40,613 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:35765
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:52426 remote=tcp://127.0.0.1:35765>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:47,735 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:46729 -> tcp://127.0.0.1:45723
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:46729 remote=tcp://127.0.0.1:41876>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:49,932 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36671
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:33300 remote=tcp://127.0.0.1:36671>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:49,986 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41189 -> tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41189 remote=tcp://127.0.0.1:47666>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:55,182 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38523
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:60058 remote=tcp://127.0.0.1:38523>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:56,381 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40923
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:44102 remote=tcp://127.0.0.1:40923>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:56,453 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46729
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:41924 remote=tcp://127.0.0.1:46729>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:56,691 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:34123 -> tcp://127.0.0.1:45723
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:34123 remote=tcp://127.0.0.1:42728>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:13:56,843 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38523
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:60024 remote=tcp://127.0.0.1:38523>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:13:57,497 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:33493 -> tcp://127.0.0.1:38525
# ...
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:38525 remote=tcp://127.0.0.1:60542>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:15:24,505 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41805 -> tcp://127.0.0.1:41189
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41805 remote=tcp://127.0.0.1:47696>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:15:25,416 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41805
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:47696 remote=tcp://127.0.0.1:41805>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:15:33,848 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38523
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48538 remote=tcp://127.0.0.1:38523>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:15:34,591 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38525
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:60542 remote=tcp://127.0.0.1:38525>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:15:42,630 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33777
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:43392 remote=tcp://127.0.0.1:33777>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:15:57,151 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41805
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:52056 remote=tcp://127.0.0.1:41805>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-08-06 11:15:59,859 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:33777 -> tcp://127.0.0.1:46107
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:33777 remote=tcp://127.0.0.1:43392>: TimeoutError: [Errno 110] Connection timed out
# 2025-08-06 11:16:02,908 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:41805 -> tcp://127.0.0.1:33777
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:41805 remote=tcp://127.0.0.1:52056>: TimeoutError: [Errno 110] Connection timed out

# %%
# Time mean
swmt_shelf_sum_ave_M = swmt_shelf_sum_M.mean(dim='time')

for da in [swmt_shelf_sum_ave_M]: #, heat_shelf_sum_ave_M, salt_shelf_sum_ave_M]:
    da.attrs["units"] = "Sv"

# %%
swmt_shelf_sum_ave_M.compute()
# Out:
# <xarray.DataArray (isopycnal_bins: 129)> Size: 1kB
# array([-1.96803597e-01, -2.00268899e-01, -2.02041537e-01, -1.85940839e-01,
#        -1.92161829e-01, -1.91597780e-01, -1.64940581e-01, -1.79829126e-01,
#        -1.84153999e-01, -1.75477988e-01, -1.81877198e-01, -1.53582699e-01,
#        -1.63964938e-01, -1.65447564e-01, -1.55656501e-01, -1.57576613e-01,
#        -1.45908450e-01, -1.29330384e-01, -1.27162674e-01, -1.14673314e-01,
#        -1.04530340e-01, -1.02926015e-01, -9.26165042e-02, -9.02392476e-02,
#        -8.27936883e-02, -8.88027305e-02, -1.38217826e-01, -2.01196801e-01,
#        -1.83911492e-01, -1.75302987e-01, -1.76068080e-01, -1.28323391e-01,
#        -1.29796187e-01, -1.22607844e-01, -1.23737079e-01, -1.35191680e-01,
#        -1.32980486e-01, -1.66367725e-01, -2.50559879e-01, -2.61343693e-01,
#        -2.52662825e-01, -1.96695435e-01, -2.25047110e-01, -2.25923451e-01,
#        -2.91337102e-01, -2.87241257e-01, -1.65737015e-01,  9.93280634e-03,
#         8.51517034e-02,  1.20122478e-01,  1.33872343e-01,  1.10978573e-01,
#         1.09533024e-02,  3.82853585e-02,  3.90166719e-01,  5.23693891e-01,
#         6.02573591e-01,  6.32520160e-01,  7.16469099e-01,  9.33534618e-01,
#         1.04138677e+00,  1.09526799e+00,  1.07618162e+00,  1.12358970e+00,
#         1.30166555e+00,  1.56387326e+00,  1.78655471e+00,  1.86913169e+00,
#         2.05641556e+00,  2.19500139e+00,  2.40680303e+00,  2.98379540e+00,
#         3.22014158e+00,  3.24223485e+00,  3.47698619e+00,  3.60486212e+00,
#         3.97222588e+00,  4.82842074e+00,  5.26365022e+00,  5.13098617e+00,
#         5.56542167e+00,  6.15189115e+00,  6.33111844e+00,  6.76187071e+00,
#         7.04053462e+00,  7.22308781e+00,  7.39714728e+00,  7.23044369e+00,
#         6.87804642e+00,  5.75576690e+00,  5.22640153e+00,  4.96224362e+00,
#         4.70001001e+00,  4.14689672e+00,  3.46955377e+00,  2.63269028e+00,
#         2.10152626e+00,  1.77096987e+00,  1.58732096e+00,  1.49359659e+00,
#         1.35032231e+00,  1.08708129e+00,  8.88958174e-01,  7.17602275e-01,
#         3.71531428e-01,  1.06328821e-01,  2.67572170e-02,  8.49371748e-03,
#         7.54659134e-03,  6.83350636e-03,  6.11676208e-03,  5.90584850e-03,
#         5.01340129e-03,  4.30171888e-03,  4.50122803e-03,  4.18244616e-03,
#         3.63801624e-03,  2.89526170e-03,  3.54746557e-03,  3.16646058e-03,
#         2.67327033e-03,  2.58193388e-03,  2.01495306e-03,  1.83489651e-03,
#         2.14265665e-03,  1.88568051e-03,  1.95811453e-03,  1.81575753e-03,
#         1.45362768e-03])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 1kB 25.02 25.08 ... 28.45 28.47
#     z_l             float64 8B 0.5413
# Attributes:
#     units:    Sv

# %%
swmt_shelf_sum_ave_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_M_pan005.nc')

# %%
# Open loaded data
swmt_shelf_sum_ave_C = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_C_pan005.nc')
swmt_shelf_sum_ave_M = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_M_pan005.nc')

# %%
swmt_shelf_sum_ave_C.plot()#.drop_vars('z_l')

# %%
# 25% and 75% thresholds
## Replace when using new data
cont_d25 = 27.87
cont_d75 = 27.71

# %%
fig, ax1 = plt.subplots(figsize=(4.5, 5.33))

ax1.plot(swmt_shelf_sum_ave_C, swmt_shelf_sum_ave_C['isopycnal_bins'], color = 'k', label='Control: 3.74 Sv')
ax1.plot(swmt_shelf_sum_ave_M, swmt_shelf_sum_ave_M['isopycnal_bins'], color = 'r', label='Meltwater: 3.17 Sv')
ax1.plot([0, 0], [26.5,28.49], 'k', linewidth=0.5)
ax1.plot([-5, 15], [cont_d25, cont_d25], 'k--', linewidth=1)
ax1.plot([-5, 15], [cont_d75, cont_d75], 'k--', linewidth=1)
ax1.set_ylim((28.45, 26.5))
ax1.set_xlim((-1.5, 10))
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()
ax1.set_ylabel('Density $\sigma_0$ (kg m$^{-3}$)')
ax1.set_xlabel('Surface water-mass transformation (Sv)')
ax1.legend();

# %% [markdown]
# #### SWMT map

# %%
transformation_density = 32.58 ## Replace when using new data
shelf_subduction_plot_C = net_tr_C.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_C = depth.cf['X']
swmt_yt_C = depth.cf['Y']

shelf_subduction_plot_M = net_tr_M.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_M = depth.cf['X']
swmt_yt_M = depth.cf['Y']

# %%
shelf_subduction_plot_C.astype('float32').compute()

# %%
shelf_subduction_plot_M.astype('float32').compute()

# %%
anom_xt = swmt_xt_M.fillna(0) - swmt_xt_C.fillna(0)
anom_yt = swmt_yt_M.fillna(0) - swmt_yt_C.fillna(0)
shelf_subduction_plot_anom = shelf_subduction_plot_M.fillna(0) - shelf_subduction_plot_C.fillna(0)

# %%
# Taking time means
shelf_subduction_plot_ave_anom = shelf_subduction_plot_anom.mean(dim='time')
shelf_subduction_plot_ave_anom

# %%
shelf_subduction_plot_ave_anom = shelf_subduction_plot_ave_anom.load()

# %%
# Check before saving
shelf_subduction_plot_ave_anom.plot(vmin=-2,vmax=2, cmap=cm.cm.balance)

# %%
shelf_subduction_plot_ave_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/plots/swmt_shelf_plot_anom_pan005.nc')

# %% [markdown]
# #### Finding the 25% and 75%

# %% [markdown]
# Control max = 7.645755 Sv (at density 27.67).
# - 25% of max (1.91143875 Sv) = occurs at 27.87.
# - 75% of max (5.73431625 Sv) = occurs at 27.71.
#
# Finding the means in this region:
# - Mean of control in this slice = **3.73778507 Sv**.
# - Mean of meltwater in this region = **3.17140144 Sv**.
#
# We just use the control lines as our formation region.

# %%
# Finding maximum
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(27.65,27.75)) # Pick slice based on plot, test for max value
# Out:
# <xarray.DataArray (isopycnal_bins: 5)> Size: 40B
# array([7.645755, 6.954727, 5.830856, 5.39573 , 4.909248])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 40B 27.67 27.69 27.71 27.73 27.75
#     z_l             float64 8B ...
# Attributes:
#     units:    Sv

# %% [markdown]
# Finding the sums: (change density values below to match 25 and 75 thresholds)

# %%
val_25 = 27.87
val_75 = 27.71

# %%
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(val_75,val_25)).compute().mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(3.73778507)
# Coordinates:
#     z_l      float64 8B 0.5413

# %%
swmt_shelf_sum_ave_M.sel(isopycnal_bins=slice(val_75,val_25)).compute().mean()
# Out:
# <xarray.DataArray ()> Size: 8B
# array(3.17140144)
# Coordinates:
#     z_l      float64 8B 0.5413

# %% [markdown]
# #### Time series

# %%
pan01_25 = 27.89
pan01_75 = 27.73

# %%
swmt_shelf_time_C = swmt_shelf_sum_C.sel(isopycnal_bins=slice(pan01_75,pan01_25)).mean('isopycnal_bins').compute()

# %%
swmt_shelf_time_M = swmt_shelf_sum_M.sel(isopycnal_bins=slice(pan01_75,pan01_75)).mean('isopycnal_bins').compute()

# %%
# Saving
swmt_shelf_time_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_time_pan005_C.nc')
swmt_shelf_time_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_time_pan005_M.nc')

# %%
swmt_shelf_time_C.plot(label="Control")
swmt_shelf_time_M.plot(label="Meltwater")
plt.ylabel("Surface water mass transformation (Sv)")
plt.xlabel("Year")
plt.legend(loc="lower left")
plt.title("Panan01 Surface Water Mass Transformation over 25-75% range")

# %%
swmt_shelf_time_anom = swmt_shelf_time_M - swmt_shelf_time_C

# %%
swmt_shelf_time_anom.plot()

# %%
swmt_shelf_time_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf_rho0/plots/swmt_shelf_time_pan005_anom.nc')

# %% [markdown]
# ## Saving per year via manual method

# %%
# Change to your experiment of interest
expt_con = 'panant-005-zstar-ACCESSyr2'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)
freq = '1 monthly'

# Select time period and region
lon_slice = slice(None, None)
lat_slice = slice(None, -59)

# %%
# Checking get_var function
start_time = '2001-01-01'
end_time = '2001-12-31'
ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
ds
# Out:
# {'temperature': {'thetao': <xarray.DataArray 'thetao' (time: 12, yh: 1019, xh: 7200)> Size: 704MB
#   array([[[        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           [        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           [        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           ...,
#           [-0.44529088, -0.45150922, -0.45710383, ..., -0.42346004,
#            -0.43125784, -0.4387381 ],
#           [-0.42615965, -0.4322085 , -0.43839317, ..., -0.40536368,
#            -0.41334389, -0.41974192],
#           [-0.37759102, -0.38348353, -0.39126518, ..., -0.37344133,
#            -0.37350139, -0.37446215]],
#
#          [[        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           [        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           [        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#   ...
#           [-1.51539352, -1.51526009, -1.51569758, ..., -1.51504306,
#            -1.51547219, -1.51546625],
#           [-1.49590181, -1.49620518, -1.49652206, ..., -1.49436517,
#            -1.49536945, -1.49591312],
#           [-1.47320336, -1.47429138, -1.4753231 , ..., -1.46877215,
#            -1.47056447, -1.47224718]],
#
#          [[        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           [        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           [        nan,         nan,         nan, ...,         nan,
#                    nan,         nan],
#           ...,
#           [-0.93437785, -0.9383927 , -0.94055558, ..., -0.93157031,
#            -0.93045316, -0.9308777 ],
#           [-0.92858172, -0.93487771, -0.93713664, ..., -0.9100448 ,
#            -0.91462684, -0.92195014],
#           [-0.9216493 , -0.92868285, -0.93077032, ..., -0.88903426,
#            -0.89891569, -0.90867817]]])
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#       z_l      float64 8B 0.5413
#     * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#   Attributes:
#       units:          degC
#       long_name:      Sea Water Potential Temperature
#       cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#       cell_measures:  volume: volcello area: areacello
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  sea_water_potential_temperature
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'salinity': {'so': <xarray.DataArray 'so' (time: 12, yh: 1019, xh: 7200)> Size: 352MB
#   dask.array<getitem, shape=(12, 1019, 7200), dtype=float32, chunksize=(1, 94, 100), chunktype=numpy.ndarray>
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#       z_l      float64 8B 0.5413
#     * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#   Attributes:
#       units:          psu
#       long_name:      Sea Water Salinity
#       cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#       cell_measures:  volume: volcello area: areacello
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  sea_water_salinity
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'water_flux_into_ocean': {'wfo': <xarray.DataArray 'wfo' (time: 12, yh: 1019, xh: 7200)> Size: 352MB
#   dask.array<getitem, shape=(12, 1019, 7200), dtype=float32, chunksize=(1, 188, 200), chunktype=numpy.ndarray>
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#     * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#   Attributes:
#       units:          kg m-2 s-1
#       long_name:      Water Flux Into Sea Water
#       cell_methods:   area:mean yh:mean xh:mean time: mean
#       cell_measures:  area: areacello
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  water_flux_into_sea_water
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'salt_flux': {'salt_flux': <xarray.DataArray 'salt_flux' (time: 12, yh: 1019, xh: 7200)> Size: 352MB
#   dask.array<getitem, shape=(12, 1019, 7200), dtype=float32, chunksize=(1, 188, 200), chunktype=numpy.ndarray>
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#     * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#   Attributes:
#       units:          kg m-2 s-1
#       long_name:      Net salt flux into ocean at surface (restoring + sea-ice)
#       cell_methods:   area:mean yh:mean xh:mean time: mean
#       cell_measures:  area: areacello
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'heat_flux': {'hfds': <xarray.DataArray 'hfds' (time: 12, yh: 1019, xh: 7200)> Size: 352MB
#   dask.array<getitem, shape=(12, 1019, 7200), dtype=float32, chunksize=(1, 188, 200), chunktype=numpy.ndarray>
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#     * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#   Attributes:
#       units:          W m-2
#       long_name:      Surface ocean heat flux from SW+LW+latent+sensible+masstr...
#       cell_methods:   area:mean yh:mean xh:mean time: mean
#       cell_measures:  area: areacello
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  surface_downward_heat_flux_in_sea_water
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'area': {'areacello': <xarray.DataArray 'areacello' (yh: 1019, xh: 7200)> Size: 29MB
#   dask.array<getitem, shape=(1019, 7200), dtype=float32, chunksize=(188, 200), chunktype=numpy.ndarray>
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#   Attributes:
#       units:          m2
#       long_name:      Ocean Grid-Cell Area
#       cell_methods:   area:sum yh:sum xh:sum time: point
#       standard_name:  cell_area
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'maximum_depth': {'deptho': <xarray.DataArray 'deptho' (yh: 1019, xh: 7200)> Size: 29MB
#   dask.array<getitem, shape=(1019, 7200), dtype=float32, chunksize=(188, 200), chunktype=numpy.ndarray>
#   Coordinates:
#     * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#     * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#   Attributes:
#       units:          m
#       long_name:      Sea Floor Depth
#       cell_methods:   area:mean yh:mean xh:mean time: point
#       cell_measures:  area: areacello
#       standard_name:  sea_floor_depth_below_geoid
#       ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...},
#  'pressure': <xarray.DataArray 'pressure' (yh: 1019)> Size: 8kB
#  array([0.54708714, 0.54708681, 0.54708648, ..., 0.54639173, 0.54639059,
#         0.54638944])
#  Coordinates:
#    * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#  Attributes:
#      units:      degrees_north
#      long_name:  h point nominal latitude
#      axis:       Y,
#  'SA': <xarray.DataArray 'SA' (time: 12, yh: 1019, xh: 7200)> Size: 704MB
#  dask.array<sa_from_sp, shape=(12, 1019, 7200), dtype=float64, chunksize=(1, 94, 100), chunktype=numpy.ndarray>
#  Coordinates:
#    * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#    * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#      z_l      float64 8B 0.5413
#    * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#  Attributes:
#      units:          psu
#      long_name:      Sea Water Salinity
#      cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#      cell_measures:  volume: volcello area: areacello
#      time_avg_info:  average_T1,average_T2,average_DT
#      standard_name:  sea_water_salinity
#      ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...,
#  'pot_rho_0': <xarray.DataArray 'SA' (time: 12, yh: 1019, xh: 7200)> Size: 704MB
#  dask.array<sigma0, shape=(12, 1019, 7200), dtype=float64, chunksize=(1, 94, 100), chunktype=numpy.ndarray>
#  Coordinates:
#    * xh       (xh) float64 58kB -280.0 -279.9 -279.9 -279.8 ... 79.87 79.92 79.97
#    * yh       (yh) float64 8kB -81.1 -81.08 -81.06 ... -59.07 -59.05 -59.02
#      z_l      float64 8B 0.5413
#    * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00
#  Attributes:
#      units:          psu
#      long_name:      Sea Water Salinity
#      cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#      cell_measures:  volume: volcello area: areacello
#      time_avg_info:  average_T1,average_T2,average_DT
#      standard_name:  sea_water_salinity
#      ncfiles:        ['/g/data/ol01/outputs/mom6-panan/panant-005-zstar-ACCESS...,
#  'days_per_month': <xarray.DataArray 'days_per_month' (time: 12)> Size: 96B
#  array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
#  Coordinates:
#    * time     (time) object 96B 2001-01-16 12:00:00 ... 2001-12-16 12:00:00}

# %% [markdown]
# Woo get_variables finally works! Let's reset kernel and run from start properly.

# %% [markdown]
# ### First doing the control

# %%
# Painfully manual don't mind this 1
start_time = '2001-01-01'
end_time = '2001-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_01.nc')
# Out:
# Exception ignored in: <function WeakSet.__init__.<locals>._remove at 0x15499ef945e0>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/_weakrefset.py", line 39, in _remove
#     def _remove(item, selfref=ref(self)):
#
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt:
# 2025-08-04 11:55:20,098 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,100 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,101 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,097 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,112 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,098 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,100 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,098 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,114 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,136 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,132 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,129 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,099 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,099 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,106 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,109 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
# ...
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,109 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,112 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,130 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,132 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# 2025-08-04 11:55:20,102 - distributed.worker - ERROR -
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/compatibility.py", line 204, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 637, in run_until_complete
#     self.run_forever()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/utils.py", line 805, in wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 1577, in close
#     await r.close_gracefully(reason=reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1256, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError

# %% [markdown]
# The cell above took 3 hours.

# %%
# Painfully manual don't mind this 2

start_time = '2002-01-01'
end_time = '2002-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_02.nc')

# %%
# Painfully manual don't mind this 3

start_time = '2003-01-01'
end_time = '2003-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_03.nc')

# %%
# Painfully manual don't mind this 4

start_time = '2004-01-01'
end_time = '2004-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_04.nc')

# %%
# Painfully manual don't mind this 5

start_time = '2005-01-01'
end_time = '2005-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_05.nc')

# %%
# Painfully manual don't mind this 6

start_time = '2006-01-01'
end_time = '2006-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_06.nc')

# %%
# Painfully manual don't mind this 7

start_time = '2007-01-01'
end_time = '2007-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_07.nc')

# %%
# Painfully manual don't mind this 8

start_time = '2008-01-01'
end_time = '2008-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_08.nc')

# %%
# Painfully manual don't mind this 9

start_time = '2009-01-01'
end_time = '2009-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_09.nc')

# %%
# Painfully manual don't mind this 10

start_time = '2010-01-01'
end_time = '2010-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_salt_trans_pan005_C_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan005_SWMT_shelf/binned_heat_trans_pan005_C_10.nc')

# %% [markdown]
# #### Second doing the perturbation:

# %%
# Change to your experiment of interest
expt_melt = 'panant-005-zstar-ssp126-MW-only'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)
freq = '1 monthly'

# Select time period and region
lon_slice = slice(None, None)
lat_slice = slice(None, -59)

# %%
# Confirm its working
start_time = '2001-01-01'
end_time = '2001-12-31'
ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
ds

# %%
# Painfully manual don't mind this 1

start_time = '2001-01-01'
end_time = '2001-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_01.nc')

# %%
# Painfully manual don't mind this 2

start_time = '2002-01-01'
end_time = '2002-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_02.nc')

# %%
# Painfully manual don't mind this 3

start_time = '2003-01-01'
end_time = '2003-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_03.nc')

# %%
# Painfully manual don't mind this 4

start_time = '2004-01-01'
end_time = '2004-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_04.nc')

# %%
# Painfully manual don't mind this 5

start_time = '2005-01-01'
end_time = '2005-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_05.nc')

# %%
# Painfully manual don't mind this 6

start_time = '2006-01-01'
end_time = '2006-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_06.nc')

# %%
# Painfully manual don't mind this 7

start_time = '2007-01-01'
end_time = '2007-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_07.nc')

# %%
# Painfully manual don't mind this 8

start_time = '2008-01-01'
end_time = '2008-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_08.nc')

# %%
# Painfully manual don't mind this 9

start_time = '2009-01-01'
end_time = '2009-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_09.nc')

# %%
# Painfully manual don't mind this 10

start_time = '2010-01-01'
end_time = '2010-12-31'

ds = get_variables(expt_melt, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom6')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_salt_trans_pan01_M_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_Pan01_SWMT_shelf/binned_heat_trans_pan01_M_10.nc')
