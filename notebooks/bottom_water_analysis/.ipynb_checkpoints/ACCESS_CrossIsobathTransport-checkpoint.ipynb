# %%
import pandas as pd
import intake
import glob
import dask
import matplotlib.pyplot as plt
import netCDF4 as nc
import xarray as xr
import numpy as np
import cmocean

from dask.distributed import Client

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
client = Client(threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:42349' processes=28 threads=28, memory=251.19 GiB>
# 2025-05-26 22:51:17,474 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45377 (pid=998636) exceeded 95% memory budget. Restarting...
# 2025-05-26 22:51:17,791 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45377' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7964), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 23267), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7973), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7555), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7564), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7573), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7811), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 9797), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7582), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7820), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7591), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7829), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 9815), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7838), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 16716), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7847), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 29148), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7676), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7685), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 15669), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 24547), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7694), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 13692), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7703), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7941), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 10165), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 30325), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7712), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 9936), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7950), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7959), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 9518), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 23262), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7968), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7541), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 23271), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 4670), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7550), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7977), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7559), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7568), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7806), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 12672), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 18005), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7577), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7815), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 9801), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7824), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7833), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7842), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 16729), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 18288), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7671), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 12775), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7680), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 12546), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7689), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 13687), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7927), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7698), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 13696), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7936), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 7707), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 22345), ('rechunk-split-f21b74b93d962138d5f6edf67618c603', 12384), ('rechunk-split-f21b ...
# 2025-05-26 22:51:17,934 - distributed.nanny - WARNING - Restarting worker

# %%
#Importing data

pathsC = np.sort(glob.glob('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/outpu*/ocean/ocean.nc'))
pathsM = np.sort(glob.glob('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath_sofia_ssp126/*/ocean/ocean.nc'))

depth = xr.open_dataset('/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091_21mbath/output012/ocean/ocean_grid.nc')[['ht', 'hu']]

# %%
# Select time period and region

freq = '1 monthly'
lon_slice = slice(None, None)
lat_slice = slice(None, -59)
start_time = '1910-01-01'
end_time = '1919-12-31'
time_slice = slice(start_time, end_time)

# %%
ht = depth['ht'].sel(yt_ocean = lat_slice)
hu = depth['hu'].sel(yu_ocean = lat_slice) 
ht
# Out:
# <xarray.DataArray 'ht' (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
# [1836000 values with dtype=float32]
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     geolon_t  (yt_ocean, xt_ocean) float32 7MB ...
#     geolat_t  (yt_ocean, xt_ocean) float32 7MB ...
# Attributes:
#     long_name:      ocean depth on t-cells
#     units:          m
#     valid_range:    [-1.e+09  1.e+09]
#     cell_methods:   time: point
#     standard_name:  sea_floor_depth_below_geoid

# %%
contour_depth = 1000 # metres

# %%
fig = plt.figure(figsize = (10, 4))

ht.plot(extend='both', cbar_kwargs={'label': "ocean depth [m]"})
ht.plot.contour(levels = [contour_depth], colors = 'r', linestyles = '-')
plt.title('Ocean depth (m)')
# Out:
# Text(0.5, 1.0, 'Ocean depth (m)')

# %% [markdown]
# Fill in land with zeros and load:

# %%
ht = ht.fillna(0).load()

# %% [markdown]
# Contour is on t-grid (we assume ACCESS-OM2 B-grid transports)

# %%
grid_sel = 't'
x_var = ht['xt_ocean']
y_var = ht['yt_ocean']

# %% [markdown]
# #### Select the contour
# We need to isolate out the single contour along the slope and get rid of the contours on the little isolated sea mounts and depressions.

# %%
fig = plt.figure(figsize = (10, 4))
sc = plt.contour(ht, levels=[contour_depth])

path_vertices = (sc.get_paths()[0]).vertices
x_vertices = path_vertices[:, 0]
y_vertices = path_vertices[:, 1]

# %% [markdown]
# This list of path_vertices includes all of the paths in the above figure. But we want to only select the longest contour. The contours are all stacked in x_vertices and y_vertices, with the longest contour listed first. We need to find the end of the longest contour and cut x_vertices/y_vertices at that point.
#
# Along our desired contour, x_vertices/y_vertices should increase/decrease by max 1, so we can use the location where diff(x_vertices) > 1 to find the end of our desired contour.
#
# When we call np.diff, we wind up with floating point numbers. To get a mask where the difference is greater than 1, we can just turn the result of np.diff(x_vertices) back into an array of integers using .astype(int) on it - so we can cleanly check if the result is greater than 1.

# %%
last_contour_index = np.where(np.abs(np.diff(x_vertices).astype(int)) > 1)[0][0]

x_contour = x_vertices[:last_contour_index + 1]
y_contour = y_vertices[:last_contour_index + 1]

# Check desired contour looks right:
fig = plt.figure(figsize = (10, 4))
plt.scatter(x_contour, y_contour, s=5, alpha=0.5, color='tomato');

# %% [markdown]
# x_contour and y_contour are not integers with this updated contour method. We need to convert them to integers so we can use them as indices for selecting data on the contour.

# %%
x_contour = np.round(x_contour).astype(int)
y_contour = np.round(y_contour).astype(int)

# check that the difference between coords of contour never increase by more than 1:
if np.max(np.abs(np.diff(x_contour))) != 1:
    print('help! x_contour increases by more than 1 between coords.')

if np.max(np.abs(np.diff(y_contour))) != 1:
    print('help! y_contour increases by more than 1 between coords.')

# %% [markdown]
# #### Processing
# Now process these coordinates to make sure there are no double ups.
# N.B: It can be tempting to use numpy's unique functionality to do this sort of task - be careful, as it won't preserve order!

# %%
# Difference between two neighbouring indices
diff_x_contour = np.diff(x_contour)
diff_y_contour = np.diff(y_contour)

# Get a list with the indices of duplicates
diff_ind = []
for ii in range(len(diff_x_contour)):
    if (diff_x_contour[ii]==0) and (diff_y_contour[ii]==0):
        diff_ind.append(ii)
# Now remove the indices (start from the end so the indices don't shift)
for ii in range(len(diff_ind)):
    index = diff_ind[::-1][ii]
    x_contour = np.delete(x_contour, index)
    y_contour = np.delete(y_contour, index)
ht_contour = np.zeros(len(x_contour))

for ii in range(len(ht_contour)):
    ht_contour[ii] = ht[y_contour[ii], x_contour[ii]]

# %% [markdown]
# Due to the discrete grid, the values on our contour are not exactly the same. We check this makes sense -- if this plot is blank, then something has gone wrong.

# %%
fig = plt.figure(figsize=(10, 4))

plt.plot(ht_contour, 'o', markersize=1)
plt.axhline(contour_depth, color='k', linewidth=0.5);

# %%
# Number of grid points on the contour
num_points = len(x_contour)

# %%
# start numbering from 1 not 0:
contour_mask_numbered = np.arange(1, len(x_contour)+1)

# %%
contour_mask = xr.zeros_like(ht)

for ii in range(num_points):
    contour_mask[y_contour[ii], x_contour[ii]] = contour_mask_numbered[ii]

# %%
contour_mask.attrs['long_name'] = 'Contour index'
plt.figure(1, figsize=(10, 4))
contour_mask.plot(extend='both', cmap = cmocean.cm.amp);

# %% [markdown]
# #### Create mask
# Now we create a mask below contour so that the direction of the contour can be determined

# %%
mask_value = -1000
contour_mask_numbered = contour_mask

# fill in points to north of contour:
contour_masked_above = np.copy(contour_mask_numbered)
contour_masked_above[-1, 0] = mask_value

# from top left:
for ii in range(len(contour_mask.xt_ocean)-1):
    for jj in range(len(contour_mask.yt_ocean))[::-1][:-1]:
        if contour_masked_above[jj, ii] == mask_value:
            if contour_masked_above[jj-1, ii] == 0:
                contour_masked_above[jj-1, ii] = mask_value
            if contour_masked_above[jj, ii+1] == 0:
                contour_masked_above[jj, ii+1] = mask_value

#from top right:
for ii in range(len(contour_mask.xt_ocean))[::-1][:-1]:
    for jj in range(len(contour_mask.yt_ocean))[::-1][:-1]:
        if contour_masked_above[jj, ii] == mask_value:
            if contour_masked_above[jj-1, ii] == 0:
                contour_masked_above[jj-1, ii] = mask_value
            if contour_masked_above[jj, ii-1] == 0:
                contour_masked_above[jj, ii-1] = mask_value

# from bottom right:
for ii in range(len(contour_mask.xt_ocean))[::-1][:-1]:
    for jj in range(len(contour_mask.yt_ocean)-1):
        if contour_masked_above[jj, ii] == mask_value:
            if contour_masked_above[jj+1, ii] == 0:
                contour_masked_above[jj+1, ii] = mask_value
            if contour_masked_above[jj, ii-1] == 0:
                contour_masked_above[jj, ii-1] = mask_value

#from bottom left:
for ii in range(len(contour_mask.xt_ocean)-1):
    for jj in range(len(contour_mask.yt_ocean)-1):
        if contour_masked_above[jj, ii] == mask_value:
            if contour_masked_above[jj+1, ii] == 0:
                contour_masked_above[jj+1, ii] = mask_value
            if contour_masked_above[jj, ii+1] == 0:
                contour_masked_above[jj, ii+1] = mask_value

# %%
plt.figure(1, figsize=(10, 4))

plt.pcolormesh(contour_mask.xt_ocean, contour_mask.yt_ocean, contour_masked_above)
plt.colorbar()

# %% [markdown]
# North of the contour, values have been filled in to be -1000, and it is thus a different colour in the plot.

# %% [markdown]
# #### Direction of cross-contour transport
# Now we can use the mask to determine whether the transport across the contour should be north, east, south or west (the grid is made of discrete square(ish) shaped cells). This is done by looping through the contour points and determining in which directions there are zeros (i.e. below contour) and -1000 (i.e. above contour). This means the orientation of the contour can be determined. This is saved as mask_x_transport, which has -1 and +1 in a 2D (x and y) array where the contour has eastward transport, and mask_y_transport which as -1 and +1 for coordinates with northward transport. All other positions in the array are 0. This means that multiplying the northward transport ty_trans by the mask_y_transport gives all the northward transport across the contour, and zeros everywhere else (e.g. where contour goes upwards and cross-contour transport is thus eastward).

# %%
mask_x_transport = np.zeros_like(contour_mask_numbered)
mask_y_transport = np.zeros_like(contour_mask_numbered)

mask_y_transport_numbered = np.zeros_like(contour_mask_numbered)
mask_x_transport_numbered = np.zeros_like(contour_mask_numbered)

# make halos:
shape = contour_masked_above.shape
contour_masked_above_halo = np.zeros((shape[0], shape[1]+2))
contour_masked_above_halo[:, 0] = contour_masked_above[:, -1]
contour_masked_above_halo[:, 1:-1] = contour_masked_above
contour_masked_above_halo[:, -1] = contour_masked_above[:, 0]

new_number_count = 1
for mask_loc in range(1, int(np.max(contour_mask_numbered))+1):
    index_i = np.where(contour_mask_numbered==mask_loc)[1]
    index_j = np.where(contour_mask_numbered==mask_loc)[0]
    # if point above is towards Antarctica and point below is away from Antarctica:
    # take transport grid point to north of t grid:
    if (contour_masked_above[index_j+1, index_i]==0) and (contour_masked_above[index_j-1, index_i]!=0):
        mask_y_transport[index_j, index_i] = -1
        # important to do 
        mask_y_transport_numbered[index_j, index_i] = new_number_count
        new_number_count += 1
    # if point below is towards Antarctica and point above is away from Antarctica:
    # take transport grid point to south of t grid:
    elif (contour_masked_above[index_j-1, index_i]==0) and (contour_masked_above[index_j+1, index_i]!=0):
        mask_y_transport[index_j-1, index_i] = 1
        mask_y_transport_numbered[index_j-1, index_i] = new_number_count
        new_number_count += 1
    # if point below and point above are BOTH towards Antarctica:
    # take transport grid point to south of t grid:
    elif (contour_masked_above[index_j-1, index_i]==0) and (contour_masked_above[index_j+1, index_i]==0):
        mask_y_transport[index_j-1, index_i] = 1
        mask_y_transport[index_j, index_i] = -1        
        mask_y_transport_numbered[index_j-1, index_i] = new_number_count
        mask_y_transport_numbered[index_j, index_i] = new_number_count+1
        new_number_count += 2
    # if point to right is towards Antarctica and point to left is away from Antarctica:
    # zonal indices increased by 1 due to halos
    # take transport grid point on right of t grid:
    if (contour_masked_above_halo[index_j, index_i+2]==0) and (contour_masked_above_halo[index_j, index_i]!=0):
        mask_x_transport[index_j, index_i] = -1
        mask_x_transport_numbered[index_j, index_i] = new_number_count
        new_number_count += 1
    # if point to left is towards Antarctica and point to right is away from Antarctica:
    # take transport grid point on left of t grid:
    elif (contour_masked_above_halo[index_j, index_i]==0) and (contour_masked_above_halo[index_j, index_i+2]!=0):
        mask_x_transport[index_j, index_i-1] = 1
        mask_x_transport_numbered[index_j, index_i-1] = new_number_count
        new_number_count += 1
    # if point to left and right BOTH toward Antarctica
    elif (contour_masked_above_halo[index_j, index_i]==0) and (contour_masked_above_halo[index_j, index_i+2]==0):
        mask_x_transport[index_j, index_i-1] = 1
        mask_x_transport[index_j, index_i] = -1        
        mask_x_transport_numbered[index_j, index_i-1] = new_number_count
        mask_x_transport_numbered[index_j, index_i] = new_number_count+1
        new_number_count += 2

# %%
# Plot the mask for the x-transport:
plt.figure(1, figsize=(10, 4))

plt.pcolormesh(contour_mask.xt_ocean, contour_mask.yt_ocean, mask_x_transport,
               cmap=cmocean.cm.balance, vmin=-1.5, vmax=1.5)
plt.colorbar();

# %% [markdown]
# As can be seen, in mask_x_transport there is red (+1) where eastward transport crosses the contour, and blue (-1) where westward transport crosses the contour (in the net northward direction). There are zeros everywhere else.

# %% [markdown]
# **We now have the coordinates of the contours, and whether the x or y transport is needed to calculate cross-contour transport.**
# We now proceed to calculate transports across the contour. Here we convert the contour masks to data arrays, so we can multiply them later. We need to ensure the lat / lon coordinates correspond to the actual data location:
#
# - The y masks are used for ty_trans, so like vhrho this should have dimensions (yu_ocean, xt_ocean).
# - The x masks are used for tx_trans, so like uhrho this should have dimensions (yt_ocean, xu_ocean).
#
# However we set the actual name to always be simply latitude/longitude irrespective of the variable to make concatenation of transports in both direction and sorting possible.

# %%
mask_x_transport = xr.DataArray(mask_x_transport,
                                coords = [ht.yt_ocean, hu.xu_ocean],
                                dims = ['latitude', 'longitude'])
mask_y_transport = xr.DataArray(mask_y_transport,
                                coords = [hu.yu_ocean, ht.xt_ocean],
                                dims = ['latitude', 'longitude'])
mask_x_transport_numbered = xr.DataArray(mask_x_transport_numbered,
                                         coords = [ht.yt_ocean, hu.xu_ocean],
                                         dims = ['latitude', 'longitude'])
mask_y_transport_numbered = xr.DataArray(mask_y_transport_numbered,
                                         coords = [hu.yu_ocean, ht.xt_ocean],
                                         dims = ['latitude', 'longitude'])

# %%
# Plot to check we didn't mess up
plt.figure(1, figsize=(10, 4))

mask_x_transport.plot(cmap=cmocean.cm.balance, vmin=-1.5, vmax=1.5);

# %% [markdown]
# #### Stack contour data into 1D
# Create the contour order data-array. Note that in this procedure the x-grid counts have x-grid dimensions and the y-grid counts have y-grid dimensions, but these are implicit, the dimension names are kept general across the counts, the generic latitude, longitude, so that concatening works but we dont double up with numerous counts for one lat/lon point.

# %%
# stack contour data into 1d:
mask_x_numbered_1d = mask_x_transport_numbered.stack(contour_index = ['latitude', 'longitude'])
mask_x_numbered_1d = mask_x_numbered_1d.where(mask_x_numbered_1d > 0, drop = True)

mask_y_numbered_1d = mask_y_transport_numbered.stack(contour_index = ['latitude', 'longitude'])
mask_y_numbered_1d = mask_y_numbered_1d.where(mask_y_numbered_1d > 0, drop = True)

contour_ordering = xr.concat((mask_x_numbered_1d, mask_y_numbered_1d), dim = 'contour_index')
contour_ordering = contour_ordering.sortby(contour_ordering)
contour_index_array = np.arange(1, len(contour_ordering)+1)

# %% [markdown]
# ### Load transports tx_trans and ty_trans

# %%
#Time variant variables #Can this be condensed?
def preprocess(ds):
    ds = ds[['ty_trans', 'tx_trans']].sel(yt_ocean=lat_slice)
    return ds

cont = xr.open_mfdataset(pathsC, preprocess = preprocess, chunks = 'auto')
melt = xr.open_mfdataset(pathsM, preprocess = preprocess, chunks = 'auto')

# %%
# First for control as test

darrayC = cont['ty_trans']
darrayC = darrayC.sel(time=time_slice)
ty_transC = darrayC
ty_transC = ty_transC.sel(yu_ocean = lat_slice, time = time_slice)
ty_transC.chunk(chunks={"time": -1})

ty_transC = ty_transC.chunk(chunks={"time": -1, "st_ocean": -1, "yu_ocean": 102, "xt_ocean": 400})
ty_transC
# Out:
# <xarray.DataArray 'ty_trans' (time: 120, st_ocean: 75, yu_ocean: 510,
#                               xt_ocean: 3600)> Size: 66GB
# dask.array<rechunk-merge, shape=(120, 75, 510, 3600), dtype=float32, chunksize=(120, 75, 102, 400), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * st_ocean  (st_ocean) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) object 960B 1910-01-16 12:00:00 ... 1919-12-16 12:00:00
#   * yu_ocean  (yu_ocean) float64 4kB -81.09 -81.05 -81.0 ... -59.06 -59.01
# Attributes:
#     long_name:      T-cell j-mass transport
#     units:          kg/s
#     valid_range:    [-1.e+20  1.e+20]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  ocean_mass_y_transport

# %%
# Now for melt
darrayM = melt['ty_trans']
darrayM = darrayM.sel(time=time_slice)
ty_transM = darrayM
ty_transM = ty_transM.sel(yu_ocean = lat_slice, time = time_slice)
ty_transM.chunk(chunks={"time": -1})

ty_transM = ty_transM.chunk(chunks={"time": -1, "st_ocean": -1, "yu_ocean": 102, "xt_ocean": 400})
ty_transM
# Out:
# <xarray.DataArray 'ty_trans' (time: 118, st_ocean: 75, yu_ocean: 510,
#                               xt_ocean: 3600)> Size: 65GB
# dask.array<rechunk-merge, shape=(118, 75, 510, 3600), dtype=float32, chunksize=(118, 75, 102, 400), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * st_ocean  (st_ocean) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) object 944B 1910-01-16 12:00:00 ... 1919-10-16 12:00:00
#   * yu_ocean  (yu_ocean) float64 4kB -81.09 -81.05 -81.0 ... -59.06 -59.01
# Attributes:
#     long_name:      T-cell j-mass transport
#     units:          kg/s
#     valid_range:    [-1.e+20  1.e+20]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  ocean_mass_y_transport

# %%
## Now for tx

# Control
darrayC = cont['tx_trans']
darrayC = darrayC.sel(time=slice(start_time, end_time))
tx_transC = darrayC
tx_transC = tx_transC.sel(yt_ocean = lat_slice, time = time_slice)
tx_transC = tx_transC.chunk(chunks={"time": -1, "st_ocean": -1, "yt_ocean": 102, "xu_ocean": 400})

ty_transC = ty_transC.rename({'yu_ocean': 'latitude', 'xt_ocean': 'longitude'})
tx_transC = tx_transC.rename({'yt_ocean': 'latitude', 'xu_ocean': 'longitude'})

# Melt
darrayM = melt['tx_trans']
darrayM = darrayM.sel(time=slice(start_time, end_time))
tx_transM = darrayM
tx_transM = tx_transM.sel(yt_ocean = lat_slice, time = time_slice)
tx_transM = tx_transM.chunk(chunks={"time": -1, "st_ocean": -1, "yt_ocean": 102, "xu_ocean": 400})

ty_transM = ty_transM.rename({'yu_ocean': 'latitude', 'xt_ocean': 'longitude'})
tx_transM = tx_transM.rename({'yt_ocean': 'latitude', 'xu_ocean': 'longitude'})

# %%
# Take time average

# weighed time mean by month length
days_in_month = ty_transC.time.dt.days_in_month
days_in_year = 365

tx_transC = (tx_transC * days_in_month / days_in_year).sum('time')
tx_transC = tx_transC.load()

ty_transC = (ty_transC * days_in_month / days_in_year).sum('time')
ty_transC = ty_transC.load()

tx_transM = (tx_transM * days_in_month / days_in_year).sum('time')
tx_transM = tx_transM.load()

ty_transM = (ty_transM * days_in_month / days_in_year).sum('time')
ty_transM = ty_transM.load()
# Out:
# 2025-05-26 22:47:41,502 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.53 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:41,777 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.22 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:41,789 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.33 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:41,797 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.30 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:42,227 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.83 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:42,842 - distributed.worker.memory - WARNING - Worker is at 4% memory usage. Resuming worker. Process memory: 442.35 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:47,740 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:47,742 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.69 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:47,856 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.34 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:47,857 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.63 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:48,046 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:48,158 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 5.06 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:48,709 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,016 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.46 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,112 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.38 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,120 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.39 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,208 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.43 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,215 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.42 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,232 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.43 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,266 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.32 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,292 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:49,681 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,100 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 461.49 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,193 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.33 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,209 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 474.08 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,210 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,218 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 463.01 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,294 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 479.79 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,400 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 473.69 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:50,584 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.83 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:56,152 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:56,162 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 4.92 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:56,503 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.32 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:56,505 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 4.91 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:57,342 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:57,465 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 4.94 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:57,870 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:57,874 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 5.03 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,005 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.27 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,013 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,126 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 5.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,702 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 4.76 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,812 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.51 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,970 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.32 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:58,983 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,016 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,022 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 4.95 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,099 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.34 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,109 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,150 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,161 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.64 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,270 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.42 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,752 - distributed.worker.memory - WARNING - Worker is at 50% memory usage. Resuming worker. Process memory: 4.55 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,875 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,876 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:47:59,942 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 478.80 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,126 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.82 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,217 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.33 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,225 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,355 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,470 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,473 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,559 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.16 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,670 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 505.57 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:00,729 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 7.51 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:01,548 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.90 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:01,724 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 463.99 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:05,641 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:05,784 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 4.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:07,095 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 7.47 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:07,329 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.32 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:07,854 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.85 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:07,966 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.43 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:08,276 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:08,278 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 4.83 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:08,794 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 480.94 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:08,896 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:08,897 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.61 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:11,095 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:11,190 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.34 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:11,295 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.82 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:11,390 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.90 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:19,485 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:21,035 - distributed.worker.memory - WARNING - Worker is at 50% memory usage. Resuming worker. Process memory: 4.55 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:21,510 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.97 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:23,797 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.77 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:27,054 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:36,292 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.20 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:39,555 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.58 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:39,633 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:39,647 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:39,732 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.58 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:39,746 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.58 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:39,825 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.22 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:40,504 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 4.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:50,008 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:52,741 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:52,937 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:53,042 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.60 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:53,379 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.38 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:53,878 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:54,357 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:55,295 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:55,328 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 476.34 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:55,519 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:55,543 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.37 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,221 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,388 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.59 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,432 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.24 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,510 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,646 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,711 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.39 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:56,755 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,270 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.85 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,289 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,398 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 552.88 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,404 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,417 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.66 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,429 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.83 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,628 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.83 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,658 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,747 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 490.77 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,757 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,764 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.86 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:57,854 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.86 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:58,222 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:58,223 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:58,516 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:58,793 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.34 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:58,839 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 484.88 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:58,933 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 476.23 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:59,458 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.89 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:59,637 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:59,724 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 499.99 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:48:59,812 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:05,211 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.44 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:05,548 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:05,843 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:06,170 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:06,352 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 461.63 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:06,548 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.42 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:06,584 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:06,742 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 504.94 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:06,878 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:07,331 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 482.80 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:07,475 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.30 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:07,744 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 485.02 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:08,048 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 469.91 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:33,498 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.96 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:33,681 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:34,547 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.40 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:34,580 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 513.90 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:34,935 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.91 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:39,696 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:39,698 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.70 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,627 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,655 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.43 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,661 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,746 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 4.95 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,750 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,755 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.70 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,807 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.72 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:40,901 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:41,323 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.34 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:41,476 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 485.53 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:41,620 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:41,800 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.38 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:41,966 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 497.47 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:42,086 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.36 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:42,186 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:42,606 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.86 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:42,756 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:43,024 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 494.80 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:43,045 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 505.21 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:43,050 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.41 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:43,107 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:43,276 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 555.59 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:49,643 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:49,673 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 4.92 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,128 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,230 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,235 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,241 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.74 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,354 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 5.09 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,438 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.24 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,617 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 5.10 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,648 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 5.20 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,704 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.20 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,728 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,772 - distributed.worker.memory - WARNING - Worker is at 55% memory usage. Resuming worker. Process memory: 4.98 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,974 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:50,984 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 4.81 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:51,042 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 5.06 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:51,238 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.32 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:51,537 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.40 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:51,866 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.25 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:51,867 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:51,905 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.37 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,053 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.34 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,378 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.40 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,390 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.93 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,450 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,556 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 5.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,649 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,669 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:52,947 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:53,148 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:53,189 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.89 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:53,276 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 479.44 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:53,315 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 481.18 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:53,617 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.83 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:54,125 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.36 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:49:54,755 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 482.53 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:00,335 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:00,511 - distributed.worker.memory - WARNING - Worker is at 56% memory usage. Resuming worker. Process memory: 5.03 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:01,759 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.20 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:01,800 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:02,657 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.89 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:02,826 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.90 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:04,620 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.24 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:04,756 - distributed.worker.memory - WARNING - Worker is at 57% memory usage. Resuming worker. Process memory: 5.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:10,519 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 7.49 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:10,525 - distributed.worker.memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 7.78 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:10,866 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.36 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:10,953 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:11,545 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 533.85 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:11,610 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:11,677 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 533.32 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:11,690 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.92 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:11,894 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.40 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:12,477 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:12,511 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.85 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:12,526 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:12,624 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:12,794 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:13,425 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 556.45 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:13,589 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 484.45 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:13,635 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.89 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:13,858 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.38 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:14,347 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.41 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:14,717 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 558.03 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:14,862 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.39 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:14,980 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:15,155 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:15,907 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 537.48 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:15,937 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.43 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:16,235 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 546.01 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:16,555 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.35 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:16,968 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 531.01 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:17,488 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.33 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:50:17,766 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 513.68 MiB -- Worker memory limit: 8.97 GiB
# ...
# 2025-05-26 22:52:57,064 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:52:58,055 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.90 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:02,705 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.20 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:02,706 - distributed.worker.memory - WARNING - Worker is at 53% memory usage. Resuming worker. Process memory: 4.77 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:04,860 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:04,862 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.74 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:05,270 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.19 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:05,272 - distributed.worker.memory - WARNING - Worker is at 50% memory usage. Resuming worker. Process memory: 4.54 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:06,087 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:06,089 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.70 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:06,250 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:06,254 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.64 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:07,190 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.18 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:07,193 - distributed.worker.memory - WARNING - Worker is at 51% memory usage. Resuming worker. Process memory: 4.66 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:08,313 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.24 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:08,314 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.24 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:08,423 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.16 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:08,502 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.59 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:08,741 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 526.32 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:09,020 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.37 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:09,581 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:09,692 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.27 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:09,692 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.27 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:09,920 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 532.54 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:09,948 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.94 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:10,061 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:10,061 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:10,611 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:10,612 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:10,647 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.92 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:11,010 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.91 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:11,730 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:11,865 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.29 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:11,900 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 524.45 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:13,224 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 569.33 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:20,301 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.40 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:20,678 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.51 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:20,897 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.30 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:20,966 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.22 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:20,970 - distributed.worker.memory - WARNING - Worker is at 52% memory usage. Resuming worker. Process memory: 4.70 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:21,208 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.23 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:21,590 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.88 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:21,976 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 560.73 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:22,250 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.21 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,032 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.22 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,044 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.43 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,105 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.02 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,122 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,124 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.28 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,175 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.54 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,194 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.95 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,300 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.32 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,536 - distributed.worker.memory - WARNING - Worker is at 6% memory usage. Resuming worker. Process memory: 570.19 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,832 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:23,955 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.94 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:24,032 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.92 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:24,181 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.36 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:24,390 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.26 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:24,403 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 528.41 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:24,499 - distributed.worker.memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 7.17 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:24,981 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.89 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:25,038 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.66 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:25,361 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 7.52 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:25,420 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.44 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:26,042 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.91 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:26,147 - distributed.worker.memory - WARNING - Worker is at 21% memory usage. Resuming worker. Process memory: 1.89 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:26,356 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 7.41 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:27,059 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.84 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:32,574 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.09 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:33,055 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:33,293 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 6.42 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:33,877 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 7.31 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:34,018 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 544.57 MiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:34,207 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 7.24 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:34,977 - distributed.worker.memory - WARNING - Worker is at 20% memory usage. Resuming worker. Process memory: 1.86 GiB -- Worker memory limit: 8.97 GiB
# 2025-05-26 22:53:35,107 - distributed.worker.memory - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 502.28 MiB -- Worker memory limit: 8.97 GiB

# %%
## Convert from mass transport to volume transport
ρ0 = 1035 # kg/m^3

# Control
ty_transC = ty_transC * mask_y_transport / ρ0 # convert kg/s -> m^3/s
tx_transC = tx_transC * mask_x_transport / ρ0 # convert kg/s -> m^3/s

# Melt
ty_transM = ty_transM * mask_y_transport / ρ0 # convert kg/s -> m^3/s
tx_transM = tx_transM * mask_x_transport / ρ0 # convert kg/s -> m^3/s

# %%
### Extract transport values along contour
## We could also loop in time if we didn't want the time average. 
# In that case, initialise a data array and fill in data by looping in time.

## Control
# stack transports into 1d and drop any points not on contour:
x_transport_1d_C = tx_transC.stack(contour_index = ['latitude', 'longitude'])
x_transport_1d_C = x_transport_1d_C.where(mask_x_numbered_1d>0, drop = True)
y_transport_1d_C = ty_transC.stack(contour_index = ['latitude', 'longitude'])
y_transport_1d_C = y_transport_1d_C.where(mask_y_numbered_1d>0, drop = True)

# combine all points on contour:
vol_trans_across_contour_C = xr.concat((x_transport_1d_C, y_transport_1d_C), dim = 'contour_index')
vol_trans_across_contour_C = vol_trans_across_contour_C.sortby(contour_ordering)
vol_trans_across_contour_C.coords['contour_index'] = contour_index_array
vol_trans_across_contour_C = vol_trans_across_contour_C.load()

## Melt
# stack transports into 1d and drop any points not on contour:
x_transport_1d_M = tx_transM.stack(contour_index = ['latitude', 'longitude'])
x_transport_1d_M = x_transport_1d_M.where(mask_x_numbered_1d>0, drop = True)
y_transport_1d_M = ty_transM.stack(contour_index = ['latitude', 'longitude'])
y_transport_1d_M = y_transport_1d_M.where(mask_y_numbered_1d>0, drop = True)

# combine all points on contour:
vol_trans_across_contour_M = xr.concat((x_transport_1d_M, y_transport_1d_M), dim = 'contour_index')
vol_trans_across_contour_M = vol_trans_across_contour_M.sortby(contour_ordering)
vol_trans_across_contour_M.coords['contour_index'] = contour_index_array
vol_trans_across_contour_M = vol_trans_across_contour_M.load()

# %% [markdown]
# Plot the cumulative transport along the contour, summed over the lower part of the water column. We can clearly see the northward dense water export in the Ross and Weddell Seas.

# %%
plt.figure(1, figsize=(10, 4))

(vol_trans_across_contour_C.sel(st_ocean=slice(800, 6000)).sum('st_ocean').cumsum('contour_index')/1e6).plot(label='Control')
(vol_trans_across_contour_M.sel(st_ocean=slice(800, 6000)).sum('st_ocean').cumsum('contour_index')/1e6).plot(label='Melt')
plt.ylabel('Cumulative transport across contour (Sv)');
plt.legend()

# %% [markdown]
# We can extract the coordinates of the contour index, and the distance, for a more meaningful axis.

# %%
contour_ordering = xr.concat((mask_x_numbered_1d, mask_y_numbered_1d), dim = 'contour_index')
contour_ordering = contour_ordering.sortby(contour_ordering)

# get lat and lon along contour, useful for plotting later:
lat_along_contour = contour_ordering.latitude.copy()
lon_along_contour = contour_ordering.longitude.copy()

contour_index_array = np.arange(1, len(contour_ordering)+1)

# don't need the multi-index anymore, replace with contour count and save
lat_along_contour.coords['contour_index'] = contour_index_array
lon_along_contour.coords['contour_index'] = contour_index_array

# %% [markdown]
# **Extract distance in between contour coordinates**
# This is used to label the x-axis in the plots below. Note these distances don't exactly match the dxt / dyt variables in the model, but it's only used for plotting, so it's probably ok.

# %%
from geopy import distance

num_points = len(lat_along_contour)
d_distance_along_contour = np.zeros((num_points))

for i in range(num_points-1):
    d_distance_along_contour[i+1] = distance.distance((lat_along_contour[i], lon_along_contour[i]), (lat_along_contour[i+1], lon_along_contour[i+1])).km

distance_along_contour = np.cumsum(d_distance_along_contour)

# %% [markdown]
# Select the indices for axis labels of specific longitudes, so we can plot transport vs distance but have longitude labels instead of length

# %%
target_lons = [-280, -240, -180, -120, -60, 0, 6., 80]

distance_indices = np.zeros_like(target_lons)

for j, lon in enumerate(target_lons):
    distance_indices[j] = np.argmin(np.abs((lon_along_contour.values - lon)))

# %% [markdown]
# Plot cumulative transport against distance along the contour.

# %%
depth_to_integrate = 800 # m

# %%
fig, axes = plt.subplots(nrows = 2, figsize = (10, 8))

# factor 1e-6 converts m^3/s -> Sv
axes[0].plot(distance_along_contour, (1e-6 * vol_trans_across_contour_C.sel(st_ocean = slice(depth_to_integrate, 6000)).sum('st_ocean').cumsum('contour_index')), label='Control')
axes[0].plot(distance_along_contour, (1e-6 * vol_trans_across_contour_M.sel(st_ocean = slice(depth_to_integrate, 6000)).sum('st_ocean').cumsum('contour_index')), label='Melt')

axes[0].set_ylabel('Cumulative transport (Sv)')
axes[0].set_xlabel('Distance from 80$^\circ$E (10$^3$ km)')
axes[0].set_xlim(0, distance_along_contour[-1])
axes[0].set_title(f'Cumulative transport across {contour_depth} m isobath below {depth_to_integrate} m depth')
axes[0].legend()

# factor 1e-6 converts m^3/s -> Sv
axes[1].plot(distance_along_contour, (1e-6 * vol_trans_across_contour_C.sel(st_ocean = slice(depth_to_integrate, 6000)).sum('st_ocean').cumsum('contour_index')),label='Control')
axes[1].plot(distance_along_contour, (1e-6 * vol_trans_across_contour_M.sel(st_ocean = slice(depth_to_integrate, 6000)).sum('st_ocean').cumsum('contour_index')),label='Melt')

axes[1].set_xticks(distance_along_contour[distance_indices.astype(int)[:-1]])
axes[1].set_xticklabels(('80$^\circ$E', '120$^\circ$E', '180$^\circ$W', '120$^\circ$W', '60$^\circ$W', '0$^\circ$', '60$^\circ$E'))
axes[1].set_xlim(0, distance_along_contour[-1])

axes[1].set_xlabel('Longitude coordinates along contour')
axes[1].set_ylabel('Cumulative transport (Sv)');
axes[1].legend()
