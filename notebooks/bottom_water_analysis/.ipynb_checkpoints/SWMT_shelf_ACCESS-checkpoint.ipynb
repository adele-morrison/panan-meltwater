# %% [markdown]
# # SWMT on shelf for ACCESS-OM2-01

# %%
import intake
import cosima_cookbook as cc
import glob

import cartopy.crs as ccrs
import cf_xarray as cfxr
import cmocean as cm
import dask.distributed
import gsw
import matplotlib.pyplot as plt
from matplotlib import gridspec 
import matplotlib.colors as mcolors
import numpy as np
import xarray as xr
import pdb
import os
import pathlib
import shutil

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker = 1)
# Out:
# 2025-07-17 20:53:08,655 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43375 (pid=2512394) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:53:09,171 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43375' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 3, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749589.1709273')
# 2025-07-17 20:53:09,190 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:01,521 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46565 (pid=2512400) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:01,573 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34737 (pid=2512421) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:01,781 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44533 (pid=2512397) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:01,883 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46565' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749641.8828037')
# 2025-07-17 20:54:01,901 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:02,007 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33075 (pid=2512324) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:02,024 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44911 (pid=2512409) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:02,187 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44533' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749642.1873767')
# 2025-07-17 20:54:02,191 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35299 (pid=2512372) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:02,229 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34737' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749642.229078')
# 2025-07-17 20:54:02,246 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:02,262 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:02,462 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44911' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 5, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749642.461772')
# 2025-07-17 20:54:02,473 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:02,535 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33075' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749642.5353336')
# 2025-07-17 20:54:02,576 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:02,648 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44759 (pid=2512382) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:02,665 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35299' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749642.6648414')
# 2025-07-17 20:54:02,667 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34519 (pid=2512416) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:02,682 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:02,995 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44759' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749642.9948375')
# 2025-07-17 20:54:03,015 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34519' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 8, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749643.0151803')
# 2025-07-17 20:54:03,016 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:03,050 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:03,455 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:32837 (pid=2512344) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:03,807 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:32837' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 2, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749643.8076646')
# 2025-07-17 20:54:03,869 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:07,507 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41013 (pid=2512328) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:07,761 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41013' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 3, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749647.7614927')
# 2025-07-17 20:54:07,794 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:10,730 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41989 (pid=2512404) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:11,085 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41989' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'original-open_dataset-salt_transformation-eebb84e12bf20da31b3e49327c71ce76', ('getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749651.085719')
# 2025-07-17 20:54:11,093 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:13,510 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37395 (pid=2512320) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:13,806 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37395' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 5, 0, 0, 0), ('getitem-e824804bd05485845595b15b6f06a0d5', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749653.8062508')
# 2025-07-17 20:54:13,813 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:13,915 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:32853 (pid=2512369) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:13,958 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43251 (pid=2512332) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:13,964 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33673 (pid=2512361) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:14,182 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43251' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 5, 0, 0, 0), ('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 8, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749654.182416')
# 2025-07-17 20:54:14,210 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33673' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 3, 0, 0, 0), ('getitem-e824804bd05485845595b15b6f06a0d5', 3, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749654.2099855')
# 2025-07-17 20:54:14,214 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:14,240 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:14,315 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:32853' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749654.3148565')
# 2025-07-17 20:54:14,359 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:14,710 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46389 (pid=2512348) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:14,896 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46389' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749654.8959122')
# 2025-07-17 20:54:14,919 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:14,960 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40637 (pid=2512336) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:15,162 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40637' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749655.1626523')
# 2025-07-17 20:54:15,177 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:15,358 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35059 (pid=2512412) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:15,712 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35059' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 2, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749655.7117734')
# 2025-07-17 20:54:15,844 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:20,210 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41723 (pid=2512352) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:20,464 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41723' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 4, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749660.4639394')
# 2025-07-17 20:54:20,501 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:20,658 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37961 (pid=2512340) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:20,810 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37961' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-2ddb97d91f20df9b278ab25998642a67', 0, 0, 0), ('getitem-e824804bd05485845595b15b6f06a0d5', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749660.8099377')
# 2025-07-17 20:54:20,928 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:24,706 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37773 (pid=2512316) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:24,990 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37773' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 1, 0, 0, 0), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 2), ('getitem-e824804bd05485845595b15b6f06a0d5', 9, 0, 0, 0), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 3)} (stimulus_id='handle-worker-cleanup-1752749664.9904857')
# 2025-07-17 20:54:25,039 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:25,869 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34305 (pid=2512423) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:25,964 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34711 (pid=2512357) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:26,172 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34305' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749666.17254')
# 2025-07-17 20:54:26,193 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:26,319 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34711' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 0, 0, 0, 0), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 4)} (stimulus_id='handle-worker-cleanup-1752749666.3188775')
# 2025-07-17 20:54:26,370 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:26,654 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37227 (pid=2512964) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:26,798 - distributed.scheduler - ERROR - Task ('add-71d9bbad3468167e53027f413a22b67e', 3, 0, 0, 0) marked as failed because 4 workers died while trying to run it
# 2025-07-17 20:54:26,798 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37227' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 3, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1752749666.79754')
# 2025-07-17 20:54:26,856 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:27,507 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43137 (pid=2512955) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:29,856 - distributed.nanny - WARNING - Restarting worker
# 2025-07-17 20:54:32,518 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39689 (pid=2513074) exceeded 95% memory budget. Restarting...
# 2025-07-17 20:54:32,687 - distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# ### Defining the functions

# %%
def get_variables(expt, freq, start_time, end_time, lon_slice, lat_slice, model):

    # The models require different diagnostics to calculate the heat and salt fluxes.
    # mom6 outputs a net flux, whilst with mom5 we need to work with the separate components.
    model_vars = {
                    "mom5": {
                        "temperature":           ["temp"],
                        "salinity":              ["salt"],
                        "water_flux_into_ocean": ["pme_river"],
                        "salt_flux":             ["sfc_salt_flux_ice", "sfc_salt_flux_restore"],
                        "heat_flux":             ["sfc_hflux_coupler", "sfc_hflux_from_runoff",
                                                  "frazil_3d_int_z", "sfc_hflux_pme"],
                        "area":                  ["area_t"],
                        "maximum_depth":         ["ht"],
                    },
                    "mom6": {
                        "temperature":           ["thetao"],
                        "salinity":              ["so"],
                        "water_flux_into_ocean": ["wfo"],
                        "salt_flux":             ["salt_flux"],
                        "heat_flux":             ["hfds"],
                        "area":                  ["areacello"],
                        "maximum_depth":         ["deptho"],
                    }
                }
    # Load variables in a dictionary
    ds = {}
    keys = list(model_vars[model].keys())
    for k in keys:
        ds[k] = {}
        for var in model_vars[model][k]:
            if k in ["area", "maximum_depth"]:
                ds[k][var] = cc.querying.getvar(expt, var, session, n = 1) 
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice)
            else:
                try:
                    ds[k][var] = cc.querying.getvar(expt, var, session,
                                                frequency = freq,
                                                start_time = start_time,
                                                end_time = end_time,
                                                chunks = {'time': 1})
                    ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice, time = slice(start_time, end_time))
                
                    # Correct temperatures (if in K convert to C)
                    if k == 'temperature' and np.max(ds[k][var]) > 100:
                        ds[k][var] = ds[k][var] - 273.15
    
                    # If 3D field, grab the surface
                    if ds[k][var].cf.axes.get('Z'):
                        surface_z = ds[k][var].cf['Z'][0].values
                        ds[k][var] = ds[k][var].cf.sel(Z = 0, method = 'nearest')
                except Exception as e:
                    raise Exception(f"Data loading error: var={var}, freq={freq}, start_time={start_time}, end_time={end_time}, expt={expt}: {str(e)}")

    # Get temperature and salinity to calculate few other things we'll need later on
    SP = ds['salinity'][model_vars[model]['salinity'][0]]
    CT = ds['temperature'][model_vars[model]['temperature'][0]]

    # Calculate pressure
    pressure = gsw.p_from_z(-surface_z, SP.cf['Y']).rename('pressure')

    # Calculate absolute salinity
    SA = gsw.SA_from_SP(SP, pressure, SP.cf['X'], SP.cf['Y']).rename('SA')

    # Ensure we have conservative temperature; Convert MOM6's potential temperature to conservative
    if model == 'mom6':
        CT = gsw.CT_from_pt(SA, CT)
        ds['temperature'][model_vars[model]['temperature'][0]].data = CT.values

    # Calculate potential density
    pot_rho_1 = gsw.sigma1(SA, CT)#.rename('pot_rho_11')

    # Save everything to our dictionary
    ds['pressure'] = pressure
    ds['SA'] = SA
    ds['pot_rho_1'] = pot_rho_1
    
    # Calculate days per month accounting for leap years
    months_standard_noleap = np.array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    months_standard_leap = np.array([31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    if 'ryf' or 'panan' in expt:
        nyears = len(np.unique(CT['time.year']))
        days_per_month = np.tile(months_standard_noleap, nyears)
    elif 'iaf' in expt:
        nyears = len(np.unique(CT['time.year']))
        if CT['time.year'][0] % 4 == 0:
            days_per_month = months_standard_leap
        else: 
            days_per_month = months_standard_noleap
        for yr in CT['time.year'][::12][1:]:
            if yr % 4 == 0:
                days_per_month = np.concatenate([days_per_month, months_standard_leap])
            else:
                days_per_month = np.concatenate([days_per_month, months_standard_noleap])
    days_per_month = xr.DataArray(days_per_month, dims = ['time'], coords = {'time': CT['time']}, name = 'days_per_month')
    ds['days_per_month'] = days_per_month

    return ds

# %%
def get_variables_1(expt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model):

    # The models require different diagnostics to calculate the heat and salt fluxes.
    # mom6 outputs a net flux, whilst with mom5 we need to work with the separate components.
    model_vars = {
                    "mom5": {
                        "temperature":           ["temp"],
                        "salinity":              ["salt"],
                        "water_flux_into_ocean": ["pme_river"],
                        "salt_flux":             ["sfc_salt_flux_ice", "sfc_salt_flux_restore"],
                        "heat_flux":             ["sfc_hflux_coupler", "sfc_hflux_from_runoff",
                                                  "frazil_3d_int_z", "sfc_hflux_pme"],
                        "area":                  ["area_t"],
                        "maximum_depth":         ["ht"],
                    },
                    "mom6": {
                        "temperature":           ["thetao"],
                        "salinity":              ["so"],
                        "water_flux_into_ocean": ["wfo"],
                        "salt_flux":             ["salt_flux"],
                        "heat_flux":             ["hfds"],
                        "area":                  ["areacello"],
                        "maximum_depth":         ["deptho"],
                    }
                }
    # Load variables in a dictionary
    ds = {}
    keys = list(model_vars[model].keys())
    for k in keys:
        ds[k] = {}
        for var in model_vars[model][k]:
            if k in ["area", "maximum_depth"]:
                ds[k][var] = cc.querying.getvar(expt, var, session, n = 1) 
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice)
            else:
                try:
                    ds[k][var] = cc.querying.getvar(expt, var, session,
                                                frequency = freq,
                                                start_time = start_time_broad,
                                                end_time = end_time_broad,
                                                chunks = {'time': 1})
                    ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice, time = slice(start_time_real, end_time_real))
                
                    # Correct temperatures (if in K convert to C)
                    if k == 'temperature' and np.max(ds[k][var]) > 100:
                        ds[k][var] = ds[k][var] - 273.15
    
                    # If 3D field, grab the surface
                    if ds[k][var].cf.axes.get('Z'):
                        surface_z = ds[k][var].cf['Z'][0].values
                        ds[k][var] = ds[k][var].cf.sel(Z = 0, method = 'nearest')
                except Exception as e:
                    raise Exception(f"Data loading error: var={var}, freq={freq}, start_time={start_time}, end_time={end_time}, expt={expt}: {str(e)}")

    # Get temperature and salinity to calculate few other things we'll need later on
    SP = ds['salinity'][model_vars[model]['salinity'][0]]
    CT = ds['temperature'][model_vars[model]['temperature'][0]]

    # Calculate pressure
    pressure = gsw.p_from_z(-surface_z, SP.cf['Y']).rename('pressure')

    # Calculate absolute salinity
    SA = gsw.SA_from_SP(SP, pressure, SP.cf['X'], SP.cf['Y']).rename('SA')

    # Ensure we have conservative temperature; Convert MOM6's potential temperature to conservative
    if model == 'mom6':
        CT = gsw.CT_from_pt(SA, CT)
        ds['temperature'][model_vars[model]['temperature'][0]].data = CT.values

    # Calculate potential density
    pot_rho_1 = gsw.sigma1(SA, CT)#.rename('pot_rho_11')

    # Save everything to our dictionary
    ds['pressure'] = pressure
    ds['SA'] = SA
    ds['pot_rho_1'] = pot_rho_1
    
    # Calculate days per month accounting for leap years
    months_standard_noleap = np.array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    months_standard_leap = np.array([31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    if 'ryf' or 'panan' in expt:
        nyears = len(np.unique(CT['time.year']))
        days_per_month = np.tile(months_standard_noleap, nyears)
    elif 'iaf' in expt:
        nyears = len(np.unique(CT['time.year']))
        if CT['time.year'][0] % 4 == 0:
            days_per_month = months_standard_leap
        else: 
            days_per_month = months_standard_noleap
        for yr in CT['time.year'][::12][1:]:
            if yr % 4 == 0:
                days_per_month = np.concatenate([days_per_month, months_standard_leap])
            else:
                days_per_month = np.concatenate([days_per_month, months_standard_noleap])
    days_per_month = xr.DataArray(days_per_month, dims = ['time'], coords = {'time': CT['time']}, name = 'days_per_month')
    ds['days_per_month'] = days_per_month

    return ds

# %%
def compute_salt_transformation(ds):
    
    # First retrieve temperature and water_flux as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Multiply the water flux by absolute salinity to get it in the correct units
    water_flux_into_ocean = xr.Dataset(ds['water_flux_into_ocean']).to_array().squeeze().drop_vars('variable')
    water_flux_into_ocean = ds['SA'] * water_flux_into_ocean

    # Caculate the haline contraction coefficient
    haline_contraction = gsw.beta(ds['SA'], CT, ds['pressure']).rename('beta')

    # Calculate the net salt flux and multiply by 1000 to convert units
    net_salt_flux = xr.Dataset(ds['salt_flux']).to_array().sum(dim = 'variable') * 1000

    # Note that we also multiply pme_river by absolute salinity to have the correct units
    salt_transformation = haline_contraction * (water_flux_into_ocean - net_salt_flux) * ds['days_per_month']
    salt_transformation = salt_transformation.load()

    return salt_transformation

def compute_heat_transformation(ds):

    # First retrieve temperature as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Calculate the thermal expansion coefficient 
    thermal_expansion = gsw.alpha(ds['SA'], CT, ds['pressure']).rename('alpha')
    
    # Calculate the net surface heating
    net_surface_heating = xr.Dataset(ds['heat_flux']).to_array().sum(dim = 'variable')
    
    # Calculate the heat transformation
    heat_transformation = thermal_expansion * net_surface_heating * ds['days_per_month']
    heat_transformation = heat_transformation.load()

    return heat_transformation

# %%
def isopycnal_bins(ds, salt_transformation, heat_transformation):

    # Next section does a few things. It cycles through isopycnal bins, determines which cells are 
    # within the given bin for each month, finds the transformation values for those cells for each month, 
    # and sums these through time. You are left with an array of shape (isopyncal bins * lats * lons) 
    # where the array associated with a given isopycnal bin is NaN everywhere except where pot_rho_1 
    # was within the bin, there it has a time summed transformation value.
    
    # Choose appropriate bin range
    isopycnal_bins = np.arange(31, 33.5, 0.02)  # 125 bins - 31, 33.5, 0.02 (sigma1)
    #isopycnal_bins = np.concatenate([np.arange(25.0, 26.5, 0.05), np.arange(26.5, 28.5, 0.02)])  # 130 bins (sigma0)
    bin_bottoms = isopycnal_bins[:-1]
    isopycnal_bin_mid = (isopycnal_bins[1:] + bin_bottoms) / 2
    isopycnal_bin_diff = np.diff(isopycnal_bins)

    pot_rho_1 = ds['pot_rho_1']

    results_salt = []
    results_heat = []

    for i in range(len(bin_bottoms)):
        # Create binary mask for each bin
        bin_mask = xr.where((pot_rho_1 > bin_bottoms[i]) & (pot_rho_1 <= isopycnal_bins[i + 1]), 1, np.nan)

        # Multiply and sum over time
        salt_sum = (salt_transformation * bin_mask).sum(dim='time')
        heat_sum = (heat_transformation * bin_mask).sum(dim='time')

        results_salt.append(salt_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))
        results_heat.append(heat_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))

    # Concatenate results along isopycnal dimension
    salt_transformation = xr.concat(results_salt, dim='isopycnal_bins')
    heat_transformation = xr.concat(results_heat, dim='isopycnal_bins')

    # Normalise by number of days and bin thickness
    ndays = ds['days_per_month'].sum()
    c_p = 3992.1 # J kg-1 degC-1

    salt_transformation /= ndays
    heat_transformation /= (c_p * ndays)

    salt_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]
    heat_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]

    # Overwrite zeros with NANs 
    # (Note: the code within the for-loop should provide nans but lazy computing with dask can sometimes give unpredictable results)
    salt_transformation = salt_transformation.where(salt_transformation != 0)
    heat_transformation = heat_transformation.where(heat_transformation != 0)

    # Change the sign so that positive means conversion into denser water masses
    salt_transformation *= -1
    heat_transformation *= -1

    # Renaming
    salt_transformation.name = "salt_transformation"
    heat_transformation.name = "heat_transformation"

    return salt_transformation.load(), heat_transformation.load()

# %% [markdown]
# ## Opening the saved data
#
# For saving method, scroll to section below.

# %%
# Importing the saved files
salt_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_*'))
heat_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_*'))

salt_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_*'))
heat_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_*'))

# %%
salt_tr_C = xr.open_mfdataset(salt_files_C, concat_dim='time', combine='nested')
heat_tr_C = xr.open_mfdataset(heat_files_C, concat_dim='time', combine='nested')
salt_tr_C = salt_tr_C.to_array().squeeze()
heat_tr_C = heat_tr_C.to_array().squeeze()

# %%
salt_tr_C
# Out:
# <xarray.DataArray (time: 10, isopycnal_bins: 124, yt_ocean: 510, xt_ocean: 3600)> Size: 18GB
# dask.array<getitem, shape=(10, 124, 510, 3600), dtype=float64, chunksize=(1, 124, 510, 3600), chunktype=numpy.ndarray>
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 992B 31.01 31.03 ... 33.45 33.47
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
#     variable        <U19 76B 'salt_transformation'
# Dimensions without coordinates: time

# %%
salt_tr_M = xr.open_mfdataset(salt_files_M, concat_dim='time', combine='nested')
heat_tr_M = xr.open_mfdataset(heat_files_M, concat_dim='time', combine='nested')
salt_tr_M = salt_tr_M.to_array().squeeze()
heat_tr_M = heat_tr_M.to_array().squeeze()

# %%
net_tr_C = salt_tr_C + heat_tr_C
net_tr_M = salt_tr_M + heat_tr_M

# %%
# Defining the data separately for variables like area, depth, etc.
expt_con = '01deg_jra55v13_ryf9091_21mbath'
expt_melt = '01deg_jra55v13_ryf9091_21mbath_sofia_ssp126'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)

lon_slice = slice(None, None)
lat_slice = slice(None, -59)
freq = '1 monthly'
start_time_broad = '1910-10-01'
end_time_broad = '1913-01-01'
start_time_real = '1911-01-01'
end_time_real = '1911-12-31' # only one year here because we are only needing it for area  

start_time = '1911-01-01'
end_time = '1911-12-31'

ds_cont = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
ds_melt = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')

# %% [markdown]
# #### Antarctic shelf dense water formation

# %%
def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.Dataset(ds_cont['maximum_depth']).to_array().squeeze()
depth_M = xr.Dataset(ds_melt['maximum_depth']).to_array().squeeze()
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom5')

# %%
area_C = xr.Dataset(ds_cont['area']).to_array().squeeze().drop_vars('variable')

swmt_shelf_C = (net_tr_C * area_C / 1e6).where(shelf_mask == 1)
heat_shelf_C = (heat_tr_C * area_C / 1e6).where(shelf_mask == 1)
salt_shelf_C = (salt_tr_C * area_C / 1e6).where(shelf_mask == 1)
swmt_shelf_sum_C = swmt_shelf_C.cf.sum(['longitude', 'latitude'])
heat_shelf_sum_C = heat_shelf_C.cf.sum(['longitude', 'latitude'])
salt_shelf_sum_C = salt_shelf_C.cf.sum(['longitude', 'latitude'])

for da in [swmt_shelf_sum_C, heat_shelf_sum_C, salt_shelf_sum_C]:
    da.attrs["units"] = "Sv"

# %%
area_M = xr.Dataset(ds_melt['area']).to_array().squeeze().drop_vars('variable')

swmt_shelf_M = (net_tr_M * area_M / 1e6).where(shelf_mask == 1)
heat_shelf_M = (heat_tr_M * area_M / 1e6).where(shelf_mask == 1)
salt_shelf_M = (salt_tr_M * area_M / 1e6).where(shelf_mask == 1)
swmt_shelf_sum_M = swmt_shelf_M.cf.sum(['longitude', 'latitude'])
heat_shelf_sum_M = heat_shelf_M.cf.sum(['longitude', 'latitude'])
salt_shelf_sum_M = salt_shelf_M.cf.sum(['longitude', 'latitude'])

for da in [swmt_shelf_sum_M, heat_shelf_sum_M, salt_shelf_sum_M]:
    da.attrs["units"] = "Sv"

# %%
swmt_shelf_C
# Out:
# <xarray.DataArray (time: 10, isopycnal_bins: 124, yt_ocean: 510, xt_ocean: 3600)> Size: 18GB
# dask.array<where, shape=(10, 124, 510, 3600), dtype=float64, chunksize=(1, 124, 510, 720), chunktype=numpy.ndarray>
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 992B 31.01 31.03 ... 33.45 33.47
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
#     geolon_t        (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#     geolat_t        (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#     variable        <U2 8B 'ht'
# Dimensions without coordinates: time

# %%
transformation_density = 32.62
shelf_subduction_plot_C = net_tr_C.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_C = depth.cf['X']
swmt_yt_C = depth.cf['Y']

shelf_subduction_plot_M = net_tr_M.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_M = depth_M.cf['X']
swmt_yt_M = depth_M.cf['Y']

# %%
anom_xt = swmt_xt_M - swmt_xt_C
anom_yt = swmt_yt_M - swmt_yt_C
shelf_subduction_plot_anom = shelf_subduction_plot_M - shelf_subduction_plot_C

# %%
shelf_subduction_plot_anom
# Out:
# <xarray.DataArray (time: 10, yt_ocean: 510, xt_ocean: 3600)> Size: 147MB
# dask.array<sub, shape=(10, 510, 3600), dtype=float64, chunksize=(1, 510, 3600), chunktype=numpy.ndarray>
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
# Dimensions without coordinates: time

# %%
import matplotlib.path as mpath

# %%
# Taking time means
shelf_subduction_plot_ave_anom = shelf_subduction_plot_anom.mean(dim='time')

swmt_shelf_sum_ave_M = swmt_shelf_sum_M.mean(dim='time')
heat_shelf_sum_ave_M = heat_shelf_sum_M.mean(dim='time')
salt_shelf_sum_ave_M = salt_shelf_sum_M.mean(dim='time')

swmt_shelf_sum_ave_C = swmt_shelf_sum_C.mean(dim='time')
heat_shelf_sum_ave_C = heat_shelf_sum_C.mean(dim='time')
salt_shelf_sum_ave_C = salt_shelf_sum_C.mean(dim='time')

# %%
#Cell defining 25% and 75% markers.
cont_d25 = 32.69
cont_d75 = 32.55

# %%
shelf_subduction_plot_ave_anom
# Out:
# <xarray.DataArray (yt_ocean: 510, xt_ocean: 3600)> Size: 15MB
# dask.array<mean_agg-aggregate, shape=(510, 3600), dtype=float64, chunksize=(510, 3600), chunktype=numpy.ndarray>
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413

# %%
swmt_shelf_sum_ave_C = swmt_shelf_sum_ave_C.load()
# Out:
# 2025-07-17 20:54:00,008 - distributed.worker.memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 3.91 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:00,009 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.91 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:00,038 - distributed.worker.memory - WARNING - Worker is at 49% memory usage. Resuming worker. Process memory: 2.21 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:11,059 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41989
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:59646 remote=tcp://127.0.0.1:41989>: Stream is closed
# 2025-07-17 20:54:13,786 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37395
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38418 remote=tcp://127.0.0.1:37395>: Stream is closed
# 2025-07-17 20:54:20,463 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41723
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:56898 remote=tcp://127.0.0.1:41723>: Stream is closed
# 2025-07-17 20:54:20,810 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37961
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:44950 remote=tcp://127.0.0.1:37961>: Stream is closed
# 2025-07-17 20:54:23,493 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.66 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:23,493 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.66 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:24,211 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.66 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:24,524 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:24,991 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37773
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55062 remote=tcp://127.0.0.1:37773>: Stream is closed
# 2025-07-17 20:54:25,121 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:54:26,172 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34305
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:46848 remote=tcp://127.0.0.1:34305>: Stream is closed
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 swmt_shelf_sum_ave_C = swmt_shelf_sum_ave_C.load()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/dataarray.py:1172, in DataArray.load(self, **kwargs)
#    1152 def load(self, **kwargs) -> Self:
#    1153     """Manually trigger loading of this array's data from disk or a
#    1154     remote source into memory and return this array.
#    1155
#    (...)
#    1170     dask.compute
#    1171     """
# -> 1172     ds = self._to_temp_dataset().load(**kwargs)
#    1173     new = self._from_temp_dataset(ds)
#    1174     self._variable = new._variable
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/dataset.py:873, in Dataset.load(self, **kwargs)
#     870 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     872 # evaluate all the chunked arrays simultaneously
# --> 873 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     874     *lazy_data.values(), **kwargs
#     875 )
#     877 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     878     self.variables[k].data = data
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/client.py:2427, in Client._gather(self, futures, errors, direct, local_worker)
#    2425     exception = st.exception
#    2426     traceback = st.traceback
# -> 2427     raise exception.with_traceback(traceback)
#    2428 if errors == "skip":
#    2429     bad_keys.add(key)
#
# KilledWorker: Attempted to run task ('add-71d9bbad3468167e53027f413a22b67e', 3, 0, 0, 0) on 4 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:37227. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.

# %%
swmt_shelf_sum_ave_M = swmt_shelf_sum_ave_M.load()

# %%
shelf_subduction_plot_ave_anom = shelf_subduction_plot_ave_anom.load()
# Out:
# 2025-07-17 20:27:08,765 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.39 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:37,928 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.63 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:48,147 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.15 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:49,646 - distributed.worker.memory - WARNING - Worker is at 49% memory usage. Resuming worker. Process memory: 2.20 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:51,794 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 3.60 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:51,795 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.60 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:52,914 - distributed.worker.memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 3.87 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:52,916 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.87 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:54,097 - distributed.worker.memory - WARNING - Worker is at 45% memory usage. Resuming worker. Process memory: 2.04 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:54,117 - distributed.worker.memory - WARNING - Worker is at 48% memory usage. Resuming worker. Process memory: 2.17 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:54,401 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:32797
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:53936 remote=tcp://127.0.0.1:32797>: Stream is closed
# 2025-07-17 20:27:54,525 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39955
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:47978 remote=tcp://127.0.0.1:39955>: Stream is closed
# 2025-07-17 20:27:55,546 - distributed.diskutils - ERROR - Failed to remove '/jobfs/145432464.gadi-pbs/dask-scratch-space/worker-zv33s52j/storage' (failed in <built-in function rmdir>): [Errno 2] No such file or directory: 'storage'
# 2025-07-17 20:27:55,547 - distributed.diskutils - ERROR - Failed to remove '/jobfs/145432464.gadi-pbs/dask-scratch-space/worker-zv33s52j' (failed in <built-in function rmdir>): [Errno 2] No such file or directory: '/jobfs/145432464.gadi-pbs/dask-scratch-space/worker-zv33s52j'
# 2025-07-17 20:27:55,681 - distributed.worker.memory - WARNING - Worker is at 85% memory usage. Pausing worker.  Process memory: 3.82 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:55,682 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.82 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:54,624 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:41857
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:52106 remote=tcp://127.0.0.1:41857>: Stream is closed
# 2025-07-17 20:27:55,863 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46881
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:50378 remote=tcp://127.0.0.1:46881>: Stream is closed
# 2025-07-17 20:27:56,643 - distributed.worker.memory - WARNING - Worker is at 48% memory usage. Resuming worker. Process memory: 2.18 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:57,551 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36869
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48066 remote=tcp://127.0.0.1:36869>: Stream is closed
# 2025-07-17 20:27:57,551 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36869
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 227, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 366, in read_bytes_rw
#     actual = await stream.read_into(chunk)  # type: ignore[arg-type]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48082 remote=tcp://127.0.0.1:36869>: Stream is closed
# 2025-07-17 20:27:57,958 - distributed.worker.memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 3.88 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:57,959 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.88 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:58,066 - distributed.worker.memory - WARNING - Worker is at 48% memory usage. Resuming worker. Process memory: 2.19 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:27:59,848 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:35246 remote=tcp://127.0.0.1:40877>: Stream is closed
# 2025-07-17 20:27:59,848 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 227, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 366, in read_bytes_rw
#     actual = await stream.read_into(chunk)  # type: ignore[arg-type]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:37920 remote=tcp://127.0.0.1:40877>: Stream is closed
# 2025-07-17 20:28:03,310 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42375
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:37818 remote=tcp://127.0.0.1:42375>: Stream is closed
# 2025-07-17 20:28:03,310 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42375
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:48020 remote=tcp://127.0.0.1:42375>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-07-17 20:28:28,346 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.14 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 20:28:47,063 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34097
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:50582 remote=tcp://127.0.0.1:34097>: Stream is closed
# 2025-07-17 20:28:47,139 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33411
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:46200 remote=tcp://127.0.0.1:33411>: Stream is closed
# 2025-07-17 20:28:47,280 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33015
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38388 remote=tcp://127.0.0.1:33015>: Stream is closed
# 2025-07-17 20:28:47,335 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:34949
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:46294 remote=tcp://127.0.0.1:34949>: Stream is closed
# 2025-07-17 20:28:47,832 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33617
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:36136 remote=tcp://127.0.0.1:33617>: Stream is closed
# 2025-07-17 20:30:00,859 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39027
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48974 remote=tcp://127.0.0.1:39027>: Stream is closed
# [gadi-cpu-bdw-0055:2504402:0:2504402] Caught signal 7 (Bus error: nonexistent physical address)
# [gadi-cpu-bdw-0055:2504410:0:2504410] Caught signal 7 (Bus error: nonexistent physical address)
# [gadi-cpu-bdw-0055:2504400:0:2504400] Caught signal 7 (Bus error: nonexistent physical address)
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section.
#  section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section..debug_ranges
#
#  section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.Dwarf Error: Can't find
# .debug_ranges section.
# BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
# .debug_ranges
#  section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.Dwarf Error: Can't find
#
# .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section.
#
#  section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges section. section.
#
# Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: Dwarf Error: Can't find .debug_ranges section.
# Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# BFD: BFD: BFD: Dwarf Error: Can't find Dwarf Error: Can't find Dwarf Error: Can't find .debug_ranges.debug_ranges.debug_ranges section. section. section.
#
#
# ...
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# BFD: Dwarf Error: Can't find .debug_ranges section.
# ==== backtrace (tid:2504417) ====
#  0 0x0000000000012990 __funlockfile()  :0
#  1 0x00000000000029da memset()  /usr/src/debug/glibc-2.28-251.el8_10.16.x86_64/string/../sysdeps/x86_64/multiarch/memset-vec-unaligned-erms.S:277
#  2 0x000000000000ade3 _dl_map_object_from_fd()  /usr/src/debug/glibc-2.28-251.el8_10.16.x86_64/elf/./dl-map-segments.h:131
#  3 0x000000000000c911 _dl_map_object()  /usr/src/debug/glibc-2.28-251.el8_10.16.x86_64/elf/dl-load.c:2233
#  4 0x0000000000010fd9 dl_open_worker_begin()  /usr/src/debug/glibc-2.28-251.el8_10.16.x86_64/elf/dl-open.c:551
#  5 0x00000000001790d4 __GI__dl_catch_exception()  :0
#  6 0x00000000000108c7 dl_open_worker()  /usr/src/debug/glibc-2.28-251.el8_10.16.x86_64/elf/dl-open.c:762
#  7 0x00000000001790d4 __GI__dl_catch_exception()  :0
#  8 0x0000000000010b81 _dl_open()  /usr/src/debug/glibc-2.28-251.el8_10.16.x86_64/elf/dl-open.c:870
#  9 0x0000000000000f8a dlopen_doit()  ???:0
# 10 0x00000000001790d4 __GI__dl_catch_exception()  :0
# 11 0x0000000000179193 __GI__dl_catch_error()  :0
# 12 0x000000000000152e _dlerror_run()  :0
# 13 0x000000000000102a __dlopen_check()  :0
# 14 0x00000000002d6cbd _PyImport_FindSharedFuncptr()  :0
# 15 0x00000000002d5828 _imp_create_dynamic()  :0
# 16 0x000000000020692b cfunction_vectorcall_FASTCALL()  :0
# 17 0x00000000001f1929 _PyEval_EvalFrameDefault()  ???:0
# 18 0x0000000000210113 _PyFunction_Vectorcall()  ???:0
# 19 0x00000000001fee83 object_vacall()  :0
# 20 0x000000000022ed8c PyObject_CallMethodObjArgs()  ???:0
# 21 0x000000000022df89 PyImport_ImportModuleLevelObject.localalias()  :0
# 22 0x0000000000241f10 builtin___import__()  :0
# 23 0x00000000001f5faf cfunction_vectorcall_FASTCALL_KEYWORDS()  :0
# 24 0x00000000001f1929 _PyEval_EvalFrameDefault()  ???:0
# 25 0x0000000000210113 _PyFunction_Vectorcall()  ???:0
# 26 0x00000000001fee83 object_vacall()  :0
# 27 0x000000000022ed8c PyObject_CallMethodObjArgs()  ???:0
# 28 0x000000000022e1f9 PyImport_ImportModuleLevelObject.localalias()  :0
# 29 0x00000000001edd9b _PyEval_EvalFrameDefault()  ???:0
# 30 0x00000000002a605e _PyEval_Vector()  :0
# 31 0x00000000002a55ef PyEval_EvalCode()  ???:0
# 32 0x00000000002c0b5e builtin_exec()  :0
# 33 0x00000000001f5faf cfunction_vectorcall_FASTCALL_KEYWORDS()  :0
# 34 0x00000000001f1929 _PyEval_EvalFrameDefault()  ???:0
# 35 0x0000000000210113 _PyFunction_Vectorcall()  ???:0
# 36 0x00000000001fee83 object_vacall()  :0
# 37 0x000000000022ed8c PyObject_CallMethodObjArgs()  ???:0
# 38 0x000000000022df89 PyImport_ImportModuleLevelObject.localalias()  :0
# 39 0x00000000001edd9b _PyEval_EvalFrameDefault()  ???:0
# 40 0x00000000002a605e _PyEval_Vector()  :0
# 41 0x00000000002a55ef PyEval_EvalCode()  ???:0
# 42 0x00000000002c0b5e builtin_exec()  :0
# 43 0x00000000001f5faf cfunction_vectorcall_FASTCALL_KEYWORDS()  :0
# 44 0x00000000001f1929 _PyEval_EvalFrameDefault()  ???:0
# 45 0x0000000000210113 _PyFunction_Vectorcall()  ???:0
# 46 0x00000000001fee83 object_vacall()  :0
# 47 0x000000000022ed8c PyObject_CallMethodObjArgs()  ???:0
# 48 0x000000000022df89 PyImport_ImportModuleLevelObject.localalias()  :0
# 49 0x00000000001edd9b _PyEval_EvalFrameDefault()  ???:0
# 50 0x00000000002a605e _PyEval_Vector()  :0
# 51 0x00000000002a55ef PyEval_EvalCode()  ???:0
# 52 0x00000000002c0b5e builtin_exec()  :0
# 53 0x00000000001f5faf cfunction_vectorcall_FASTCALL_KEYWORDS()  :0
# 54 0x00000000001f1929 _PyEval_EvalFrameDefault()  ???:0
# 55 0x0000000000210113 _PyFunction_Vectorcall()  ???:0
# 56 0x00000000001fee83 object_vacall()  :0
# 57 0x000000000022ed8c PyObject_CallMethodObjArgs()  ???:0
# =================================
# 2025-07-17 20:30:07,764 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:32967
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36344 remote=tcp://127.0.0.1:32967>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2025-07-17 20:30:07,764 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:32967
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/iostream.py", line 1116, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 140, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36352 remote=tcp://127.0.0.1:32967>: ConnectionResetError: [Errno 104] Connection reset by peer
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 shelf_subduction_plot_ave_anom = shelf_subduction_plot_ave_anom.load()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/dataarray.py:1172, in DataArray.load(self, **kwargs)
#    1152 def load(self, **kwargs) -> Self:
#    1153     """Manually trigger loading of this array's data from disk or a
#    1154     remote source into memory and return this array.
#    1155
#    (...)
#    1170     dask.compute
#    1171     """
# -> 1172     ds = self._to_temp_dataset().load(**kwargs)
#    1173     new = self._from_temp_dataset(ds)
#    1174     self._variable = new._variable
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/dataset.py:873, in Dataset.load(self, **kwargs)
#     870 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     872 # evaluate all the chunked arrays simultaneously
# --> 873 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     874     *lazy_data.values(), **kwargs
#     875 )
#     877 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     878     self.variables[k].data = data
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/client.py:2427, in Client._gather(self, futures, errors, direct, local_worker)
#    2425     exception = st.exception
#    2426     traceback = st.traceback
# -> 2427     raise exception.with_traceback(traceback)
#    2428 if errors == "skip":
#    2429     bad_keys.add(key)
#
# KilledWorker: Attempted to run task ('open_dataset-heat_transformation-4b3e6c7a0cb270f77ada9c1ca76929bc', 0, 0, 0) on 4 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:41115. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.
# 2025-07-17 20:30:09,523 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:32967
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1485, in connect
#     return await self._connect(addr=addr, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1429, in _connect
#     comm = await connect(
#            ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/core.py", line 377, in connect
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1476, in connect
#     async with asyncio.timeout(math.inf) as scope:
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/asyncio/timeouts.py", line 98, in __aexit__
#     raise TimeoutError
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2878, in get_data_from_worker
#     comm = await rpc.connect(worker)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1497, in connect
#     raise CommClosedError(reason)
# distributed.comm.core.CommClosedError: Address removed.
# 2025-07-17 20:30:12,723 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33551
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 227, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 366, in read_bytes_rw
#     actual = await stream.read_into(chunk)  # type: ignore[arg-type]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:52918 remote=tcp://127.0.0.1:33551>: Stream is closed

# %%
fig, ax1 = plt.subplots(figsize=(4.5, 5.33))

ax1.plot(swmt_shelf_sum_ave_C, swmt_shelf_sum_ave_C['isopycnal_bins'], color = 'k', label='Control: 3.71 Sv')
ax1.plot(swmt_shelf_sum_ave_M, swmt_shelf_sum_ave_M['isopycnal_bins'], color = 'r', label='Meltwater: 2.88 Sv')
ax1.plot([0, 0], [31, 33.2], 'k', linewidth=0.5)
ax1.set_ylim((33.2, 31))
ax1.set_xlim((-1.5, 10))
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()
ax1.set_ylabel('Density $\sigma_1$ (kg m$^{-3}$)')
ax1.set_xlabel('Surface water-mass transformation (Sv)')
ax1.legend();
# Out:
# 2025-07-17 19:57:53,766 - distributed.worker.memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 3.89 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:57:54,543 - distributed.worker.memory - WARNING - Worker is at 49% memory usage. Resuming worker. Process memory: 2.20 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:57:55,073 - distributed.worker.memory - WARNING - Worker is at 87% memory usage. Pausing worker.  Process memory: 3.89 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:57:56,167 - distributed.worker.memory - WARNING - Worker is at 49% memory usage. Resuming worker. Process memory: 2.20 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:57:57,742 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36555
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:59182 remote=tcp://127.0.0.1:36555>: Stream is closed
# 2025-07-17 19:58:07,109 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37829
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48828 remote=tcp://127.0.0.1:37829>: Stream is closed
# 2025-07-17 19:58:07,109 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37829
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 227, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 366, in read_bytes_rw
#     actual = await stream.read_into(chunk)  # type: ignore[arg-type]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:48806 remote=tcp://127.0.0.1:37829>: Stream is closed
# 2025-07-17 19:58:07,693 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:46459
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:58740 remote=tcp://127.0.0.1:46459>: Stream is closed
# 2025-07-17 19:58:44,554 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.65 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:45,262 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.65 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:45,308 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:46,165 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:49,467 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.65 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:50,237 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.65 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:50,582 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 3.66 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:50,626 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33247
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:58468 remote=tcp://127.0.0.1:33247>: Stream is closed
# 2025-07-17 19:58:50,999 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:52,353 - distributed.worker.memory - WARNING - Worker is at 43% memory usage. Resuming worker. Process memory: 1.96 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:52,535 - distributed.worker.memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 3.87 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:52,536 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.87 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:52,632 - distributed.worker.memory - WARNING - Worker is at 48% memory usage. Resuming worker. Process memory: 2.18 GiB -- Worker memory limit: 4.47 GiB
# 2025-07-17 19:58:54,113 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43207
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 227, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 366, in read_bytes_rw
#     actual = await stream.read_into(chunk)  # type: ignore[arg-type]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:49048 remote=tcp://127.0.0.1:43207>: Stream is closed
# 2025-07-17 19:58:56,758 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43829
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2075, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2881, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:43504 remote=tcp://127.0.0.1:43829>: Stream is closed
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# Cell In[21], line 3
#       1 fig, ax1 = plt.subplots(figsize=(4.5, 5.33))
# ----> 3 ax1.plot(swmt_shelf_sum_ave_C, swmt_shelf_sum_ave_C['isopycnal_bins'], color = 'k', label='Control: 3.71 Sv')
#       4 ax1.plot(swmt_shelf_sum_ave_M, swmt_shelf_sum_ave_M['isopycnal_bins'], color = 'r', label='Meltwater: 2.88 Sv')
#       5 ax1.plot([0, 0], [31, 33.2], 'k', linewidth=0.5)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/matplotlib/axes/_base.py:488, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     485         kw[prop_name] = val
#     487 if len(xy) == 2:
# --> 488     x = _check_1d(xy[0])
#     489     y = _check_1d(xy[1])
#     490 else:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/matplotlib/cbook.py:1351, in _check_1d(x)
#    1349 """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1350 # Unpack in case of e.g. Pandas or xarray object
# -> 1351 x = _unpack_to_numpy(x)
#    1352 # plot requires `shape` and `ndim`.  If passed an
#    1353 # object that doesn't provide them, then force to numpy array.
#    1354 # Note this will strip unit information.
#    1355 if (not hasattr(x, 'shape') or
#    1356         not hasattr(x, 'ndim') or
#    1357         len(x.shape) < 1):
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/matplotlib/cbook.py:2316, in _unpack_to_numpy(x)
#    2313     return x
#    2314 if hasattr(x, 'to_numpy'):
#    2315     # Assume that any to_numpy() method actually returns a numpy array
# -> 2316     return x.to_numpy()
#    2317 if hasattr(x, 'values'):
#    2318     xtmp = x.values
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/dataarray.py:828, in DataArray.to_numpy(self)
#     817 def to_numpy(self) -> np.ndarray:
#     818     """
#     819     Coerces wrapped data to numpy and returns a numpy.ndarray.
#     820
#    (...)
#     826     DataArray.data
#     827     """
# --> 828     return self.variable.to_numpy()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/namedarray/core.py:857, in NamedArray.to_numpy(self)
#     855 """Coerces wrapped data to numpy and returns a numpy.ndarray"""
#     856 # TODO an entrypoint so array libraries can choose coercion method?
# --> 857 return to_numpy(self._data)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/namedarray/pycompat.py:111, in to_numpy(data, **kwargs)
#     109 if is_chunked_array(data):
#     110     chunkmanager = get_chunked_array_type(data)
# --> 111     data, *_ = chunkmanager.compute(data, **kwargs)
#     112 if isinstance(data, array_type("cupy")):
#     113     data = data.get()
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/dask/base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/client.py:2427, in Client._gather(self, futures, errors, direct, local_worker)
#    2425     exception = st.exception
#    2426     traceback = st.traceback
# -> 2427     raise exception.with_traceback(traceback)
#    2428 if errors == "skip":
#    2429     bad_keys.add(key)
#
# KilledWorker: Attempted to run task ('add-71d9bbad3468167e53027f413a22b67e', 7, 0, 0, 0) on 4 different workers, but all those workers died while running it. The last worker that attempt to run the task was tcp://127.0.0.1:33497. Inspecting worker logs is often a good next step to diagnose what went wrong. For more information see https://distributed.dask.org/en/stable/killed.html.

# %% [markdown]
# #### Finding the 25% and 75%
#
# Control max = 9.21304257 Sv (at density ).
# - 25% of max (2.3032606425 Sv) = 32.69
# - 75% of max (6.9097819275 Sv) = 32.55
# - Control mean transport in this slice = 3.7060457 Sv
#
# Melt max = BLANK Sv (at density BLANK).
# - 25% of max (BLANK Sv) = BLANK
# - 75% of max (BLANK Sv) = BLANK
# - Melt mean transport in this slice = 2.87528989 Sv.
#
# We just use the control lines as our formation region.
#
# Finding the sums: (change density values below to match 25 and 75 thresholds)

# %%
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(32.55,32.69)).compute().mean()

# %%
swmt_shelf_sum_ave_M.sel(isopycnal_bins=slice(32.55,32.69)).compute().mean()

# %%
swmt_shelf_time_C = swmt_shelf_sum_C.sel(isopycnal_bins=slice(32.55,32.69)).mean('isopycnal_bins').compute()

# %%
swmt_shelf_time_M = swmt_shelf_sum_M.sel(isopycnal_bins=slice(32.55,32.69)).mean('isopycnal_bins').compute()

# %%
# Saving
swmt_shelf_time_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_time_access_C.nc')
swmt_shelf_time_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_time_access_M.nc')

# %%
swmt_shelf_time_C.plot(label="Control")
swmt_shelf_time_M.plot(label="Meltwater")
plt.ylabel("Surface water mass transformation (Sv)")
plt.xlabel("Year")
plt.legend(loc="lower left")
plt.title("Panan01 Surface Water Mass Transformation over 25-75% range")

# %% [markdown]
# ## Saving per year via manual method

# %%
# Change to your experiment of interest
expt_con = '01deg_jra55v13_ryf9091_21mbath'
expt_melt = '01deg_jra55v13_ryf9091_21mbath_sofia_ssp126'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)
freq = '1 monthly'

# Select time period and region
lon_slice = slice(None, None)
lat_slice = slice(None, -59)

# %% [markdown]
# #### First doing the control

# %%
# Painfully manual don't mind this

start_time = '1910-01-01'
end_time = '1910-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_01.nc')
# Out:
# 2025-07-17 11:42:49,777 - tornado.application - ERROR - Exception in callback <bound method Worker.trigger_profile of <Worker 'tcp://127.0.0.1:33617', name: 22, status: running, stored: 0, running: 1/1, ready: 0, comm: 0, waiting: 0>>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 66, in identifier
#     co.co_name,
#     ^^^^^^^^^^
# AttributeError: 'cell' object has no attribute 'co_name'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2448, in trigger_profile
#     state = profile.process(
#             ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 194, in process
#     new_state = process(prev, frame, state, stop=stop, depth=depth - 1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 199, in process
#     ident = identifier(frame)
#             ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 72, in identifier
#     if co.__module__:
#        ^^^^^^^^^^^^^
# AttributeError: 'cell' object has no attribute '__module__'

# %%
# Painfully manual don't mind this 2

start_time = '1911-01-01'
end_time = '1911-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_02.nc')

# %%
# Painfully manual don't mind this 3

start_time = '1912-01-01'
end_time = '1912-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_03.nc')

# %%
# Painfully manual don't mind this 4

start_time = '1913-01-01'
end_time = '1913-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_04.nc')

# %%
# Painfully manual don't mind this 5

start_time = '1914-01-01'
end_time = '1914-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_05.nc')

# %%
# Painfully manual don't mind this 6
start_time = '1915-01-01'
end_time = '1915-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_06.nc')

# %%
# Painfully manual don't mind this 7
start_time = '1916-01-01'
end_time = '1916-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_07.nc')

# %%
# Painfully manual don't mind this 8
start_time = '1917-01-01'
end_time = '1917-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_08.nc')

# %%
# Painfully manual don't mind this 9
start_time = '1918-01-01'
end_time = '1918-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_09.nc')

# %%
# Painfully manual don't mind this 10
start_time = '1919-01-01'
end_time = '1919-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_10.nc')

# %% [markdown]
# #### Second doing the perturbation

# %%
# Checking time slice
start_time_broad = '1910-01-01'
start_time_real = '1910-01-01'
end_time_broad = '1911-04-01'
end_time_real = '1910-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
ds
# Out:
# {'temperature': {'temp': <xarray.DataArray 'temp' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       st_ocean  float64 8B 0.5413
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00},
#  'salinity': {'salt': <xarray.DataArray 'salt' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       st_ocean  float64 8B 0.5413
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      Practical Salinity
#       units:          psu
#       valid_range:    [-10. 100.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  sea_water_salinity
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'water_flux_into_ocean': {'pme_river': <xarray.DataArray 'pme_river' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      mass flux of precip-evap+river via sbc (liquid, frozen, e...
#       units:          (kg/m^3)*(m/sec)
#       valid_range:    [-1000000.  1000000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  water_flux_into_sea_water
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'salt_flux': {'sfc_salt_flux_ice': <xarray.DataArray 'sfc_salt_flux_ice' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      sfc_salt_flux_ice
#       units:          kg/(m^2*sec)
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  downward_sea_ice_basal_salt_flux
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'sfc_salt_flux_restore': <xarray.DataArray 'sfc_salt_flux_restore' (time: 12, yt_ocean: 510,
#                                              xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      sfc_salt_flux_restore: flux from restoring term
#       units:          kg/(m^2*sec)
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'heat_flux': {'sfc_hflux_coupler': <xarray.DataArray 'sfc_hflux_coupler' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      surface heat flux coming through coupler
#       units:          Watts/m^2
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'sfc_hflux_from_runoff': <xarray.DataArray 'sfc_hflux_from_runoff' (time: 12, yt_ocean: 510,
#                                              xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      heat flux (relative to 0C) from liquid river runoff
#       units:          Watts/m^2
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  temperature_flux_due_to_runoff_expressed_as_heat_flux_int...
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'frazil_3d_int_z': <xarray.DataArray 'frazil_3d_int_z' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      Vertical sum of ocn frazil heat flux over time step
#       units:          W/m^2
#       valid_range:    [-1.e+10  1.e+10]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'sfc_hflux_pme': <xarray.DataArray 'sfc_hflux_pme' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      heat flux (relative to 0C) from pme transfer of water acr...
#       units:          Watts/m^2
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'area': {'area_t': <xarray.DataArray 'area_t' (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
#   dask.array<getitem, shape=(510, 3600), dtype=float32, chunksize=(510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       geolon_t  (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#       geolat_t  (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#   Attributes:
#       long_name:     tracer cell area
#       units:         m^2
#       valid_range:   [0.e+00 1.e+15]
#       cell_methods:  time: point
#       ncfiles:       ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf909...},
#  'maximum_depth': {'ht': <xarray.DataArray 'ht' (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
#   dask.array<getitem, shape=(510, 3600), dtype=float32, chunksize=(510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       geolon_t  (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#       geolat_t  (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#   Attributes:
#       long_name:      ocean depth on t-cells
#       units:          m
#       valid_range:    [-1.e+09  1.e+09]
#       cell_methods:   time: point
#       standard_name:  sea_floor_depth_below_geoid
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'pressure': <xarray.DataArray 'pressure' (yt_ocean: 510)> Size: 4kB
#  array([0.5470873 , 0.54708664, 0.54708599, 0.54708533, 0.54708466,
#         0.547084  , 0.54708333, 0.54708266, 0.54708198, 0.54708131,
#         0.54708062, 0.54707994, 0.54707925, 0.54707856, 0.54707787,
#         0.54707717, 0.54707648, 0.54707577, 0.54707507, 0.54707436,
#         0.54707365, 0.54707294, 0.54707222, 0.5470715 , 0.54707078,
#         0.54707005, 0.54706932, 0.54706859, 0.54706786, 0.54706712,
#         0.54706638, 0.54706564, 0.54706489, 0.54706414, 0.54706339,
#         0.54706264, 0.54706188, 0.54706112, 0.54706035, 0.54705959,
#         0.54705882, 0.54705804, 0.54705727, 0.54705649, 0.54705571,
#         0.54705492, 0.54705414, 0.54705335, 0.54705255, 0.54705176,
#         0.54705096, 0.54705016, 0.54704935, 0.54704854, 0.54704773,
#         0.54704692, 0.5470461 , 0.54704528, 0.54704446, 0.54704364,
#         0.54704281, 0.54704198, 0.54704114, 0.54704031, 0.54703947,
#         0.54703862, 0.54703778, 0.54703693, 0.54703608, 0.54703522,
#         0.54703437, 0.54703351, 0.54703265, 0.54703178, 0.54703091,
#         0.54703004, 0.54702917, 0.54702829, 0.54702741, 0.54702653,
#         0.54702564, 0.54702475, 0.54702386, 0.54702296, 0.54702207,
#         0.54702117, 0.54702026, 0.54701936, 0.54701845, 0.54701754,
#         0.54701662, 0.54701571, 0.54701479, 0.54701386, 0.54701294,
#         0.54701201, 0.54701108, 0.54701015, 0.54700921, 0.54700827,
#  ...
#         0.54659049, 0.54658872, 0.54658694, 0.54658515, 0.54658337,
#         0.54658157, 0.54657978, 0.54657797, 0.54657617, 0.54657435,
#         0.54657254, 0.54657071, 0.54656889, 0.54656705, 0.54656522,
#         0.54656337, 0.54656153, 0.54655968, 0.54655782, 0.54655596,
#         0.54655409, 0.54655222, 0.54655034, 0.54654846, 0.54654657,
#         0.54654468, 0.54654278, 0.54654088, 0.54653897, 0.54653706,
#         0.54653514, 0.54653321, 0.54653129, 0.54652935, 0.54652741,
#         0.54652547, 0.54652352, 0.54652157, 0.54651961, 0.54651764,
#         0.54651568, 0.5465137 , 0.54651172, 0.54650974, 0.54650775,
#         0.54650575, 0.54650375, 0.54650174, 0.54649973, 0.54649771,
#         0.54649569, 0.54649367, 0.54649163, 0.5464896 , 0.54648755,
#         0.5464855 , 0.54648345, 0.54648139, 0.54647933, 0.54647726,
#         0.54647518, 0.5464731 , 0.54647102, 0.54646893, 0.54646683,
#         0.54646473, 0.54646262, 0.54646051, 0.54645839, 0.54645627,
#         0.54645414, 0.546452  , 0.54644986, 0.54644772, 0.54644557,
#         0.54644341, 0.54644125, 0.54643908, 0.54643691, 0.54643473,
#         0.54643255, 0.54643036, 0.54642817, 0.54642597, 0.54642376,
#         0.54642155, 0.54641933, 0.54641711, 0.54641488, 0.54641265,
#         0.54641041, 0.54640817, 0.54640592, 0.54640366, 0.5464014 ,
#         0.54639913, 0.54639686, 0.54639459, 0.5463923 , 0.54639001])
#  Coordinates:
#    * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#  Attributes:
#      long_name:       tcell latitude
#      units:           degrees_N
#      cartesian_axis:  Y,
#  'SA': <xarray.DataArray 'SA' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 176MB
#  dask.array<sa_from_sp, shape=(12, 510, 3600), dtype=float64, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#  Coordinates:
#    * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#    * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#      st_ocean  float64 8B 0.5413
#    * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#  Attributes:
#      long_name:      Practical Salinity
#      units:          psu
#      valid_range:    [-10. 100.]
#      cell_methods:   time: mean
#      time_avg_info:  average_T1,average_T2,average_DT
#      standard_name:  sea_water_salinity
#      ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#  'pot_rho_1': <xarray.DataArray 'SA' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 176MB
#  dask.array<sigma1, shape=(12, 510, 3600), dtype=float64, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#  Coordinates:
#    * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#    * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#      st_ocean  float64 8B 0.5413
#    * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#  Attributes:
#      long_name:      Practical Salinity
#      units:          psu
#      valid_range:    [-10. 100.]
#      cell_methods:   time: mean
#      time_avg_info:  average_T1,average_T2,average_DT
#      standard_name:  sea_water_salinity
#      ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#  'days_per_month': <xarray.DataArray 'days_per_month' (time: 12)> Size: 96B
#  array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
#  Coordinates:
#    * time     (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00}

# %%
# Painfully manual don't mind this
start_time_broad = '1910-01-01'
start_time_real = '1910-01-01'
end_time_broad = '1911-04-01'
end_time_real = '1910-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_01.nc')

# %%
# Painfully manual don't mind this 2

start_time_real = '1911-01-01'
end_time_broad = '1912-04-01'
end_time_real = '1911-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_02.nc')

# %%
# Painfully manual don't mind this 3

start_time_broad = '1911-06-01'
start_time_real = '1912-01-01'
end_time_broad = '1913-04-01'
end_time_real = '1912-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_03.nc')

# %%
# Painfully manual don't mind this 4

start_time_broad = '1912-06-01'
start_time_real = '1913-01-01'
end_time_broad = '1914-04-01'
end_time_real = '1913-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
             
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_04.nc')

# %%
# Painfully manual don't mind this 5
 
start_time_broad = '1913-10-01'
start_time_real = '1914-01-01'
end_time_broad = '1915-04-01'
end_time_real = '1914-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')

salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_05.nc')

# %%
# Painfully manual don't mind this 6
start_time_broad = '1914-10-01'
start_time_real = '1915-01-01'
end_time_broad = '1916-04-01'
end_time_real = '1915-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')

salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_06.nc')

# %%
# Painfully manual don't mind this 7
start_time_broad = '1915-10-01'
start_time_real = '1916-01-01'
end_time_broad = '1917-04-01'
end_time_real = '1916-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_07.nc')

# %%
# Painfully manual don't mind this 8
start_time_broad = '1916-10-01'
start_time_real = '1917-01-01'
end_time_broad = '1918-04-01'
end_time_real = '1917-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
            
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_08.nc')

# %%
# Painfully manual don't mind this 9
start_time_broad = '1917-10-01'
start_time_real = '1918-01-01'
end_time_broad = '1919-04-01'
end_time_real = '1918-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_09.nc')

# %%
# Painfully manual don't mind this 10
start_time_broad = '1918-06-01'
start_time_real = '1919-01-01'
end_time_broad = '1920-04-01'
end_time_real = '1919-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
          
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_10.nc')
