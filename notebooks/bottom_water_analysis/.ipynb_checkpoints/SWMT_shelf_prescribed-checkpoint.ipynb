# %% [markdown]
# # SWMT prescribed comparison

# %%
import intake
import glob

import dask.distributed
import gsw
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker = 1)

# %% [markdown]
# ## Time series

# %% [markdown]
# ### Importing the data

# %%
pan01_anom_panlims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_time_pan01_rho0_anom.nc', chunks = 'auto') 
acc_anom_acclims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_rho0_anom.nc', chunks = 'auto')

# %%
pan01_anom_panlims_new = pan01_anom_panlims.to_series()
acc_anom_acclims_new = acc_anom_acclims.to_series()

# %%
pan01_time_C_panlims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_time_pan01_rho0_C.nc', chunks = 'auto') 
pan01_time_M_panlims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_time_pan01_rho0_M.nc', chunks = 'auto') 
acc_time_C_acclims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_rho0_C.nc', chunks = 'auto')
acc_time_M_acclims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_rho0_M.nc', chunks = 'auto')

# %%
pan01_time_C_panlims = pan01_time_C_panlims.to_series()
pan01_time_M_panlims = pan01_time_M_panlims.to_series()
acc_time_C_acclims = acc_time_C_acclims.to_series()
acc_time_M_acclims = acc_time_M_acclims.to_series()

# %% [markdown]
# ### Plotting

# %%
## Testing with different lims
pan01_time_C_acclims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_time_pan01_acclims_rho0_C.nc', chunks = 'auto') 
pan01_time_M_acclims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_time_pan01_acclims_rho0_M.nc', chunks = 'auto') 
acc_time_C_panlims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_panlims_rho0_C.nc', chunks = 'auto')
acc_time_M_panlims = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_time_access_panlims_rho0_M.nc', chunks = 'auto')

# %%
pan01_time_C_acclims = pan01_time_C_acclims.to_series()
pan01_time_M_acclims = pan01_time_M_acclims.to_series()
acc_time_C_panlims = acc_time_C_panlims.to_series()
acc_time_M_panlims = acc_time_M_panlims.to_series()

# %%
plt.rcParams['font.size'] = 20

# Note, the '+1' is to make the data go from 1-10 instead of 0-9. 
plt.figure(figsize=(16, 5))
plt.plot(pan01_time_C_acclims.index + 1, pan01_time_C_acclims.values, linestyle='--', color = 'black', label='PanAntarctic Control')
plt.plot(pan01_time_M_acclims.index + 1, pan01_time_M_acclims.values,linestyle='-', color = 'black', label='PanAntarctic Meltwater')
plt.plot(acc_time_C_acclims.index + 1, acc_time_C_acclims.values, linestyle='--',color='red', label='ACCESS-OM2 Control')
plt.plot(acc_time_M_acclims.index + 1, acc_time_M_acclims.values, linestyle='-',color='red', label='ACCESS-OM2 Meltwater')

# Labeling and formatting
plt.xlim(1, 10)
plt.ylim(0,4)
plt.xlabel('Time (years)')
plt.ylabel("SWMT anomaly (Sv)")
plt.title('')#'Surface water mass transformation anomaly for DSW on shelf')
plt.legend()
plt.grid(True, color='lightgrey')
plt.axhline(y=0, color='black', linestyle='-')
plt.title("ACCESS limits")
plt.tight_layout()
plt.show()

# %%
print('PanAnt 2 year reduction =',(pan01_time_M_acclims[1]-pan01_time_C_acclims[1]),
     '\nControl at year 2 =', pan01_time_C_acclims[1],
     '\nMelt at year 2 =', pan01_time_M_acclims[1],
     '\nPercentage reduction =', 1-pan01_time_M_acclims[1]/pan01_time_C_acclims[1])
# Out:
# PanAnt 2 year reduction = -0.6749383883776274
# Control at year 2 = 2.6124109803748072
# Melt at year 2 = 1.9374725919971798
# Percentage reduction = 0.2583584257790835

# %%
print('ACCESS 2 year reduction =',(acc_time_M_acclims[1]-acc_time_C_acclims[1]),
     '\nControl at year 2 =', acc_time_C_acclims[1],
     '\nMelt at year 2 =', acc_time_M_acclims[1],
     '\nPercentage reduction =', 1-acc_time_M_acclims[1]/acc_time_C_acclims[1])
# Out:
# ACCESS 2 year reduction = -0.3801443438362524
# Control at year 2 = 3.414597465303699
# Melt at year 2 = 3.0344531214674464
# Percentage reduction = 0.11132918234109968

# %%
print('PanAnt 4 year reduction =',(pan01_time_M_acclims[3]-pan01_time_C_acclims[3]),
     '\nControl at year 4 =', pan01_time_C_acclims[3],
     '\nMelt at year 4 =', pan01_time_M_acclims[3],
     '\nPercentage reduction =', 1-pan01_time_M_acclims[3]/pan01_time_C_acclims[3])
# Out:
# PanAnt 4 year reduction = -0.8236529132028503
# Control at year 4 = 2.5844204294587074
# Melt at year 4 = 1.7607675162558571
# Percentage reduction = 0.318699273467421

# %%
print('ACCESS 4 year reduction =',(acc_time_M_acclims[3]-acc_time_C_acclims[3]),
     '\nControl at year 4 =', acc_time_C_acclims[3],
     '\nMelt at year 4 =', acc_time_M_acclims[3],
     '\nPercentage reduction =', 1-acc_time_M_acclims[3]/acc_time_C_acclims[3])
# Out:
# ACCESS 4 year reduction = -0.5992379698632679
# Control at year 4 = 3.4282320847351926
# Melt at year 4 = 2.8289941148719246
# Percentage reduction = 0.17479504159927817

# %% [markdown]
# ## Isopycnal bins plot

# %%
pan01_C_swmt = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_C_pan01_rho0.nc', chunks = 'auto') 
pan01_M_swmt = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_Pan01_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_M_pan01_rho0.nc', chunks = 'auto') 
acc_C_swmt = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_C_access_rho0.nc', chunks = 'auto') 
acc_M_swmt = xr.open_dataarray('/g/data/g40/kc5856/access_panan_ssp126_SWMT/new_ACCESS_SWMT_shelf_rho0/plots/swmt_shelf_sum_ave_M_access_rho0.nc', chunks = 'auto')

# %%
pan01_25 = 27.89
pan01_75 = 27.73 
acc_25 = 27.93
acc_75 = 27.79

# %%
print('ACCESS control with access limits =', acc_C_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean().item())
print('PanAn01 control with access limits =', pan01_C_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean().item())
print('ACCESS control with panant limits =', acc_C_swmt.sel(isopycnal_bins=slice(pan01_75,pan01_25)).compute().mean().item())
print('PanAn01 control with panant limits =', pan01_C_swmt.sel(isopycnal_bins=slice(pan01_75,pan01_25)).compute().mean().item())
# Out:
# ACCESS control with access limits = 3.3827439669391346
# PanAn01 control with access limits = 2.5240352753517064
# ACCESS control with panant limits = 5.015910601673104
# PanAn01 control with panant limits = 3.672582822832182

# %%
print('ACCESS melt with access limits =', acc_M_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean().item())
print('PanAn01 melt with access limits =', pan01_M_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean().item())
print('ACCESS melt with panant limits =', acc_M_swmt.sel(isopycnal_bins=slice(pan01_75,pan01_25)).compute().mean().item())
print('PanAn01 melt with panant limits =', pan01_M_swmt.sel(isopycnal_bins=slice(pan01_75,pan01_25)).compute().mean().item())
# Out:
# ACCESS melt with access limits = 2.860709397288173
# PanAn01 melt with access limits = 1.8029082037792517
# ACCESS melt with panant limits = 4.29490721017039
# PanAn01 melt with panant limits = 2.7165981247520334

# %%
print("ACCESS % reduction with acclims =", 1-(acc_M_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean()/acc_C_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean()).item(),
      "\nPanAnt % reduction with acclims =", 1-(pan01_M_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean()/pan01_C_swmt.sel(isopycnal_bins=slice(acc_75,acc_25)).compute().mean()).item())
# Out:
# ACCESS % reduction with acclims = 0.1543228144822687
# PanAnt % reduction with acclims = 0.2857040385348698

# %%
plt.rcParams['font.size'] = 20


fig, ax1 = plt.subplots(figsize=(9, 10.66))

ax1.plot(pan01_C_swmt, pan01_C_swmt['isopycnal_bins'], linestyle='--', color = 'black', label='PanAn Control: 2.5 Sv')
ax1.plot(pan01_M_swmt, pan01_M_swmt['isopycnal_bins'], 'black', label='PanAn Meltwater: 1.8 Sv')
ax1.plot(acc_C_swmt, acc_C_swmt['isopycnal_bins'], linestyle='--',color='red', label='ACCESS Control: 3.4 Sv')
ax1.plot(acc_M_swmt, acc_M_swmt['isopycnal_bins'], 'red', label='ACCESS Meltwater: 2.9 Sv')

ax1.plot([0, 0], [27.4, 28.1], 'k', linewidth=0.5)
ax1.plot([-5, 15], [pan01_25, pan01_25], 'k--', linewidth=1)
ax1.plot([-5, 15], [pan01_75, pan01_75], 'k--', linewidth=1)
ax1.plot([-5, 15], [acc_25, acc_25], 'r--', linewidth=1)
ax1.plot([-5, 15], [acc_75, acc_75], 'r--', linewidth=1)

leg = plt.legend()
# Access the text objects in the legend
for text, color in zip(leg.get_texts(), ['black', 'black','#E50000','#E50000']):
    text.set_color(color)

ax1.set_ylim((28.1, 27.4))
ax1.set_xlim((-1, 10))
ax1.yaxis.set_label_position("left")
ax1.yaxis.tick_left()
ax1.set_ylabel('Density $\sigma_0$ (kg m$^{-3}$)')
ax1.set_xlabel('Surface water-mass transformation (Sv)')
;
# Out:
# ''

# %% [markdown]
# Need to play around with best presentation a bit.

# %%
colors = {'pan01_res': '#0000a2',
          'pan005_res': '#E84141',
          'pan01_pre' : '#18669C',
          'access_pre': 'tab:orange'}

# %%
plt.rcParams['font.size'] = 20

# Make the overall figure
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(2, 2, width_ratios=[1.5, 2], height_ratios=[1, 1], figure=fig)
# left panel spans two rows
ax1 = fig.add_subplot(gs[:, 0])
# top-right
ax2 = fig.add_subplot(gs[0, 1])
# bottom-right
ax3 = fig.add_subplot(gs[1, 1])

# --------------------------
# First figure (left side)
ax1.plot(pan01_C_swmt, pan01_C_swmt['isopycnal_bins'], linestyle='--', color=colors['pan01_pre'], label='PanAnt. Control: 2.5 Sv')
ax1.plot(pan01_M_swmt, pan01_M_swmt['isopycnal_bins'], color=colors['pan01_pre'], label='PanAnt. Meltwater: 1.8 Sv')
ax1.plot(acc_C_swmt, acc_C_swmt['isopycnal_bins'], linestyle='--', color=colors['access_pre'], label='OM2-01 Control: 3.4 Sv')
ax1.plot(acc_M_swmt, acc_M_swmt['isopycnal_bins'], color=colors['access_pre'], label='OM2-01 Meltwater: 2.9 Sv')

ax1.plot([0, 0], [27.4, 28.1], 'k', linewidth=0.5)
ax1.plot([-5, 15], [acc_25, acc_25], 'k--', linewidth=1)
ax1.plot([-5, 15], [acc_75, acc_75], 'k--', linewidth=1)

leg = ax1.legend()
# for text, color in zip(leg.get_texts(), [colors['pan01_pre'],colors['pan01_pre'],colors['access_pre'],colors['access_pre']]):
#     text.set_color(color)

ax1.set_ylim((28.1, 27.4))
ax1.set_xlim((0, 11))
ax1.set_ylabel('Density $\sigma_0$ (kg m$^{-3}$)')
ax1.set_xlabel('Surface water-mass transformation (Sv)')

# --------------------------
# Second figure (top-right)
ax2.plot((pan01_time_M_acclims-pan01_time_C_acclims).index + 1, (pan01_time_M_acclims-pan01_time_C_acclims).values, label='PanAntarctic',linewidth=3)
ax2.plot((acc_time_M_acclims-acc_time_C_acclims).index + 1, (acc_time_M_acclims-acc_time_C_acclims).values, label='ACCESS-OM2-01',linewidth=3)

ax2.set_xlim(1, 10)
ax2.set_ylim(-1, 0)
ax2.set_xlabel('Time (years)')
ax2.set_ylabel("DSW formation anomaly (Sv)")
ax2.set_title('')
ax2.legend(ncols=1)
ax2.grid(True, color='lightgrey')
ax2.axhline(y=0, color='black', linestyle='-')

# --------------------------
# Third figure (bottom-right)
ax3.plot(pan01_time_C_acclims.index + 1, pan01_time_C_acclims.values, color=colors['pan01_pre'], linestyle='--', label='PanAnt. Control')
ax3.plot(pan01_time_M_acclims.index + 1, pan01_time_M_acclims.values, color=colors['pan01_pre'], linestyle='-', label='PanAnt. Meltwater')
ax3.plot(acc_time_C_acclims.index + 1, acc_time_C_acclims.values, color=colors['access_pre'], linestyle='--', label='OM2-01 Control')
ax3.plot(acc_time_M_acclims.index + 1, acc_time_M_acclims.values, color=colors['access_pre'], linestyle='-', label='OM2-01 Meltwater')

ax3.set_xlim(1, 10)
ax3.set_ylim(0, 4)
ax3.set_xlabel('Time (years)')
ax3.set_ylabel("DSW formation (Sv)")
ax3.set_title('')
ax3.legend(ncol=2)
ax3.grid(True, color='lightgrey')
ax3.axhline(y=0, color='black', linestyle='-')

leg3 = ax3.legend(ncol=2)
# for text, color in zip(leg3.get_texts(), '[colors['pan01_pre'],colors['pan01_pre'],colors['access_pre'],colors['access_pre']]):
#     text.set_color(color)

# Add panel labels
ax1.text(-0.15, 1.02, 'a)', transform=ax1.transAxes,
         fontsize=22, fontweight='bold', va='bottom', ha='right')
ax2.text(-0.15, 1.02, 'b)', transform=ax2.transAxes,
         fontsize=22, fontweight='bold', va='bottom', ha='right')
ax3.text(-0.15, 1.02, 'c)', transform=ax3.transAxes,
         fontsize=22, fontweight='bold', va='bottom', ha='right')

plt.tight_layout()
plt.show()

fig.savefig("/g/data/g40/kc5856/thesis_figures/intermodel_SWMT_shelf_acclims_fixed.png", dpi=300, bbox_inches='tight')
