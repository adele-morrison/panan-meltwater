# %% [markdown]
# # SWMT on shelf for ACCESS-OM2-01

# %%
import intake
import cosima_cookbook as cc
import glob

import cartopy.crs as ccrs
import cf_xarray as cfxr
import cmocean as cm
import dask.distributed
import gsw
import matplotlib.pyplot as plt
from matplotlib import gridspec 
import matplotlib.colors as mcolors
import matplotlib.path as mpath
import numpy as np
import xarray as xr
import pdb
import os
import pathlib
import shutil

import warnings # ignore these warnings
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)
warnings.filterwarnings("ignore", category = RuntimeWarning)

# %%
#Starting a dask client
from os import environ
environ["PYTHONWARNINGS"] = "ignore"

from dask.distributed import Client
client = Client(threads_per_worker = 1)
# Out:
# 2025-07-21 10:36:00,164 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35183 (pid=1591307) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:00,376 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35183' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 8, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058160.3762686')
# 2025-07-21 10:36:00,456 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:00,964 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35907 (pid=1591295) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:01,197 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35907' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058161.197141')
# 2025-07-21 10:36:01,237 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:02,639 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42157 (pid=1591390) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:02,835 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42157' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 5, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058162.8352985')
# 2025-07-21 10:36:02,886 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:02,970 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36023 (pid=1591316) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:03,133 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40993 (pid=1591380) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:03,161 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36023' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 2, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058163.1615355')
# 2025-07-21 10:36:03,202 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:03,385 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40993' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058163.3848674')
# 2025-07-21 10:36:03,425 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:05,717 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36087 (pid=1591320) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:05,990 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:36087' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058165.9901736')
# 2025-07-21 10:36:06,048 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:06,973 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33721 (pid=1591327) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:07,285 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33721' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058167.2851508')
# 2025-07-21 10:36:07,336 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:08,020 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39871 (pid=1591364) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:08,191 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39871' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058168.1910048')
# 2025-07-21 10:36:08,224 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:08,572 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44549 (pid=1591367) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:08,852 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44549' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 8, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058168.8518658')
# 2025-07-21 10:36:08,883 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33603 (pid=1591303) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:08,892 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:09,062 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45291 (pid=1591284) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:09,130 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42209 (pid=1591355) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:09,148 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33603' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 2, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 2, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058169.1486814')
# 2025-07-21 10:36:09,177 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:09,351 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45291' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058169.3513198')
# 2025-07-21 10:36:09,381 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:09,449 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42209' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 3, 0, 0, 0), ('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058169.4489703')
# 2025-07-21 10:36:09,504 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:11,019 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44955 (pid=1591331) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:11,046 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44955' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 5, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058171.045789')
# 2025-07-21 10:36:11,055 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:13,212 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37757 (pid=1591300) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:13,535 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37757' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 9, 0, 0, 0), ('getitem-e824804bd05485845595b15b6f06a0d5', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058173.5349479')
# 2025-07-21 10:36:13,548 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:14,372 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43931 (pid=1591387) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:14,552 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43931' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {
caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058202.5109775')
# 2025-07-21 10:36:42,548 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:42,564 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43179 (pid=1591807) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:42,689 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46561' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 5, 0, 0, 0), ('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058202.6890333')
# 2025-07-21 10:36:42,703 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:42,717 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43179' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058202.7177749')
# 2025-07-21 10:36:42,746 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:44,978 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46485 (pid=1592224) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:45,286 - distributed.scheduler - ERROR - Task ('add-71d9bbad3468167e53027f413a22b67e', 6, 0, 0, 0) marked as failed because 4 workers died while trying to run it
# 2025-07-21 10:36:45,287 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46485' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058205.2852683')
# 2025-07-21 10:36:46,009 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:36:48,020 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34567 (pid=1591908) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:36:48,233 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:26,072 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33439 (pid=1592008) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:26,483 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33439' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058366.4825978')
# 2025-07-21 10:39:26,498 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:30,319 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44609 (pid=1592037) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:30,476 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33487 (pid=1591324) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:30,479 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40779 (pid=1592093) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:30,635 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44609' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058370.634887')
# 2025-07-21 10:39:30,657 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:30,744 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40779' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058370.7439785')
# 2025-07-21 10:39:30,752 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:30,949 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33487' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 8, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058370.9490519')
# 2025-07-21 10:39:30,956 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:31,094 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35417 (pid=1592352) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:31,335 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35417' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 3, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058371.335317')
# 2025-07-21 10:39:31,362 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:31,563 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43139 (pid=1592180) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:31,629 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37983 (pid=1592432) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:31,673 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33759 (pid=1592418) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:31,772 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37427 (pid=1592338) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:31,911 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37983' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 4, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058371.9108663')
# 2025-07-21 10:39:31,959 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33759' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058371.9593863')
# 2025-07-21 10:39:31,974 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43139' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058371.9746535')
# 2025-07-21 10:39:31,984 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:31,994 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:31,999 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:32,139 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38507 (pid=1592297) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:32,188 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37427' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 5, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058372.18857')
# 2025-07-21 10:39:32,223 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:32,341 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38507' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 2, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058372.3415053')
# 2025-07-21 10:39:32,367 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:35,866 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38631 (pid=1591897) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:36,024 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38631' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058376.0238085')
# 2025-07-21 10:39:36,034 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:41,126 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46267 (pid=1592302) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:41,409 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46267' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0), 'original-open_dataset-salt_transformation-e9c8abc95fb3b852a2ae22a0d94fced4'} (stimulus_id='handle-worker-cleanup-1753058381.4090972')
# 2025-07-21 10:39:41,452 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:41,723 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37093 (pid=1591846) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:41,955 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37093' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0), ('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058381.9549491')
# 2025-07-21 10:39:41,962 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:46,371 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43711 (pid=1592278) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:46,502 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43711' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058386.5026336')
# 2025-07-21 10:39:46,536 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:46,692 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35763 (pid=1592088) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:46,812 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35937 (pid=1591992) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:46,935 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35763' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 4, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 3, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058386.9350057')
# 2025-07-21 10:39:46,972 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35937' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 7, 0, 0, 0), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 2), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 1), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 4), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 3), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058386.9719872')
# 2025-07-21 10:39:46,989 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:46,993 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:49,122 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46749 (pid=1592247) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:49,344 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46749' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 5, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058389.3440475')
# 2025-07-21 10:39:49,371 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:49,617 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:38991 (pid=1591881) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:49,839 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:38991' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 2, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 5, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058389.8393898')
# 2025-07-21 10:39:49,871 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:51,364 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42279 (pid=1592366) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:51,499 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42279' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058391.49913')
# 2025-07-21 10:39:51,545 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:53,219 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41489 (pid=1592023) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:53,238 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41489' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 8, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 8, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058393.2384913')
# 2025-07-21 10:39:53,253 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:55,914 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44957 (pid=1592199) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:56,046 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44957' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 6, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058396.0463665')
# 2025-07-21 10:39:56,081 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:56,370 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:33673 (pid=1592362) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:56,489 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33673' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058396.489223')
# 2025-07-21 10:39:56,531 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:57,339 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:34279 (pid=1592589) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:57,452 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34279' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 1, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058397.452186')
# 2025-07-21 10:39:57,492 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:39:59,813 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:46461 (pid=1592116) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:39:59,943 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:46461' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 9, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058399.9435012')
# 2025-07-21 10:39:59,993 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:40:01,364 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43093 (pid=1592580) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:40:01,530 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43093' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058401.529964')
# 2025-07-21 10:40:01,558 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:40:02,719 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37191 (pid=1592532) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:40:02,856 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37191' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 2, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058402.8563454')
# 2025-07-21 10:40:02,895 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:40:03,911 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:41483 (pid=1592711) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:40:04,150 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:41483' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-e824804bd05485845595b15b6f06a0d5', 0, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058404.1503015')
# 2025-07-21 10:40:04,159 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:40:04,972 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45041 (pid=1592540) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:40:05,153 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45041' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-heat_transformation-81d29b9eaf521f58c5013ee4745fb7a4', 0, 0, 0), ('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058405.1527607')
# 2025-07-21 10:40:05,172 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:40:05,420 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1
caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 2), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 1), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 4), ('broadcast_to-concatenate-stack-getitem-e824804bd05485845595b15b6f06a0d5', 6, 0, 0, 0), 'original-open_dataset-heat_transformation-83bf509e75276bcdec661fc20054624f', ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 3), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 0), ('getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058759.327133')
# 2025-07-21 10:45:59,377 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:39055 (pid=1592997) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:45:59,381 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:45:59,499 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:39055' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 4), ('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0), ('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 6, 0, 0, 0), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 0), 'original-open_dataset-salt_transformation-0fd8e4e8caea33ef71562118ff0bb843', ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 3), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 2), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 1)} (stimulus_id='handle-worker-cleanup-1753058759.4990404')
# 2025-07-21 10:45:59,544 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:46:11,772 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:43077 (pid=1593239) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:46:11,908 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:43077' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('getitem-9e444172e7587e3d2369fcee57377ad7', 7, 0, 0, 0), ('open_dataset-salt_transformation-f73b5d1cc4a6cdc759ade45ed6dcdb71', 0, 0, 0), 'original-open_dataset-heat_transformation-83bf509e75276bcdec661fc20054624f', ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 2)} (stimulus_id='handle-worker-cleanup-1753058771.908018')
# 2025-07-21 10:46:11,959 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:46:12,862 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35437 (pid=1593252) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:46:13,009 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35437' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 4), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 2), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 1), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 0), ('open_dataset-stack-getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 0), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 4), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 3), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 3), ('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0), ('open_dataset-heat_transformation-8adf72f75173f0be4d3430af04f1cf77', 0, 0, 0), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 1)} (stimulus_id='handle-worker-cleanup-1753058773.009272')
# 2025-07-21 10:46:13,036 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:46:14,366 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:40653 (pid=1593256) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:46:14,652 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40653' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-salt_transformation-0fd8e4e8caea33ef71562118ff0bb843', 0, 0, 0), 'original-open_dataset-heat_transformation-694290706f86b39e7e1446a810d591ff', ('broadcast_to-concatenate-stack-getitem-e824804bd05485845595b15b6f06a0d5', 4, 0, 0, 0)} (stimulus_id='handle-worker-cleanup-1753058774.6526144')
# 2025-07-21 10:46:14,705 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:46:23,371 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37885 (pid=1593285) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:46:23,719 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:37885' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('broadcast_to-concatenate-stack-getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0), 'original-open_dataset-area_t-79b33058e67a198b450f1651e116d14e', 'original-open_dataset-heat_transformation-31703511ef44e409c6bbdd17a2702006', 'original-open_dataset-salt_transformation-36488afcb6c7b23fe068af37f3699201'} (stimulus_id='handle-worker-cleanup-1753058783.7195652')
# 2025-07-21 10:46:23,745 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:46:25,465 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:35453 (pid=1593310) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:46:25,603 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35453' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 4), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 0), 'original-open_dataset-heat_transformation-8adf72f75173f0be4d3430af04f1cf77', ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 4), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 3), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 2), ('broadcast_to-concatenate-stack-getitem-9e444172e7587e3d2369fcee57377ad7', 4, 0, 0, 0), ('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 1)} (stimulus_id='handle-worker-cleanup-1753058785.6031864')
# 2025-07-21 10:46:25,635 - distributed.nanny - WARNING - Restarting worker
# 2025-07-21 10:46:35,672 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:45141 (pid=1593333) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:46:35,949 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45141' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('rechunk-merge-a4501d9c6b9f7c74d1574df07d169545', 0, 4), ('getitem-e824804bd05485845595b15b6f06a0d5', 7, 0, 0, 0), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 2), ('getitem-0aa4477212cc2106ab4eebc57f8a7015', 0, 0, 0, 1), ('open_dataset-heat_transformation-31703511ef44e409c6bbdd17a2702006', 0, 0, 0), 'original-open_dataset-salt_transformation-eebb84e12bf20da31b3e49327c71ce76', ('
- distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:42359 (pid=1593443) exceeded 95% memory budget. Restarting...
# 2025-07-21 10:47:14,398 - distributed.scheduler - ERROR - Task ('open_dataset-salt_transformation-36488afcb6c7b23fe068af37f3699201', 0, 0, 0) marked as failed because 4 workers died while trying to run it
# 2025-07-21 10:47:14,399 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42359' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('open_dataset-heat_transformation-694290706f86b39e7e1446a810d591ff', 0, 0, 0), 'original-open_dataset-salt_transformation-36488afcb6c7b23fe068af37f3699201'} (stimulus_id='handle-worker-cleanup-1753058834.3972764')
# 2025-07-21 10:47:14,460 - distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# ### Defining the functions

# %%
def get_variables(expt, freq, start_time, end_time, lon_slice, lat_slice, model):

    # The models require different diagnostics to calculate the heat and salt fluxes.
    # mom6 outputs a net flux, whilst with mom5 we need to work with the separate components.
    model_vars = {
                    "mom5": {
                        "temperature":           ["temp"],
                        "salinity":              ["salt"],
                        "water_flux_into_ocean": ["pme_river"],
                        "salt_flux":             ["sfc_salt_flux_ice", "sfc_salt_flux_restore"],
                        "heat_flux":             ["sfc_hflux_coupler", "sfc_hflux_from_runoff",
                                                  "frazil_3d_int_z", "sfc_hflux_pme"],
                        "area":                  ["area_t"],
                        "maximum_depth":         ["ht"],
                    },
                    "mom6": {
                        "temperature":           ["thetao"],
                        "salinity":              ["so"],
                        "water_flux_into_ocean": ["wfo"],
                        "salt_flux":             ["salt_flux"],
                        "heat_flux":             ["hfds"],
                        "area":                  ["areacello"],
                        "maximum_depth":         ["deptho"],
                    }
                }
    # Load variables in a dictionary
    ds = {}
    keys = list(model_vars[model].keys())
    for k in keys:
        ds[k] = {}
        for var in model_vars[model][k]:
            if k in ["area", "maximum_depth"]:
                ds[k][var] = cc.querying.getvar(expt, var, session, n = 1) 
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice)
            else:
                try:
                    ds[k][var] = cc.querying.getvar(expt, var, session,
                                                frequency = freq,
                                                start_time = start_time,
                                                end_time = end_time,
                                                chunks = {'time': 1})
                    ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice, time = slice(start_time, end_time))
                
                    # Correct temperatures (if in K convert to C)
                    if k == 'temperature' and np.max(ds[k][var]) > 100:
                        ds[k][var] = ds[k][var] - 273.15
    
                    # If 3D field, grab the surface
                    if ds[k][var].cf.axes.get('Z'):
                        surface_z = ds[k][var].cf['Z'][0].values
                        ds[k][var] = ds[k][var].cf.sel(Z = 0, method = 'nearest')
                except Exception as e:
                    raise Exception(f"Data loading error: var={var}, freq={freq}, start_time={start_time}, end_time={end_time}, expt={expt}: {str(e)}")

    # Get temperature and salinity to calculate few other things we'll need later on
    SP = ds['salinity'][model_vars[model]['salinity'][0]]
    CT = ds['temperature'][model_vars[model]['temperature'][0]]

    # Calculate pressure
    pressure = gsw.p_from_z(-surface_z, SP.cf['Y']).rename('pressure')

    # Calculate absolute salinity
    SA = gsw.SA_from_SP(SP, pressure, SP.cf['X'], SP.cf['Y']).rename('SA')

    # Ensure we have conservative temperature; Convert MOM6's potential temperature to conservative
    if model == 'mom6':
        CT = gsw.CT_from_pt(SA, CT)
        ds['temperature'][model_vars[model]['temperature'][0]].data = CT.values

    # Calculate potential density
    pot_rho_1 = gsw.sigma1(SA, CT)#.rename('pot_rho_11')

    # Save everything to our dictionary
    ds['pressure'] = pressure
    ds['SA'] = SA
    ds['pot_rho_1'] = pot_rho_1
    
    # Calculate days per month accounting for leap years
    months_standard_noleap = np.array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    months_standard_leap = np.array([31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    if 'ryf' or 'panan' in expt:
        nyears = len(np.unique(CT['time.year']))
        days_per_month = np.tile(months_standard_noleap, nyears)
    elif 'iaf' in expt:
        nyears = len(np.unique(CT['time.year']))
        if CT['time.year'][0] % 4 == 0:
            days_per_month = months_standard_leap
        else: 
            days_per_month = months_standard_noleap
        for yr in CT['time.year'][::12][1:]:
            if yr % 4 == 0:
                days_per_month = np.concatenate([days_per_month, months_standard_leap])
            else:
                days_per_month = np.concatenate([days_per_month, months_standard_noleap])
    days_per_month = xr.DataArray(days_per_month, dims = ['time'], coords = {'time': CT['time']}, name = 'days_per_month')
    ds['days_per_month'] = days_per_month

    return ds

# %%
def get_variables_1(expt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model):

    # The models require different diagnostics to calculate the heat and salt fluxes.
    # mom6 outputs a net flux, whilst with mom5 we need to work with the separate components.
    model_vars = {
                    "mom5": {
                        "temperature":           ["temp"],
                        "salinity":              ["salt"],
                        "water_flux_into_ocean": ["pme_river"],
                        "salt_flux":             ["sfc_salt_flux_ice", "sfc_salt_flux_restore"],
                        "heat_flux":             ["sfc_hflux_coupler", "sfc_hflux_from_runoff",
                                                  "frazil_3d_int_z", "sfc_hflux_pme"],
                        "area":                  ["area_t"],
                        "maximum_depth":         ["ht"],
                    },
                    "mom6": {
                        "temperature":           ["thetao"],
                        "salinity":              ["so"],
                        "water_flux_into_ocean": ["wfo"],
                        "salt_flux":             ["salt_flux"],
                        "heat_flux":             ["hfds"],
                        "area":                  ["areacello"],
                        "maximum_depth":         ["deptho"],
                    }
                }
    # Load variables in a dictionary
    ds = {}
    keys = list(model_vars[model].keys())
    for k in keys:
        ds[k] = {}
        for var in model_vars[model][k]:
            if k in ["area", "maximum_depth"]:
                ds[k][var] = cc.querying.getvar(expt, var, session, n = 1) 
                ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice)
            else:
                try:
                    ds[k][var] = cc.querying.getvar(expt, var, session,
                                                frequency = freq,
                                                start_time = start_time_broad,
                                                end_time = end_time_broad,
                                                chunks = {'time': 1})
                    ds[k][var] = ds[k][var].cf.sel(X = lon_slice, Y = lat_slice, time = slice(start_time_real, end_time_real))
                
                    # Correct temperatures (if in K convert to C)
                    if k == 'temperature' and np.max(ds[k][var]) > 100:
                        ds[k][var] = ds[k][var] - 273.15
    
                    # If 3D field, grab the surface
                    if ds[k][var].cf.axes.get('Z'):
                        surface_z = ds[k][var].cf['Z'][0].values
                        ds[k][var] = ds[k][var].cf.sel(Z = 0, method = 'nearest')
                except Exception as e:
                    raise Exception(f"Data loading error: var={var}, freq={freq}, start_time={start_time}, end_time={end_time}, expt={expt}: {str(e)}")

    # Get temperature and salinity to calculate few other things we'll need later on
    SP = ds['salinity'][model_vars[model]['salinity'][0]]
    CT = ds['temperature'][model_vars[model]['temperature'][0]]

    # Calculate pressure
    pressure = gsw.p_from_z(-surface_z, SP.cf['Y']).rename('pressure')

    # Calculate absolute salinity
    SA = gsw.SA_from_SP(SP, pressure, SP.cf['X'], SP.cf['Y']).rename('SA')

    # Ensure we have conservative temperature; Convert MOM6's potential temperature to conservative
    if model == 'mom6':
        CT = gsw.CT_from_pt(SA, CT)
        ds['temperature'][model_vars[model]['temperature'][0]].data = CT.values

    # Calculate potential density
    pot_rho_1 = gsw.sigma1(SA, CT)#.rename('pot_rho_11')

    # Save everything to our dictionary
    ds['pressure'] = pressure
    ds['SA'] = SA
    ds['pot_rho_1'] = pot_rho_1
    
    # Calculate days per month accounting for leap years
    months_standard_noleap = np.array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    months_standard_leap = np.array([31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
    if 'ryf' or 'panan' in expt:
        nyears = len(np.unique(CT['time.year']))
        days_per_month = np.tile(months_standard_noleap, nyears)
    elif 'iaf' in expt:
        nyears = len(np.unique(CT['time.year']))
        if CT['time.year'][0] % 4 == 0:
            days_per_month = months_standard_leap
        else: 
            days_per_month = months_standard_noleap
        for yr in CT['time.year'][::12][1:]:
            if yr % 4 == 0:
                days_per_month = np.concatenate([days_per_month, months_standard_leap])
            else:
                days_per_month = np.concatenate([days_per_month, months_standard_noleap])
    days_per_month = xr.DataArray(days_per_month, dims = ['time'], coords = {'time': CT['time']}, name = 'days_per_month')
    ds['days_per_month'] = days_per_month

    return ds

# %%
def compute_salt_transformation(ds):
    
    # First retrieve temperature and water_flux as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Multiply the water flux by absolute salinity to get it in the correct units
    water_flux_into_ocean = xr.Dataset(ds['water_flux_into_ocean']).to_array().squeeze().drop_vars('variable')
    water_flux_into_ocean = ds['SA'] * water_flux_into_ocean

    # Caculate the haline contraction coefficient
    haline_contraction = gsw.beta(ds['SA'], CT, ds['pressure']).rename('beta')

    # Calculate the net salt flux and multiply by 1000 to convert units
    net_salt_flux = xr.Dataset(ds['salt_flux']).to_array().sum(dim = 'variable') * 1000

    # Note that we also multiply pme_river by absolute salinity to have the correct units
    salt_transformation = haline_contraction * (water_flux_into_ocean - net_salt_flux) * ds['days_per_month']
    salt_transformation = salt_transformation.load()

    return salt_transformation

def compute_heat_transformation(ds):

    # First retrieve temperature as an xarray instead of a dictionary
    CT = xr.Dataset(ds['temperature']).to_array().squeeze().drop_vars('variable')

    # Calculate the thermal expansion coefficient 
    thermal_expansion = gsw.alpha(ds['SA'], CT, ds['pressure']).rename('alpha')
    
    # Calculate the net surface heating
    net_surface_heating = xr.Dataset(ds['heat_flux']).to_array().sum(dim = 'variable')
    
    # Calculate the heat transformation
    heat_transformation = thermal_expansion * net_surface_heating * ds['days_per_month']
    heat_transformation = heat_transformation.load()

    return heat_transformation

# %%
def isopycnal_bins(ds, salt_transformation, heat_transformation):

    # Next section does a few things. It cycles through isopycnal bins, determines which cells are 
    # within the given bin for each month, finds the transformation values for those cells for each month, 
    # and sums these through time. You are left with an array of shape (isopyncal bins * lats * lons) 
    # where the array associated with a given isopycnal bin is NaN everywhere except where pot_rho_1 
    # was within the bin, there it has a time summed transformation value.
    
    # Choose appropriate bin range
    isopycnal_bins = np.arange(31, 33.5, 0.02)  # 125 bins - 31, 33.5, 0.02 (sigma1)
    #isopycnal_bins = np.concatenate([np.arange(25.0, 26.5, 0.05), np.arange(26.5, 28.5, 0.02)])  # 130 bins (sigma0)
    bin_bottoms = isopycnal_bins[:-1]
    isopycnal_bin_mid = (isopycnal_bins[1:] + bin_bottoms) / 2
    isopycnal_bin_diff = np.diff(isopycnal_bins)

    pot_rho_1 = ds['pot_rho_1']

    results_salt = []
    results_heat = []

    for i in range(len(bin_bottoms)):
        # Create binary mask for each bin
        bin_mask = xr.where((pot_rho_1 > bin_bottoms[i]) & (pot_rho_1 <= isopycnal_bins[i + 1]), 1, np.nan)

        # Multiply and sum over time
        salt_sum = (salt_transformation * bin_mask).sum(dim='time')
        heat_sum = (heat_transformation * bin_mask).sum(dim='time')

        results_salt.append(salt_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))
        results_heat.append(heat_sum.expand_dims({'isopycnal_bins': [isopycnal_bin_mid[i]]}))

    # Concatenate results along isopycnal dimension
    salt_transformation = xr.concat(results_salt, dim='isopycnal_bins')
    heat_transformation = xr.concat(results_heat, dim='isopycnal_bins')

    # Normalise by number of days and bin thickness
    ndays = ds['days_per_month'].sum()
    c_p = 3992.1 # J kg-1 degC-1

    salt_transformation /= ndays
    heat_transformation /= (c_p * ndays)

    salt_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]
    heat_transformation /= isopycnal_bin_diff[:, np.newaxis, np.newaxis]

    # Overwrite zeros with NANs 
    # (Note: the code within the for-loop should provide nans but lazy computing with dask can sometimes give unpredictable results)
    salt_transformation = salt_transformation.where(salt_transformation != 0)
    heat_transformation = heat_transformation.where(heat_transformation != 0)

    # Change the sign so that positive means conversion into denser water masses
    salt_transformation *= -1
    heat_transformation *= -1

    # Renaming
    salt_transformation.name = "salt_transformation"
    heat_transformation.name = "heat_transformation"

    return salt_transformation.load(), heat_transformation.load()

# %% [markdown]
# ## Opening the saved data
#
# For saving method, scroll to section below.

# %%
# Importing the saved files
salt_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_*'))
heat_files_C = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_*'))

salt_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_*'))
heat_files_M = np.sort(glob.glob('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_*'))

# %%
salt_tr_C = xr.open_mfdataset(salt_files_C, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_tr_C = xr.open_mfdataset(heat_files_C, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_tr_C = salt_tr_C.to_array().squeeze()
heat_tr_C = heat_tr_C.to_array().squeeze()

# %%
salt_tr_C
# Out:
# <xarray.DataArray (time: 10, isopycnal_bins: 124, yt_ocean: 510, xt_ocean: 3600)> Size: 18GB
# dask.array<getitem, shape=(10, 124, 510, 3600), dtype=float64, chunksize=(1, 124, 100, 100), chunktype=numpy.ndarray>
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 992B 31.01 31.03 ... 33.45 33.47
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
#     variable        <U19 76B 'salt_transformation'
# Dimensions without coordinates: time

# %%
salt_tr_M = xr.open_mfdataset(salt_files_M, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_tr_M = xr.open_mfdataset(heat_files_M, concat_dim='time', combine='nested', chunks={'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_tr_M = salt_tr_M.to_array().squeeze()
heat_tr_M = heat_tr_M.to_array().squeeze()

# %%
net_tr_C = salt_tr_C + heat_tr_C
net_tr_M = salt_tr_M + heat_tr_M

# %%
# Defining the data separately for variables like area, depth, etc.
expt_con = '01deg_jra55v13_ryf9091_21mbath'
expt_melt = '01deg_jra55v13_ryf9091_21mbath_sofia_ssp126'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)

lon_slice = slice(None, None)
lat_slice = slice(None, -59)
freq = '1 monthly'
start_time_broad = '1910-10-01'
end_time_broad = '1913-01-01'
start_time_real = '1911-01-01'
end_time_real = '1911-12-31' # only one year here because we are only needing it for area  

start_time = '1911-01-01'
end_time = '1911-12-31'

ds_cont = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
ds_melt = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')

# %% [markdown]
# #### Antarctic shelf dense water formation

# %%
def shelf_mask_isobath(var, model_dict):

    paths = {
             "mom5": "/g/data/ik11/grids/Antarctic_slope_contour_1000m.npz",
             "mom6_01": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_01deg.nc",
            "mom6_005": "/g/data/ik11/grids/Antarctic_slope_contour_1000m_MOM6_005deg.nc"
             }

    var = var.cf.sel({'latitude': slice(-90, -59)})

    if paths[model_dict][-3:] == '.nc':
        shelf_mask = xr.open_dataset(paths[model_dict])['contour_masked_above']
    else:
        contour_file = np.load(paths[model_dict])
        shelf_mask = xr.DataArray(contour_file['contour_masked_above'],
                                  coords = var.coords, 
                                  dims = var.dims,
                                  name = 'contour_masked_above')
    
    shelf_mask = xr.where(shelf_mask == 0, 1, 0)
    masked_var = var * shelf_mask
    
    return masked_var, shelf_mask

# %%
depth = xr.Dataset(ds_cont['maximum_depth']).to_array().squeeze()
depth_M = xr.Dataset(ds_melt['maximum_depth']).to_array().squeeze()
land_mask = (0 * depth).fillna(1)
depth_shelf, shelf_mask = shelf_mask_isobath(depth, 'mom5')

# %%
# Creating corrected area
area = xr.Dataset(ds_cont['area']).to_array().squeeze().drop_vars('variable')
varr = xr.Dataset(ds_cont['salinity']).to_array().squeeze().isel(time=0)
area_corr = (area*(varr*0+1)).drop_vars('variable')
area_corr = area_corr.drop_vars(['time','z_l'])

# %%
# Check mask
area_corr.plot()

# %%
swmt_shelf_C = (net_tr_C * area_corr / 1e6).where(shelf_mask == 1)
heat_shelf_C = (heat_tr_C * area_corr / 1e6).where(shelf_mask == 1)
salt_shelf_C = (salt_tr_C * area_corr / 1e6).where(shelf_mask == 1)

swmt_shelf_C = swmt_shelf_C.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_shelf_C = heat_shelf_C.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_shelf_C = salt_shelf_C.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})

# %%
swmt_shelf_sum_C = swmt_shelf_C.cf.sum(['xt_ocean', 'yt_ocean']).compute()
#heat_shelf_sum_C = heat_shelf_C.cf.sum(['xt_ocean', 'yt_ocean']).compute()
#salt_shelf_sum_C = salt_shelf_C.cf.sum(['xt_ocean', 'yt_ocean']).compute()

# %%
# Time mean
swmt_shelf_sum_ave_C = swmt_shelf_sum_C.mean(dim='time')

for da in [swmt_shelf_sum_ave_C]:#, heat_shelf_sum_ave_C, salt_shelf_sum_ave_C]:
    da.attrs["units"] = "Sv"

# %%
swmt_shelf_M = (net_tr_M * area_corr / 1e6).where(shelf_mask == 1)
heat_shelf_M = (heat_tr_M * area_corr / 1e6).where(shelf_mask == 1)
salt_shelf_M = (salt_tr_M * area_corr / 1e6).where(shelf_mask == 1)

swmt_shelf_M = swmt_shelf_M.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
heat_shelf_M = heat_shelf_M.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})
salt_shelf_M = salt_shelf_M.chunk({'time': 1, 'yt_ocean': 100, 'xt_ocean': 100})

# %%
swmt_shelf_sum_M = swmt_shelf_M.cf.sum(['xt_ocean', 'yt_ocean']).compute()
#swmt_shelf_sum_M = heat_shelf_M.cf.sum(['xt_ocean', 'yt_ocean']).compute()
#salt_shelf_sum_M = salt_shelf_M.cf.sum(['xt_ocean', 'yt_ocean']).compute()

# %%
swmt_shelf_sum_ave_M = swmt_shelf_sum_M.mean(dim='time')
#heat_shelf_sum_ave_M = swmt_shelf_sum_M.mean(dim='time')
#salt_shelf_sum_ave_M = salt_shelf_sum_M.mean(dim='time')

for da in [swmt_shelf_sum_ave_M]: #, heat_shelf_sum_ave_M, salt_shelf_sum_ave_M]:
# Attributes:
#     units:    Sv

# %%
swmt_shelf_sum_ave_C.compute()
# Out:
# <xarray.DataArray (isopycnal_bins: 124)> Size: 992B
# array([-5.66828211e-01, -5.65618067e-01, -5.67894066e-01, -5.91257519e-01,
#        -5.87989592e-01, -5.57041325e-01, -5.98560568e-01, -5.97475561e-01,
#        -6.34123803e-01, -5.66526880e-01, -6.22011945e-01, -5.84897054e-01,
#        -6.24517068e-01, -5.66724927e-01, -5.93230886e-01, -5.63126810e-01,
#        -5.79095367e-01, -5.67649983e-01, -5.79122946e-01, -5.35367714e-01,
#        -5.02941674e-01, -5.47309844e-01, -5.14282279e-01, -4.87688128e-01,
#        -4.68591817e-01, -4.88928387e-01, -4.95559318e-01, -5.72024149e-01,
#        -6.52211134e-01, -7.66351671e-01, -6.23693062e-01, -5.67168079e-01,
#        -4.78599112e-01, -5.49330434e-01, -5.68103132e-01, -4.73155981e-01,
#        -2.16759126e-01, -1.68340874e-02,  1.39697179e-01,  2.77292847e-01,
#         3.22662464e-01,  3.25119882e-01,  4.08460310e-01,  5.73554953e-01,
#         8.73388641e-01,  1.11705602e+00,  1.40957639e+00,  1.43339694e+00,
#         1.48632826e+00,  1.63859742e+00,  1.71297241e+00,  1.71295398e+00,
#         1.95138070e+00,  2.09295015e+00,  2.28077356e+00,  2.66537131e+00,
#         3.23788724e+00,  3.53456472e+00,  3.61552260e+00,  3.78303466e+00,
#         4.07761093e+00,  4.41775545e+00,  4.89017287e+00,  5.48621618e+00,
#         5.72035387e+00,  5.99489249e+00,  6.68603412e+00,  7.31931864e+00,
#         7.72615908e+00,  7.97117415e+00,  8.34336476e+00,  8.79899590e+00,
#         9.21304257e+00,  8.98580997e+00,  8.65679231e+00,  8.41823975e+00,
#         7.55382540e+00,  7.01130899e+00,  5.82144177e+00,  4.56544976e+00,
#         3.96893794e+00,  3.45868330e+00,  3.03227117e+00,  2.72526651e+00,
#         2.37026948e+00,  2.10395698e+00,  1.85492973e+00,  1.43795045e+00,
#         1.27148963e+00,  1.02879723e+00,  8.07130533e-01,  3.77524049e-01,
#         1.93558280e-01,  1.63820894e-01,  1.29738950e-01,  1.16963043e-01,
#         1.05680639e-01,  8.23973456e-02,  6.99255758e-02,  5.59006275e-02,
#         5.09624557e-02,  5.89690361e-02,  5.29465840e-02,  5.54014844e-02,
#         5.00232820e-02,  4.36322217e-02,  4.11220986e-02,  3.81400091e-02,
#         2.98870055e-02,  2.50454575e-02,  1.90127796e-02,  2.05849059e-02,
#         1.73072098e-02,  1.53018598e-02,  1.39485168e-02,  1.37842761e-02,
#         1.74084386e-02,  1.00490087e-02,  1.10295725e-02,  1.00764158e-02,
#         7.26140616e-03,  8.46293976e-03,  5.40636784e-03,  7.21181607e-03])
# Coordinates:
#   * isopycnal_bins  (isopycnal_bins) float64 992B 31.01 31.03 ... 33.45 33.47
#     st_ocean        float64 8B 0.5413
#     variable        <U2 8B 'ht'
# Attributes:
#     units:    Sv

# %%
swmt_shelf_sum_ave_M.compute()
# Out:
# <xarray.DataArray (isopycnal_bins: 124)> Size: 992B
ax1.plot(swmt_shelf_sum_ave_C, swmt_shelf_sum_ave_C['isopycnal_bins'], color = 'k', label='Control: 3.71 Sv')
ax1.plot(swmt_shelf_sum_ave_M, swmt_shelf_sum_ave_M['isopycnal_bins'], color = 'r', label='Meltwater: 2.88 Sv')
ax1.plot([0, 0], [31, 33.2], 'k', linewidth=0.5)
ax1.plot([-5, 15], [cont_d25, cont_d25], 'k--', linewidth=1)
ax1.plot([-5, 15], [cont_d75, cont_d75], 'k--', linewidth=1)
ax1.set_ylim((33.2, 31))
ax1.set_xlim((-1.5, 10))
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()
ax1.set_ylabel('Density $\sigma_1$ (kg m$^{-3}$)')
ax1.set_xlabel('Surface water-mass transformation (Sv)')
ax1.legend();

# %%
swmt_shelf_sum_ave_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_sum_ave_C_access.nc')
swmt_shelf_sum_ave_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_sum_ave_M_access.nc')

# %% [markdown]
# ### SWMT map:

# %%
transformation_density = 32.62
shelf_subduction_plot_C = net_tr_C.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_C = depth.cf['X']
swmt_yt_C = depth.cf['Y']

shelf_subduction_plot_M = net_tr_M.sel(isopycnal_bins = transformation_density, method = 'nearest') * 1e5
swmt_xt_M = depth_M.cf['X']
swmt_yt_M = depth_M.cf['Y']

# %%
shelf_subduction_plot_C.astype('float32').compute()
# Out:
# <xarray.DataArray (time: 10, yt_ocean: 510, xt_ocean: 3600)> Size: 73MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
# Dimensions without coordinates: time

# %%
shelf_subduction_plot_M.astype('float32').compute()
# Out:
# <xarray.DataArray (time: 10, yt_ocean: 510, xt_ocean: 3600)> Size: 73MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413
# Dimensions without coordinates: time

# %%
anom_xt = swmt_xt_M.fillna(0) - swmt_xt_C.fillna(0)
anom_yt = swmt_yt_M.fillna(0) - swmt_yt_C.fillna(0)
shelf_subduction_plot_anom = shelf_subduction_plot_M.fillna(0) - shelf_subduction_plot_C.fillna(0)

# %%
# Taking time means
shelf_subduction_plot_ave_anom = shelf_subduction_plot_anom.mean(dim='time')
shelf_subduction_plot_ave_anom
# Out:
# <xarray.DataArray (yt_ocean: 510, xt_ocean: 3600)> Size: 15MB
# dask.array<mean_agg-aggregate, shape=(510, 3600), dtype=float64, chunksize=(100, 100), chunktype=numpy.ndarray>
# Coordinates:
#     isopycnal_bins  float64 8B 32.63
#   * xt_ocean        (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.85 79.95
#   * yt_ocean        (yt_ocean) float64 4kB -81.11 -81.07 ... -59.08 -59.03
#     st_ocean        float64 8B 0.5413

# %%
shelf_subduction_plot_ave_anom = shelf_subduction_plot_ave_anom.load()

# %%
# Check before saving
shelf_subduction_plot_ave_anom.plot(vmin=-2,vmax=2, cmap=cm.cm.balance)

# %%
shelf_subduction_plot_ave_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_plot_anom_access.nc')

# %% [markdown]
# #### Finding the 25% and 75%
#
# Control max = 9.21304257 Sv (at density ).
# - 25% of max (2.3032606425 Sv) = 32.69
# - 75% of max (6.9097819275 Sv) = 32.55
# - Control mean transport in this slice = 3.7060457 Sv
#
# Melt max = BLANK Sv (at density BLANK).
# - 25% of max (BLANK Sv) = BLANK
# - 75% of max (BLANK Sv) = BLANK
# - Melt mean transport in this slice = 2.87528989 Sv.
#
# We just use the control lines as our formation region.

# %%
# Finding maximum
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(32.55,32.69)).compute() # Pick slice based on plot, test for max value

# %%
max_value = 
swmt_shelf_sum_ave_C.isel(isopycnal_bins=max_value).load()

# %% [markdown]
# Finding the sums: (change density values below to match 25 and 75 thresholds)

# %%
val_25 = 32.69
val_75 = 32.55

# %%
swmt_shelf_sum_ave_C.sel(isopycnal_bins=slice(val_75,val_25)).compute().mean()

# %%
swmt_shelf_sum_ave_M.sel(isopycnal_bins=slice(val_75,val_25)).compute().mean()

# %% [markdown]
# ### Time series plot

# %%
swmt_shelf_time_C = swmt_shelf_sum_C.sel(isopycnal_bins=slice(val_75,val_25)).mean('isopycnal_bins').compute()

# %%
swmt_shelf_time_M = swmt_shelf_sum_M.sel(isopycnal_bins=slice(val_75,val_25)).mean('isopycnal_bins').compute()

# %%
swmt_shelf_time_C.plot(label="Control")
swmt_shelf_time_M.plot(label="Meltwater")
plt.ylabel("Surface water mass transformation (Sv)")
plt.xlabel("Year")
plt.legend(loc="lower left")
plt.title("ACCESS Surface Water Mass Transformation over 25-75% range")
# Out:
# Text(0.5, 1.0, 'ACCESS Surface Water Mass Transformation over 25-75% range')

# %%
# Saving
swmt_shelf_time_C.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_time_access_C.nc')
swmt_shelf_time_M.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_time_access_M.nc')

# %%
swmt_shelf_time_anom = swmt_shelf_time_M - swmt_shelf_time_C

# %%
swmt_shelf_time_anom.plot()

# %%
swmt_shelf_time_anom.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/timeseries/swmt_shelf_time_access_anom.nc')

# %% [markdown]
# ## Saving per year via manual method

# %%
# Change to your experiment of interest
expt_con = '01deg_jra55v13_ryf9091_21mbath'
expt_melt = '01deg_jra55v13_ryf9091_21mbath_sofia_ssp126'
db = '/home/272/kc5856/databases/honours_test.db'
session = cc.database.create_session(db)
freq = '1 monthly'

# Select time period and region
lon_slice = slice(None, None)
lat_slice = slice(None, -59)

# %% [markdown]
# #### First doing the control

# %%
# Painfully manual don't mind this

start_time = '1910-01-01'
end_time = '1910-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_01.nc')
# Out:
# 2025-07-17 11:42:49,777 - tornado.application - ERROR - Exception in callback <bound method Worker.trigger_profile of <Worker 'tcp://127.0.0.1:33617', name: 22, status: running, stored: 0, running: 1/1, ready: 0, comm: 0, waiting: 0>>
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 66, in identifier
#     co.co_name,
#     ^^^^^^^^^^
# AttributeError: 'cell' object has no attribute 'co_name'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/tornado/ioloop.py", line 937, in _run
#     val = self.callback()
#           ^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/worker.py", line 2448, in trigger_profile
#     state = profile.process(
#             ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 194, in process
#     new_state = process(prev, frame, state, stop=stop, depth=depth - 1)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 199, in process
#     ident = identifier(frame)
#             ^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/distributed/profile.py", line 72, in identifier
#     if co.__module__:
#        ^^^^^^^^^^^^^
# AttributeError: 'cell' object has no attribute '__module__'

# %%
# Painfully manual don't mind this 2

start_time = '1911-01-01'
end_time = '1911-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_02.nc')

# %%
# Painfully manual don't mind this 3

start_time = '1912-01-01'
end_time = '1912-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_03.nc')

# %%
# Painfully manual don't mind this 4

start_time = '1913-01-01'
end_time = '1913-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_04.nc')

# %%
# Painfully manual don't mind this 5

start_time = '1914-01-01'
end_time = '1914-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_05.nc')

# %%
# Painfully manual don't mind this 6
start_time = '1915-01-01'
end_time = '1915-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_06.nc')

# %%
# Painfully manual don't mind this 7
start_time = '1916-01-01'
end_time = '1916-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_07.nc')

# %%
# Painfully manual don't mind this 8
start_time = '1917-01-01'
end_time = '1917-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_08.nc')

# %%
# Painfully manual don't mind this 9
start_time = '1918-01-01'
end_time = '1918-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_09.nc')

# %%
# Painfully manual don't mind this 10
start_time = '1919-01-01'
end_time = '1919-12-31'

ds = get_variables(expt_con, freq, start_time, end_time, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_C_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_C_10.nc')

# %% [markdown]
# #### Second doing the perturbation

# %%
# Checking time slice
start_time_broad = '1910-01-01'
start_time_real = '1910-01-01'
end_time_broad = '1911-04-01'
end_time_real = '1910-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
ds
# Out:
# {'temperature': {'temp': <xarray.DataArray 'temp' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       st_ocean  float64 8B 0.5413
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00},
#  'salinity': {'salt': <xarray.DataArray 'salt' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       st_ocean  float64 8B 0.5413
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      Practical Salinity
#       units:          psu
#       valid_range:    [-10. 100.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  sea_water_salinity
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'water_flux_into_ocean': {'pme_river': <xarray.DataArray 'pme_river' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      mass flux of precip-evap+river via sbc (liquid, frozen, e...
#       units:          (kg/m^3)*(m/sec)
#       valid_range:    [-1000000.  1000000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  water_flux_into_sea_water
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'salt_flux': {'sfc_salt_flux_ice': <xarray.DataArray 'sfc_salt_flux_ice' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      sfc_salt_flux_ice
#       units:          kg/(m^2*sec)
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  downward_sea_ice_basal_salt_flux
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'sfc_salt_flux_restore': <xarray.DataArray 'sfc_salt_flux_restore' (time: 12, yt_ocean: 510,
#                                              xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      sfc_salt_flux_restore: flux from restoring term
#       units:          kg/(m^2*sec)
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'heat_flux': {'sfc_hflux_coupler': <xarray.DataArray 'sfc_hflux_coupler' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      surface heat flux coming through coupler
#       units:          Watts/m^2
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'sfc_hflux_from_runoff': <xarray.DataArray 'sfc_hflux_from_runoff' (time: 12, yt_ocean: 510,
#                                              xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      heat flux (relative to 0C) from liquid river runoff
#       units:          Watts/m^2
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       standard_name:  temperature_flux_due_to_runoff_expressed_as_heat_flux_int...
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'frazil_3d_int_z': <xarray.DataArray 'frazil_3d_int_z' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      Vertical sum of ocn frazil heat flux over time step
#       units:          W/m^2
#       valid_range:    [-1.e+10  1.e+10]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#   'sfc_hflux_pme': <xarray.DataArray 'sfc_hflux_pme' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 88MB
#   dask.array<getitem, shape=(12, 510, 3600), dtype=float32, chunksize=(1, 510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#     * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#   Attributes:
#       long_name:      heat flux (relative to 0C) from pme transfer of water acr...
#       units:          Watts/m^2
#       valid_range:    [-10000.  10000.]
#       cell_methods:   time: mean
#       time_avg_info:  average_T1,average_T2,average_DT
#       ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...},
#  'area': {'area_t': <xarray.DataArray 'area_t' (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
#   dask.array<getitem, shape=(510, 3600), dtype=float32, chunksize=(510, 720), chunktype=numpy.ndarray>
#   Coordinates:
#     * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#     * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#       geolon_t  (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#       geolat_t  (yt_ocean, xt_ocean) float32 7MB dask.array<chunksize=(510, 720), meta=np.ndarray>
#   Attributes:
#       long_name:     tracer cell area
#       units:         m^2
#       valid_range:   [0.e+00 1.e+15]
#       cell_methods:  time: point
#       ncfiles:       ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf909...},
#  'maximum_depth': {'ht': <xarray.DataArray 'ht' (yt_ocean: 510, xt_ocean: 3600)> Size: 7MB
#   dask.array<getitem, shape=(510, 3600), dtype=float32, chunksize=(510, 720), chunktype=numpy.ndarray>
#         0.54649569, 0.54649367, 0.54649163, 0.5464896 , 0.54648755,
#         0.5464855 , 0.54648345, 0.54648139, 0.54647933, 0.54647726,
#         0.54647518, 0.5464731 , 0.54647102, 0.54646893, 0.54646683,
#         0.54646473, 0.54646262, 0.54646051, 0.54645839, 0.54645627,
#         0.54645414, 0.546452  , 0.54644986, 0.54644772, 0.54644557,
#         0.54644341, 0.54644125, 0.54643908, 0.54643691, 0.54643473,
#         0.54643255, 0.54643036, 0.54642817, 0.54642597, 0.54642376,
#         0.54642155, 0.54641933, 0.54641711, 0.54641488, 0.54641265,
#         0.54641041, 0.54640817, 0.54640592, 0.54640366, 0.5464014 ,
#         0.54639913, 0.54639686, 0.54639459, 0.5463923 , 0.54639001])
#  Coordinates:
#    * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#  Attributes:
#      long_name:       tcell latitude
#      units:           degrees_N
#      cartesian_axis:  Y,
#  'SA': <xarray.DataArray 'SA' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 176MB
#  dask.array<sa_from_sp, shape=(12, 510, 3600), dtype=float64, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#  Coordinates:
#    * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#    * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#      st_ocean  float64 8B 0.5413
#    * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#  Attributes:
#      long_name:      Practical Salinity
#      units:          psu
#      valid_range:    [-10. 100.]
#      cell_methods:   time: mean
#      time_avg_info:  average_T1,average_T2,average_DT
#      standard_name:  sea_water_salinity
#      ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#  'pot_rho_1': <xarray.DataArray 'SA' (time: 12, yt_ocean: 510, xt_ocean: 3600)> Size: 176MB
#  dask.array<sigma1, shape=(12, 510, 3600), dtype=float64, chunksize=(1, 135, 180), chunktype=numpy.ndarray>
#  Coordinates:
#    * xt_ocean  (xt_ocean) float64 29kB -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#    * yt_ocean  (yt_ocean) float64 4kB -81.11 -81.07 -81.02 ... -59.08 -59.03
#      st_ocean  float64 8B 0.5413
#    * time      (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00
#  Attributes:
#      long_name:      Practical Salinity
#      units:          psu
#      valid_range:    [-10. 100.]
#      cell_methods:   time: mean
#      time_avg_info:  average_T1,average_T2,average_DT
#      standard_name:  sea_water_salinity
#      ncfiles:        ['/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf90...,
#  'days_per_month': <xarray.DataArray 'days_per_month' (time: 12)> Size: 96B
#  array([31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31])
#  Coordinates:
#    * time     (time) object 96B 1910-01-16 12:00:00 ... 1910-12-16 12:00:00}

# %%
# Painfully manual don't mind this
start_time_broad = '1910-01-01'
start_time_real = '1910-01-01'
end_time_broad = '1911-04-01'
end_time_real = '1910-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_01.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_01.nc')

# %%
# Painfully manual don't mind this 2

start_time_real = '1911-01-01'
end_time_broad = '1912-04-01'
end_time_real = '1911-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_02.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_02.nc')

# %%
# Painfully manual don't mind this 3

start_time_broad = '1911-06-01'
start_time_real = '1912-01-01'
end_time_broad = '1913-04-01'
end_time_real = '1912-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_03.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_03.nc')

# %%
# Painfully manual don't mind this 4

start_time_broad = '1912-06-01'
start_time_real = '1913-01-01'
end_time_broad = '1914-04-01'
end_time_real = '1913-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
             
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_04.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_04.nc')

# %%
# Painfully manual don't mind this 5
 
start_time_broad = '1913-10-01'
start_time_real = '1914-01-01'
end_time_broad = '1915-04-01'
end_time_real = '1914-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')

salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_05.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_05.nc')

# %%
# Painfully manual don't mind this 6
start_time_broad = '1914-10-01'
start_time_real = '1915-01-01'
end_time_broad = '1916-04-01'
end_time_real = '1915-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')

salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_06.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_06.nc')

# %%
# Painfully manual don't mind this 7
start_time_broad = '1915-10-01'
start_time_real = '1916-01-01'
end_time_broad = '1917-04-01'
end_time_real = '1916-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_07.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_07.nc')

# %%
# Painfully manual don't mind this 8
start_time_broad = '1916-10-01'
start_time_real = '1917-01-01'
end_time_broad = '1918-04-01'
end_time_real = '1917-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
            
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_08.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_08.nc')

# %%
# Painfully manual don't mind this 9
start_time_broad = '1917-10-01'
start_time_real = '1918-01-01'
end_time_broad = '1919-04-01'
end_time_real = '1918-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
           
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_09.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_09.nc')

# %%
# Painfully manual don't mind this 10
start_time_broad = '1918-06-01'
start_time_real = '1919-01-01'
end_time_broad = '1920-04-01'
end_time_real = '1919-12-31'

ds = get_variables_1(expt_melt, freq, start_time_broad, start_time_real, end_time_broad, end_time_real, lon_slice, lat_slice, model = 'mom5')
          
salt_transformation = compute_salt_transformation(ds)
heat_transformation = compute_heat_transformation(ds)

salt_transformation_binned, heat_transformation_binned = isopycnal_bins(ds, salt_transformation, heat_transformation)

salt_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_salt_trans_access_M_10.nc')
heat_transformation_binned.to_netcdf('/g/data/g40/kc5856/access_panan_ssp126_SWMT/old_ACCESS_SWMT_shelf/binned_heat_trans_access_M_10.nc')
